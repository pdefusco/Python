# %%
import pandas as pd
import os
import sklearn as sk
from sklearn.linear_model import MultiTaskLasso, MultiTaskElasticNet, ElasticNet
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error
import sklearn.metrics as skmet
import numpy as np
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords

# %%
os.listdir("inside_airbnb")
# Out:
# ['.DS_Store',
#  'calendar.csv',
#  'listings.csv',
#  'listings_summ.csv',
#  'neighbourhoods.csv',
#  'neighbourhoods.geo.json',
#  'neighbourhoods.geojson',
#  'neighbourhoods.json',
#  'reviews.csv',
#  'reviews_summ.csv',
#  'stations.geojson']

# %%
listings = pd.read_csv('inside_airbnb/listings.csv')
list_summ = pd.read_csv('inside_airbnb/listings_summ.csv')
neighborhoods = pd.read_csv('inside_airbnb/neighbourhoods.csv')
reviews = pd.read_csv('inside_airbnb/reviews.csv')
reviews_summ = pd.read_csv('inside_airbnb/reviews_summ.csv')
calendar = pd.read_csv('inside_airbnb/calendar.csv')

# %%
calendar['date'] = pd.to_datetime(calendar['date'])

# %%
calendar['month'] = calendar['date'].apply(lambda x: x.month)
calendar['day'] = calendar['date'].apply(lambda x: x.day)
calendar['holiday'] = False

# %%
calendar
# Out:
#          listing_id       date available   price  month  day  holiday
# 0          11204286 2017-07-05         t  $49.00      7    5    False
# 1          11204286 2017-07-04         t  $49.00      7    4    False
# 2          11204286 2017-07-03         t  $49.00      7    3    False
# 3          11204286 2017-07-02         t  $49.00      7    2    False
# 4          11204286 2017-07-01         t  $49.00      7    1    False
# 5          11204286 2017-06-30         t  $49.00      6   30    False
# 6          11204286 2017-06-29         t  $49.00      6   29    False
# 7          11204286 2017-06-28         t  $49.00      6   28    False
# 8          11204286 2017-06-27         t  $49.00      6   27    False
# 9          11204286 2017-06-26         t  $49.00      6   26    False
# 10         11204286 2017-06-25         t  $49.00      6   25    False
# 11         11204286 2017-06-24         t  $49.00      6   24    False
# 12         11204286 2017-06-23         t  $49.00      6   23    False
# 13         11204286 2017-06-06         t  $49.00      6    6    False
# 14         11204286 2017-06-05         t  $49.00      6    5    False
# 15         11204286 2017-06-04         t  $49.00      6    4    False
# 16         11204286 2017-06-03         t  $49.00      6    3    False
# 17         11204286 2017-06-02         t  $49.00      6    2    False
# 18         11204286 2017-06-01         t  $49.00      6    1    False
# 19         11204286 2017-05-31         t  $49.00      5   31    False
# 20         11204286 2017-05-30         t  $49.00      5   30    False
# 21         11204286 2017-05-29         t  $49.00      5   29    False
# 22         11204286 2017-05-28         t  $49.00      5   28    False
# 23         11204286 2017-05-27         t  $49.00      5   27    False
# 24         11204286 2017-05-26         t  $49.00      5   26    False
# 25         11204286 2017-05-25         t  $49.00      5   25    False
# 26         11204286 2017-05-24         t  $49.00      5   24    False
# 27         11204286 2017-05-23         t  $49.00      5   23    False
# 28         11204286 2017-05-22         t  $49.00      5   22    False
# 29         11204286 2017-05-21         t  $49.00      5   21    False
# ...             ...        ...       ...     ...    ...  ...      ...
# 2411890    13452448 2016-08-04         f     NaN      8    4    False
# 2411891    13452448 2016-08-03         f     NaN      8    3    False
# 2411892    13452448 2016-08-02         f     NaN      8    2    False
# 2411893    13452448 2016-08-01         f     NaN      8    1    False
# 2411894    13452448 2016-07-31         f     NaN      7   31    False
# 2411895    13452448 2016-07-30         f     NaN      7   30    False
# 2411896    13452448 2016-07-29         f     NaN      7   29    False
# 2411897    13452448 2016-07-28         f     NaN      7   28    False
# 2411898    13452448 2016-07-27         f     NaN      7   27    False
# 2411899    13452448 2016-07-26         f     NaN      7   26    False
# 2411900    13452448 2016-07-25         f     NaN      7   25    False
# 2411901    13452448 2016-07-24         f     NaN      7   24    False
# 2411902    13452448 2016-07-23         f     NaN      7   23    False
# 2411903    13452448 2016-07-22         f     NaN      7   22    False
# 2411904    13452448 2016-07-21         f     NaN      7   21    False
# 2411905    13452448 2016-07-20         f     NaN      7   20    False
# 2411906    13452448 2016-07-19         f     NaN      7   19    False
# 2411907    13452448 2016-07-18         f     NaN      7   18    False
# 2411908    13452448 2016-07-17         f     NaN      7   17    False
# 2411909    13452448 2016-07-16         f     NaN      7   16    False
# 2411910    13452448 2016-07-15         f     NaN      7   15    False
# 2411911    13452448 2016-07-14         f     NaN      7   14    False
# 2411912    13452448 2016-07-13         f     NaN      7   13    False
# 2411913    13452448 2016-07-12         f     NaN      7   12    False
# 2411914    13452448 2016-07-11         f     NaN      7   11    False
# 2411915    13452448 2016-07-10         f     NaN      7   10    False
# 2411916    13452448 2016-07-09         f     NaN      7    9    False
# 2411917    13452448 2016-07-08         f     NaN      7    8    False
# 2411918    13452448 2016-07-07         f     NaN      7    7    False
# 2411919    13452448 2016-07-06         f     NaN      7    6    False
#
# [2411920 rows x 7 columns]

# %%
calendar[calendar['month'] == 7 & calendar['day'].isin(range(21, 25))][['listing_id','price']]
# Out:
#          listing_id    price
# 146        11204286   $49.00
# 147        11204286   $49.00
# 148        11204286   $49.00
# 149        11204286   $49.00
# 493         7972006      NaN
# 494         7972006      NaN
# 495         7972006      NaN
# 496         7972006      NaN
# 859         7727710      NaN
# 1059        7727710      NaN
# 1060        7727710      NaN
# 1061        7727710      NaN
# 1257       13124681  $120.00
# 1258       13124681  $120.00
# 1259       13124681  $120.00
# 1260       13124681  $120.00
# 1547        3469225   $70.00
# 1548        3469225   $70.00
# 1549        3469225   $70.00
# 1550        3469225   $80.00
# 2142         877473   $70.00
# 2143         877473   $70.00
# 2144         877473   $70.00
# 2145         877473   $80.00
# 2314        3124507   $90.00
# 2315        3124507   $90.00
# 2316        3124507   $90.00
# 2317        3124507   $90.00
# 2621        3432507  $150.00
# 2622        3432507  $150.00
# ...             ...      ...
# 2409076    13466129      NaN
# 2409077    13466129      NaN
# 2409483     4698549      NaN
# 2409484     4698549      NaN
# 2409485     4698549      NaN
# 2409486     4698549      NaN
# 2409835    10908984   $23.00
# 2409836    10908984   $23.00
# 2409837    10908984   $23.00
# 2409838    10908984   $23.00
# 2410193    13733446      NaN
# 2410194    13733446      NaN
# 2410195    13733446      NaN
# 2410196    13733446      NaN
# 2410542    11990520   $75.00
# 2410543    11990520   $75.00
# 2410544    11990520   $75.00
# 2410545    11990520   $95.00
# 2410987    13358607      NaN
# 2410988    13358607      NaN
# 2410989    13358607      NaN
# 2410990    13358607      NaN
# 2411270     9147128  $119.00
# 2411271     9147128  $119.00
# 2411272     9147128  $119.00
# 2411273     9147128  $129.00
# 2411665    13452448      NaN
# 2411666    13452448      NaN
# 2411667    13452448      NaN
# 2411668    13452448      NaN
#
# [26432 rows x 2 columns]

# %%
calendar[calendar['listing_id'] == 11204286]['price']
# Out:
# 0      $49.00
# 1      $49.00
# 2      $49.00
# 3      $49.00
# 4      $49.00
# 5      $49.00
# 6      $49.00
# 7      $49.00
# 8      $49.00
# 9      $49.00
# 10     $49.00
# 11     $49.00
# 12     $49.00
# 13     $49.00
# 14     $49.00
# 15     $49.00
# 16     $49.00
# 17     $49.00
# 18     $49.00
# 19     $49.00
# 20     $49.00
# 21     $49.00
# 22     $49.00
# 23     $49.00
# 24     $49.00
# 25     $49.00
# 26     $49.00
# 27     $49.00
# 28     $49.00
# 29     $49.00
#         ...
# 335    $49.00
# 336    $49.00
# 337    $49.00
# 338    $49.00
# 339    $49.00
# 340    $49.00
# 341    $49.00
# 342    $49.00
# 343    $49.00
# 344    $49.00
# 345    $49.00
# 346    $49.00
# 347       NaN
# 348       NaN
# 349       NaN
# 350    $49.00
# 351    $49.00
# 352    $49.00
# 353    $49.00
# 354    $49.00
# 355    $49.00
# 356    $49.00
# 357    $49.00
# 358    $49.00
# 359    $49.00
# 360    $49.00
# 361       NaN
# 362    $49.00
# 363       NaN
# 364    $49.00
# Name: price, Length: 365, dtype: object

# %%
calendar[calendar['listing_id'] == 13124681]['price']
# Out:
# 1095    $120.00
# 1096    $120.00
# 1097    $120.00
# 1098    $120.00
# 1099    $120.00
# 1100    $120.00
# 1101    $120.00
# 1102    $120.00
# 1103    $120.00
# 1104    $120.00
# 1105    $120.00
# 1106    $120.00
# 1107    $120.00
# 1108    $120.00
# 1109    $120.00
# 1110    $120.00
# 1111    $120.00
# 1112    $120.00
# 1113    $120.00
# 1114    $120.00
# 1115    $120.00
# 1116    $120.00
# 1117    $120.00
# 1118    $120.00
# 1119    $120.00
# 1120    $120.00
# 1121    $120.00
# 1122    $120.00
# 1123    $120.00
# 1124    $120.00
#          ...
# 1430        NaN
# 1431        NaN
# 1432        NaN
# 1433        NaN
# 1434        NaN
# 1435        NaN
# 1436        NaN
# 1437        NaN
# 1438        NaN
# 1439        NaN
# 1440        NaN
# 1441        NaN
# 1442        NaN
# 1443        NaN
# 1444        NaN
# 1445        NaN
# 1446        NaN
# 1447        NaN
# 1448        NaN
# 1449        NaN
# 1450        NaN
# 1451        NaN
# 1452        NaN
# 1453        NaN
# 1454        NaN
# 1455        NaN
# 1456        NaN
# 1457        NaN
# 1458        NaN
# 1459        NaN
# Name: price, Length: 365, dtype: object

# %%
calendar[calendar['listing_id'] == 11204286]['price'].min(), calendar[calendar['listing_id'] == 11204286]['price'].max()
# Out:
# (inf, '$49.00')

# %%
calendar['price'].isnull()[493]
# Out:
# True

# %%
count = 0
p = 0

for date in calendar['date'].unique():
    a = len(calendar[calendar['date'] == date].dropna())
    p = p + a
    
    if a == 0:
        count = count + 1
    
    print((a, date))
    
print((count, float(p)/365))
# Out:
# (3839, numpy.datetime64('2017-07-05T00:00:00.000000000'))
# (3842, numpy.datetime64('2017-07-04T00:00:00.000000000'))
# (3840, numpy.datetime64('2017-07-03T00:00:00.000000000'))
# (3843, numpy.datetime64('2017-07-02T00:00:00.000000000'))
# (3844, numpy.datetime64('2017-07-01T00:00:00.000000000'))
# (3840, numpy.datetime64('2017-06-30T00:00:00.000000000'))
# (3841, numpy.datetime64('2017-06-29T00:00:00.000000000'))
# (3841, numpy.datetime64('2017-06-28T00:00:00.000000000'))
# (3838, numpy.datetime64('2017-06-27T00:00:00.000000000'))
# (3838, numpy.datetime64('2017-06-26T00:00:00.000000000'))
# (3895, numpy.datetime64('2017-06-25T00:00:00.000000000'))
# (3898, numpy.datetime64('2017-06-24T00:00:00.000000000'))
# (3902, numpy.datetime64('2017-06-23T00:00:00.000000000'))
# (3896, numpy.datetime64('2017-06-06T00:00:00.000000000'))
# (3891, numpy.datetime64('2017-06-05T00:00:00.000000000'))
# (3891, numpy.datetime64('2017-06-04T00:00:00.000000000'))
# (3880, numpy.datetime64('2017-06-03T00:00:00.000000000'))
# (3875, numpy.datetime64('2017-06-02T00:00:00.000000000'))
# (3880, numpy.datetime64('2017-06-01T00:00:00.000000000'))
# (3840, numpy.datetime64('2017-05-31T00:00:00.000000000'))
# (3835, numpy.datetime64('2017-05-30T00:00:00.000000000'))
# (3834, numpy.datetime64('2017-05-29T00:00:00.000000000'))
# (3832, numpy.datetime64('2017-05-28T00:00:00.000000000'))
# (3832, numpy.datetime64('2017-05-27T00:00:00.000000000'))
# (3835, numpy.datetime64('2017-05-26T00:00:00.000000000'))
# (3841, numpy.datetime64('2017-05-25T00:00:00.000000000'))
# (3837, numpy.datetime64('2017-05-24T00:00:00.000000000'))
# (3912, numpy.datetime64('2017-05-23T00:00:00.000000000'))
# (3909, numpy.datetime64('2017-05-22T00:00:00.000000000'))
# (3911, numpy.datetime64('2017-05-21T00:00:00.000000000'))
# (3911, numpy.datetime64('2017-05-20T00:00:00.000000000'))
# (3912, numpy.datetime64('2017-05-19T00:00:00.000000000'))
# (3908, numpy.datetime64('2017-05-18T00:00:00.000000000'))
# (3908, numpy.datetime64('2017-05-17T00:00:00.000000000'))
# (3910, numpy.datetime64('2017-05-16T00:00:00.000000000'))
# (3910, numpy.datetime64('2017-05-15T00:00:00.000000000'))
# (3904, numpy.datetime64('2017-05-14T00:00:00.000000000'))
# (3905, numpy.datetime64('2017-05-13T00:00:00.000000000'))
# (3904, numpy.datetime64('2017-05-12T00:00:00.000000000'))
# (3907, numpy.datetime64('2017-05-11T00:00:00.000000000'))
# (3909, numpy.datetime64('2017-05-10T00:00:00.000000000'))
# (3908, numpy.datetime64('2017-05-09T00:00:00.000000000'))
# (3910, numpy.datetime64('2017-05-08T00:00:00.000000000'))
# (3914, numpy.datetime64('2017-05-07T00:00:00.000000000'))
# (3905, numpy.datetime64('2017-05-06T00:00:00.000000000'))
# (3903, numpy.datetime64('2017-05-05T00:00:00.000000000'))
# (3902, numpy.datetime64('2017-05-04T00:00:00.000000000'))
# (3903, numpy.datetime64('2017-05-03T00:00:00.000000000'))
# (3906, numpy.datetime64('2017-05-02T00:00:00.000000000'))
# (3901, numpy.datetime64('2017-05-01T00:00:00.000000000'))
# (3889, numpy.datetime64('2017-04-30T00:00:00.000000000'))
# (3886, numpy.datetime64('2017-04-29T00:00:00.000000000'))
# (3885, numpy.datetime64('2017-04-28T00:00:00.000000000'))
# (3881, numpy.datetime64('2017-04-27T00:00:00.000000000'))
# (3881, numpy.datetime64('2017-04-26T00:00:00.000000000'))
# (3884, numpy.datetime64('2017-04-25T00:00:00.000000000'))
# (3882, numpy.datetime64('2017-04-24T00:00:00.000000000'))
# (3883, numpy.datetime64('2017-04-23T00:00:00.000000000'))
# (3885, numpy.datetime64('2017-04-22T00:00:00.000000000'))
# (3885, numpy.datetime64('2017-04-21T00:00:00.000000000'))
# (3884, numpy.datetime64('2017-04-20T00:00:00.000000000'))
# (3879, numpy.datetime64('2017-04-19T00:00:00.000000000'))
# (3881, numpy.datetime64('2017-04-18T00:00:00.000000000'))
# (3882, numpy.datetime64('2017-04-17T00:00:00.000000000'))
# (3882, numpy.datetime64('2017-04-16T00:00:00.000000000'))
# (3878, numpy.datetime64('2017-04-15T00:00:00.000000000'))
# (3871, numpy.datetime64('2017-04-14T00:00:00.000000000'))
# (3867, numpy.datetime64('2017-04-13T00:00:00.000000000'))
# (3863, numpy.datetime64('2017-04-12T00:00:00.000000000'))
# (3865, numpy.datetime64('2017-04-11T00:00:00.000000000'))
# (3864, numpy.datetime64('2017-04-10T00:00:00.000000000'))
# (3866, numpy.datetime64('2017-04-09T00:00:00.000000000'))
# (3865, numpy.datetime64('2017-04-08T00:00:00.000000000'))
# (3871, numpy.datetime64('2017-04-07T00:00:00.000000000'))
# (3871, numpy.datetime64('2017-04-06T00:00:00.000000000'))
# (3869, numpy.datetime64('2017-04-05T00:00:00.000000000'))
# (3869, numpy.datetime64('2017-04-04T00:00:00.000000000'))
# (3864, numpy.datetime64('2017-04-03T00:00:00.000000000'))
# (3865, numpy.datetime64('2017-04-02T00:00:00.000000000'))
# (3858, numpy.datetime64('2017-04-01T00:00:00.000000000'))
# (3836, numpy.datetime64('2017-03-31T00:00:00.000000000'))
# (3822, numpy.datetime64('2017-03-30T00:00:00.000000000'))
# (3822, numpy.datetime64('2017-03-29T00:00:00.000000000'))
# (3823, numpy.datetime64('2017-03-28T00:00:00.000000000'))
# (3820, numpy.datetime64('2017-03-27T00:00:00.000000000'))
# (3819, numpy.datetime64('2017-03-26T00:00:00.000000000'))
# (3818, numpy.datetime64('2017-03-25T00:00:00.000000000'))
# (3817, numpy.datetime64('2017-03-24T00:00:00.000000000'))
# (3810, numpy.datetime64('2017-03-23T00:00:00.000000000'))
# (3807, numpy.datetime64('2017-03-22T00:00:00.000000000'))
# (3809, numpy.datetime64('2017-03-21T00:00:00.000000000'))
# (3807, numpy.datetime64('2017-03-20T00:00:00.000000000'))
# (3808, numpy.datetime64('2017-03-19T00:00:00.000000000'))
# (3804, numpy.datetime64('2017-03-18T00:00:00.000000000'))
# (3784, numpy.datetime64('2017-03-17T00:00:00.000000000'))
# (3780, numpy.datetime64('2017-03-16T00:00:00.000000000'))
# (3783, numpy.datetime64('2017-03-15T00:00:00.000000000'))
# (3774, numpy.datetime64('2017-03-14T00:00:00.000000000'))
# (3781, numpy.datetime64('2017-03-13T00:00:00.000000000'))
# (3783, numpy.datetime64('2017-03-12T00:00:00.000000000'))
# (3781, numpy.datetime64('2017-03-11T00:00:00.000000000'))
# (3790, numpy.datetime64('2017-03-10T00:00:00.000000000'))
# (3793, numpy.datetime64('2017-03-09T00:00:00.000000000'))
# (3789, numpy.datetime64('2017-03-08T00:00:00.000000000'))
# (3791, numpy.datetime64('2017-03-07T00:00:00.000000000'))
# (3782, numpy.datetime64('2017-03-06T00:00:00.000000000'))
# (3785, numpy.datetime64('2017-03-05T00:00:00.000000000'))
# (3776, numpy.datetime64('2017-03-04T00:00:00.000000000'))
# (3754, numpy.datetime64('2017-03-03T00:00:00.000000000'))
# (3757, numpy.datetime64('2017-03-02T00:00:00.000000000'))
# (3753, numpy.datetime64('2017-03-01T00:00:00.000000000'))
# (3733, numpy.datetime64('2017-02-28T00:00:00.000000000'))
# (3713, numpy.datetime64('2017-02-27T00:00:00.000000000'))
# (3712, numpy.datetime64('2017-02-26T00:00:00.000000000'))
# (3707, numpy.datetime64('2017-02-25T00:00:00.000000000'))
# (3700, numpy.datetime64('2017-02-24T00:00:00.000000000'))
# (3702, numpy.datetime64('2017-02-23T00:00:00.000000000'))
# (3698, numpy.datetime64('2017-02-22T00:00:00.000000000'))
# (3692, numpy.datetime64('2017-02-21T00:00:00.000000000'))
# (3691, numpy.datetime64('2017-02-20T00:00:00.000000000'))
# (3686, numpy.datetime64('2017-02-19T00:00:00.000000000'))
# (3689, numpy.datetime64('2017-02-18T00:00:00.000000000'))
# (3687, numpy.datetime64('2017-02-17T00:00:00.000000000'))
# (3680, numpy.datetime64('2017-02-16T00:00:00.000000000'))
# (3685, numpy.datetime64('2017-02-15T00:00:00.000000000'))
# (3682, numpy.datetime64('2017-02-14T00:00:00.000000000'))
# (3679, numpy.datetime64('2017-02-13T00:00:00.000000000'))
# (3679, numpy.datetime64('2017-02-12T00:00:00.000000000'))
# (3684, numpy.datetime64('2017-02-11T00:00:00.000000000'))
# (3685, numpy.datetime64('2017-02-10T00:00:00.000000000'))
# (3690, numpy.datetime64('2017-02-09T00:00:00.000000000'))
# (3690, numpy.datetime64('2017-02-08T00:00:00.000000000'))
# (3695, numpy.datetime64('2017-02-07T00:00:00.000000000'))
# (3694, numpy.datetime64('2017-02-06T00:00:00.000000000'))
# (3691, numpy.datetime64('2017-02-05T00:00:00.000000000'))
# (3689, numpy.datetime64('2017-02-04T00:00:00.000000000'))
# (3684, numpy.datetime64('2017-02-03T00:00:00.000000000'))
# (3684, numpy.datetime64('2017-02-02T00:00:00.000000000'))
# (3680, numpy.datetime64('2017-02-01T00:00:00.000000000'))
# (3696, numpy.datetime64('2017-01-31T00:00:00.000000000'))
# (3693, numpy.datetime64('2017-01-30T00:00:00.000000000'))
# (3699, numpy.datetime64('2017-01-29T00:00:00.000000000'))
# (3683, numpy.datetime64('2017-01-28T00:00:00.000000000'))
# (3689, numpy.datetime64('2017-01-27T00:00:00.000000000'))
# (3700, numpy.datetime64('2017-01-26T00:00:00.000000000'))
# (3706, numpy.datetime64('2017-01-25T00:00:00.000000000'))
# (3710, numpy.datetime64('2017-01-24T00:00:00.000000000'))
# (3705, numpy.datetime64('2017-01-23T00:00:00.000000000'))
# (3712, numpy.datetime64('2017-01-22T00:00:00.000000000'))
# (3706, numpy.datetime64('2017-01-21T00:00:00.000000000'))
# (3709, numpy.datetime64('2017-01-20T00:00:00.000000000'))
# (3705, numpy.datetime64('2017-01-19T00:00:00.000000000'))
# (3707, numpy.datetime64('2017-01-18T00:00:00.000000000'))
# (3710, numpy.datetime64('2017-01-17T00:00:00.000000000'))
# (3713, numpy.datetime64('2017-01-16T00:00:00.000000000'))
# (3714, numpy.datetime64('2017-01-15T00:00:00.000000000'))
# (3726, numpy.datetime64('2017-01-14T00:00:00.000000000'))
# (3729, numpy.datetime64('2017-01-13T00:00:00.000000000'))
# (3724, numpy.datetime64('2017-01-12T00:00:00.000000000'))
# (3728, numpy.datetime64('2017-01-11T00:00:00.000000000'))
# (3731, numpy.datetime64('2017-01-10T00:00:00.000000000'))
# (3730, numpy.datetime64('2017-01-09T00:00:00.000000000'))
# (3733, numpy.datetime64('2017-01-08T00:00:00.000000000'))
# (3728, numpy.datetime64('2017-01-07T00:00:00.000000000'))
# (3733, numpy.datetime64('2017-01-06T00:00:00.000000000'))
# (3730, numpy.datetime64('2017-01-05T00:00:00.000000000'))
# (3732, numpy.datetime64('2017-01-04T00:00:00.000000000'))
# (3739, numpy.datetime64('2017-01-03T00:00:00.000000000'))
# (3737, numpy.datetime64('2017-01-02T00:00:00.000000000'))
# (4052, numpy.datetime64('2017-01-01T00:00:00.000000000'))
# (3918, numpy.datetime64('2016-12-31T00:00:00.000000000'))
# (3899, numpy.datetime64('2016-12-30T00:00:00.000000000'))
# (3863, numpy.datetime64('2016-12-29T00:00:00.000000000'))
# (3852, numpy.datetime64('2016-12-28T00:00:00.000000000'))
# (3841, numpy.datetime64('2016-12-27T00:00:00.000000000'))
# (3838, numpy.datetime64('2016-12-26T00:00:00.000000000'))
# (3861, numpy.datetime64('2016-12-25T00:00:00.000000000'))
# (3880, numpy.datetime64('2016-12-24T00:00:00.000000000'))
# (3903, numpy.datetime64('2016-12-23T00:00:00.000000000'))
# (3949, numpy.datetime64('2016-12-22T00:00:00.000000000'))
# (3967, numpy.datetime64('2016-12-21T00:00:00.000000000'))
# (3984, numpy.datetime64('2016-12-20T00:00:00.000000000'))
# (3997, numpy.datetime64('2016-12-19T00:00:00.000000000'))
# (4012, numpy.datetime64('2016-12-18T00:00:00.000000000'))
# (4018, numpy.datetime64('2016-12-17T00:00:00.000000000'))
# (4028, numpy.datetime64('2016-12-16T00:00:00.000000000'))
# (4036, numpy.datetime64('2016-12-15T00:00:00.000000000'))
# (4034, numpy.datetime64('2016-12-14T00:00:00.000000000'))
# (4032, numpy.datetime64('2016-12-13T00:00:00.000000000'))
# (4023, numpy.datetime64('2016-12-12T00:00:00.000000000'))
# (4024, numpy.datetime64('2016-12-11T00:00:00.000000000'))
# (4031, numpy.datetime64('2016-12-10T00:00:00.000000000'))
# (4029, numpy.datetime64('2016-12-09T00:00:00.000000000'))
# (4019, numpy.datetime64('2016-12-08T00:00:00.000000000'))
# (4020, numpy.datetime64('2016-12-07T00:00:00.000000000'))
# (4010, numpy.datetime64('2016-12-06T00:00:00.000000000'))
# (4003, numpy.datetime64('2016-12-05T00:00:00.000000000'))
# (3997, numpy.datetime64('2016-12-04T00:00:00.000000000'))
# (3989, numpy.datetime64('2016-12-03T00:00:00.000000000'))
# (3985, numpy.datetime64('2016-12-02T00:00:00.000000000'))
# (3993, numpy.datetime64('2016-12-01T00:00:00.000000000'))
# (3990, numpy.datetime64('2016-11-30T00:00:00.000000000'))
# (3978, numpy.datetime64('2016-11-29T00:00:00.000000000'))
# (3958, numpy.datetime64('2016-11-28T00:00:00.000000000'))
# (3939, numpy.datetime64('2016-11-27T00:00:00.000000000'))
# (3865, numpy.datetime64('2016-11-26T00:00:00.000000000'))
# (3804, numpy.datetime64('2016-11-25T00:00:00.000000000'))
# (3786, numpy.datetime64('2016-11-24T00:00:00.000000000'))
# (3793, numpy.datetime64('2016-11-23T00:00:00.000000000'))
# (3838, numpy.datetime64('2016-11-22T00:00:00.000000000'))
# (3878, numpy.datetime64('2016-11-21T00:00:00.000000000'))
# (3890, numpy.datetime64('2016-11-20T00:00:00.000000000'))
# (3899, numpy.datetime64('2016-11-19T00:00:00.000000000'))
# (3918, numpy.datetime64('2016-11-18T00:00:00.000000000'))
# (3891, numpy.datetime64('2016-11-17T00:00:00.000000000'))
# (3783, numpy.datetime64('2016-11-16T00:00:00.000000000'))
# (3629, numpy.datetime64('2016-11-15T00:00:00.000000000'))
# (3607, numpy.datetime64('2016-11-14T00:00:00.000000000'))
# (3584, numpy.datetime64('2016-11-13T00:00:00.000000000'))
# (3557, numpy.datetime64('2016-11-12T00:00:00.000000000'))
# (3603, numpy.datetime64('2016-11-11T00:00:00.000000000'))
# (3776, numpy.datetime64('2016-11-10T00:00:00.000000000'))
# (3891, numpy.datetime64('2016-11-09T00:00:00.000000000'))
# (3912, numpy.datetime64('2016-11-08T00:00:00.000000000'))
# (3875, numpy.datetime64('2016-11-07T00:00:00.000000000'))
# (3872, numpy.datetime64('2016-11-06T00:00:00.000000000'))
# (3840, numpy.datetime64('2016-11-05T00:00:00.000000000'))
# (3829, numpy.datetime64('2016-11-04T00:00:00.000000000'))
# (3841, numpy.datetime64('2016-11-03T00:00:00.000000000'))
# (3855, numpy.datetime64('2016-11-02T00:00:00.000000000'))
# (3861, numpy.datetime64('2016-11-01T00:00:00.000000000'))
# (3880, numpy.datetime64('2016-10-31T00:00:00.000000000'))
# (3863, numpy.datetime64('2016-10-30T00:00:00.000000000'))
# (3825, numpy.datetime64('2016-10-29T00:00:00.000000000'))
# (3817, numpy.datetime64('2016-10-28T00:00:00.000000000'))
# (3830, numpy.datetime64('2016-10-27T00:00:00.000000000'))
# (3838, numpy.datetime64('2016-10-26T00:00:00.000000000'))
# (3829, numpy.datetime64('2016-10-25T00:00:00.000000000'))
# (3800, numpy.datetime64('2016-10-24T00:00:00.000000000'))
# (3769, numpy.datetime64('2016-10-23T00:00:00.000000000'))
# (3722, numpy.datetime64('2016-10-22T00:00:00.000000000'))
# (3705, numpy.datetime64('2016-10-21T00:00:00.000000000'))
# (3733, numpy.datetime64('2016-10-20T00:00:00.000000000'))
# (3768, numpy.datetime64('2016-10-19T00:00:00.000000000'))
# (3778, numpy.datetime64('2016-10-18T00:00:00.000000000'))
# (3776, numpy.datetime64('2016-10-17T00:00:00.000000000'))
# (3729, numpy.datetime64('2016-10-16T00:00:00.000000000'))
# (3642, numpy.datetime64('2016-10-15T00:00:00.000000000'))
# (3621, numpy.datetime64('2016-10-14T00:00:00.000000000'))
# (3632, numpy.datetime64('2016-10-13T00:00:00.000000000'))
# (3679, numpy.datetime64('2016-10-12T00:00:00.000000000'))
# (3719, numpy.datetime64('2016-10-11T00:00:00.000000000'))
# (3702, numpy.datetime64('2016-10-10T00:00:00.000000000'))
# (3710, numpy.datetime64('2016-10-09T00:00:00.000000000'))
# (3663, numpy.datetime64('2016-10-08T00:00:00.000000000'))
# (3664, numpy.datetime64('2016-10-07T00:00:00.000000000'))
# (3692, numpy.datetime64('2016-10-06T00:00:00.000000000'))
# (3709, numpy.datetime64('2016-10-05T00:00:00.000000000'))
# (3724, numpy.datetime64('2016-10-04T00:00:00.000000000'))
# (4317, numpy.datetime64('2016-10-03T00:00:00.000000000'))
# (4110, numpy.datetime64('2016-10-02T00:00:00.000000000'))
# (3994, numpy.datetime64('2016-10-01T00:00:00.000000000'))
# (4013, numpy.datetime64('2016-09-30T00:00:00.000000000'))
# (4042, numpy.datetime64('2016-09-29T00:00:00.000000000'))
# (4192, numpy.datetime64('2016-09-28T00:00:00.000000000'))
# (4230, numpy.datetime64('2016-09-27T00:00:00.000000000'))
# (4215, numpy.datetime64('2016-09-26T00:00:00.000000000'))
# (4168, numpy.datetime64('2016-09-25T00:00:00.000000000'))
# (4060, numpy.datetime64('2016-09-24T00:00:00.000000000'))
# (4043, numpy.datetime64('2016-09-23T00:00:00.000000000'))
# (4068, numpy.datetime64('2016-09-22T00:00:00.000000000'))
# (4130, numpy.datetime64('2016-09-21T00:00:00.000000000'))
# (4150, numpy.datetime64('2016-09-20T00:00:00.000000000'))
# (4111, numpy.datetime64('2016-09-19T00:00:00.000000000'))
# (4041, numpy.datetime64('2016-09-18T00:00:00.000000000'))
# (3909, numpy.datetime64('2016-09-17T00:00:00.000000000'))
# (3921, numpy.datetime64('2016-09-16T00:00:00.000000000'))
# (3991, numpy.datetime64('2016-09-15T00:00:00.000000000'))
# (4060, numpy.datetime64('2016-09-14T00:00:00.000000000'))
# (4058, numpy.datetime64('2016-09-13T00:00:00.000000000'))
# (4067, numpy.datetime64('2016-09-12T00:00:00.000000000'))
# (4010, numpy.datetime64('2016-09-11T00:00:00.000000000'))
# (3888, numpy.datetime64('2016-09-10T00:00:00.000000000'))
# (3920, numpy.datetime64('2016-09-09T00:00:00.000000000'))
# (4000, numpy.datetime64('2016-09-08T00:00:00.000000000'))
# (4057, numpy.datetime64('2016-09-07T00:00:00.000000000'))
# (4070, numpy.datetime64('2016-09-06T00:00:00.000000000'))
# (4000, numpy.datetime64('2016-09-05T00:00:00.000000000'))
# (3753, numpy.datetime64('2016-09-04T00:00:00.000000000'))
# (3901, numpy.datetime64('2017-06-22T00:00:00.000000000'))
# (3899, numpy.datetime64('2017-06-21T00:00:00.000000000'))
# (3898, numpy.datetime64('2017-06-20T00:00:00.000000000'))
# (3895, numpy.datetime64('2017-06-19T00:00:00.000000000'))
# (3891, numpy.datetime64('2017-06-18T00:00:00.000000000'))
# (3894, numpy.datetime64('2017-06-17T00:00:00.000000000'))
# (3891, numpy.datetime64('2017-06-16T00:00:00.000000000'))
# (3900, numpy.datetime64('2017-06-15T00:00:00.000000000'))
# (3898, numpy.datetime64('2017-06-14T00:00:00.000000000'))
# (3898, numpy.datetime64('2017-06-13T00:00:00.000000000'))
# (3897, numpy.datetime64('2017-06-12T00:00:00.000000000'))
# (3903, numpy.datetime64('2017-06-11T00:00:00.000000000'))
# (3898, numpy.datetime64('2017-06-10T00:00:00.000000000'))
# (3895, numpy.datetime64('2017-06-09T00:00:00.000000000'))
# (3893, numpy.datetime64('2017-06-08T00:00:00.000000000'))
# (3896, numpy.datetime64('2017-06-07T00:00:00.000000000'))
# (3617, numpy.datetime64('2016-09-03T00:00:00.000000000'))
# (3644, numpy.datetime64('2016-09-02T00:00:00.000000000'))
# (3832, numpy.datetime64('2016-09-01T00:00:00.000000000'))
# (3945, numpy.datetime64('2016-08-31T00:00:00.000000000'))
# (3929, numpy.datetime64('2016-08-30T00:00:00.000000000'))
# (3874, numpy.datetime64('2016-08-29T00:00:00.000000000'))
# (3766, numpy.datetime64('2016-08-28T00:00:00.000000000'))
# (3573, numpy.datetime64('2016-08-27T00:00:00.000000000'))
# (3495, numpy.datetime64('2016-08-26T00:00:00.000000000'))
# (3500, numpy.datetime64('2016-08-25T00:00:00.000000000'))
# (3574, numpy.datetime64('2016-08-24T00:00:00.000000000'))
# (3569, numpy.datetime64('2016-08-23T00:00:00.000000000'))
# (3548, numpy.datetime64('2016-08-22T00:00:00.000000000'))
# (3493, numpy.datetime64('2016-08-21T00:00:00.000000000'))
# (3293, numpy.datetime64('2016-08-20T00:00:00.000000000'))
# (3269, numpy.datetime64('2016-08-19T00:00:00.000000000'))
# (3371, numpy.datetime64('2016-08-18T00:00:00.000000000'))
# (3437, numpy.datetime64('2016-08-17T00:00:00.000000000'))
# (3432, numpy.datetime64('2016-08-16T00:00:00.000000000'))
# (3367, numpy.datetime64('2016-08-15T00:00:00.000000000'))
# (3253, numpy.datetime64('2016-08-14T00:00:00.000000000'))
# (2965, numpy.datetime64('2016-08-13T00:00:00.000000000'))
# (2819, numpy.datetime64('2016-08-12T00:00:00.000000000'))
# (2905, numpy.datetime64('2016-08-11T00:00:00.000000000'))
# (3039, numpy.datetime64('2016-08-10T00:00:00.000000000'))
# (3036, numpy.datetime64('2016-08-09T00:00:00.000000000'))
# (3037, numpy.datetime64('2016-08-08T00:00:00.000000000'))
# (2951, numpy.datetime64('2016-08-07T00:00:00.000000000'))
# (2613, numpy.datetime64('2016-08-06T00:00:00.000000000'))
# (2540, numpy.datetime64('2016-08-05T00:00:00.000000000'))
# (2656, numpy.datetime64('2016-08-04T00:00:00.000000000'))
# (2750, numpy.datetime64('2016-08-03T00:00:00.000000000'))
# (2751, numpy.datetime64('2016-08-02T00:00:00.000000000'))
# (2718, numpy.datetime64('2016-08-01T00:00:00.000000000'))
# (2611, numpy.datetime64('2016-07-31T00:00:00.000000000'))
# (2180, numpy.datetime64('2016-07-30T00:00:00.000000000'))
# (2065, numpy.datetime64('2016-07-29T00:00:00.000000000'))
# (2263, numpy.datetime64('2016-07-28T00:00:00.000000000'))
# (2427, numpy.datetime64('2016-07-27T00:00:00.000000000'))
# (2446, numpy.datetime64('2016-07-26T00:00:00.000000000'))
# (2472, numpy.datetime64('2016-07-25T00:00:00.000000000'))
# (2172, numpy.datetime64('2016-07-24T00:00:00.000000000'))
# (1235, numpy.datetime64('2016-07-23T00:00:00.000000000'))
# (1187, numpy.datetime64('2016-07-22T00:00:00.000000000'))
# (1340, numpy.datetime64('2016-07-21T00:00:00.000000000'))
# (1646, numpy.datetime64('2016-07-20T00:00:00.000000000'))
# (2265, numpy.datetime64('2016-07-19T00:00:00.000000000'))
# (2265, numpy.datetime64('2016-07-18T00:00:00.000000000'))
# (2004, numpy.datetime64('2016-07-17T00:00:00.000000000'))
# (1441, numpy.datetime64('2016-07-16T00:00:00.000000000'))
# (1489, numpy.datetime64('2016-07-15T00:00:00.000000000'))
# (1861, numpy.datetime64('2016-07-14T00:00:00.000000000'))
# (2108, numpy.datetime64('2016-07-13T00:00:00.000000000'))
# (2012, numpy.datetime64('2016-07-12T00:00:00.000000000'))
# (1943, numpy.datetime64('2016-07-11T00:00:00.000000000'))
# (1857, numpy.datetime64('2016-07-10T00:00:00.000000000'))
# (1575, numpy.datetime64('2016-07-09T00:00:00.000000000'))
# (1562, numpy.datetime64('2016-07-08T00:00:00.000000000'))
# (1676, numpy.datetime64('2016-07-07T00:00:00.000000000'))
# (1695, numpy.datetime64('2016-07-06T00:00:00.000000000'))
# (0, 3656.613698630137)
