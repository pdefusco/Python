# %%
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
listings_original = pd.read_csv('Datasources/inside_airbnb/listings.csv')

# %%
listings = pd.read_csv('Datasources/listings_augmented/listings_original_modified_2018-06-04_V1.csv',low_memory=False)

# %%
listings_other = pd.read_csv('Datasources/listings_augmented/listings_augmented_2018-06-03_V1.csv',low_memory=False)

# %%
listings_other = listings_other.drop(listings_other.index[4323:4325])

# %%
len(listings_other['distance_from_ocean'].dropna())
# Out:
# 5751

# %%
sns.distplot(listings_other['distance_from_ocean'].dropna(), kde=False, rug=True)
# Out:
# C:\Users\sanka\Anaconda2\lib\site-packages\matplotlib\axes\_axes.py:6462: UserWarning: The 'normed' kwarg is deprecated, and has been replaced by the 'density' kwarg.
#   warnings.warn("The 'normed' kwarg is deprecated, and has been "

# %%
plt.show()

# %%
sns.regplot(x="distance_from_ocean", y="accommodates", data=listings_other)

# %%
plt.show()

# %%
events_features_list = []

for w in listings_other.columns:
    if 'events' in w:
        events_features_list.append(w)

# %%
events_features_list
# Out:
# ['count_of_events_at_min_distance',
#  'all_events_within_1_km_at_min_distance',
#  'all_events_within_3_km_at_min_distance',
#  'all_events_within_5_km_at_min_distance',
#  'all_events_within_1_km_at_min_distance_bin',
#  'all_events_within_3_km_at_min_distance_bin',
#  'all_events_within_5_km_at_min_distance_bin']

# %%
parks_features_list = []

for w in listings_other.columns:
    if 'park' in w:
        parks_features_list.append(w)

# %%
parks_features_list
# Out:
# ['park_count_1km',
#  'park_count_3km',
#  'park_count_5km',
#  'distance_to_closest_park_km',
#  'closest_park_index',
#  'closest_park_full_name',
#  'park_type',
#  'closest_park_full_name_enc',
#  'park_type_enc']

# %%
sns.distplot(listings_other['event_count_1km'].dropna())

# %%
plt.show()

# %%
def greater_than_zero(x):
    if 0 < x:
        return 1
    else:
        return 0

# %%
sns.barplot(listings_other['event_count_1km'].dropna().map(greater_than_zero))

# %%
plt.show()

# %%
sns.barplot(listings_other['park_count_1km'].dropna().map(greater_than_zero))

# %%
plt.show()

# %%
listings_other['event_count_1km'].dropna().map(greater_than_zero).mean()
# Out:
# 0.9528777603894975

# %%
listings_other['park_count_1km'].dropna().map(greater_than_zero).mean()
# Out:
# 0.9732220483394193

# %%
listings_other['all_events_within_1_km_at_min_distance_bin'].dropna().mean()
# Out:
# 0.06172839506172839

# %%
listings_other['all_events_within_3_km_at_min_distance_bin'].dropna().mean()
# Out:
# 0.04121022430881586

# %%
listings_other['all_events_within_5_km_at_min_distance_bin'].dropna().mean()
# Out:
# 0.0012171796209354895

# %%
event_features_list = []

for w in listings_other.columns:
    if 'event' in w:
        event_features_list.append(w)

# %%
event_features_list
# Out:
# ['event_count_1km',
#  'event_count_3km',
#  'event_count_5km',
#  'distance_to_closest_event_km',
#  'count_of_events_at_min_distance',
#  'all_events_within_1_km_at_min_distance',
#  'all_events_within_3_km_at_min_distance',
#  'all_events_within_5_km_at_min_distance',
#  'all_events_within_1_km_at_min_distance_bin',
#  'all_events_within_3_km_at_min_distance_bin',
#  'all_events_within_5_km_at_min_distance_bin']

# %%
from scipy.stats import kendalltau, pearsonr

# %%
sns.set(style="ticks")

sns.jointplot(listings_other['distance_from_ocean'], listings_other['park_count_1km'], kind="hex", stat_func=pearsonr, color="#4CB391")

# %%
plt.show()

# %%
sns.set(style="ticks")

sns.jointplot(listings_other['distance_from_ocean'], listings_other['park_count_3km'], kind="hex", stat_func=pearsonr, color="#4CB391")

# %%
plt.show()

# %%
sns.set(style="ticks")

sns.jointplot(listings_other['distance_from_ocean'], listings_other['park_count_5km'], kind="hex", stat_func=pearsonr, color="#4CB391")

# %%
plt.show()

# %%
sns.set(style="ticks")

sns.jointplot(listings_other['distance_from_ocean'], listings_other['event_count_1km'], kind="hex", stat_func=pearsonr, color="#4CB391")

# %%
plt.show()

# %%
sns.set(style="ticks")

sns.jointplot(listings_other['distance_from_ocean'], listings_other['event_count_3km'], kind="hex", stat_func=pearsonr, color="#4CB391")

# %%
plt.show()

# %%
sns.set(style="ticks")

sns.jointplot(listings_other['distance_from_ocean'], listings_other['count_of_events_at_min_distance'], kind="hex", stat_func=pearsonr, color="#4CB391")

# %%
plt.show()

# %%
sns.set(style="ticks")

sns.jointplot(listings_other['distance_from_ocean'], listings_other['accommodates'], kind="hex", stat_func=pearsonr, color="#4CB391")

# %%
plt.show()

# %%
sns.set(style="ticks")

sns.jointplot(listings_other['price_y'], listings_other['accommodates'], kind="hex", stat_func=pearsonr, color="#4CB391")

# %%
plt.show()

# %%
sns.set(style="ticks")

sns.jointplot(listings_other['bedrooms'], listings_other['accommodates'], kind="hex", stat_func=pearsonr, color="#4CB391")

# %%
plt.show()

# %%
has_list = []

for w in listings_other.columns:
    if 'has' in w:
        has_list.append(w)

# %%
has_list
# Out:
# ['host_has_profile_pic',
#  'has_availability',
#  'has_Other_pet(s)',
#  'has_Essentials',
#  'has_Carbon_Monoxide_Detector',
#  'has_Elevator_in_Building',
#  'has_Indoor_Fireplace',
#  'has_Internet',
#  'has_Washer',
#  'has_Hangers',
#  'has_Buzzer/Wireless_Intercom',
#  'has_TV',
#  'has_Gym',
#  'has_Fire_Extinguisher',
#  'has_Hot_Tub',
#  'has_Dryer',
#  'has_Air_Conditioning',
#  'has_Suitable_for_Events',
#  'has_Kitchen',
#  'has_Family/Kid_Friendly',
#  'has_Shampoo',
#  'has_Heating',
#  'has_Hair_Dryer',
#  'has_Smoke_Detector',
#  'has_Iron',
#  'has_Lock_on_Bedroom_Door',
#  'has_Free_Parking_on_Premises',
#  'has_Pets_live_on_this_property',
#  'has_Safety_Card',
#  'has_Doorman',
#  'has_Pool',
#  'has_Pets_Allowed',
#  'has_Wheelchair_Accessible',
#  'has_First_Aid_Kit',
#  'has_Dog(s)',
#  'has_Wireless_Internet',
#  'has_Cable_TV',
#  'has_Laptop_Friendly_Workspace',
#  'has_Breakfast',
#  'has_Smoking_Allowed',
#  'has_Cat(s)',
#  'has_24-Hour_Check-in',
# ...

# %%
sns.set(style="darkgrid")

g = sns.FacetGrid(listings_other, row="has_Cable_TV", col="has_Doorman", margin_titles=True)
bins = np.linspace(0, 60, 13)
g.map(plt.hist, "price_y", color="steelblue", bins=bins, lw=0)

# %%
plt.show()

# %%
sns.set(style="white")

g = sns.PairGrid(listings_other[['accommodates', 'bathrooms', 'bedrooms', 'distance_from_ocean']], diag_sharey=False)
g.map_lower(sns.kdeplot, cmap="Blues_d")
g.map_upper(plt.scatter)
g.map_diag(sns.kdeplot, lw=3)
# Out:
# C:\Users\sanka\Anaconda2\lib\site-packages\matplotlib\contour.py:1480: UserWarning: Warning: converting a masked element to nan.
#   self.zmax = float(z.max())
# C:\Users\sanka\Anaconda2\lib\site-packages\matplotlib\contour.py:1481: UserWarning: Warning: converting a masked element to nan.
#   self.zmin = float(z.min())
# C:\Users\sanka\Anaconda2\lib\site-packages\matplotlib\contour.py:1169: RuntimeWarning: invalid value encountered in greater
#   inside = (self.levels > self.zmin) & (self.levels < self.zmax)
# C:\Users\sanka\Anaconda2\lib\site-packages\matplotlib\contour.py:1169: RuntimeWarning: invalid value encountered in less
#   inside = (self.levels > self.zmin) & (self.levels < self.zmax)
# C:\Users\sanka\Anaconda2\lib\site-packages\matplotlib\contour.py:1173: UserWarning: No contour levels were found within the data range.
#   warnings.warn("No contour levels were found"
# ...

# %%
plt.show()

# %%
listings_other.columns[180:]
# Out:
# Index([u'has_Hangers', u'has_Buzzer/Wireless_Intercom', u'has_TV', u'has_Gym',
#        u'has_Fire_Extinguisher', u'has_Hot_Tub', u'has_Dryer',
#        u'has_Air_Conditioning', u'has_Suitable_for_Events', u'has_Kitchen',
#        u'has_Family/Kid_Friendly', u'has_Shampoo', u'has_Heating',
#        u'has_Hair_Dryer', u'has_Smoke_Detector', u'has_Iron',
#        u'has_Lock_on_Bedroom_Door', u'has_Free_Parking_on_Premises',
#        u'has_Pets_live_on_this_property', u'has_Safety_Card', u'has_Doorman',
#        u'has_Pool', u'has_Pets_Allowed', u'has_Wheelchair_Accessible',
#        u'has_First_Aid_Kit', u'has_Dog(s)', u'has_Wireless_Internet',
#        u'has_Cable_TV', u'has_Laptop_Friendly_Workspace', u'has_Breakfast',
#        u'has_Smoking_Allowed', u'has_Cat(s)', u'has_24-Hour_Check-in',
#        u'uses_phone', u'uses_linkedin', u'uses_email', u'uses_manual_online',
#        u'uses_facebook', u'uses_amex', u'uses_sent_id', u'uses_jumio',
# ...

# %%
sns.set(style="ticks")

sns.jointplot(listings_other['longitude'], listings_other['distance_from_ocean'], kind="hex", stat_func=pearsonr, color="#4CB391")

# %%
plt.show()

# %%
sns.set(style="ticks")

sns.jointplot(listings_other['longitude'], listings_other['accommodates'], kind="hex", stat_func=pearsonr, color="#4CB391")

# %%
plt.show()

# %%
sns.set(style="ticks")

sns.jointplot(listings_other['longitude'], listings_other['price_y'], kind="hex", stat_func=pearsonr, color="#4CB391")

plt.show()

# %%
sns.set(style="ticks")

sns.jointplot(listings_other['calendar_updated_numeric'], listings_other['price_y'], kind="hex", stat_func=pearsonr, color="#4CB391")

plt.show()

# %%
sns.set(style="ticks")

sns.jointplot(listings_other['zipcode_enc'], listings_other['price_y'], kind="hex", stat_func=pearsonr, color="#4CB391")

plt.show()

# %%
sns.set(style="ticks")

sns.jointplot(listings_other['amenity_level_enc'], listings_other['price_y'], kind="hex", stat_func=pearsonr, color="#4CB391")

plt.show()

# %%
nghbrd_roomtype_nbghrd_count = listings_other[['bed_type','neighbourhood','id']].groupby(['bed_type','neighbourhood'])

# %%
listings_other['neighbourhood'].nunique()
# Out:
# 104

# %%
COL_NUM=8
ROW_NUM=13
forplot = nghbrd_roomtype_nbghrd_count.size().unstack()

# %%
fig, axes = plt.subplots(COL_NUM,ROW_NUM, 
                     sharex=True, sharey=True, figsize=(30,30))
for i, nghbrd in enumerate(forplot):
    ax = axes[i/COL_NUM, i%ROW_NUM]
    forplot[nghbrd].plot(ax=ax, kind='bar')
    ax.set_title(nghbrd)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-93-8f33f168cb4d> in <module>()
#       2                      sharex=True, sharey=True, figsize=(30,30))
#       3 for i, nghbrd in enumerate(forplot):
# ----> 4     ax = axes[i/COL_NUM, i%ROW_NUM]
#       5     forplot[nghbrd].plot(ax=ax, kind='bar')
#       6     ax.set_title(nghbrd)
#
# IndexError: index 8 is out of bounds for axis 0 with size 8
