# %% [markdown]
# Notebook inlcluding Manifolds and PCA to explore the data

# %% [markdown]
# Starting with the same data used in the modeling_normalizeddata nb

# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix
import matplotlib.cm as cm
# %matplotlib inline

# %%
import sys
sys.path.append('./lib')
from airbnb_modeling import detect_feature_importance, scale_data, normalize_data, eval_metrics, plot_residuals, plot_predictions
from parse_methods import parse_columns
from airbnb_modeling import detect_interactions, add_interactions, map_variable, plot_rmse_instances,plot_rmse_features, plot_accuracy_instances
# Out:
# /Users/pauldefusco/anaconda2/envs/py27/lib/python2.7/site-packages/statsmodels/compat/pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
from sklearn import linear_model
from sklearn.metrics import r2_score, mean_squared_error,mean_absolute_error
from sklearn.model_selection import KFold,cross_val_score, cross_validate, train_test_split, GridSearchCV
from sklearn.preprocessing import LabelEncoder, LabelBinarizer, PolynomialFeatures, MinMaxScaler, StandardScaler
from sklearn.pipeline import Pipeline
from sklearn import preprocessing
from sklearn.neighbors import LocalOutlierFactor, KNeighborsRegressor
from sklearn.feature_selection import RFE, f_regression, RFECV
from sklearn.ensemble import RandomForestRegressor, BaggingRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.svm import SVR
from sklearn.decomposition import PCA

# %%
listings = pd.read_csv('Datasources/listings_augmented/listings_augmented_2018-05-31_V3.csv',low_memory=False)
listings = listings.drop(listings.index[4323:4325])
listings.index = [i for i in range(len(listings))]

# %%
#Excluded variables from the featuresExploration notebook
# %store -r excluded

# %%
cols = [i for i in listings.columns if i not in excluded]
X = listings[cols]

# %%
X = X.fillna(X.mean())

# %%
X = parse_columns(X, ['has_Pets_Allowed','has_Wheelchair_Accessible','has_First_Aid_Kit',
'has_Cat(s)','has_24-Hour_Check-in','uses_jumio','description-Topic0','description-Topic1',
'description-Topic4','description-Topic5','description-Topic6','description-Topic10',
'description-Topic11','description-Topic12','description-Topic13','description-Topic15',
'description-Topic17','description-Topic18','description-Dominant_Topic'])

# %%
X = X.select_dtypes(include=['int64', 'float64'])

# %%
X = X[[i for i in X.columns if i not in X.filter(regex='enc').columns]]
donotscale = X.filter(regex='bin').columns
cols = [i for i in X.columns if i not in donotscale]
helper_df = pd.DataFrame(preprocessing.scale(X[cols]), columns = cols)
X_scaled = helper_df.merge(X[donotscale], right_index=True, left_index=True)
# Out:
# /Users/pauldefusco/anaconda2/envs/py27/lib/python2.7/site-packages/sklearn/preprocessing/data.py:181: UserWarning: Numerical issues were encountered when scaling the data and might not be solved. The standard deviation of the data is probably very close to 0.
#   warnings.warn("Numerical issues were encountered "

# %%
y_scaled = X_scaled['price_y'].fillna(X_scaled['price_y'].mean())
X_scaled = X_scaled[X_scaled.columns.drop(X_scaled[list(X_scaled.filter(regex='price'))])]

# %%
#Checking that features are clean - output should be True and False
print np.any(np.isnan(X_scaled))
print np.all(np.isfinite(X_scaled))
# Out:
# False
# True

# %% [markdown]
# Doing a PCA to visualize variance?

# %% [markdown]
# Sankarshan Task: how does PCA help us understand the structure of our data? What does it tell us about outliers, etc? Does it give us any insights? Insights for Regressions are particularly welcome

# %%
n_comps = 137
pca = PCA(n_components=n_comps)
model_fit = pca.fit(X_scaled)
X_transform = model_fit.transform(X_scaled)
print'Score for PCA with %i Components: %i' %(n_comps,model_fit.score(X_scaled))
# Out:
# Score for PCA with 137 Components: 348745170021409

# %%
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('number of components')
plt.ylabel('cumulative explained variance');

# %% [markdown]
# Insight: not clear where the "elbow" is here but taking 60 components should give us most of the explained variance

# %%
pd.set_option('display.float_format', lambda x: '%.3f' % x)
print 'Explained Variance: '
print pd.Series(model_fit.explained_variance_).head()
print '\n'
print 'Explained Variance Ratio: '
print pd.Series(model_fit.explained_variance_ratio_).head()
# Out:
# Explained Variance:
# 0   15.293
# 1    6.883
# 2    5.675
# 3    4.824
# 4    4.079
# dtype: float64
#
#
# Explained Variance Ratio:
# 0   0.119
# 1   0.053
# 2   0.044
# 3   0.037
# 4   0.032
# dtype: float64

# %%
from yellowbrick.features.pca import PCADecomposition
from yellowbrick.features.importances import FeatureImportances


visualizer = PCADecomposition(n_components=60, scale=False, colormap='autumn')
visualizer.fit(X_scaled)
visualizer.transform(X_scaled)
visualizer.poof()

# %%
visualizer = PCADecomposition(scale=False,n_components=60, proj_dim=3, colormap='autumn')
visualizer.fit(X_scaled)
visualizer.transform(X_scaled)
visualizer.poof()

# %%
from sklearn import linear_model
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.metrics import r2_score, mean_squared_error,mean_absolute_error

# %% [markdown]
# First we run a test pipeline to see what the optimal number of components will be with GridSearchCV. Then we run the actual regression to make predictions

# %%
test_lr = linear_model.LinearRegression()

# %%
pca = PCA()
comps = [40,60,80]

# %%
pipe = Pipeline(steps=[('pca', pca), ('reg', test_lr)])

# %%
estimator = GridSearchCV(pipe, dict(pca__n_components=comps), cv=3)

# %%
estimator.fit(X_scaled, y_scaled)
# Out:
# GridSearchCV(cv=3, error_score='raise',
#        estimator=Pipeline(memory=None,
#      steps=[('pca', PCA(copy=True, iterated_power='auto', n_components=None, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=False)), ('reg', LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False))]),
#        fit_params=None, iid=True, n_jobs=1,
#        param_grid={'pca__n_components': [40, 60, 80]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=0)

# %%
estimator.best_estimator_
# Out:
# Pipeline(memory=None,
#      steps=[('pca', PCA(copy=True, iterated_power='auto', n_components=60, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=False)), ('reg', LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False))])

# %% [markdown]
# Insight: 60 components is the confirmed best number

# %%
estimator.best_estimator_.named_steps['reg']
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %% [markdown]
# Now actually running the regression on the reduced dataset

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y_scaled)

# %%
pca = PCA(n_components=60)
lr = linear_model.LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
pipe = Pipeline(steps=[('pca', pca), ('reg', lr)])

# %%
pipe.fit(X_train,y_train)
# Out:
# Pipeline(memory=None,
#      steps=[('pca', PCA(copy=True, iterated_power='auto', n_components=60, random_state=None,
#   svd_solver='auto', tol=0.0, whiten=False)), ('reg', LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False))])

# %%
pipe.predict(X_test)
# Out:
# array([-0.31018055, -0.82887958,  0.37418511, ..., -0.21445269,
#        -0.59376273, -0.51714025])

# %%
pipe.score(X_test, y_test)
# Out:
# 0.5804404543908278

# %% [markdown]
# Insight: with this rudimental, untuned linear regression on 60 principal components we obtained an R2 of 58%

# %%
#Just checking that it's the same as above...
print 'R2 with PCA with 60 components: ', r2_score(y_test,pipe.predict(X_test))
# Out:
# R2 with PCA with 60 components:  0.5804404543908278

# %%
print 'RMSE with PCA with 60 components: ', mean_squared_error(y_test,pipe.predict(X_test))
# Out:
# RMSE with PCA with 60 components:  0.45586200014324735

# %% [markdown]
# Insight from first glance: there are three clusters, two being more closely related. So what does that imply for regressions?

# %% [markdown]
# Manifolds

# %% [markdown]
# Doing Manifolds to visualize structure of data?

# %% [markdown]
# Sankarshan task: how does manifolds help us understand the structure of the data? How does it help us understand our regressions better? Does it tell us anything about the sparsity (number of zeros) of our data? Does it tell us anything about the distance between the data points? How is that relevant to regressions?

# %% [markdown]
# Should the data be scaled for manifolds? Using scaled data now but check this please

# %% [markdown]
# For more visualizatioins, read this manual: https://media.readthedocs.org/pdf/yellowbrick/latest/yellowbrick.pdf
#         Search for "Manifolds" - page 51

# %% [markdown]
# What do the manifold types (i.e. tsne, isomap, etc.) mean? Which one should we choose to best visualize the data? Why?
# Manual Page 53: The manifold algorithm used to do the embedding in scatter plot space can either be a transformer or a string
# representing one of the already specified manifolds as follows:
# Manifold Description
# "lle" Locally Linear Embedding
# "ltsa" LTSA LLE
# "hessian" Hessian LLE
# "modified" Modified LLE
# "isomap" Isomap
# "mds" Multi-Dimensional Scaling
# "spectral" Spectral Embedding
# "tsne" t-SNE

# %% [markdown]
# Looks like the below will only work for a subset of the data features - how should one choose wich features to use as inputs? Should it be features that are nonlinear? How does one know ahead of time

# %%
#Trying random feautres now
random_features = list(X_scaled.iloc[:,20:26].columns)

# %%
from yellowbrick.features.manifold import Manifold
visualizer = Manifold(manifold='tsne', target='continuous')
visualizer.fit_transform(X_scaled[random_features],y_scaled)
visualizer.poof()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-66-022061afd9b7> in <module>()
#       1 from yellowbrick.features.manifold import Manifold
#       2 visualizer = Manifold(manifold='tsne', target='continuous')
# ----> 3 visualizer.fit_transform(X_scaled[random_features],y_scaled)
#       4 visualizer.poof()
#
# /Users/pauldefusco/anaconda2/envs/py27/lib/python2.7/site-packages/sklearn/base.pyc in fit_transform(self, X, y, **fit_params)
#     518         else:
#     519             # fit method of arity 2 (supervised transformation)
# --> 520             return self.fit(X, y, **fit_params).transform(X)
#     521
#     522
#
# /Users/pauldefusco/anaconda2/envs/py27/lib/python2.7/site-packages/yellowbrick/features/manifold.pyc in transform(self, X)
#     328             Returns the 2-dimensional embedding of the instances.
#     329         """
# ...

# %%
from yellowbrick.features.manifold import Manifold
visualizer = Manifold(manifold='isomap', target='continuous')
visualizer.fit_transform(X_scaled[random_features],y_scaled)
visualizer.poof()

# %% [markdown]
# Now doing isomap again but this time using the F score to take only highest three features individually correlated with y_scaled - try other methods for score_func

# %%
from sklearn.pipeline import Pipeline
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_classif
model = Pipeline([
("selectk", SelectKBest(k=3, score_func=f_classif)),
("viz", Manifold(manifold='isomap', target='continuous')),
])

# %%
model.fit(X_scaled[random_features],y_scaled)
model.named_steps['viz'].poof()

# %% [markdown]
# Now passing Locally Linear Embedding - does this help us for linaer regression?

# %%
from yellowbrick.features.manifold import Manifold
visualizer = Manifold(manifold='lle', target='continuous')
visualizer.fit_transform(X_scaled[random_features],y_scaled)
visualizer.poof()
