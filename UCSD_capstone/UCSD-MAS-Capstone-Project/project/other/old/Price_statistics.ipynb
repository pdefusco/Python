# %%
import pandas as pd
import os
import sklearn as sk
from sklearn.linear_model import MultiTaskLasso, MultiTaskElasticNet, ElasticNet
from sklearn.cross_validation import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error
import sklearn.metrics as skmet
import numpy as np
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.corpus import stopwords, names
import datetime

# %%
listings = pd.read_csv('inside_airbnb/listings.csv')
list_summ = pd.read_csv('inside_airbnb/listings_summ.csv')
neighborhoods = pd.read_csv('inside_airbnb/neighbourhoods.csv')
reviews = pd.read_csv('inside_airbnb/reviews.csv')
reviews_summ = pd.read_csv('inside_airbnb/reviews_summ.csv')
calendar = pd.read_csv('inside_airbnb/calendar.csv')

# %%
listings.columns
# Out:
# Index([u'id', u'listing_url', u'scrape_id', u'last_scraped', u'name',
#        u'summary', u'space', u'description', u'experiences_offered',
#        u'neighborhood_overview', u'notes', u'transit', u'access',
#        u'interaction', u'house_rules', u'thumbnail_url', u'medium_url',
#        u'picture_url', u'xl_picture_url', u'host_id', u'host_url',
#        u'host_name', u'host_since', u'host_location', u'host_about',
#        u'host_response_time', u'host_response_rate', u'host_acceptance_rate',
#        u'host_is_superhost', u'host_thumbnail_url', u'host_picture_url',
#        u'host_neighbourhood', u'host_listings_count',
#        u'host_total_listings_count', u'host_verifications',
#        u'host_has_profile_pic', u'host_identity_verified', u'street',
#        u'neighbourhood', u'neighbourhood_cleansed',
#        u'neighbourhood_group_cleansed', u'city', u'state', u'zipcode',
#        u'market', u'smart_location', u'country_code', u'country', u'latitude',
#        u'longitude', u'is_location_exact', u'property_type', u'room_type',
#        u'accommodates', u'bathrooms', u'bedrooms', u'beds', u'bed_type',
#        u'amenities', u'square_feet', u'price', u'weekly_price',
#        u'monthly_price', u'security_deposit', u'cleaning_fee',
#        u'guests_included', u'extra_people', u'minimum_nights',
#        u'maximum_nights', u'calendar_updated', u'has_availability',
#        u'availability_30', u'availability_60', u'availability_90',
#        u'availability_365', u'calendar_last_scraped', u'number_of_reviews',
#        u'first_review', u'last_review', u'review_scores_rating',
#        u'review_scores_accuracy', u'review_scores_cleanliness',
#        u'review_scores_checkin', u'review_scores_communication',
#        u'review_scores_location', u'review_scores_value', u'requires_license',
#        u'license', u'jurisdiction_names', u'instant_bookable',
#        u'cancellation_policy', u'require_guest_profile_picture',
#        u'require_guest_phone_verification', u'calculated_host_listings_count',
#        u'reviews_per_month'],
#       dtype='object')

# %%
def parse_columns(listings, cols):
    chars = "%$"
    for i in cols:
        listings[i].astype(str).map(lambda x: x.rstrip(chars))
        listings[i] = listings[i].apply(pd.to_numeric, errors='coerce')
        listings[i].replace(regex=True,inplace=True,to_replace=r'\D',value=r'')
    return listings

# %%
listings = parse_columns(listings, ['host_response_rate', 'cleaning_fee',\
                                     'host_acceptance_rate','extra_people',\
                                     'weekly_price', 'monthly_price', 'security_deposit'])

# %%
cal = calendar

# %%
from pandas.tseries.holiday import USFederalHolidayCalendar as calendar

# %%
cal['price'] = cal['price'].astype(str).map(lambda x: x.lstrip('$'))
cal['price'] = cal['price'].apply(pd.to_numeric, errors='coerce')
cal['price'].replace(regex=True,inplace=True,to_replace=r'\D',value=r'')
cal['date'] = pd.to_datetime(cal['date'])
cal['month'] = cal['date'].apply(lambda x: x.month)
cal['day'] = cal['date'].apply(lambda x: x.day)
cal['day_of_week'] = cal['date'].dt.weekday_name
    
cl = calendar()
holidays = cl.holidays(start=cal['date'].min(), end=cal['date'].max())
    
cal['holiday'] = cal['date'].isin(holidays)
cal = cal[(cal['date']>'2016-07-06')&(cal['date']<'2016-10-06')]
    
c = cal.loc[cal.available!='f']
c = c[['listing_id','date','price','month','day_of_week','holiday']]
c=c.fillna(c.mean())
    
c_hol = c[c['holiday']==True]
c_wke = c[(c['holiday']==False)&((c['day_of_week']=='Sunday')|(c['day_of_week']=='Saturday'))]
c_wkd = c[(~c.isin(c_hol['date']))&(~c.isin(c_wke['date']))]


price_hol_dict = {'price': c_hol.groupby(by='listing_id')['price'].mean(), 
                  'max_price': c_hol.groupby(by='listing_id')['price'].max(), 
                  'min_price': c_hol.groupby(by='listing_id')['price'].min(), 
                  'stdev_of_price': c_hol.groupby(by='listing_id')['price'].fillna(0).std(),                 
                  'skew_of_price': c_hol.groupby(by='listing_id')['price'].fillna(0).skew()}


price_wke_dict = {'price': c_wke.groupby(by='listing_id')['price'].mean(), 
                  'max_price': c_wke.groupby(by='listing_id')['price'].max(), 
                  'min_price': c_wke.groupby(by='listing_id')['price'].min(), 
                  'stdev_of_price': c_wke.groupby(by='listing_id')['price'].fillna(0).std(),
                  'skew_of_price': c_wke.groupby(by='listing_id')['price'].fillna(0).skew()}


price_wkd_dict = {'price': c_wkd.groupby(by='listing_id')['price'].mean(), 
                  'max_price': c_wkd.groupby(by='listing_id')['price'].max(), 
                  'min_price': c_wkd.groupby(by='listing_id')['price'].min(), 
                  'stdev_of_price': c_wkd.groupby(by='listing_id')['price'].fillna(0).std(),
                  'skew_of_price': c_wkd.groupby(by='listing_id')['price'].fillna(0).skew()}


price_whole_dict = {'price': c.groupby(by='listing_id')['price'].mean(), 
                  'max_price': c.groupby(by='listing_id')['price'].max(), 
                  'min_price': c.groupby(by='listing_id')['price'].min(), 
                  'stdev_of_price': c.groupby(by='listing_id')['price'].fillna(0).std(),
                  'skew_of_price': c.groupby(by='listing_id')['price'].fillna(0).skew()}



price_hol = pd.DataFrame(price_hol_dict)
price_wke = pd.DataFrame(price_wke_dict)
price_wkd = pd.DataFrame(price_wkd_dict)
price_c = pd.DataFrame(price_whole_dict)    
    
price_hol = price_hol.reset_index()
price_wke = price_wke.reset_index()
price_wkd = price_wkd.reset_index()
price_c = price_c.reset_index()

listings_hol = listings.merge(price_hol, how='inner', left_on='id', right_on='listing_id')
listings_wke = listings.merge(price_wke, how='inner', left_on='id', right_on='listing_id')
listings_wkd = listings.merge(price_wkd, how='inner', left_on='id', right_on='listing_id')
listings_c = listings.merge(price_c, how='inner', left_on='id', right_on='listing_id')

# %%
listings_hol.shape, listings_wke.shape, listings_wkd.shape, listings_c.shape
# Out:
# ((4000, 101), (5656, 101), (5753, 101), (5753, 101))

# %%
c_hol.shape, c_wke.shape, c_wkd.shape, c.shape
# Out:
# ((4000, 6), (80532, 6), (288684, 6), (288684, 6))

# %%
price_hol
# Out:
#       listing_id   max_price   min_price       price  skew_of_price  \
# 0           9553   99.000000   99.000000   99.000000       1.916102
# 1          14668   58.000000   58.000000   58.000000       1.916102
# 2          38245   65.000000   65.000000   65.000000       1.916102
# 3          45429  160.000000  160.000000  160.000000       1.916102
#       stdev_of_price
# 0          164.93312
# 1          164.93312
# 2          164.93312
# 3          164.93312
# 4          164.93312
# 5          164.93312
# 6          164.93312
# 7          164.93312
# 8          164.93312
# 9          164.93312
# 10         164.93312
# 11         164.93312
# 12         164.93312
# 13         164.93312
# 14         164.93312
# 15         164.93312
# 16         164.93312
# 17         164.93312
# 18         164.93312
# 19         164.93312
# 20         164.93312
# 21         164.93312
# 22         164.93312
# 23         164.93312
# 24         164.93312
# 25         164.93312
# 26         164.93312
# 27         164.93312
# 28         164.93312
# 29         164.93312
# ...              ...
# 3970       164.93312
# 3971       164.93312
# 3972       164.93312
# 3973       164.93312
# 3974       164.93312
# 3975       164.93312
# 3976       164.93312
# 3977       164.93312
# 3978       164.93312
# 3979       164.93312
# 3980       164.93312
# 3981       164.93312
# 3982       164.93312
# 3983       164.93312
# 3984       164.93312
# 3985       164.93312
# 3986       164.93312
# 3987       164.93312
# 3988       164.93312
# 3989       164.93312
# 3990       164.93312
# 3991       164.93312
# 3992       164.93312
# 3993       164.93312
# 3994       164.93312
# 3995       164.93312
# 3996       164.93312
# 3997       164.93312
# 3998       164.93312
# 3999       164.93312
#
# [4000 rows x 6 columns]

# %%
price_hol_new = price_hol.rename(columns = {'max_price': 'hol_max_price', 'min_price': 'hol_min_price', 'price': 'hol_price',
                                           'skew_of_price': 'hol_skew_of_price', 'stdev_of_price': 'hol_stdev_of_price'})
price_wke_new = price_wke.rename(columns = {'max_price': 'wke_max_price', 'min_price': 'wke_min_price', 'price': 'wke_price',
                                           'skew_of_price': 'wke_skew_of_price', 'stdev_of_price': 'wke_stdev_of_price'})
price_wkd_new = price_wkd.rename(columns = {'max_price': 'wkd_max_price', 'min_price': 'wkd_min_price', 'price': 'wkd_price',
                                           'skew_of_price': 'wkd_skew_of_price', 'stdev_of_price': 'wkd_stdev_of_price'})

# %%
listings_all = listings_c.merge(price_hol_new, how='inner', left_on='listing_id', right_on='listing_id')
listings_all = listings_all.merge(price_wke_new, how='inner', left_on='listing_id', right_on='listing_id')
listings_all = listings_all.merge(price_wkd_new, how='inner', left_on='listing_id', right_on='listing_id')

# %%
listings_all
# Out:
#             id                            listing_url       scrape_id  \
# 0     11204286  https://www.airbnb.com/rooms/11204286  20160706203047
# 1      7972006   https://www.airbnb.com/rooms/7972006  20160706203047
# 2     13124681  https://www.airbnb.com/rooms/13124681  20160706203047
# 3      3469225   https://www.airbnb.com/rooms/3469225  20160706203047
# 4       877473    https://www.airbnb.com/rooms/877473  20160706203047
# 5      3124507   https://www.airbnb.com/rooms/3124507  20160706203047
# 6      3432507   https://www.airbnb.com/rooms/3432507  20160706203047
# 7      3249729   https://www.airbnb.com/rooms/3249729  20160706203047
# 8     13157364  https://www.airbnb.com/rooms/13157364  20160706203047
# 9      9756570   https://www.airbnb.com/rooms/9756570  20160706203047
# 10    10687910  https://www.airbnb.com/rooms/10687910  20160706203047
# 11     7938260   https://www.airbnb.com/rooms/7938260  20160706203047
# 12    10779932  https://www.airbnb.com/rooms/10779932  20160706203047
# 13    13301630  https://www.airbnb.com/rooms/13301630  20160706203047
# 3996   2016-07-07                *NEW Studio-Rancho Bernardo, Poway*
# 3997   2016-07-07                                    Double R's camp
# 3998   2016-07-07                                      Room "Shanti"
# 3999   2016-07-07                  Beach Living Near the Race Track!
#
#                                                 summary  \
# 0     Aquatica Waterpark, Sleep train Amphitheater, ...
# 1     Your spacious room awaiting is with a Queen Si...
# 2     This 2 Story TownHome  is close to Otay Ranch ...
# 3     Hello; we are offering a private secluded bedr...
# 4     Private Bedroom with full size bed, + futon, p...
# 5     In this beautiful home, located near the Olymp...
# 6     In a great house  with view on Otay Lakes and ...
# 7     Beautiful home in the Eastlake community with ...
# 8     Habitaciones amuebladas con Closet, television...
# 9     Fully equipped home in a quiet family-friendly...
# 10    Newly built community (2009), gated security. ...
# 11    My home is in a nice neighborhood in East Chul...
# 12    My home is in a nice neighborhood in East Chul...
# 13    My place is close to My home is in a nice neig...
# 14    My place is in East Chula Vista close to The S...
# 15    Large 1 story house with Garden, open floor de...
# 16    This is a fairly new town home complex (2-3 ye...
# 17    The home is spacious, tastefully decorated and...
# 18    Private entrance  bedroom with full bathroom(p...
# 19           Beautiful quiet room with shared bathroom.
# 20    This is a new town home (3 years old) and prov...
# 21    Perfect if you're looking for a more suburban ...
# 22    family-friendly activities, nightlife, the air...
# 23    Spacious 5 bedroom house, with easy access to ...
# 24    Located close to shopping and 20 minutes from ...
# 25    Townhouse in a nice Neighborhood 1-big master ...
# 26    Little room with wood flooring on the 2nd floo...
# 27    This bedroom is on the second floor. The bath ...
# 28    Nice & cozy private bedroom with a brand new q...
# 29    A private room in a Nice condo, very quiet nei...
# ...                                                 ...
# 3970                                          Nice room
# 3971  - One (1) Quiet, large, private suite bedroom ...
# 3972  The property is a 3 floors townhouse.This bed ...
# 3973  Our little cottage  is a few minutes to windns...
# 3974  Bright stylish Solana Beach 3 bedroom with ple...
# 3975  A cozy beach apartment with an open floor plan...
# 3976                 The outdoor shower area available.
# 3977  Sit back, relax, and take some time away from ...
# 3978  This is a condo in beautiful La Mesa, CA with ...
# 3979  Beautiful private, 2-bedroom bungalow in Old D...
# 3980  You’ll love my place because of whitewater oce...
# 3981  Although this room has 2 single beds, it is fo...
# 3982  The boat is close to restaurants and dining an...
# 3983  A peaceful garden retreat Bed and Breakfast (s...
# 3984                                                NaN
# 3985  1BR for rent in large house with pool and spa....
# 3986  You’ll love my place because of 7 minutes to D...
# 3987  Cozy and quaint waterfront hideaway. Dockside ...
# 3988  En la mejor zona de Playas de Tijuana. Pet Fri...
# 3989  "MEA CULPA" is an All-American Beauty - a 46' ...
# 3990  We are new to Airbnb and look forward to shari...
# 3991  My place is good for couples, solo adventurers...
# 3992  My place is close to Galley At the Marina (Res...
# 3993  Located directly across from Del Mar Race trac...
# 3994  you are welcome to stay in our 2 bedroom 1.5 b...
# 3995  My place is close to The Beach!. You’ll love m...
# 3996  Brand new, clean and very private apartment wi...
# 3997  My place is close to the beach, restaurants an...
# 3998  Este es el 2o cuarto q ofrezco en mi casa, par...
# 3999  If you love the beach, the fairgrounds or the ...
#
#                                                   space  \
# 0     Walking to Aquatica Waterpark, Sleep train Amp...
# 1                                                   NaN
# 2     My place is good for couples, business travele...
# 3     Beautiful, quiet award-winning suburban neighb...
# 4     Private bedroom with full size Bed, in large n...
# 5            The location and view of lake and mountain
# 6     the proximity to lake ,trail and Olympic train...
# 7     Location on the border of the town with nice t...
# 8                                                   NaN
# 9                                                   NaN
# 10    안녕하세요. 아주 조용하고 아늑한 단지에 위치하고 있습니다. 단지안에 수영장 짐을 ...
# 11    My home is in a nice neighborhood in East Chul...
# 12    My home is in a nice neighborhood in East Chul...
# 13    My home is in a nice neighborhood in East Chul...
# 14    My home is in a nice neighborhood in East Chul...
# 15    The house is very spacious , well designed, a ...
# 16    We bought our house a year ago because of its ...
# 17                                                  NaN
# 18    Private entrance to the side of the house to a...
# 19    Quiet and peaceful neighborhood, located 20 mi...
# 20    Our home is spacious (1900 sq ft home), and br...
# 21    Our guest bedroom is for 1-2 guests total. Req...
# 22    Newly built 3-story townhouse with distressed ...
# 23                                                  NaN
# 24                                                  NaN
# 25    The room had 3 closet where you can put all yo...
# 26    Clotheshanger. The house is located on a quiet...
# 27    This bedroom is on the second floor. The share...
# 28                                                  NaN
# 29         Quiet neighbours, the room has a big closet.
# ...                                                 ...
# 3970                                                NaN
# 3971                                                NaN
# 3972  You can have a private room with queen size be...
# 3973                                                NaN
# 3974  The nice bright, spacious 3 bedroom space is o...
# 3975  1 parking space for a mid size car The apartme...
# 3976                                                NaN
# 3977  Only 2 blocks from the Famous Pacific Beach Bo...
# 3978                                                NaN
# 3979  Beautiful private, 2-bedroom bungalow in Old D...
# 3980                                                NaN
# 3981                                                NaN
# 3982                                                NaN
# 3983  THE CULTURE OF THE CITY NEAR THE QUIET OF THE ...
# 3984                                                NaN
# 3985  Very relaxed atmosphere. The backyard and pool...
# 3986                 Your own private house to yourself
# 3987                                                NaN
# 3988  Vivo en una mini ciudad, con todo lo que quier...
# 3989  "MEA CULPA" is an All-American Beauty - a 46' ...
# 3990  This detached house was built in 1950. It was ...
# 3991  Welcome to the ocean front Whale's Tail Cabin....
# 3992                                                NaN
# 3993  Walk across to Del Mar Race track or use the s...
# 3994                                                NaN
# 3995  Beautiful 1-bedroom bungalow in Old Del Mar. T...
# 3996  Beautifully appointed studio apartment with st...
# 3997                                                NaN
# 3998  This is the secondary room i offer. To know th...
# 3999  Apartment is approx. 1100 sq. ft. (102 m2) Bea...
#
#                                             description experiences_offered  \
# 0     Aquatica Waterpark, Sleep train Amphitheater, ...                none
# 1     Your spacious room awaiting is with a Queen Si...                none
# 2     This 2 Story TownHome  is close to Otay Ranch ...                none
# 3     Hello; we are offering a private secluded bedr...                none
# 4     Private Bedroom with full size bed, + futon, p...                none
# 5     In this beautiful home, located near the Olymp...                none
# 6     In a great house  with view on Otay Lakes and ...                none
# 7     Beautiful home in the Eastlake community with ...                none
# 8     Habitaciones amuebladas con Closet, television...                none
# 9     Fully equipped home in a quiet family-friendly...                none
# 10    Newly built community (2009), gated security. ...                none
# 11    My home is in a nice neighborhood in East Chul...                none
# 12    My home is in a nice neighborhood in East Chul...                none
# 13    My place is close to My home is in a nice neig...                none
# 14    My place is in East Chula Vista close to The S...                none
# 15    Large 1 story house with Garden, open floor de...                none
# 16    This is a fairly new town home complex (2-3 ye...                none
# 17    The home is spacious, tastefully decorated and...                none
# 18    Private entrance  bedroom with full bathroom(p...                none
# 19    Beautiful quiet room with shared bathroom. Qui...                none
# 20    This is a new town home (3 years old) and prov...                none
# 21    Perfect if you're looking for a more suburban ...                none
# 22    family-friendly activities, nightlife, the air...                none
# 23    Spacious 5 bedroom house, with easy access to ...                none
# 24    Located close to shopping and 20 minutes from ...                none
# 25    Townhouse in a nice Neighborhood 1-big master ...                none
# 26    Little room with wood flooring on the 2nd floo...                none
# 27    This bedroom is on the second floor. The bath ...                none
# 28    Nice & cozy private bedroom with a brand new q...                none
# 29    A private room in a Nice condo, very quiet nei...                none
# ...                                                 ...                 ...
# 3970  Nice room Breakfast is free I always have time...                none
# 3971  - One (1) Quiet, large, private suite bedroom ...                none
# 3972  The property is a 3 floors townhouse.This bed ...                none
# 3973  Our little cottage  is a few minutes to windns...                none
# 3974  Bright stylish Solana Beach 3 bedroom with ple...                none
# 3975  A cozy beach apartment with an open floor plan...                none
# 3976                 The outdoor shower area available.                none
# 3977  Sit back, relax, and take some time away from ...                none
# 3978  This is a condo in beautiful La Mesa, CA with ...                none
# 3979  Beautiful private, 2-bedroom bungalow in Old D...                none
# 3980  You’ll love my place because of whitewater oce...                none
# 3981  Although this room has 2 single beds, it is fo...                none
# 3982  The boat is close to restaurants and dining an...                none
# 3983  A peaceful garden retreat Bed and Breakfast (s...                none
# 3984                                                NaN                none
# 3985  1BR for rent in large house with pool and spa....                none
# 3986  You’ll love my place because of 7 minutes to D...                none
# 3987  Cozy and quaint waterfront hideaway. Dockside ...                none
# 3988  En la mejor zona de Playas de Tijuana. Pet Fri...                none
# 3989  "MEA CULPA" is an All-American Beauty - a 46' ...                none
# 3990  We are new to Airbnb and look forward to shari...                none
# 3991  My place is good for couples, solo adventurers...                none
# 3992  My place is close to Galley At the Marina (Res...                none
# 3993  Located directly across from Del Mar Race trac...                none
# 3994  you are welcome to stay in our 2 bedroom 1.5 b...                none
# 3995  My place is close to The Beach!. You’ll love m...                none
# 3996  Brand new, clean and very private apartment wi...                none
# 3997  My place is close to the beach, restaurants an...                none
# 3998  Este es el 2o cuarto q ofrezco en mi casa, par...                none
# 3999  If you love the beach, the fairgrounds or the ...                none
#
#                                   neighborhood_overview         ...          \
# 0                                                   NaN         ...
# 1     Getting around is easy. Very close to Eastlake...         ...
# 2     Located in eastern Chula Vista, Otay Ranch is ...         ...
# 3     The quiet serenity; near Park and lakes, beaut...         ...
# 4     It is quiet, serene, tranquil, suburban; yet c...         ...
# 5     Like countryside and also near from downtown S...         ...
# 6                                     Freedom in nature         ...
# 7                         open , quiet, country feeling         ...
# 8     Preciosa zona Residencial, en Eastlake Greens ...         ...
# 9                                                   NaN         ...
# 10    Hi~ Welcome home:) We are close to Mexico bord...         ...
# 11    Cross Streets: H street and Paseo Del Rey.   N...         ...
# 12    Cross Streets: H street and Paseo Del Rey.   N...         ...
# 13    Cross Streets: H street and Paseo Del Rey.   N...         ...
# 14    Cross Streets: H street and Paseo Del Rey.   N...         ...
# 15    the neighborhood is a relaxed family friendly ...         ...
# 16    It is a new community, mostly with tranquil co...         ...
# 17                                                  NaN         ...
# 18    Centrally located,5minutes from the 805fwy,10 ...         ...
# 19                                                  NaN         ...
# 20    The location is in the new Eastlake developmen...         ...
# 21    We are located in the "South Bay" region of Sa...         ...
# 22    The Otay Ranch community is the newest premier...         ...
# 23                                                  NaN         ...
# 24                                                  NaN         ...
# 25    Quiet neighbors where you feel safe and enjoy ...         ...
# 26                                                  NaN         ...
# 27    The neighborhood has plenty of walking, hiking...         ...
# 28                                                  NaN         ...
# 29                                                  NaN         ...
# ...                                                 ...         ...
# 3970                  Our neighbors are nice and quiet.         ...
# 3971  Nice quiet neighborhood near hiking and biking...         ...
# 3972  This is very quiet neighborhood nearby center ...         ...
# 3973                                                NaN         ...
# 3974  Centrally located in Solana Beach, this neighb...         ...
# 3975  The apartment is quiet, clean, open concept an...         ...
# 3976                                                NaN         ...
# 3977                                                NaN         ...
# 3978                                                NaN         ...
# 3979  Enjoy the fresh ocean air walking on the beach...         ...
# 3980                                                NaN         ...
# 3981                                                NaN         ...
# 3982                                                NaN         ...
# 3983  The property is like a large private park, but...         ...
# 3984                                                NaN         ...
# 3985                                                NaN         ...
# 3986  Close to the Beach Close to Mexico Close to Sh...         ...
# 3987                                                NaN         ...
# 3988                                                NaN         ...
# 3989                                                NaN         ...
# 3990  Great location in desirable North Pacific Beac...         ...
# 3991                                                NaN         ...
# 3992                                    Gated community         ...
# 3993        Close to freeway and Solana Beach downtown.         ...
# 3994                                                NaN         ...
# 3995  Our house is located within walking distance o...         ...
# 3996           Beautifully landscaped master community.         ...
# 3997                                                NaN         ...
# 3998                                                NaN         ...
# 3999  Relaxing Solana beach, close to ocean and Del ...         ...
#
#      wke_max_price wke_min_price   wke_price wke_skew_of_price  \
# 0             49.0     49.000000   49.000000           1.89154
# 1             59.0     59.000000   59.000000           1.89154
# 2            120.0    120.000000  120.000000           1.89154
# 3             80.0     70.000000   75.000000           1.89154
# 4             80.0     70.000000   74.666667           1.89154
# 5             90.0     90.000000   90.000000           1.89154
# 6            150.0    150.000000  150.000000           1.89154
# 7             90.0     90.000000   90.000000           1.89154
# 8            110.0    110.000000  110.000000           1.89154
# 9            300.0    300.000000  300.000000           1.89154
# 10            95.0     45.000000   51.086957           1.89154
# 11            50.0     35.000000   41.388889           1.89154
# 12            60.0     45.000000   50.294118           1.89154
# 13            70.0     60.000000   65.000000           1.89154
# 14           500.0    450.000000  473.529412           1.89154
# 15           280.0    200.000000  235.714286           1.89154
# 16           450.0    265.000000  284.583333           1.89154
# 17           450.0    320.000000  343.000000           1.89154
# 18            65.0     45.000000   59.090909           1.89154
# 19            40.0     40.000000   40.000000           1.89154
# 20           155.0     75.000000   83.000000           1.89154
# 21            46.0     46.000000   46.000000           1.89154
# 22            66.0     48.000000   60.550000           1.89154
# 23            82.0     75.000000   75.269231           1.89154
# 24            40.0     40.000000   40.000000           1.89154
# 25            89.0     79.000000   83.800000           1.89154
# 26            45.0     45.000000   45.000000           1.89154
# 27            89.0     59.000000   61.500000           1.89154
