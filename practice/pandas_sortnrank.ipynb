# %% [markdown]
# More practice on sorting and ranking

# %%
import pandas as pd
import numpy as np

# %%
listings = pd.read_csv('listings.csv')

# %%
listings.set_index('id', inplace=True)

# %%
listings.head(3)
# Out:
#                                     listing_url       scrape_id last_scraped  \
# id
# 11204286  https://www.airbnb.com/rooms/11204286  20160706203047   2016-07-07
# 7972006    https://www.airbnb.com/rooms/7972006  20160706203047   2016-07-07
# 7727710    https://www.airbnb.com/rooms/7727710  20160706203047   2016-07-07
#
#                                          name  \
# id
# 11204286      Family friendly/California king
# 7972006               Welcome to Sunset Suite
# 7727710   San Diego/Eastlake. Gated community
#
#                                                     summary  \
# id
# 11204286  Aquatica Waterpark, Sleep train Amphitheater, ...
# 7972006   Your spacious room awaiting is with a Queen Si...
# 7727710   This is an immaculate 3 bedroom, 2 1/2 bath co...
#
#                                                       space  \
# id
# 11204286  Walking to Aquatica Waterpark, Sleep train Amp...
# 7972006                                                 NaN
# ...

# %%
listings.sort_index().head(3)
# Out:
#                             listing_url       scrape_id last_scraped  \
# id
# 6        https://www.airbnb.com/rooms/6  20160706203047   2016-07-07
# 5570  https://www.airbnb.com/rooms/5570  20160706203047   2016-07-07
# 9553  https://www.airbnb.com/rooms/9553  20160706203047   2016-07-07
#
#                                                    name  \
# id
# 6     Heart of North Park ~ Large Craftsmen Home w/ ...
# 5570                      Ocean front condo on the sand
# 9553                Private Master Suite (North Park 1)
#
#                                                 summary  \
# id
# 6     Our Beautiful Craftsmen house has all the mode...
# 5570  Missionbeachretreat.   Great Ocean Front Condo...
# 9553  Private master bedroom & attached bathroom in ...
#
#                                                   space  \
# id
# 6     We are located in the heart of North Park, the...
# 5570  This charming two bedroom beachfront condomini...
# ...

# %%
listings.sort_index(ascending=False).head(3)
# Out:
#                                     listing_url       scrape_id last_scraped  \
# id
# 13882933  https://www.airbnb.com/rooms/13882933  20160706203047   2016-07-07
# 13882606  https://www.airbnb.com/rooms/13882606  20160706203047   2016-07-07
# 13882335  https://www.airbnb.com/rooms/13882335  20160706203047   2016-07-07
#
#                                                        name  \
# id
# 13882933                  Cozy and Charming Private Studio.
# 13882606         Modern luxury Apartment downtown San Diego
# 13882335  Private room and shared bathroom in cute craft...
#
#                                                     summary  \
# id
# 13882933  This bright cozy Private Studio is perfect for...
# 13882606  My place is close to My place is located in th...
# 13882335  My place is close to Alexander's, Underbelly N...
#
#                                               space  \
# id
# 13882933  It's Private Studio with affordable price
# ...

# %%
#sorting on the columns:
listings.sort_index(axis=1).head()
# Out:
#                                                      access  accommodates  \
# id
# 11204286                                                NaN             2
# 7972006                                                 NaN             2
# 7727710                                                 NaN             6
# 13124681  Kitchen Washing machine and dryer Patio and ga...             4
# 3469225   Living Rm, Dining Rm, Kitchen, Laundry Rm, 2 p...             2
#
#                                                   amenities  availability_30  \
# id
# 11204286  {TV,"Wireless Internet",Heating,"Family/Kid Fr...               25
# 7972006   {Internet,"Wireless Internet","Air Conditionin...               20
# 7727710   {TV,"Cable TV","Wireless Internet","Air Condit...                0
# 13124681  {TV,"Cable TV",Internet,"Wireless Internet",Ki...                0
# 3469225   {TV,"Cable TV",Internet,"Wireless Internet",Po...                0
#
# ...

# %%
listings.sort_index(axis=1, ascending=False).head()
# Out:
#           zipcode                                     xl_picture_url  \
# id
# 11204286  92154.0  https://a2.muscache.com/im/pictures/12cf03b4-7...
# 7972006   91913.0  https://a2.muscache.com/im/pictures/106372476/...
# 7727710   91914.0  https://a1.muscache.com/im/pictures/98227073/7...
# 13124681  91915.0  https://a2.muscache.com/im/pictures/2092fc74-f...
# 3469225   91915.0  https://a1.muscache.com/im/pictures/43847899/7...
#
#          weekly_price                                            transit  \
# id
# 11204286          NaN                                                NaN
# 7972006           NaN  Getting around is easy. Very close to Eastlake...
# 7727710       $750.00                                                NaN
# 13124681          NaN                                                NaN
# 3469225       $500.00  Sorry, no buses within 1.5 mile; plenty of str...
#
#                                               thumbnail_url  \
# id
# ...

# %%
#sorting by values:
listings.index.sort_values()
# Out:
# Int64Index([       6,     5570,     9553,    14668,    37149,    38245,
#                39516,    45429,    54001,    62274,
#             ...
#             13881033, 13881298, 13881474, 13881744, 13881863, 13882013,
#             13882245, 13882335, 13882606, 13882933],
#            dtype='int64', name=u'id', length=6608)

# %%
listings.zipcode.sort_values().head()
# Out:
# id
# 10908984    22204.0
# 13131810    91901.0
# 13136539    91901.0
# 13137165    91901.0
# 13136775    91901.0
# Name: zipcode, dtype: float64

# %%
listings.zipcode.sort_values(ascending=False).head()
# Out:
# id
# 7004554     92173.0
# 5846098     92173.0
# 11825052    92173.0
# 7226946     92173.0
# 10973934    92173.0
# Name: zipcode, dtype: float64

# %%
listings.dtypes
# Out:
# listing_url                          object
# scrape_id                             int64
# last_scraped                         object
# name                                 object
# summary                              object
# space                                object
# description                          object
# experiences_offered                  object
# neighborhood_overview                object
# notes                                object
# transit                              object
# access                               object
# interaction                          object
# house_rules                          object
# thumbnail_url                        object
# medium_url                           object
# picture_url                          object
# xl_picture_url                       object
# host_id                               int64
# host_url                             object
# host_name                            object
# ...

# %%
#sorting on more than one column:
listings[['number_of_reviews', 
          'review_scores_rating', 
          'review_scores_accuracy']].sort_values(ascending=[False,True],
                                                by=['number_of_reviews',
                                                    'review_scores_rating']).head()
# Out:
#          number_of_reviews  review_scores_rating  review_scores_accuracy
# id
# 204718                 367                  93.0                     9.0
# 62274                  299                  96.0                    10.0
# 1083576                287                  97.0                     9.0
# 616718                 283                  92.0                     9.0
# 587443                 269                  91.0                     9.0

# %%
#the rank method returns an index that rearranges values relative to the series:
listings.number_of_reviews.rank()
# Out:
# id
# 11204286    4234.0
# 7972006     4234.0
# 7727710     2396.5
# 13124681    3339.5
# 3469225     1009.5
# 877473      5459.0
# 3124507     4380.0
# 3432507     2396.5
# 3249729     2979.5
# 11756336    2979.5
# 12173670    2396.5
# 13157364    1009.5
# 9756570     2979.5
# 10687910    4829.0
# 7938260     5423.5
# 10779932    4516.0
# 13301630    2979.5
# 5285136     3882.0
# 13313236    1009.5
# 7663518     4630.5
# 5077385     4912.0
# 7113838     2396.5
# 8555262     3629.5
# 13472856    1009.5
# 4997701     3629.5
# 6098460     4630.5
# 13562988    2979.5
# 10284248    1009.5
# 13693167    2396.5
# 12988363    2396.5
#              ...
# 13765978    1009.5
# 13637335    1009.5
# 7462953     1009.5
# 13816897    1009.5
# 181308      6506.5
# 12485414    1009.5
# 13710734    1009.5
# 13868104    1009.5
# 13526039    2396.5
# 13689250    1009.5
# 13495353    2396.5
# 10328997    4984.5
# 9710574     2396.5
# 13448725    1009.5
# 13864897    1009.5
# 13859950    1009.5
# ...

# %%
listings[['number_of_reviews']].rank(axis=1).head()
# Out:
#           number_of_reviews
# id
# 11204286                1.0
# 7972006                 1.0
# 7727710                 1.0
# 13124681                1.0
# 3469225                 1.0

# %%
#notice ties are handled by default by setting them to the lowest rank possible
pd.Series([1,1,1,4,5,6]).rank()
# Out:
# 0    2.0
# 1    2.0
# 2    2.0
# 3    4.0
# 4    5.0
# 5    6.0
# dtype: float64

# %%
#however you can pass the method argument to decide how to handle ties
pd.Series([1,1,1,4,5,6]).rank(method='min')
# Out:
# 0    1.0
# 1    1.0
# 2    1.0
# 3    4.0
# 4    5.0
# 5    6.0
# dtype: float64

# %%
#however you can pass the method argument to decide how to handle ties
pd.Series([1,1,1,4,5,6]).rank(method='first')
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.0
# 4    5.0
# 5    6.0
# dtype: float64

# %%
#notice we changed the series elements this time:
pd.Series([1,2,2,4,4,1,1]).rank(method='max')
# Out:
# 0    3.0
# 1    5.0
# 2    5.0
# 3    7.0
# 4    7.0
# 5    3.0
# 6    3.0
# dtype: float64

# %%
#Calling the DataFrame's rank method results in the ranks of all columns:
listings[['number_of_reviews', 
          'review_scores_rating', 
          'review_scores_accuracy']].rank(ascending=False).head()
# Out:
#           number_of_reviews  review_scores_rating  review_scores_accuracy
# id
# 11204286             2375.0                 703.5                  1591.5
# 7972006              2375.0                 703.5                  1591.5
# 7727710              4212.5                4259.5                  4253.0
# 13124681             3269.5                 703.5                  1591.5
# 3469225              5599.5                   NaN                     NaN
