# %% [markdown]
# ### Excercise 1: reconstruct a file from segments.

# %% [markdown]
# Each of the files F* is a short segment of the original text file.
#
# The format of the file is `(n1: 5 char int),(n2: 5 char int),string`
# The string represents the content of the file in the range `[n1:n2]`
#
# Your task is to reconstruct the original file.

# %%
# %cd ../data/NLTK/Chopped/
# !ls -F
# Out:
# [Errno 2] No such file or directory: '../data/NLTK/Chopped/'
# /Users/pauldefusco/Documents/DSE/pdefusco/DSE200/data/NLTK/Chopped
# F0            F140          F183          F227          F58
# F1            F141          F185          F228          F59
# F10           F142          F186          F229          F6
# F100          F144          F187          F23           F60
# F101          F145          F189          F230          F61
# F102          F146          F19           F231          F62
# F104          F147          F190          F232          F63
# F106          F148          F191          F233          F64
# F107          F149          F192          F24           F65
# F108          F15           F193          F25           F66
# F109          F151          F194          F26           F67
# F11           F152          F195          F27           F68
# F110          F153          F196          F28           F69
# F111          F154          F197          F29           F7
# F112          F155          F198          F3            F70
# F113          F156          F199          F30           F71
# F114          F157          F2            F31           F72
# F115          F158          F20           F32           F73
# F117          F159          F200          F33           F74
# F118          F16           F201          F34           F75
# F119          F160          F202          F35           F76
# F12           F161          F204          F36           F77
# F120          F162          F205          F37           F78
# F121          F163          F206          F38           F79
# F122          F164          F207          F39           F8
# F123          F165          F208          F4            F80
# F124          F166          F209          F40           F81
# F125          F167          F210          F41           F82
# F126          F168          F211          F42           F83
# F127          F169          F212          F43           F84
# F128          F170          F213          F44           F85
# F129          F171          F214          F45           F86
# F13           F172          F215          F46           F87
# F130          F173          F216          F48           F88
# F131          F174          F218          F49           F9
# F132          F175          F219          F5            F90
# F133          F176          F22           F50           F91
# F134          F177          F220          F51           F93
# F135          F178          F221          F52           F94
# F136          F179          F222          F53           F95
# F137          F18           F223          F54           F96
# F138          F180          F224          F55           F97
# F139          F181          F225          F56           F99
# F14           F182          F226          F57           subDirectory/

# %%
# !cat F11*
# Out:
#   183  191 term-en
#  1009 1011st
#   792  796f th
#   859  870egistration
#   736  737s
#   210  225 the City Execu
#   891  894 ar
#   592  595ayo
#   912  913e
#   965  982ulton legislators

# %%
# !cat F* 1>> file
#!cat newfile
# !cat file
# Out:
#   669  681 received ''
#   894  897e o
#   844  854 of Georgi
#   897  899ut
#   523  527le `
#  1268 1281ices which in
#   419  427r term j
#  1053 1069g and improving
#   178  180id
#   439  443 cha
#  1259 1266ted pra
#   183  191 term-en
#  1009 1011st
#   792  796f th
#   859  870egistration
#   736  737s
#   210  225 the City Execu
#   891  894 ar
#   592  595ayo
#   912  913e
#   965  982ulton legislators
#   935  954ous '' . It recomme
#   599  600m
#  1542 1545 ,
#  1254 1259accep
#    60   64 Atl
#  1250 1254lly
#   191  198d prese
#  1423 1427to a
#  1111 1115mber
#  1155 1156a
#   666  667w
#   198  199n
#  1504 1513 Purchasi
#  1591 1601l as a res
#   199  205tments
#  1617 1622onnel
#    88   99ection prod
#  1077 1085. The gr
#   681  682
#   624  626`
#   982 1006 act `` to have these la
#  1398 1423fices should be combined
#    58   60of
#   168  175further
#   764  771ber of
#   817  840 said it did find that
#  1461 1468ce the
#  1578 1589ical person
#  1096 1101mment
#  1493 1499 . The
#   771  780voters an
#  1069 1077them ''
#   569  577mary whi
#   377  384ction w
#  1156 1164 and Ful
#  1051 1053in
#  1247 1250era
#  1430 1431e
#  1164 1168ton
#   427  430ury
#   790  792 o
#  1115 1134 of other topics ,
#   913  921quate an
#    24   37Jury said Fri
#   682  690, the ju
#   954  965nded that F
#   277  290ection , `` d
#    18   24Grand
#   318  319s
#  1224 1228oper
#   225  241tive Committee ,
#   132  151rregularities took
#  1480 1493nistration ''
#  1302 1310est of b
#  1573 1578 cler
#   879  882tio
#  1376 1384lieves `
#  1134 1137amo
#   297  299 t
#  1320 1328ments ''
#   708  727dering the widespre
#   595  596r
#   804  812'' . The
#   110  117evidenc
#   452  453u
#  1352 1376er , the jury said it be
#     8   18on County
#   858  859r
#  1385 1386
#   470  474rt J
#  1524 1526nt
#   161  168e jury
#   385  416s conducted . The September-Oct
#  1239 1247llow gen
#  1206 1224 said `` are well
#   241  242
#   856  858s
#   854  856a'
#   591  592M
#   667  669as
#   175  178 sa
#  1601 1611ult of cit
#    64   83anta's recent prima
#   605  624 Ivan Allen Jr. . `
#   643  666andful of such reports
#     0    4The
#  1459 1460d
#   205  210 that
#  1624 1636olicies '' .
#  1310 1313oth
#  1228 1239ated and fo
#   812  817 jury
#   693  708said , `` consi
#   155  161e . Th
#   902  910ed or in
#    99  100u
#   299  305he pra
#  1085 1096and jury co
#   264  274rge of the
#  1479 1480i
#   527  547` irregularities ''
#   456  470n Superior Cou
#   417  419be
#  1532 1542 jury said
#  1313 1320 govern
#   549  566 the hard-fought
#  1567 1568i
#   840  843man
#   242  264which had over-all cha
#   870  879 and elec
#  1384 1385`
#  1386 1388th
#   737  751t in the elect
#  1589 1591ne
#  1188 1206partments which it
#   797  804s city
#   690  692ry
#   751  764ion , the num
#  1442 1451efficienc
#  1035 1051 end of moderniz
#   566  569pri
#   921  929d often
#   782  790the size
#  1342 1352osed Howev
#   910  912ad
#   596  599-no
#    83   88ry el
#  1012 1035died and revised to the
#    56   58n
#  1148 1155 Atlant
#   600  605inate
#  1499 1504 City
#  1472 1479 of adm
#   883  886 la
#  1471 1472t
#   305  318ise and thank
#  1427 1430chi
#   123  132hat any i
#  1460 1461u
#   727  736ad intere
#  1622 1624 p
#    37   56day an investigatio
#  1564 1567per
#   882  883n
#   577  580ch
#  1611 1617y pers
#  1011 1012u
#  1146 1148he
#  1468 1471cos
#  1388 1398ese two of
#   319  377 of the City of Atlanta '' for the manner in which the ele
#   929  931am
#   509  512ort
#  1526 1532 , the
#   512  514s
#   886  891ws ``
#   180  181
#   495  496n
#  1545 1564`` is lacking in ex
#   626  643Only a relative h
#   692  693
#  1142 1146em t
#   181  183in
#  1431 1442ve greater
#  1568 1573enced
#   384  385a
#   151  155plac
#  1137 1142ng th
#  1513 1524ng Departme
#  1328 1342 . Merger prop
#   117  123e '' t
#   780  782d
#  1266 1268ct
#   580  588was won
#   496  503vestiga
#  1006 1009ws
#   100  110ced `` no
#  1168 1188County purchasing de
#  1101 1111ed on a nu
#   416  417o
#   474  495udge Durwood Pye to i
#   899  902mod
#     4    8Fult
#   547  549in
#   796  797i
#   514  523of possib
#  1281 1294ure to the be
#  1451 1459y and re
#  1294 1302st inter
#   843  844y
#   931  935bigu
#   290  297eserves
#   588  591by
#   274  277 el
#   430  439 had been
#   453  456lto
#   503  509te rep
#   443  452rged by F

# %% [markdown]
# ### Excercise 2:

# %%
# !rm Caesar
# !ls Caesar
# Out:
# rm: Caesar: No such file or directory
# ls: Caesar: No such file or directory

# %%
# !echo """Caesar, a great general, is petitioned by several citizens to show clemency to one of his enemies. He declines, pompously speaking of himself in the third person. The group of conspirators then proceeds to stab him. With his dying breath he gasps, \"Et tu, Brute? \"And you, Brutus?\" Thus falls Caesar.\" The conspirators exult, and Shakespeare inserts a self-referential joke as Cassius says, \"How many ages hence shall this our lofty scene be acted over in states unborn and accents yet unknown!\" """ 1>> Caesar

# %%
# !ls -l Caesar
# !chmod 666 Caesar
# Out:
# -rw-r--r--  1 pauldefusco  staff  497 Oct 13 17:47 Caesar

# %%
# !file Caesar
# Out:
# Caesar: ASCII text, with very long lines

# %%
#!cat Caesar
# !grep -v [aeiou] Caesar | wc -w
# Out:
#        0

# %%
# !sed -i.bak 's/Caesar/Leonidas/g' Caesar 
#!cat Caesar | sed -e 's/Caesar/Leonidas' 1>> Caesar
# !cat Caesar
# Out:
# Leonidas, a great general, is petitioned by several citizens to show clemency to one of his enemies. He declines, pompously speaking of himself in the third person. The group of conspirators then proceeds to stab him. With his dying breath he gasps, "Et tu, Brute? "And you, Brutus?" Thus falls Leonidas." The conspirators exult, and Shakespeare inserts a self-referential joke as Cassius says, "How many ages hence shall this our lofty scene be acted over in states unborn and accents yet unknown!"

# %%
# !cat Caesar
# !rm Leonidas
# !touch Leonidas
# !ls -l Leonidas
# !cp Caesar Leonidas
#!sed '1d' Leonidas | sed '$d' #>> Leonidas
#!sed -i.bak '1d;$d' Leonidas
#!sed -e '2,$!d' -e '$d' Leonidas
#!sed -i.bak '1d;$d' Leonidas >> Leonidas
# !cat Leonidas
#!cut Caesar | head -1 Caesar >> Leonidas
#!| tail -1 Caesar > Leonidas
#!head -n +2 Caesar | tail -n +2 >> Leonidas
#!cat Leonidas
#!awk 'FNR <= 3' Caesar >> Leonidas
#!cat Leonidas
# Out:
# Leonidas, a great general, is petitioned by several citizens to show clemency to one of his enemies. He declines, pompously speaking of himself in the third person. The group of conspirators then proceeds to stab him. With his dying breath he gasps, "Et tu, Brute? "And you, Brutus?" Thus falls Leonidas." The conspirators exult, and Shakespeare inserts a self-referential joke as Cassius says, "How many ages hence shall this our lofty scene be acted over in states unborn and accents yet unknown!"
# rm: Leonidas: No such file or directory
# -rw-r--r--  1 pauldefusco  staff  0 Oct 13 17:47 Leonidas
# Leonidas, a great general, is petitioned by several citizens to show clemency to one of his enemies. He declines, pompously speaking of himself in the third person. The group of conspirators then proceeds to stab him. With his dying breath he gasps, "Et tu, Brute? "And you, Brutus?" Thus falls Leonidas." The conspirators exult, and Shakespeare inserts a self-referential joke as Cassius says, "How many ages hence shall this our lofty scene be acted over in states unborn and accents yet unknown!"

# %%
#Issue a UNIX command to create a file called Caesar that contains the following lines (include the mistakes!!)

Text = """Caesar, a great general, is petitioned by several citizens to show clemency to one of his enemies.
He declines, pompously speaking of himself in the third person. The group of conspirators then proceeds to stab him.
With his dying breath he gasps, "Et tu, Brute? ("And you, Brutus?") Thus falls Caesar." 
The conspirators exult, and Shakespeare inserts a self-referential joke as Cassius says, 
"How many ages hence shall this our lofty scene be acted over in states unborn and accents yet unknown!"
"""

#Change the permissions of this file to 666
#Issue a UNIX command to determine the file type
#Isue a uniix comannd to count the number of words in the above text that contains no vowels
#Replace the word Caesar wherever it is found in the entire text to Leonidas
#Make a copy of the above file without the first and last lines of the text and rename this file to Leonidas

# %% [markdown]
# ### Excercise 3:

# %%
#What is the command to count lines,words and characters in a file and how do you make this comand display only linecount?
#Also write a single command that lists the files in the current directory that begin with upper case letters

#The command applied to file Caesar
# !wc < Caesar

#The same but displaying only line count
# !wc -l < Caesar

#Listing files in directory beginning with upper case letters:
# !find . -type f -name "[[:upper:]]*"
# Out:
#        1      82     501
#        1
# ./Caesar
# ./Caesar.bak
# ./F0
# ./F1
# ./F10
# ./F100
# ./F101
# ./F102
# ./F104
# ./F106
# ./F107
# ./F108
# ./F109
# ./F11
# ./F110
# ./F111
# ./F112
# ./F113
# ./F114
# ./F115
# ./F117
# ./F118
# ./F119
# ./F12
# ./F120
# ./F121
# ./F122
# ./F123
# ./F124
# ./F125
# ./F126
# ./F127
# ./F128
# ./F129
# ./F13
# ./F130
# ./F131
# ./F132
# ./F133
# ./F134
# ./F135
# ./F136
# ./F137
# ./F138
# ./F139
# ./F14
# ./F140
# ./F141
# ./F142
# ./F144
# ./F145
# ./F146
# ./F147
# ./F148
# ./F149
# ./F15
# ./F151
# ./F152
# ./F153
# ./F154
# ./F155
# ./F156
# ./F157
# ./F158
# ./F159
# ./F16
# ./F160
# ./F161
# ./F162
# ./F163
# ./F164
# ./F165
# ./F166
# ./F167
# ./F168
# ./F169
# ./F170
# ./F171
# ./F172
# ./F173
# ./F174
# ./F175
# ./F176
# ./F177
# ./F178
# ./F179
# ./F18
# ./F180
# ./F181
# ./F182
# ./F183
# ./F185
# ./F186
# ./F187
# ./F189
# ./F19
# ./F190
# ./F191
# ./F192
# ./F193
# ./F194
# ./F195
# ./F196
# ./F197
# ./F198
# ./F199
# ./F2
# ./F20
# ./F200
# ./F201
# ./F202
# ./F204
# ./F205
# ./F206
# ./F207
# ./F208
# ./F209
# ./F210
# ./F211
# ./F212
# ./F213
# ./F214
# ./F215
# ./F216
# ./F218
# ./F219
# ./F22
# ./F220
# ./F221
# ./F222
# ./F223
# ./F224
# ./F225
# ./F226
# ./F227
# ./F228
# ./F229
# ./F23
# ./F230
# ./F231
# ./F232
# ./F233
# ./F24
# ./F25
# ./F26
# ./F27
# ./F28
# ./F29
# ./F3
# ./F30
# ./F31
# ./F32
# ./F33
# ./F34
# ./F35
# ./F36
# ./F37
# ./F38
# ./F39
# ./F4
# ./F40
# ./F41
# ./F42
# ./F43
# ./F44
# ./F45
# ./F46
# ./F48
# ./F49
# ./F5
# ./F50
# ./F51
# ./F52
# ./F53
# ./F54
# ./subDirectory/F20
# ./subDirectory/F200
# ./subDirectory/F201
# ./subDirectory/F202
# ./subDirectory/F204
# ./subDirectory/F205
# ./subDirectory/F206
# ./subDirectory/F207
# ./subDirectory/F208
# ./subDirectory/F209
# ./subDirectory/F210
# ./subDirectory/F211
# ./subDirectory/F212
# ./subDirectory/F213
# ./subDirectory/F214
# ./subDirectory/F215
# ./subDirectory/F216
# ./subDirectory/F218
# ./subDirectory/F219
# ./subDirectory/F22
# ./subDirectory/F220
# ./subDirectory/F221
# ./subDirectory/F222
# ./subDirectory/F223
# ./subDirectory/F224
# ./subDirectory/F225
# ./subDirectory/F226
# ./subDirectory/F227
# ./subDirectory/F228
# ./subDirectory/F229
# ./subDirectory/F23
# ./subDirectory/F230
# ./subDirectory/F231
# ./subDirectory/F232
# ./subDirectory/F233
# ./subDirectory/F24
# ./subDirectory/F25
# ./subDirectory/F26
# ./subDirectory/F27
# ./subDirectory/F28
# ./subDirectory/F29
# ./subDirectory/F3
# ./subDirectory/F30
# ./subDirectory/F31
# ./subDirectory/F32
# ./subDirectory/F33
# ./subDirectory/F34
# ./subDirectory/F35
# ./subDirectory/F36
# ./subDirectory/F37
# ./subDirectory/F38
# ./subDirectory/F39
# ./subDirectory/F4
# ./subDirectory/F40
# ./subDirectory/F41
# ./subDirectory/F42
# ./subDirectory/F43
# ./subDirectory/F44
# ./subDirectory/F45
# ./subDirectory/F46
# ./subDirectory/F48
# ./subDirectory/F49
# ./subDirectory/F5
# ./subDirectory/F50
# ./subDirectory/F51
# ./subDirectory/F52
# ./subDirectory/F53
# ./subDirectory/F54
# ./subDirectory/F55
# ./subDirectory/F56
# ./subDirectory/F57
# ./subDirectory/F58
# ./subDirectory/F59
# ./subDirectory/F6
# ./subDirectory/F60
# ./subDirectory/F61
# ./subDirectory/F62
# ./subDirectory/F63
# ./subDirectory/F64
# ./subDirectory/F65
# ./subDirectory/F66
# ./subDirectory/F67
# ./subDirectory/F68
# ./subDirectory/F69
# ./subDirectory/F7
# ./subDirectory/F70
# ./subDirectory/F71
# ./subDirectory/F72
# ./subDirectory/F73
# ./subDirectory/F74
# ./subDirectory/F75
# ./subDirectory/F76
# ./subDirectory/F77
# ./subDirectory/F78
# ./subDirectory/F79
# ./subDirectory/F8
# ./subDirectory/F80
# ./subDirectory/F81
# ./subDirectory/F82
# ./subDirectory/F83
# ./subDirectory/F84
# ./subDirectory/F85
# ./subDirectory/F86
# ./subDirectory/F87
# ./subDirectory/F88
# ./subDirectory/F9
# ./subDirectory/F90
# ./subDirectory/F91
# ./subDirectory/F93
# ./subDirectory/F94
# ./subDirectory/F95
# ./subDirectory/F96
# ./subDirectory/F97
# ./subDirectory/F99
# ./subDirectory/Leonidas

# %% [markdown]
# ### Excercise 4:

# %%
#Combine the files Caesar and Leonidas and save the combined file as kings
#!rm kings
# !touch kings
# !cat Caesar Leonidas > kings

#Display the contents of this file using more command
# !more kings

#Sort this file in reverse alphabetic order and display it by piping it into more
# !more kings | tr ' ' '\n' | tr -d '[:punct:]' | sort -r
# Out:
# cents yet unknown!"
# cents yet unknown!"
# >you
# you
# yet
# yet
# unknown
# unknown
# unborn
# unborn
# tu
# tu
# to
# to
# to
# to
# to
# to
# this
# this
# third
# third
# then
# then
# the
# the
# states
# states
# stab
# stab
# speaking
# speaking
# show
# show
# shall
# shall
# several
# several
# selfreferential
# selfreferential
# scene
# scene
# says
# says
# proceeds
# proceeds
# pompously
# pompously
# petitioned
# petitioned
# person
# person
# over
# over
# our
# our
# one
# one
# of
# of
# of
# of
# of
# of
# many
# many
# lofty
# lofty
# joke
# joke
# is
# is
# inserts
# inserts
# in
# in
# in
# in
# his
# his
# his
# his
# himself
# himself
# him
# him
# hence
# hence
# he
# he
# group
# group
# great
# great
# general
# general
# gasps
# gasps
# falls
# falls
# exult
# exult
# enemies
# enemies
# dying
# dying
# declines
# declines
# conspirators
# conspirators
# conspirators
# conspirators
# clemency
# clemency
# citizens
# citizens
# by
# by
# breath
# breath
# be
# be
# as
# as
# and
# and
# and
# and
# ages
# ages
# acted
# acted
# accents
# accents
# a
# a
# a
# a
# With
# With
# Thus
# Thus
# The
# The
# The
# The
# Shakespeare
# Shakespeare
# Leonidas
# Leonidas
# Leonidas
# Leonidas
# How
# How
# He
# He
# Et
# Et
# Cassius
# Cassius
# Brutus
# Brutus
# Brute
# Brute
# And
# And

# %% [markdown]
# ### Excercise 5:

# %%
#List all files in your current directory. Make a subDirectory and copy all these files in the subdirectory.
#!rm -rf subDirectory
#!mkdir subDirectory
#!cp `ls -1` subDirectory 
#!ls subDirectory

#Write Unix commands to rename all the files to the format - currentDate_originalname
# !date >> thedate
# !rm filelist
# !ls >> filelist
# !cat filelist | sed "s/^/$(date)_/g"
# Out:
# Thu Oct 13 22:10:25 PDT 2016_Caesar
# Thu Oct 13 22:10:25 PDT 2016_Caesar.bak
# Thu Oct 13 22:10:25 PDT 2016_F0
# Thu Oct 13 22:10:25 PDT 2016_F1
# Thu Oct 13 22:10:25 PDT 2016_F10
# Thu Oct 13 22:10:25 PDT 2016_F100
# Thu Oct 13 22:10:25 PDT 2016_F101
# Thu Oct 13 22:10:25 PDT 2016_F102
# Thu Oct 13 22:10:25 PDT 2016_F104
# Thu Oct 13 22:10:25 PDT 2016_F106
# Thu Oct 13 22:10:25 PDT 2016_F107
# Thu Oct 13 22:10:25 PDT 2016_F108
# Thu Oct 13 22:10:25 PDT 2016_F109
# Thu Oct 13 22:10:25 PDT 2016_F11
# Thu Oct 13 22:10:25 PDT 2016_F110
# Thu Oct 13 22:10:25 PDT 2016_F111
# Thu Oct 13 22:10:25 PDT 2016_F112
# Thu Oct 13 22:10:25 PDT 2016_F113
# Thu Oct 13 22:10:25 PDT 2016_F114
# Thu Oct 13 22:10:25 PDT 2016_F115
# Thu Oct 13 22:10:25 PDT 2016_F117
# Thu Oct 13 22:10:25 PDT 2016_F118
# Thu Oct 13 22:10:25 PDT 2016_F119
# Thu Oct 13 22:10:25 PDT 2016_F12
# Thu Oct 13 22:10:25 PDT 2016_F120
# Thu Oct 13 22:10:25 PDT 2016_F121
# Thu Oct 13 22:10:25 PDT 2016_F122
# Thu Oct 13 22:10:25 PDT 2016_F123
# Thu Oct 13 22:10:25 PDT 2016_F87
# Thu Oct 13 22:10:25 PDT 2016_F88
# Thu Oct 13 22:10:25 PDT 2016_F9
# Thu Oct 13 22:10:25 PDT 2016_F90
# Thu Oct 13 22:10:25 PDT 2016_F91
# Thu Oct 13 22:10:25 PDT 2016_F93
# Thu Oct 13 22:10:25 PDT 2016_F94
# Thu Oct 13 22:10:25 PDT 2016_F95
# Thu Oct 13 22:10:25 PDT 2016_F96
# Thu Oct 13 22:10:25 PDT 2016_F97
# Thu Oct 13 22:10:25 PDT 2016_F99
# Thu Oct 13 22:10:25 PDT 2016_Leonidas
# Thu Oct 13 22:10:25 PDT 2016_file
# Thu Oct 13 22:10:25 PDT 2016_filelist
# Thu Oct 13 22:10:25 PDT 2016_final
# Thu Oct 13 22:10:25 PDT 2016_kings
# Thu Oct 13 22:10:25 PDT 2016_newlist.bak
# Thu Oct 13 22:10:25 PDT 2016_output
# Thu Oct 13 22:10:25 PDT 2016_subDirectory
# Thu Oct 13 22:10:25 PDT 2016_thedate
# Thu Oct 13 22:10:25 PDT 2016_thedate1
# Thu Oct 13 22:10:25 PDT 2016_theoutput

# %% [markdown]
# ### Excercise 6:

# %%
#Suppose we have a script that performs numerous efficiency tests. 
#The output from the script contains lots of information, but our purpose now is to extract information
#about the CPU time of each test and sort these CPU times. The output from the tests takes the following form:
output = """
f95 -c -O0  versions/main_wIO.f F77WAVE.f
f95 -o app  -static main_wIO.o F77WAVE.o   -lf2c
app < input > tmp.out
CPU-time: 255.97   f95 -O0 formatted I/O
f95 -c -O1  versions/main_wIO.f F77WAVE.f
f95 -o app  -static main_wIO.o F77WAVE.o   -lf2c
app < input > tmp.out
CPU-time: 252.47   f95 -O1 formatted I/O
f95 -c -O2  versions/main_wIO.f F77WAVE.f
f95 -o app  -static main_wIO.o F77WAVE.o   -lf2c
app < input > tmp.out
CPU-time: 252.40   f95 -O2 formatted I/O
f95 -c -O3  versions/main_wIO.f F77WAVE.f
f95 -o app  -static main_wIO.o F77WAVE.o   -lf2c
app < input > tmp.out
CPU-time: 255.28   f95 -O0 formatted I/O
f95 -c -O4  versions/main_wIO.f F77WAVE.f
f95 -o app  -static main_wIO.o F77WAVE.o   -lf2c
app < input > tmp.out
CPU-time: 251.43  f95 -O0 formatted I/O
f95 -c -O5  versions/main_wIO.f F77WAVE.f
f95 -o app  -static main_wIO.o F77WAVE.o   -lf2c
app < input > tmp.out
CPU-time: 255.90   f95 -O0 formatted I/O
f95 -c -O6  versions/main_wIO.f F77WAVE.f
f95 -o app  -static main_wIO.o F77WAVE.o   -lf2c
app < input > tmp.out
CPU-time: 252.15   f95 -O0 formatted I/O
"""

#First we need to extract the lines starting with CPU-time. 
#Then we need to sort the extracted lines with respect to the CPU time, which is the number appearing in the second column. 
#Write a script to accomplish this task. 

#First I manually created file 'output' in vi from terminal.
#Grepping for the desired pattern
# !rm theoutput
# !grep -o 'CPU-time: [0-9][0-9][0-9].[0-9][0-9]' output >> theoutput
# !cat theoutput | sort -r

#Hint: Find the lines with CPU time results by using a string comparison of the first 7 characters 
#to detect the keyword CPU-time. Then write a tailored sort function for sorting two lines 
#(extract the CPU time from the second column in both lines and compare the CPU times as floating-point numbers). 
#A tailored sort function takes two arguments a and b, which hold two list elements. 
#The sort function returns -1 if a is less than b, 1 if a is greater than b, and 0 otherwise (a equals b).
# Out:
# CPU-time: 255.97
# CPU-time: 255.90
# CPU-time: 255.28
# CPU-time: 252.47
# CPU-time: 252.40
# CPU-time: 252.15
# CPU-time: 251.43

# %% [markdown]
# ### Excercise 7:

# %%
#Make a copy of your working directory along with its subdirectories and 
#write unix+python commands that traverses the copied working directory and its subdirectories (recursively) and returns a 
#list of all files that are larger than X Mb and that have not been accessed the last Y days, 
#where X and Y are passed as user inputs.
#Include an option in this function that moves the files to a subdirectory trash under /tmp 
#(you need to create trash if it does not exist).
