# %% [markdown]
# ### Feature Engineering and Selection:

# %% [markdown]
# - Objective: engineer new features and analyze their importance
# - Method: first use Univariate tests to discard poor features (important when dealing with many features)
#     Then, use recursive feature elimination and feature importances to get a feeling for ranking among features left

# %% [markdown]
# Dilemma: should we tune a model before feeding it to RFECV? Answer: first loosely tune models and then use regularized decision trees for a potentially more rigorouse answer:
#             https://arxiv.org/pdf/1201.1587.pdf

# %%
# %load_ext autoreload

# %autoreload 2

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
from scipy.io import arff
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl
import os

# %%
from sklearn.model_selection import train_test_split, StratifiedKFold, GridSearchCV, cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn import preprocessing
from sklearn.pipeline import make_pipeline
from sklearn.metrics import confusion_matrix, precision_score, recall_score, average_precision_score
from sklearn.metrics import accuracy_score, roc_curve, roc_auc_score, precision_recall_curve
from sklearn.metrics import classification_report
from sklearn.utils.fixes import signature
pd.options.display.float_format = '{:.2f}'.format
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %%
os.listdir('../data/pickle_files/')
# Out:
# ['final_df_pickle',
#  'df_pickle_w_all_stats',
#  'df_pickle',
#  'new_df_y_pickle',
#  'new_df_pdays_pickle',
#  'new_df_camp_pickle',
#  'df_pickle_w_time_stats',
#  'new_df_prev_pickle']

# %%
#Loading final df from feature engineering notebook
final_df = pd.read_pickle('../data/pickle_files/final_df_pickle')
final_df = final_df.drop(columns = ['Date'])

# %%
def prep_df(df):
    y = df['y']
    X = df.drop(df.filter(regex='y').columns, axis=1)
    X = X.drop(columns='duration')
    #Dropping features based on y
    X = X.drop(X.filter(regex="cust_acquisition_flag").columns, axis=1) 
    X = X.drop(X.filter(regex="cust_retention_flag").columns, axis=1)
    X = X.drop(X.filter(regex="prospect_conversion_flag").columns, axis=1)
    #Dropping linearly dependent features
    X = X.drop(columns = ['new_lead'])
    names = list(X.columns)
    return X, y, names

# %%
#loading df
X, y, names = prep_df(final_df)

# %% [markdown]
# Feature Importance:

# %% [markdown]
# Starting with an exploration of the most important features with univariate methods and RFE (with CV)

# %% [markdown]
# Univariate Feature Selection

# %%
from sklearn.feature_selection import SelectKBest, f_classif, mutual_info_classif

# %%
def kbest(X,y, score_func, k):
    #Use f_classif or mutual_info_classif as scoring function
    test = SelectKBest(score_func=score_func, k=k)
    fit = test.fit(X, y)
    # summarize scores
    np.set_printoptions(precision=3)
    return sorted(list(zip(names,list(fit.scores_))), key=lambda tup:tup[1], reverse=True)

# %%
best_cols = kbest(X,y, f_classif, 'all')

# %%
best_cols
# Out:
# [('prev_subscr_flag-rolling-sum-60', 6770.790199636067),
#  ('prev_subscr_flag-rolling-avg-60', 6770.790199635986),
#  ('Household credit', 6423.957630542542),
#  ('Mortgage credit', 6259.710075255824),
#  ('prev_subscr_flag-rolling-sum-30', 6233.646879118396),
#  ('prev_subscr_flag-rolling-avg-30', 6233.646879118375),
#  ('Foreign exchange reserves', 6127.619935911332),
#  ('Government debt', 5893.926455086986),
#  ('Minimum wage', 5709.937349795137),
#  ('previous-rolling-sum-60', 5523.056883194985),
#  ('previous-rolling-avg-60', 5523.056883194942),
#  ('previous-rolling-sum-30', 5239.079764761115),
#  ('previous-rolling-avg-30', 5239.079764761028),
#  ('Private sector credit', 5171.645855551422),
#  ('prev_subscr_flag-rolling-sum-10', 5049.758626397523),
#  ('prev_subscr_flag-rolling-avg-10', 5049.75862639751),
#  ('Labor cost', 4670.487138412593),
#  ('prev_subscr_flag', 4577.560711884804),
#  ('Business credit interest rate', 4556.632400328948),
#  ('previous-rolling-avg-10', 4453.8642713621175),
#  ('previous-rolling-sum-10', 4453.864271362108),
#  ('Deposit interest rate', 4432.398191653248),
#  ('Consumer credit', 4375.106973760946),
#  ('Investment as percent of GDP', 4361.241416793941),
#  ('euribor3m', 4309.479048109171),
#  ('Mortgage credit interest rate', 4115.273907037838),
#  ('emp.var.rate', 4023.829925487281),
#  ('Investment', 3577.29704945438),
#  ('Business credit', 3565.6933778955704),
#  ('Government expenditure', 3306.875885293535),
#  ('financial_past-rolling-avg-90', 3111.5411735279044),
#  ('financial_past-rolling-avg-45', 3104.4270232457984),
#  ('financial_past', 3102.0897885964437),
#  ('previous-job-default-contact-age_bin-categorical', 2308.702795880296),
#  ('previous', 2304.2570879417895),
#  ('previous-job-default-housing-contact-age_bin-categorical',
#   2274.328497273878),
#  ('previous-job-marital-default-contact-age_bin-categorical',
#   2271.645637015665),
#  ('previous-job-default-loan-contact-age_bin-categorical', 2243.079102401641),
#  ('previous-job-default-housing-loan-contact-age_bin-categorical',
#   2222.786151447461),
#  ('previous-job-marital-default-housing-contact-age_bin-categorical',
#   2212.1278852976543),
#  ('previous-job-education-default-contact-age_bin-categorical',
#   2196.653068397317),
#  ('previous-job-marital-default-loan-contact-age_bin-categorical',
#   2145.6694862407),
#  ('previous-job-marital-education-default-contact-age_bin-categorical',
#   2140.6257245552615),
#  ('previous-job-education-default-contact-categorical', 2106.1522195498237),
#  ('previous-job-marital-education-default-contact-categorical',
#   2097.643262946015),
#  ('previous-job-marital-default-housing-loan-contact-age_bin-categorical',
#   2097.331868079323),
#  ('previous-job-marital-default-contact-categorical', 2044.5344551158576),
#  ('previous-job-education-default-loan-contact-age_bin-categorical',
#   2037.8592109793249),
#  ('previous-marital-default-contact-age_bin-categorical', 2037.54172996971),
#  ('previous-job-marital-default-loan-contact-categorical', 2025.4011265989304),
#  ('previous-marital-default-loan-contact-age_bin-categorical',
#   2014.748925667673),
#  ('previous-job-marital-default-housing-contact-categorical',
#   2014.347340154758),
#  ('previous-marital-default-housing-contact-age_bin-categorical',
#   2013.5152071094842),
#  ('previous-job-default-housing-loan-contact-categorical', 2009.8220336654551),
#  ('previous-job-education-default-housing-contact-age_bin-categorical',
#   2009.1837083416722),
#  ('previous-job-education-default-loan-contact-categorical',
#   2008.955507509247),
#  ('previous-marital-education-default-contact-age_bin-categorical',
#   2008.229391496512),
#  ('previous-job-default-loan-contact-categorical', 2005.852571086967),
#  ('previous-job-default-contact-categorical', 2005.3611911879386),
#  ('previous-job-default-housing-contact-categorical', 2003.914086459871),
#  ('previous-job-marital-default-housing-loan-contact-categorical',
#   2000.7782476457903),
#  ('previous-job-marital-contact-age_bin-categorical', 1988.3411082367218),
#  ('previous-job-contact-age_bin-categorical', 1984.8021232190222),
#  ('previous-job-housing-contact-age_bin-categorical', 1973.1124587526986),
#  ('previous-job-marital-education-default-loan-contact-categorical',
#   1970.1728020605613),
#  ('previous-education-default-contact-age_bin-categorical',
#   1956.4991566725116),
#  ('previous-marital-default-housing-loan-contact-age_bin-categorical',
#   1956.3128672290698),
#  ('previous-job-education-default-housing-contact-categorical',
#   1952.1944389531102),
#  ('previous-job-education-contact-age_bin-categorical', 1949.5794675178713),
#  ('previous-default-contact-age_bin-categorical', 1940.263444895266),
#  ('previous-job-housing-loan-contact-age_bin-categorical', 1940.1125739289484),
#  ('previous-job-loan-contact-age_bin-categorical', 1940.0529273609561),
#  ('previous-default-housing-contact-age_bin-categorical', 1938.752227657929),
#  ('previous-job-education-default-housing-loan-contact-categorical',
#   1935.4015252989184),
#  ('previous-default-loan-contact-age_bin-categorical', 1933.8819658731559),
#  ('previous-job-marital-housing-contact-age_bin-categorical',
#   1933.8011017429824),
#  ('previous-job-marital-education-default-loan-contact-age_bin-categorical',
#   1927.0696071442746),
#  ('previous-education-default-housing-contact-age_bin-categorical',
#   1926.7221687729655),
#  ('previous-job-education-default-housing-loan-contact-age_bin-categorical',
#   1923.6705387078118),
#  ('previous-marital-education-default-loan-contact-age_bin-categorical',
#   1919.8056910453442),
#  ('previous-job-marital-education-default-housing-contact-age_bin-categorical',
#   1917.8492806622935),
#  ('previous-default-housing-loan-contact-age_bin-categorical',
#   1917.597008308569),
#  ('previous-education-default-loan-contact-age_bin-categorical',
#   1917.2561232931153),
#  ('previous-job-marital-education-contact-age_bin-categorical',
#   1907.208254372709),
#  ('previous-marital-education-default-housing-contact-age_bin-categorical',
#   1904.5081467981126),
#  ('previous-job-marital-loan-contact-age_bin-categorical', 1889.6092456492418),
#  ('Budget balance', 1885.3246976005948),
#  ('previous-job-marital-education-default-housing-contact-categorical',
#   1878.0044156842766),
#  ('previous-education-default-housing-loan-contact-age_bin-categorical',
#   1860.2859181811232),
#  ('previous-job-marital-housing-loan-contact-age_bin-categorical',
#   1844.8515895836244),
#  ('previous-job-education-loan-contact-age_bin-categorical',
#   1826.5601006760692),
#  ('previous-job-marital-education-default-housing-loan-contact-categorical',
#   1813.944555857163),
#  ('previous-job-marital-education-contact-categorical', 1810.6007099393773),
#  ('previous-job-education-housing-contact-age_bin-categorical',
#   1788.6708268446034),
#  ('previous-marital-education-default-housing-loan-contact-age_bin-categorical',
#   1777.9590181901265),
#  ('previous-job-default-age_bin-categorical', 1774.387864937048),
#  ('Inflation annual', 1761.3332262114002),
#  ('previous-job-education-contact-categorical', 1752.5832246686614),
#  ('previous-job-marital-default-age_bin-categorical', 1743.4778784738735),
#  ('previous-job-marital-education-loan-contact-age_bin-categorical',
#   1735.8865531896017),
#  ('previous-job-default-housing-age_bin-categorical', 1721.8436028489807),
#  ('previous-job-education-housing-loan-contact-age_bin-categorical',
#   1719.1634552003397),
#  ('previous-marital-education-contact-age_bin-categorical',
#   1718.1197410251636),
#  ('previous-job-marital-housing-loan-contact-categorical', 1716.6388474785751),
#  ('previous-job-marital-loan-contact-categorical', 1714.2803601964442),
#  ('previous-job-marital-contact-categorical', 1709.824887951452),
#  ('Consumption as percent of GDP', 1708.3223130038814),
#  ('previous-job-marital-education-loan-contact-categorical',
#   1708.173910081222),
#  ('previous-job-marital-housing-contact-categorical', 1701.9076407725256),
#  ('previous-job-marital-education-housing-contact-age_bin-categorical',
#   1694.7103166082743),
#  ('previous-marital-education-loan-contact-age_bin-categorical',
#   1685.7601729362077),
#  ('previous-job-default-loan-age_bin-categorical', 1682.6101670770686),
#  ('previous-job-education-default-age_bin-categorical', 1681.199235800254),
#  ('previous-marital-contact-age_bin-categorical', 1674.7729520842406),
#  ('previous-job-education-loan-contact-categorical', 1674.6132161442379),
#  ('previous-job-housing-loan-contact-categorical', 1663.537936330383),
#  ('previous-marital-loan-contact-age_bin-categorical', 1662.292877759697),
#  ('previous-job-loan-contact-categorical', 1659.7128866689868),
#  ('previous-marital-housing-contact-age_bin-categorical', 1651.768518280578),
#  ('previous-job-contact-categorical', 1651.1655476486123),
#  ('previous-job-housing-contact-categorical', 1647.9884018947791),
#  ('previous-education-contact-age_bin-categorical', 1642.3154345216292),
#  ('previous-education-loan-contact-age_bin-categorical', 1638.7547335019374),
#  ('previous-job-default-housing-loan-age_bin-categorical', 1637.5600732969992),
#  ('previous-job-education-housing-contact-categorical', 1636.3294813354798),
#  ('previous-marital-education-housing-contact-age_bin-categorical',
#   1627.3481712423556),
#  ('previous-job-marital-education-default-age_bin-categorical',
#   1620.5063649326428),
#  ('previous-job-marital-education-housing-contact-categorical',
#   1620.0036746630487),
#  ('previous-education-housing-contact-age_bin-categorical',
#   1617.5978689646408),
#  ('previous-job-education-housing-loan-contact-categorical',
#   1617.5314963449669),
#  ('previous-job-marital-default-housing-age_bin-categorical',
#   1615.272925850586),
#  ('previous-marital-housing-loan-contact-age_bin-categorical',
#   1604.980068858307),
#  ('previous-job-marital-education-housing-loan-contact-age_bin-categorical',
#   1602.4575338224597),
#  ('old_prospect', 1602.1998323822904),
#  ('Economic growth Q-on-Q', 1576.5808961823507),
#  ('previous-education-housing-loan-contact-age_bin-categorical',
#   1568.4388840355928),
#  ('previous-housing-contact-age_bin-categorical', 1566.6693672904055),
#  ('previous-job-marital-education-housing-loan-contact-categorical',
#   1566.416662621633),
#  ('previous-job-marital-default-loan-age_bin-categorical', 1565.0254904709866),
#  ('previous-contact-age_bin-categorical', 1563.4476029815219),
#  ('previous-loan-contact-age_bin-categorical', 1559.3479056359113),
#  ('campaign-default-contact-age_bin-categorical', 1548.0291224656937),
#  ('previous-housing-loan-contact-age_bin-categorical', 1544.812290382602),
#  ('previous-marital-education-housing-loan-contact-age_bin-categorical',
#   1540.3384453335432),
#  ('previous-job-education-default-loan-age_bin-categorical',
#   1513.6556475792045),
#  ('previous-job-education-default-housing-age_bin-categorical',
#   1499.9248739745003),
#  ('campaign-default-housing-contact-age_bin-categorical', 1477.7033165457538),
#  ('previous-job-marital-default-housing-loan-age_bin-categorical',
#   1474.719050451346),
#  ('Current account balance', 1473.838220296028),
#  ('Exchange rate to USD', 1463.5544786753385),
#  ('previous-job-marital-education-default-categorical', 1457.4546746264186),
#  ('previous-job-education-default-categorical', 1445.4305529242768),
#  ('Investment growth', 1435.474266979942),
#  ('campaign-default-loan-contact-age_bin-categorical', 1417.1657341738858),
#  ('previous-job-marital-education-default-housing-age_bin-categorical',
#   1415.102555991393),
#  ('previous-job-marital-education-default-loan-age_bin-categorical',
#   1407.1463667640537),
#  ('previous-marital-default-age_bin-categorical', 1389.5600106414863),
#  ('previous-job-education-default-housing-loan-age_bin-categorical',
#   1389.5463230259406),
#  ('previous-job-marital-age_bin-categorical', 1381.8892424366495),
#  ('previous-job-age_bin-categorical', 1374.1488983896907),
#  ('previous-job-marital-default-categorical', 1373.9301758961758),
#  ('previous-marital-education-default-contact-categorical',
#   1372.3463188632709),
#  ('previous-marital-education-default-age_bin-categorical',
#   1371.1751076633022),
#  ('previous-job-education-age_bin-categorical', 1365.1412087559836),
#  ('previous-marital-education-default-loan-contact-categorical',
#   1355.0899339485843),
#  ('campaign-default-housing-loan-contact-age_bin-categorical',
#   1349.0365869046125),
#  ('previous-job-default-categorical', 1348.1312312619807),
#  ('previous-job-default-loan-categorical', 1345.6511253707708),
#  ('previous-job-education-default-loan-categorical', 1345.3535191293586),
#  ('previous-marital-default-housing-age_bin-categorical', 1344.7445166534085),
#  ('previous-job-marital-default-loan-categorical', 1341.1397938021125),
#  ('previous-marital-default-loan-age_bin-categorical', 1340.1673147740564),
#  ('previous-job-marital-education-default-loan-categorical',
#   1339.1195385128362),
#  ('previous-job-default-housing-categorical', 1338.977267486441),
#  ('previous-job-housing-age_bin-categorical', 1336.8480316802907),
#  ('previous-marital-education-default-housing-contact-categorical',
#   1334.5127734708374),
#  ('previous-job-default-housing-loan-categorical', 1328.6742247289963),
#  ('previous-job-marital-default-housing-categorical', 1322.4879214146229),
#  ('previous-job-marital-education-age_bin-categorical', 1305.4447834405341),
#  ('previous-marital-education-default-housing-loan-contact-categorical',
#   1303.143697440224),
#  ('previous-job-marital-education-default-housing-loan-age_bin-categorical',
#   1300.8755266679543),
#  ('previous-job-education-default-housing-categorical', 1300.5260470492497),
#  ('previous-job-marital-default-housing-loan-categorical', 1293.8156074797582),
#  ('previous-job-loan-age_bin-categorical', 1292.201887259811),
#  ('previous-job-marital-housing-age_bin-categorical', 1289.7580247829503),
#  ('previous-education-default-age_bin-categorical', 1286.4698554828844),
#  ('inflation_delta_expect-rolling-avg-90', 1283.6502878495555),
#  ('campaign-contact-age_bin-categorical', 1281.7921702901583),
#  ('previous-marital-default-housing-loan-age_bin-categorical',
#   1278.631503825829),
#  ('previous-education-default-contact-categorical', 1274.6607805328442),
#  ('previous-job-housing-loan-age_bin-categorical', 1273.5865534319998),
#  ('previous-education-default-housing-age_bin-categorical', 1268.987041447276),
#  ('previous-education-default-loan-contact-categorical', 1266.9897405231286),
#  ('previous-marital-default-loan-contact-categorical', 1265.8750435866125),
#  ('inflation_delta_expect-rolling-avg-45', 1263.3163882300728),
#  ('previous-marital-default-housing-loan-contact-categorical',
#   1261.753896475852),
#  ('previous-marital-default-housing-contact-categorical', 1260.4537579579594),
#  ('previous-education-default-housing-contact-categorical',
#   1260.4262151445328),
#  ('previous-education-default-housing-loan-contact-categorical',
#   1259.5377812849442),
#  ('previous-marital-default-contact-categorical', 1258.652507259135),
#  ('previous-job-education-default-housing-loan-categorical',
#   1258.2738987225014),
#  ('previous-job-marital-education-default-housing-categorical',
#   1258.2187926025642),
#  ('previous-default-age_bin-categorical', 1255.5620435045844),
#  ('previous-marital-education-default-housing-age_bin-categorical',
#   1255.3493890082252),
#  ('previous-marital-education-default-loan-age_bin-categorical',
#   1250.4396303757212),
#  ('campaign-housing-contact-age_bin-categorical', 1247.8617354557355),
#  ('previous-default-housing-age_bin-categorical', 1244.004512952469),
#  ('campaign-loan-contact-age_bin-categorical', 1240.119917584573),
#  ('inflation_delta_expect', 1238.188732938843),
#  ('previous-default-loan-age_bin-categorical', 1229.9811331256312),
#  ('previous-education-default-loan-age_bin-categorical', 1225.5070270290214),
#  ('previous-job-marital-loan-age_bin-categorical', 1214.3738074779205),
#  ('previous-job-education-loan-age_bin-categorical', 1214.2523412203689),
#  ('previous-default-loan-contact-categorical', 1213.790075431061),
#  ('previous-default-housing-loan-contact-categorical', 1213.2169769469656),
#  ('previous-default-contact-categorical', 1210.70554583079),
#  ('previous-default-housing-contact-categorical', 1210.3916700048399),
#  ('savings_delta_expect', 1209.943101759026),
#  ('previous-default-housing-loan-age_bin-categorical', 1207.3275500625462),
#  ('campaign-marital-default-contact-age_bin-categorical', 1206.8001543630226),
#  ('previous-job-education-housing-age_bin-categorical', 1205.7520032139328),
#  ('savings_delta_expect-rolling-avg-45', 1201.9610700585854),
#  ('savings_delta_expect-rolling-avg-90', 1198.8236417168848),
#  ('previous-job-marital-education-default-housing-loan-categorical',
#   1198.5595269424564),
#  ('previous-education-default-housing-loan-age_bin-categorical',
#   1188.740315931598),
#  ('campaign-housing-loan-contact-age_bin-categorical', 1188.1705494417342),
#  ('campaign-job-default-contact-categorical', 1160.3188404902855),
#  ('previous-job-marital-housing-loan-age_bin-categorical', 1159.3959256771343),
#  ('campaign-default-contact-categorical', 1157.0525637152675),
#  ('campaign-job-contact-age_bin-categorical', 1153.976401097141),
#  ('campaign-default-housing-contact-categorical', 1134.7469980233425),
#  ('campaign-default-loan-contact-categorical', 1124.8339121885324),
#  ('previous-marital-education-default-housing-loan-age_bin-categorical',
#   1123.2750388370773),
#  ('previous-job-marital-education-loan-age_bin-categorical',
#   1121.5758097531648),
#  ('campaign-job-default-contact-age_bin-categorical', 1113.5798661453202),
#  ('previous-job-marital-education-housing-age_bin-categorical',
#   1113.3721723762692),
#  ('campaign-default-housing-loan-contact-categorical', 1106.8016787790295),
#  ('previous-job-education-housing-loan-age_bin-categorical',
#   1106.1990182668417),
#  ('previous-job-marital-education-categorical', 1095.2241330591178),
#  ('campaign-marital-contact-age_bin-categorical', 1085.189318527061),
#  ('campaign-education-default-contact-age_bin-categorical',
#   1076.7184707823683),
#  ('campaign-default-age_bin-categorical', 1070.3938054611451),
#  ('previous-marital-education-contact-categorical', 1055.251776018991),
#  ('previous-marital-education-loan-contact-categorical', 1053.2860728652513),
#  ('previous-marital-education-housing-contact-categorical',
#   1038.0557253806833),
#  ('previous-marital-education-housing-loan-contact-categorical',
#   1031.8720163119785),
#  ('previous-job-education-categorical', 1030.9425445670486),
#  ('previous-marital-education-age_bin-categorical', 1027.2964710565032),
#  ('previous-job-marital-education-housing-loan-age_bin-categorical',
#   1024.0087546936088),
#  ('Household consumption', 1014.4890534636886),
#  ('campaign-marital-default-contact-categorical', 1011.0090236437825),
#  ('campaign-education-contact-age_bin-categorical', 996.5926692916237),
#  ('previous-job-marital-education-loan-categorical', 993.2357839881505),
#  ('campaign-marital-default-housing-contact-age_bin-categorical',
#   984.3066877928662),
#  ('previous-marital-age_bin-categorical', 974.7821134156655),
#  ('campaign-marital-default-loan-contact-age_bin-categorical',
#   969.3413859875044),
#  ('campaign-education-default-contact-categorical', 967.1792661315183),
#  ('campaign-job-contact-categorical', 965.7293331079662),
#  ('previous-marital-education-loan-age_bin-categorical', 965.2233678312507),
#  ('previous-job-marital-categorical', 964.6089167838688),
#  ('previous-marital-loan-contact-categorical', 962.0818266594586),
#  ('campaign-marital-loan-contact-age_bin-categorical', 961.0015178168984),
#  ('previous-marital-housing-loan-contact-categorical', 957.6439670445834),
#  ('previous-marital-housing-contact-categorical', 956.2208377103079),
#  ('previous-marital-contact-categorical', 954.9305988204951),
#  ('previous-job-marital-loan-categorical', 954.0071538931576),
#  ('previous-education-age_bin-categorical', 946.4286786845937),
#  ('previous-marital-housing-age_bin-categorical', 944.3425247359498),
#  ('campaign-job-loan-contact-age_bin-categorical', 939.88999543108),
#  ('previous-marital-education-housing-age_bin-categorical', 939.1187305380007),
#  ('campaign-marital-housing-contact-age_bin-categorical', 938.8371330772148),
#  ('previous-job-education-loan-categorical', 937.6465243404923),
#  ('previous-education-contact-categorical', 935.9383609450697),
#  ('previous-job-marital-housing-loan-categorical', 935.2785467314017),
#  ('previous-marital-loan-age_bin-categorical', 934.5522304551685),
#  ('previous-education-housing-loan-contact-categorical', 933.865476902127),
#  ('previous-education-loan-contact-categorical', 933.4211990207433),
#  ('previous-job-marital-housing-categorical', 930.6488052278794),
#  ('previous-job-marital-education-housing-categorical', 928.8630788449191),
#  ('previous-education-housing-contact-categorical', 928.5464398451214),
#  ('previous-education-housing-age_bin-categorical', 926.9316484806178),
#  ('campaign-default-loan-age_bin-categorical', 918.0766631522872),
#  ('campaign-default-housing-age_bin-categorical', 912.0184831296202),
#  ('previous-job-loan-categorical', 911.3147094384539),
#  ('previous-job-education-housing-categorical', 910.8835776721925),
#  ('campaign-marital-default-housing-contact-categorical', 909.5905849953597),
#  ('campaign-marital-default-loan-contact-categorical', 908.5620188817717),
#  ('previous-education-loan-age_bin-categorical', 907.513522340037),
#  ('previous-job-housing-loan-categorical', 904.9072091684541),
#  ('campaign-job-marital-default-contact-categorical', 904.559742779533),
#  ('previous-job-housing-categorical', 899.8091663390346),
#  ('campaign-job-default-loan-contact-categorical', 893.4118538882775),
#  ('campaign-job-housing-contact-age_bin-categorical', 891.1738639590316),
#  ('previous-loan-contact-categorical', 885.3569194605707),
#  ('previous-housing-loan-contact-categorical', 884.2051196701938),
#  ('previous-housing-contact-categorical', 882.9089616162188),
#  ('contact-categorical_1', 881.7070703057972),
#  ('previous-marital-housing-loan-age_bin-categorical', 879.7657187812141),
#  ('previous-job-marital-education-housing-loan-categorical', 873.142376786447),
#  ('campaign-housing-contact-categorical', 867.8369387396228),
#  ('campaign-job-loan-contact-categorical', 866.3893213798543),
#  ('previous-job-education-housing-loan-categorical', 864.663972470381),
#  ('campaign-loan-contact-categorical', 860.111964207551),
#  ('campaign-housing-loan-contact-categorical', 855.7607807853267),
#  ('previous-education-housing-loan-age_bin-categorical', 853.8397541169403),
#  ('ind_turnover-rolling-avg-90', 851.4706647363212),
#  ('campaign-marital-housing-loan-contact-age_bin-categorical',
#   844.8523839947987),
#  ('campaign-marital-default-housing-loan-contact-categorical',
#   842.0272775691558),
#  ('previous-marital-education-housing-loan-age_bin-categorical',
#   838.8927943828706),
#  ('ind_turnover-rolling-avg-45', 837.1174467042067),
#  ('campaign-education-loan-contact-age_bin-categorical', 836.5233000562502),
#  ('campaign-job-default-housing-contact-categorical', 833.0456067580967),
#  ('campaign-education-housing-contact-age_bin-categorical', 829.4704586042418),
#  ('campaign-marital-default-housing-loan-contact-age_bin-categorical',
#   829.035746188039),
#  ('campaign-marital-contact-categorical', 828.0754229248686),
#  ('campaign-job-marital-contact-categorical', 822.6568897629531),
#  ('ind_turnover', 814.6379928053427),
#  ('previous-housing-age_bin-categorical', 809.2863328796157),
#  ('campaign-default-housing-loan-age_bin-categorical', 809.0207597850367),
#  ('previous-loan-age_bin-categorical', 797.7413880717253),
#  ('Consumption growth', 793.6422507916815),
#  ('campaign-education-default-housing-contact-categorical', 784.7844463166991),
#  ('cons.price.idx', 778.5897948540367),
#  ('campaign-education-default-loan-contact-categorical', 777.3859564764434),
#  ('campaign-job-default-loan-contact-age_bin-categorical', 777.0109774976513),
#  ('campaign-job-default-housing-contact-age_bin-categorical',
#   772.5750309935628),
#  ('Consumer Price Index (CPI)', 772.3132185149897),
#  ('previous-housing-loan-age_bin-categorical', 767.0825234719829),
#  ('campaign-marital-loan-contact-categorical', 766.6390669942335),
#  ('campaign-job-housing-contact-categorical', 766.5951803732619),
#  ('campaign-marital-housing-contact-categorical', 765.3915053527941),
#  ('campaign-job-marital-contact-age_bin-categorical', 756.3422403744271),
#  ('campaign-job-default-age_bin-categorical', 740.6925102838393),
#  ('campaign-education-default-housing-contact-age_bin-categorical',
#   735.4370482045076),
#  ('campaign-marital-default-age_bin-categorical', 732.3673142112456),
#  ('campaign-marital-housing-loan-contact-categorical', 728.6840602177572),
#  ('campaign-education-default-loan-contact-age_bin-categorical',
#   725.4013277966156),
#  ('campaign-job-housing-loan-contact-age_bin-categorical', 724.4740062294092),
#  ('campaign-education-contact-categorical', 718.8178886317185),
#  ('campaign-job-education-default-contact-categorical', 718.4240679234563),
#  ('major_purch_expect-rolling-avg-90', 712.0042044908962),
#  ('campaign-job-default-housing-loan-contact-categorical', 706.3783739980272),
#  ('poutcome', 705.678164442302),
#  ('major_purch_expect-rolling-avg-45', 704.6077505538431),
#  ('campaign-marital-education-default-contact-categorical', 703.6829430147418),
#  ('campaign-job-marital-default-contact-age_bin-categorical',
#   701.6226948511303),
#  ('campaign-job-housing-loan-contact-categorical', 695.4597639784301),
#  ('major_purch_expect', 687.1475353974454),
#  ('campaign-marital-education-contact-age_bin-categorical', 680.1647658087559),
#  ('campaign-education-housing-loan-contact-age_bin-categorical',
#   672.1276974119579),
#  ('campaign-education-default-age_bin-categorical', 670.6428310148973),
#  ('campaign-job-education-contact-categorical', 665.1747713586641),
#  ('campaign-education-default-housing-loan-contact-categorical',
#   659.4041289702604),
#  ('campaign-education-housing-contact-categorical', 655.5463418604969),
#  ('campaign-education-loan-contact-categorical', 645.2042160545114),
#  ('campaign-job-marital-loan-contact-categorical', 639.6823607389407),
#  ('campaign-loan-age_bin-categorical', 637.5536175310478),
#  ('campaign-marital-education-default-contact-age_bin-categorical',
#   634.4757258995849),
#  ('previous-marital-education-default-categorical', 628.7348236745183),
#  ('campaign-job-default-categorical', 628.5322391811947),
#  ('campaign-job-marital-default-loan-contact-categorical', 621.0934246183908),
#  ('previous-marital-education-default-loan-categorical', 606.3558906059952),
#  ('campaign-job-age_bin-categorical', 605.5668370180534),
#  ('previous-marital-education-default-housing-categorical', 596.8008827522488),
#  ('campaign-job-default-housing-loan-contact-age_bin-categorical',
#   591.1191445025248),
#  ('campaign-housing-age_bin-categorical', 585.1820423010687),
#  ('Retail sales', 581.8538177068476),
#  ('campaign-job-education-contact-age_bin-categorical', 577.4889460680905),
#  ('campaign-marital-education-contact-categorical', 577.3204543269082),
#  ('previous-marital-education-default-housing-loan-categorical',
#   575.1264091703825),
#  ('campaign-education-housing-loan-contact-categorical', 566.3876713866217),
#  ('campaign-housing-loan-age_bin-categorical', 551.3927827608072),
#  ('campaign-education-default-housing-loan-contact-age_bin-categorical',
#   543.6396461524274),
#  ('campaign-job-marital-housing-contact-categorical', 533.7863568967668),
#  ('campaign-job-marital-loan-contact-age_bin-categorical', 533.5780539790745),
#  ('campaign-rolling-avg-60', 526.574826878869),
#  ('campaign-rolling-sum-60', 526.5748268786679),
#  ('previous-education-default-categorical', 526.1209053508647),
#  ('campaign-job-marital-default-housing-contact-categorical',
#   523.604696725311),
#  ('previous-education-default-housing-loan-categorical', 521.5328688607176),
#  ('previous-education-default-housing-categorical', 518.3535607397841),
#  ('campaign-job-marital-housing-contact-age_bin-categorical',
#   515.2798816829676),
#  ('previous-education-default-loan-categorical', 514.4038272119554),
#  ('campaign-job-education-default-contact-age_bin-categorical',
#   509.2094439266318),
#  ('Exports', 499.51547563319406),
#  ('campaign-marital-default-loan-age_bin-categorical', 497.08613036239836),
#  ('campaign-rolling-sum-30', 492.6574117001571),
#  ('campaign-rolling-avg-30', 492.6574117001122),
#  ('age-rolling-avg-60', 492.18303388331236),
#  ('age-rolling-sum-60', 492.18303388239275),
#  ('previous-marital-default-loan-categorical', 490.02171904135383),
#  ('previous-marital-default-categorical', 489.9560140514836),
#  ('campaign-marital-education-loan-contact-age_bin-categorical',
#   489.766624087069),
#  ('previous-marital-default-housing-loan-categorical', 488.86054219627937),
#  ('previous-marital-default-housing-categorical', 487.7764953790066),
#  ('campaign-marital-default-housing-age_bin-categorical', 481.3991104727891),
#  ('campaign-marital-education-default-loan-contact-categorical',
#   472.3939798555125),
#  ('campaign-job-default-loan-age_bin-categorical', 471.76517880194547),
#  ('new_prospect', 467.8756586323889),
#  ('campaign-job-marital-default-loan-contact-age_bin-categorical',
#   457.7154416389394),
#  ('campaign-job-marital-housing-loan-contact-categorical', 456.3393932550569),
#  ('campaign-marital-education-default-housing-contact-categorical',
#   452.7933664147279),
#  ('campaign-job-default-housing-age_bin-categorical', 447.8122785139982),
#  ('campaign-marital-age_bin-categorical', 447.8082983752975),
#  ('campaign-marital-education-housing-contact-age_bin-categorical',
#   446.80544621230734),
#  ('campaign-marital-education-loan-contact-categorical', 445.81015349933034),
#  ('campaign-education-age_bin-categorical', 432.9959746886096),
#  ('campaign-job-marital-default-housing-contact-age_bin-categorical',
#   431.17543175731396),
#  ('campaign-job-education-housing-contact-categorical', 425.59412154234894),
#  ('campaign-job-marital-default-housing-loan-contact-categorical',
#   425.5297632975024),
#  ('campaign-job-marital-housing-loan-contact-age_bin-categorical',
#   424.07811179488556),
#  ('campaign-marital-education-housing-contact-categorical', 423.3875085626114),
#  ('campaign-job-education-loan-contact-categorical', 423.3223618366119),
#  ('campaign-job-marital-education-default-contact-categorical',
#   421.4770125697571),
#  ('campaign-job-loan-age_bin-categorical', 410.9285931092623),
#  ('default-categorical_1', 410.1033363586814),
#  ('campaign-job-education-default-loan-contact-categorical',
#   409.8745882040273),
#  ('previous-default-housing-loan-categorical', 409.84582757124383),
#  ('previous-default-housing-categorical', 408.5794282642813),
#  ('previous-default-loan-categorical', 408.0051305204134),
#  ('campaign-rolling-sum-10', 402.98775655828626),
#  ('campaign-rolling-avg-10', 402.9877565581342),
#  ('campaign-job-marital-education-contact-categorical', 402.5212455801883),
#  ('campaign-job-marital-default-categorical', 400.1184313980012),
#  ('campaign-job-education-default-housing-contact-categorical',
#   399.38881529902204),
#  ('campaign-marital-education-default-loan-contact-age_bin-categorical',
#   393.72344248987713),
#  ('campaign-job-housing-age_bin-categorical', 389.83278368780503),
#  ('campaign-marital-default-housing-loan-age_bin-categorical',
#   385.28476750995793),
#  ('age-rolling-avg-30', 382.8695067667892),
#  ('age-rolling-sum-30', 382.86950676544274),
#  ('age_bin-categorical_2', 382.43176907818554),
#  ('campaign-default-loan-categorical', 382.2772261246516),
#  ('campaign-job-default-housing-categorical', 382.0100991867009),
#  ('campaign-job-default-loan-categorical', 379.8249968159789),
#  ('campaign-default-housing-categorical', 376.47940758208074),
#  ('campaign-job-education-loan-contact-age_bin-categorical',
#   376.0586759474479),
#  ('campaign-job-marital-default-age_bin-categorical', 372.6632124952449),
#  ('campaign-marital-education-default-housing-contact-age_bin-categorical',
#   371.7923287238622),
#  ('campaign-marital-education-housing-loan-contact-age_bin-categorical',
#   367.20742469760097),
#  ('job-categorical_8', 366.8090839682639),
#  ('campaign-marital-education-default-housing-loan-contact-categorical',
#   360.87629899490406),
#  ('campaign-education-default-loan-age_bin-categorical', 359.6944861484824),
#  ('campaign-job-education-default-categorical', 359.0946480548993),
#  ('campaign-job-default-housing-loan-age_bin-categorical', 358.96370463765084),
#  ('campaign-marital-education-housing-loan-contact-categorical',
#   358.4820791400084),
#  ('campaign-default-housing-loan-categorical', 354.33059892510477),
#  ('campaign-education-default-housing-age_bin-categorical', 353.3316751027326),
#  ('job-categorical_5', 353.2784315173327),
#  ('campaign-job-education-housing-contact-age_bin-categorical',
#   342.35596130941724),
#  ('campaign-job-marital-default-housing-loan-contact-age_bin-categorical',
#   340.6867204477437),
#  ('campaign-job-marital-education-contact-age_bin-categorical',
#   334.40386133966837),
#  ('campaign-marital-default-categorical', 329.88790510572574),
#  ('duration-rolling-sum-60', 328.82004776349845),
#  ('duration-rolling-avg-60', 328.8200477631549),
#  ('campaign-job-housing-loan-age_bin-categorical', 322.33638991456314),
#  ('campaign-job-education-default-loan-contact-age_bin-categorical',
#   321.190305389065),
#  ('campaign-education-default-categorical', 312.05965859902284),
#  ('age_bin-categorical_3', 310.10742157821875),
#  ('campaign-marital-education-default-age_bin-categorical', 309.2108782963515),
#  ('campaign-job-education-housing-loan-contact-categorical',
#   306.11129479744824),
#  ('campaign-job-default-housing-loan-categorical', 305.1445280102125),
#  ('duration-rolling-sum-30', 302.88377591136026),
#  ('duration-rolling-avg-30', 302.88377591112726),
#  ('unempl_expect', 301.84052115190866),
#  ('campaign-job-marital-education-default-contact-age_bin-categorical',
#   299.3781006179945),
#  ('unempl_expect-rolling-avg-45', 297.61266526501),
#  ('campaign-job-education-default-age_bin-categorical', 293.8508873323009),
#  ('campaign-marital-housing-age_bin-categorical', 293.1131217502664),
#  ('campaign-marital-loan-age_bin-categorical', 292.47395580757745),
#  ('campaign-marital-default-housing-categorical', 290.7312640110023),
#  ('unempl_expect-rolling-avg-90', 288.8103096095634),
#  ('campaign-marital-education-default-housing-loan-contact-age_bin-categorical',
#   287.90260993533377),
#  ('campaign-job-education-default-housing-loan-contact-categorical',
#   283.84390464905346),
#  ('campaign-education-housing-age_bin-categorical', 282.83545155709834),
#  ('Gross Domestic Product (GDP)', 278.4004640720997),
#  ('campaign-job-education-housing-loan-contact-age_bin-categorical',
#   278.1899038340149),
#  ('campaign-job-education-default-housing-contact-age_bin-categorical',
#   278.1778703207622),
#  ('campaign-education-loan-age_bin-categorical', 276.20045819949127),
#  ('previous-marital-education-categorical', 274.79490292823243),
#  ('campaign-job-marital-age_bin-categorical', 272.9263501239555),
#  ('duration-rolling-avg-10', 261.7349827800666),
#  ('duration-rolling-sum-10', 261.73498277996237),
#  ('previous-marital-education-loan-categorical', 261.3268023671279),
#  ('campaign-job-marital-education-loan-contact-categorical',
#   260.9381179682369),
#  ('previous-marital-education-housing-categorical', 259.621206303117),
#  ('previous-marital-education-housing-loan-categorical', 258.2778018502523),
#  ('campaign-job-education-age_bin-categorical', 257.8339135720641),
#  ('campaign-marital-default-loan-categorical', 256.7283579320691),
#  ('campaign-education-default-housing-loan-age_bin-categorical',
#   255.30365305310283),
#  ('campaign-job-marital-education-default-loan-contact-categorical',
#   253.83505469913086),
#  ('age_bin-categorical_1', 246.0593774019111),
#  ('campaign-job-marital-default-loan-categorical', 240.61958583385947),
#  ('campaign-marital-housing-loan-age_bin-categorical', 237.93304788718712),
#  ('age-rolling-avg-10', 234.8308715206469),
#  ('age-rolling-sum-10', 234.83087152033207),
#  ('campaign-job-marital-education-housing-contact-categorical',
#   233.27154908296225),
#  ('campaign-job-education-default-housing-loan-contact-age_bin-categorical',
#   231.88621290349556),
#  ('campaign-job-marital-education-loan-contact-age_bin-categorical',
#   231.63326665199625),
#  ('job-categorical_1', 229.3926400091521),
#  ('campaign-job-marital-default-loan-age_bin-categorical', 223.8637852402977),
#  ('campaign-marital-education-age_bin-categorical', 223.4434588520227),
#  ('campaign-marital-default-housing-loan-categorical', 222.97834930816325),
#  ('campaign-job-marital-default-housing-categorical', 219.3224560450605),
#  ('campaign-job-marital-education-default-housing-contact-categorical',
#   214.95323573750983),
#  ('campaign-job-marital-education-default-loan-contact-age_bin-categorical',
#   207.80651006423207),
#  ('campaign-job-marital-education-housing-contact-age_bin-categorical',
#   201.97887331820783),
#  ('campaign-job-marital-default-housing-age_bin-categorical',
#   196.67301652856588),
#  ('campaign-job-education-categorical', 196.4217346151805),
#  ('campaign-education-default-housing-categorical', 196.24600166324853),
#  ('campaign-job-loan-categorical', 195.22826509946353),
#  ('campaign-job-marital-categorical', 194.39403712354226),
#  ('campaign-job-marital-education-housing-loan-contact-categorical',
#   190.52011783002408),
#  ('campaign-job-education-default-loan-age_bin-categorical',
#   189.3629792715611),
#  ('campaign-education-default-loan-categorical', 185.57739170547336),
#  ('campaign-job-education-default-loan-categorical', 185.14174211169737),
#  ('campaign-job-marital-education-default-categorical', 183.269749135122),
#  ('campaign-education-housing-loan-age_bin-categorical', 182.38906738862215),
#  ('campaign', 182.1566728779538),
#  ('campaign-job-marital-education-default-housing-loan-contact-categorical',
#   180.30517785248028),
#  ('campaign-job-marital-education-housing-loan-contact-age_bin-categorical',
#   180.2375181788597),
#  ('campaign-job-marital-default-housing-loan-categorical', 175.39029897685424),
#  ('campaign-job-marital-default-housing-loan-age_bin-categorical',
#   173.05197282354047),
#  ('campaign-job-marital-education-default-age_bin-categorical',
#   169.06085087071938),
#  ('campaign-marital-education-default-categorical', 168.2573957223255),
#  ('campaign-job-marital-loan-age_bin-categorical', 167.70996699611706),
#  ('campaign-job-education-loan-age_bin-categorical', 166.7696327998324),
#  ('campaign-job-marital-education-default-housing-contact-age_bin-categorical',
#   165.88691531520286),
#  ('campaign-job-marital-housing-age_bin-categorical', 165.34002397869668),
#  ('campaign-job-education-default-housing-categorical', 158.72516150680698),
#  ('FDI', 158.06952761873947),
#  ('campaign-job-housing-categorical', 157.29333606086433),
#  ('campaign-marital-education-default-loan-age_bin-categorical',
#   154.66252288851604),
#  ('campaign-marital-education-default-housing-age_bin-categorical',
#   141.96322054455425),
#  ('previous-education-housing-loan-categorical', 139.73830686216712),
#  ('campaign-job-marital-housing-loan-age_bin-categorical', 139.38633945428114),
#  ('campaign-job-education-housing-age_bin-categorical', 138.85954467405574),
#  ('Economic growth', 135.70237485597355),
#  ('campaign-job-housing-loan-categorical', 134.98322667363175),
#  ('campaign-job-education-default-housing-age_bin-categorical',
#   133.79495200986747),
#  ('campaign-job-marital-education-age_bin-categorical', 133.546697558303),
#  ('previous-education-housing-categorical', 131.6792660837365),
#  ('previous-education-loan-categorical', 131.04809786787516),
#  ('campaign-job-education-default-housing-loan-age_bin-categorical',
#   130.5037170775399),
#  ('campaign-education-default-housing-loan-categorical', 125.81497350843664),
#  ('cons.conf.idx', 124.40997473290119),
#  ('cons_conf-rolling-avg-90', 123.67748053753996),
#  ('campaign-job-education-housing-loan-age_bin-categorical',
#   121.89685174328122),
#  ('marital-categorical_2', 121.04764635758544),
#  ('previous-marital-loan-categorical', 120.60222812960913),
#  ('campaign-job-marital-education-default-loan-categorical',
#   120.38587845063385),
#  ('previous-marital-housing-loan-categorical', 119.36252674877684),
#  ('campaign-job-education-default-housing-loan-categorical',
#   118.37474510792214),
#  ('campaign-job-marital-loan-categorical', 118.32918796522716),
#  ('campaign-marital-education-loan-age_bin-categorical', 117.56441580238327),
#  ('previous-marital-housing-categorical', 117.5574962968394),
#  ('campaign-job-marital-education-default-loan-age_bin-categorical',
#   116.51376238916845),
#  ('campaign-marital-education-default-housing-loan-age_bin-categorical',
#   115.65950870095456),
#  ('campaign-marital-education-housing-age_bin-categorical',
#   112.78076853545257),
#  ('cons_conf-rolling-avg-45', 112.2791345435539),
#  ('education-categorical_6', 104.7342650959867),
#  ('cons_conf', 104.12406685116402),
#  ('campaign-job-marital-education-categorical', 100.01127869831588),
#  ('campaign-job-marital-housing-categorical', 96.97839342554532),
#  ('campaign-job-education-loan-categorical', 96.25226953380384),
#  ('campaign-job-marital-housing-loan-categorical', 93.44552665457515),
#  ('campaign-job-marital-education-default-housing-loan-age_bin-categorical',
#   92.43123574327309),
#  ('campaign-job-marital-education-loan-age_bin-categorical',
#   92.18455820753516),
#  ('major_purch_opportu-rolling-avg-90', 91.72779927842147),
#  ('campaign-job-marital-education-default-housing-categorical',
#   89.97491404560324),
#  ('major_purch_opportu-rolling-avg-45', 88.76602065472002),
#  ('campaign-marital-education-housing-loan-age_bin-categorical',
#   88.15945805166349),
#  ('campaign-job-education-housing-categorical', 88.08272572177515),
#  ('campaign-job-marital-education-default-housing-loan-categorical',
#   86.82168755101304),
#  ('major_purch_opportu', 84.80120899724722),
#  ('campaign-marital-education-default-loan-categorical', 84.4017149728385),
#  ('campaign-job-marital-education-default-housing-age_bin-categorical',
#   84.24648245312149),
#  ('education-categorical_2', 84.07434224982066),
#  ('campaign-marital-education-default-housing-categorical', 80.17298289327),
#  ('campaign-job-marital-education-housing-age_bin-categorical',
#   80.05702547978048),
#  ('campaign-job-marital-education-housing-loan-age_bin-categorical',
#   77.89077370659513),
#  ('marital-categorical_1', 77.71471854222142),
#  ('campaign-job-marital-education-loan-categorical', 70.7627136510787),
#  ('campaign-job-marital-education-housing-categorical', 58.41783123525527),
#  ('campaign-marital-education-default-housing-loan-categorical',
#   57.62646251927517),
#  ('month', 56.022065296719674),
#  ('campaign-job-marital-education-housing-loan-categorical',
#   54.571282634686675),
#  ('campaign-job-education-housing-loan-categorical', 54.522110843774705),
#  ('job-categorical_7', 43.01613077387522),
#  ('age', 38.09465928898605),
#  ('campaign-marital-housing-categorical', 26.456934467191388),
#  ('education-categorical_1', 22.790083655770683),
#  ('campaign-marital-housing-loan-categorical', 20.695054082587358),
#  ('education-categorical_7', 18.92326444749819),
#  ('campaign-marital-loan-categorical', 13.798408070487008),
#  ('job-categorical_2', 11.41245812275759),
#  ('job-categorical_10', 8.96478327136086),
#  ('campaign-education-loan-categorical', 8.062516811123555),
#  ('campaign-housing-loan-categorical', 6.373359275826828),
#  ('previous-housing-loan-categorical', 5.727725786973675),
#  ('housing-categorical_2', 5.6801927084319415),
#  ('campaign-marital-education-categorical', 3.3478062178046666),
#  ('campaign-education-housing-loan-categorical', 3.0327906686970647),
#  ('education-categorical_3', 2.287580672001242),
#  ('education-categorical_4', 2.1626774035338),
#  ('job-categorical_3', 1.7428241132344513),
#  ('job-categorical_9', 1.5571271442670787),
#  ('month_last_contact', 1.5149396996025741),
#  ('savings_expect-rolling-avg-90', 1.3615862468398692),
#  ('savings_expect-rolling-avg-45', 1.3349030781459956),
#  ('campaign-marital-education-housing-categorical', 1.2517177221147282),
#  ('marital-categorical_3', 1.1183276528619301),
#  ('savings_expect', 1.106542489845242),
#  ('campaign-education-housing-categorical', 1.0893381248967757),
#  ('job-categorical_6', 0.8953753007463422),
#  ('loan-categorical_2', 0.821520785032068),
#  ('default-categorical_2', 0.3808817642625059),
#  ('campaign-marital-education-housing-loan-categorical', 0.35098813345016905),
#  ('housing-categorical_1', 0.21223341776734433),
#  ('loan-categorical_1', 0.21223341776734433),
#  ('campaign-marital-education-loan-categorical', 0.14284277428121772),
#  ('household_debt_ratio', 0.07580810832248187),
#  ('education-categorical_5', 0.041448082202958876),
#  ('household_debt_ratio-rolling-avg-45', 0.037893719440692704),
#  ('household_debt_ratio-rolling-avg-90', 0.026582025990985584),
#  ('job-categorical_4', 0.00722589702968914),
#  ('job-categorical_11', 0.0009452221009477091)]

# %%
#among the top 70 indicators, many are economic indicators that are highly related to one another
#to avoid redundancy we will pick only the top 10 economic indicators
rfe_test1 = [i[0] for i in best_cols][:40]

# %%
X[rfe_test1].shape
# Out:
# (41188, 40)

# %% [markdown]
# Feature Importances Via Decision Tree Regression

# %%
def scale_noncat_only(X):
    
    X_temp_noncat = X.select_dtypes(exclude=['int8'])
    X_temp_noncat = X_temp_noncat.drop(X_temp_noncat.filter(regex="-categorical").columns, axis=1)
    
    
    scaler = preprocessing.StandardScaler().fit(X_temp_noncat)
    X_transformed = pd.DataFrame(scaler.transform(X_temp_noncat), columns = X_temp_noncat.columns)
    
    X = X_transformed.merge(X, left_index=True, right_index=True, how='inner', suffixes=('', '_rightdf'))
    X = X.drop(X.filter(regex="_rightdf").columns, axis=1)
    
    return X

# %%
X_test1 = X[rfe_test1]

# %%
X_test1 = scale_noncat_only(X_test1)
# Out:
# /Users/pauldefusco/anaconda2/envs/py36/lib/python3.6/site-packages/sklearn/preprocessing/data.py:625: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /Users/pauldefusco/anaconda2/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:8: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.

# %%
from sklearn.feature_selection import RFE, RFECV
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import r2_score

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size = 0.20, random_state=4)

# %%
model = RandomForestClassifier(max_depth = 20, min_samples_split = 1000, random_state = 4)

# %%
model.fit(X_train,y_train)
# Out:
# /Users/pauldefusco/anaconda2/envs/py36/lib/python3.6/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=20, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=1000,
#             min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=None,
#             oob_score=False, random_state=4, verbose=0, warm_start=False)

# %%
accuracy_score(y_test, model.predict(X_test))
# Out:
# 0.8959698956057296
