# %% [markdown]
# ### Feature Engineering and Selection:

# %% [markdown]
# - Objective: engineer new features and analyze their importance
# - Method: first use Univariate tests to discard poor features (important when dealing with many features)
#     Then, use recursive feature elimination and feature importances to get a feeling for ranking among features left

# %% [markdown]
# Dilemma: should we tune a model before feeding it to RFECV? Answer: first loosely tune models and then use regularized decision trees for a potentially more rigorouse answer:
#             https://arxiv.org/pdf/1201.1587.pdf

# %%
# %load_ext autoreload

# %autoreload 2

# %%
# %matplotlib inline
import pandas as pd
import numpy as np
from scipy.io import arff
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib as mpl
import os
from math import sqrt

# %%
from sklearn.model_selection import train_test_split, StratifiedKFold, GridSearchCV, cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn import preprocessing
from sklearn.pipeline import make_pipeline
from sklearn.metrics import confusion_matrix, precision_score, recall_score, average_precision_score
from sklearn.metrics import accuracy_score, roc_curve, roc_auc_score, precision_recall_curve
from sklearn.metrics import classification_report
from sklearn.utils.fixes import signature
pd.options.display.float_format = '{:.2f}'.format
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %%
from sklearn.metrics import mean_squared_error
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
# Out:
# Using TensorFlow backend.

# %%
os.listdir('../../../../mkt_camp_data')
# Out:
# ['df_pickle.pickle',
#  'df_pickle_w_all_stats.pickle',
#  'df_pickle_w_time_stats.pickle',
#  'final_df_pickle.pickle']

# %%
#Loading final df from feature engineering notebook
final_df = pd.read_pickle('../../../../mkt_camp_data/final_df_pickle.pickle')
#final_df = final_df.drop(columns = ['Date'])

# %%
final_df = final_df[['Date','duration']]

# %%
def scale_noncat_only(X):
    
    indx = X.Date
    X.drop(columns='Date', inplace=True)
    
    X_temp_noncat = X.select_dtypes(exclude=['int8'])
    X_temp_noncat = X_temp_noncat.drop(X_temp_noncat.filter(regex="-categorical").columns, axis=1)
    
    
    scaler = preprocessing.StandardScaler().fit(X_temp_noncat)
    X_transformed = pd.DataFrame(scaler.transform(X_temp_noncat), columns = X_temp_noncat.columns)
    
    X = X_transformed.merge(X, left_index=True, right_index=True, how='inner', suffixes=('', '_rightdf'))
    X = X.drop(X.filter(regex="_rightdf").columns, axis=1)
    
    X.index = indx
    
    return X, scaler

# %%
final_df, scaler = scale_noncat_only(final_df)
# Out:
# /Users/pauldefusco/anaconda2/envs/py36/lib/python3.6/site-packages/sklearn/preprocessing/data.py:625: DataConversionWarning: Data with input dtype int64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /Users/pauldefusco/anaconda2/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:11: DataConversionWarning: Data with input dtype int64 were all converted to float64 by StandardScaler.
#   # This is added back by InteractiveShellApp.init_path()

# %%
def prep_df(df):
    y = df['duration']
    #X = df.drop(df.filter(regex='y').columns, axis=1)
    y = y.shift(1)
    #X = df.drop(columns='duration')
    #Dropping features based on y
    #X = X.drop(X.filter(regex="cust_acquisition_flag").columns, axis=1) 
    #X = X.drop(X.filter(regex="cust_retention_flag").columns, axis=1)
    #X = X.drop(X.filter(regex="prospect_conversion_flag").columns, axis=1)
    
    #Dropping linearly dependent features
    
    #X = df.drop(columns = ['new_lead'])

    X = df.copy()
     
    names = list(df.columns)
    return X, y, names

# %%
X,y,names = prep_df(final_df)

# %%
y.head()
# Out:
# Date
# 2008-05-05    0.010
# 2008-05-05   -0.422
# 2008-05-05   -0.125
# 2008-05-05   -0.414
# 2008-05-05    0.188
# Name: duration, dtype: float64

# %%
X.head()
# Out:
#             duration
# Date
# 2008-05-05    -0.422
# 2008-05-05    -0.125
# 2008-05-05    -0.414
# 2008-05-05     0.188
# 2008-05-05    -0.233

# %%
y = y.iloc[1:]

# %%
X = X.iloc[1:]

# %%
for i in X.columns:
    print(i)
# Out:
# pdays
# campaign
# previous
# emp.var.rate
# age
# duration-rolling-avg-10
# previous-rolling-avg-10
# old_prospect_y-rolling-avg-10
# duration

# %%
X.shape
# Out:
# (41187, 1)

# %%
X_train, X_test, y_train, y_test = train_test_split(np.array(X), np.array(y), test_size = 0.20, random_state=4)

# %%
X_test.shape
# Out:
# (8238, 1)

# %%
X_train = X_train.reshape((X_train.shape[0], 1, X_train.shape[1]))
X_test = X_test.reshape((X_test.shape[0], 1, X_test.shape[1]))
print(X_train.shape, y_train.shape, X_test.shape, y_test.shape)
# Out:
# (32949, 1, 1) (32949,) (8238, 1, 1) (8238,)

# %%
# design network
model = Sequential()
model.add(LSTM(5, input_shape=(X_train.shape[1], X_train.shape[2])))
model.add(Dense(1))
model.compile(loss='mse', optimizer='adam')

# %%
# fit network
history = model.fit(X_train, y_train, epochs=2, 
                    batch_size=72, validation_data=(X_test, y_test), 
                    verbose=2, shuffle=False)
# Out:
# Train on 32949 samples, validate on 8238 samples
# Epoch 1/2
#  - 4s - loss: 1.0207 - val_loss: 0.9168
# Epoch 2/2
#  - 3s - loss: 1.0185 - val_loss: 0.9166

# %%
# plot history
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='test')
plt.legend()
plt.show()

# %%
yhat = model.predict(X_test)
X_test = X_test.reshape((X_test.shape[0], X_test.shape[2]))

# %%
from numpy import concatenate
# invert scaling for forecast
inv_yhat = concatenate((yhat, X_test[:, 1:]), axis=1)
inv_yhat = scaler.inverse_transform(inv_yhat)
inv_yhat = inv_yhat[:,0]

# %%
# invert scaling for actual
y_test = y_test.reshape((len(y_test), 1))
inv_y = concatenate((y_test, X_test[:, 1:]), axis=1)
inv_y = scaler.inverse_transform(inv_y)
inv_y = inv_y[:,0]

# %%
len(inv_y)
# Out:
# 8238

# %%
np.count_nonzero(np.isnan(inv_y))
# Out:
# 0

# %%
# calculate RMSE
rmse = sqrt(mean_squared_error(inv_y, inv_yhat))
print('Test RMSE: %.3f' % rmse)
# Out:
# Test RMSE: 248.234

# %%
inv_y.mean()
# Out:
# 256.2448409808206

# %% [markdown]
# Time Series Feature Engineering

# %%
def create_rolling_features(df, names, func, window):
    
    new_names = [i+'-rolling-'+str(func)+'-'+str(window) for i in names]
    
    if func == 'avg':    
        df[new_names] = df[names].rolling(window, win_type = 'triang').mean()
    elif func == 'sum':
        df[new_names] = df[names].rolling(window, win_type = 'triang').sum()
    
    return df

# %%
customer_attr = ['age', 'duration', 'campaign', 'y','previous', 'pdays', 'new_prospect_y', 
            'old_prospect_y', 'prev_subscr_flag', 'cust_retention_flag', 
            'cust_acquisition_flag', 'prospect_conversion_flag']

# %%
#economic indicators - longer term windows
econ_attr = ['cons_conf', 'ind_turnover', 'major_purch_expect', 'major_purch_opportu', 
             'unempl_expect', 'inflation_delta_expect', 'economy_expect', 'economy_past', 
             'financial_past', 'savings_delta_expect', 'household_debt_ratio', 
             'savings_expect', 'emplmnt_industry_index', 'railway_passengers']

# %%
df = create_rolling_features(df, customer_attr, 'avg', 10)
df = create_rolling_features(df, customer_attr, 'avg', 30)
df = create_rolling_features(df, customer_attr, 'avg', 60)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-397-868d573c4981> in <module>()
# ----> 1 df = create_rolling_features(df, customer_attr, 'avg', 10)
#       2 df = create_rolling_features(df, customer_attr, 'avg', 30)
#       3 df = create_rolling_features(df, customer_attr, 'avg', 60)
#
# NameError: name 'df' is not defined

# %%
df = create_rolling_features(df, customer_attr, 'sum', 10)
df = create_rolling_features(df, customer_attr, 'sum', 30)
df = create_rolling_features(df, customer_attr, 'sum', 60)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-398-8a5e657e1bd9> in <module>()
# ----> 1 df = create_rolling_features(df, customer_attr, 'sum', 10)
#       2 df = create_rolling_features(df, customer_attr, 'sum', 30)
#       3 df = create_rolling_features(df, customer_attr, 'sum', 60)
#
# NameError: name 'df' is not defined

# %%
df = create_rolling_features(df, econ_attr, 'avg', 45)
df = create_rolling_features(df, econ_attr, 'avg', 90)

# %%
#loading df
X, y, names = prep_df(final_df)

# %% [markdown]
# Feature Importance:

# %% [markdown]
# Starting with an exploration of the most important features with univariate methods and RFE (with CV)

# %% [markdown]
# Univariate Feature Selection

# %%
from sklearn.feature_selection import SelectKBest, f_regression, mutual_info_regression

# %%
def kbest(X,y, score_func, k):
    #Use f_regression or mutual_info_regression as scoring function
    test = SelectKBest(score_func=score_func, k=k)
    fit = test.fit(X, y)
    # summarize scores
    np.set_printoptions(precision=3)
    return sorted(list(zip(names,list(fit.scores_))), key=lambda tup:tup[1], reverse=True)

# %%
best_cols = kbest(X,y, f_regression, 'all')

# %%
best_cols
# Out:
# [('duration-rolling-sum-10', 658.2322727850463),
#  ('duration-rolling-avg-10', 658.2322727850224),
#  ('duration-rolling-avg-30', 472.36586990655206),
#  ('duration-rolling-sum-30', 472.365869906534),
#  ('duration-rolling-avg-60', 465.1982134214848),
#  ('duration-rolling-sum-60', 465.19821342142563),
#  ('campaign', 212.8221977194653),
#  ('campaign-rolling-sum-60', 162.57484634813886),
#  ('campaign-rolling-avg-60', 162.5748463481367),
#  ('FDI', 127.0960409440427),
#  ('campaign-rolling-sum-30', 108.96647338777834),
#  ('campaign-rolling-avg-30', 108.96647338777736),
#  ('prev_subscr_flag', 83.11115440608762),
#  ('Foreign exchange reserves', 80.87898740255453),
#  ('Government debt', 78.98053221763733),
#  ('prev_subscr_flag-rolling-avg-30', 78.91354586820017),
#  ('prev_subscr_flag-rolling-sum-30', 78.91354586820017),
#  ('campaign-rolling-sum-10', 75.00787008485212),
#  ('campaign-rolling-avg-10', 75.00787008484477),
#  ('previous-rolling-avg-60', 74.51842520207875),
#  ('previous-rolling-sum-60', 74.51842520207872),
#  ('Minimum wage', 73.79140174507602),
#  ('prev_subscr_flag-rolling-sum-60', 73.52253536861821),
#  ('prev_subscr_flag-rolling-avg-60', 73.52253536861814),
#  ('previous-rolling-sum-30', 71.45283135722437),
#  ('previous-rolling-avg-30', 71.4528313572242),
#  ('savings_delta_expect', 69.60089063275831),
#  ('savings_delta_expect-rolling-avg-90', 65.4473995932113),
#  ('savings_delta_expect-rolling-avg-45', 65.29536363730676),
#  ('prev_subscr_flag-rolling-avg-10', 61.802080042295586),
#  ('prev_subscr_flag-rolling-sum-10', 61.80208004229532),
#  ('Mortgage credit', 57.35044863743176),
#  ('Household credit', 54.270397837235684),
#  ('previous-job-marital-default-loan-contact-categorical', 54.13457173342395),
#  ('previous-rolling-avg-10', 53.40675586505385),
#  ('previous-rolling-sum-10', 53.40675586505332),
#  ('previous-job-marital-default-housing-loan-contact-categorical',
#   53.28498587894631),
#  ('previous-job-marital-education-default-loan-contact-age_bin-categorical',
#   52.680847286489765),
#  ('campaign-job-marital-default-contact-categorical', 52.42797301366732),
#  ('previous-job-marital-default-housing-contact-categorical',
#   52.14865295195167),
#  ('Mortgage credit interest rate', 51.53250204707991),
#  ('previous-job-marital-education-default-loan-contact-categorical',
#   50.695469391181895),
#  ('Business credit interest rate', 50.374087889761526),
#  ('previous-job-education-default-contact-categorical', 48.908723952980274),
#  ('previous-job-marital-default-contact-categorical', 48.73351597214754),
#  ('Labor cost', 48.505959134127224),
#  ('previous-job-education-default-loan-contact-categorical',
#   48.400224987595784),
#  ('previous-job-education-default-housing-loan-contact-categorical',
#   48.27597454127815),
#  ('campaign-job-contact-age_bin-categorical', 47.50203277425526),
#  ('Deposit interest rate', 47.45763720003387),
#  ('previous-job-marital-default-loan-contact-age_bin-categorical',
#   47.291474284883535),
#  ('campaign-job-marital-contact-categorical', 47.16243833896525),
#  ('previous-job-marital-education-default-contact-age_bin-categorical',
#   46.86555285145152),
#  ('campaign-job-default-contact-categorical', 46.8107321683488),
#  ('campaign-job-default-contact-age_bin-categorical', 46.8063974394813),
#  ('previous-job-marital-loan-contact-categorical', 46.75319142654771),
#  ('previous-job-default-housing-loan-contact-categorical', 46.72771037449353),
#  ('previous-job-marital-housing-loan-contact-categorical', 46.532817714767624),
#  ('campaign-job-contact-categorical', 46.313539504650706),
#  ('previous-job-marital-default-housing-contact-age_bin-categorical',
#   46.17079824679563),
#  ('previous-job-default-loan-contact-categorical', 46.13877997445828),
#  ('poutcome', 45.887736793236385),
#  ('previous-job-default-housing-contact-categorical', 45.53966286756033),
#  ('previous-job-marital-education-default-housing-loan-contact-categorical',
#   45.53591996591723),
#  ('previous-job-marital-education-default-contact-categorical',
#   45.364727315867555),
#  ('previous-job-marital-housing-contact-categorical', 45.09321900937513),
#  ('previous-job-marital-education-default-housing-contact-age_bin-categorical',
#   44.679305886748075),
#  ('euribor3m', 44.61936216857),
#  ('previous-job-marital-education-default-housing-contact-categorical',
#   44.60317925420408),
#  ('previous-job-education-default-contact-age_bin-categorical',
#   44.56827787463426),
#  ('previous-job-default-contact-categorical', 44.56338062852735),
#  ('Economic growth Q-on-Q', 44.483964513703164),
#  ('previous-job-marital-default-contact-age_bin-categorical',
#   44.314811540630124),
#  ('campaign-job-loan-contact-age_bin-categorical', 44.17873600573121),
#  ('previous-job-education-default-housing-contact-categorical',
#   44.06292948059231),
#  ('campaign-job-education-default-contact-categorical', 43.84715728554942),
#  ('Investment as percent of GDP', 43.00398017780982),
#  ('previous-marital-education-default-loan-contact-age_bin-categorical',
#   42.9342162357255),
#  ('previous-job-education-default-loan-contact-age_bin-categorical',
#   42.51958249466177),
#  ('previous-job-marital-default-housing-loan-contact-age_bin-categorical',
#   42.51210556042266),
#  ('previous-job-marital-education-loan-contact-categorical',
#   42.46993062266507),
#  ('campaign-education-default-contact-categorical', 42.091362204328995),
#  ('previous-job-marital-contact-categorical', 41.91122006363097),
#  ('previous-marital-education-default-loan-contact-categorical',
#   41.3388013846773),
#  ('previous-job-marital-education-loan-contact-age_bin-categorical',
#   41.014582982161265),
#  ('campaign-education-default-contact-age_bin-categorical', 40.47369935307858),
#  ('previous-job-default-contact-age_bin-categorical', 40.433882471943676),
#  ('previous-marital-education-default-contact-categorical', 40.23086405761349),
#  ('previous-marital-education-default-housing-loan-contact-categorical',
#   40.03388289618599),
#  ('previous-job-marital-housing-contact-age_bin-categorical',
#   40.00025403511061),
#  ('previous-marital-education-loan-contact-age_bin-categorical',
#   39.84681689642361),
#  ('campaign-default-contact-age_bin-categorical', 39.7974519168199),
#  ('previous-job-marital-loan-contact-age_bin-categorical', 39.74264292574515),
#  ('previous-marital-education-default-housing-loan-contact-age_bin-categorical',
#   39.67538396177786),
#  ('campaign-job-marital-education-housing-loan-contact-age_bin-categorical',
#   39.65415248284322),
#  ('previous-marital-default-housing-loan-contact-categorical',
#   39.53635227435327),
#  ('previous-job-education-contact-categorical', 39.38536470538783),
#  ('campaign-job-loan-contact-categorical', 39.32878445428343),
#  ('previous-education-default-contact-categorical', 39.26680142673005),
#  ('previous-job-default-loan-contact-age_bin-categorical', 38.96368284936388),
#  ('Private sector credit', 38.90209784295347),
#  ('previous-education-default-housing-loan-contact-age_bin-categorical',
#   38.86658079628014),
#  ('campaign-job-housing-contact-age_bin-categorical', 38.5486014695908),
#  ('campaign-job-education-default-contact-age_bin-categorical',
#   38.53880348658422),
#  ('previous-marital-default-housing-contact-categorical', 38.50876157665921),
#  ('previous-job-housing-loan-contact-categorical', 38.49240780968615),
#  ('previous-job-marital-contact-age_bin-categorical', 38.40468893240478),
#  ('campaign-job-housing-loan-contact-categorical', 38.33920206908871),
#  ('previous-job-education-loan-contact-categorical', 38.30539586408032),
#  ('previous-marital-education-default-housing-contact-age_bin-categorical',
#   38.286071092125766),
#  ('previous-job-education-default-housing-contact-age_bin-categorical',
#   38.26257943323741),
#  ('previous-job-marital-education-contact-categorical', 38.18412215817874),
#  ('previous-marital-education-default-housing-contact-categorical',
#   38.15257590928831),
#  ('previous-job-education-housing-loan-contact-categorical',
#   38.11649559450145),
#  ('campaign-job-marital-default-contact-age_bin-categorical',
#   37.98091807879483),
#  ('previous-education-default-loan-contact-age_bin-categorical',
#   37.97272879881247),
#  ('previous-job-loan-contact-categorical', 37.94673729933406),
#  ('previous-marital-default-loan-contact-categorical', 37.94277983097047),
#  ('previous-job-default-housing-contact-age_bin-categorical',
#   37.93299703153541),
#  ('previous-marital-education-default-contact-age_bin-categorical',
#   37.88844230586748),
#  ('previous-job-marital-education-housing-loan-contact-categorical',
#   37.7143875242794),
#  ('previous-marital-default-loan-contact-age_bin-categorical',
#   37.55199219627311),
#  ('previous-education-default-housing-contact-categorical', 37.46790382097241),
#  ('previous-education-default-contact-age_bin-categorical', 37.27055060904547),
#  ('previous-education-default-housing-contact-age_bin-categorical',
#   37.095931826426),
#  ('previous-default-housing-loan-contact-age_bin-categorical',
#   37.09506348172726),
#  ('previous-job-marital-housing-loan-contact-age_bin-categorical',
#   36.998818408153035),
#  ('previous-job-default-housing-loan-contact-age_bin-categorical',
#   36.97847196219584),
#  ('previous-education-default-housing-loan-contact-categorical',
#   36.912942302411615),
#  ('campaign-education-default-loan-contact-categorical', 36.82126792482105),
#  ('previous-education-default-loan-contact-categorical', 36.79848279398803),
#  ('campaign-job-housing-contact-categorical', 36.57699837285747),
#  ('previous-default-loan-contact-age_bin-categorical', 36.56793700042924),
#  ('previous-marital-default-contact-categorical', 36.38689488822427),
#  ('previous-job-education-default-housing-loan-contact-age_bin-categorical',
#   36.371465203508905),
#  ('campaign-job-marital-default-loan-contact-categorical', 36.35681664446128),
#  ('campaign-job-marital-default-housing-contact-categorical',
#   36.33990061129591),
#  ('previous-job-housing-contact-categorical', 36.273372482758504),
#  ('campaign-job-housing-loan-contact-age_bin-categorical', 36.23020213536944),
#  ('campaign-job-education-default-loan-contact-categorical',
#   36.18067842933465),
#  ('previous-job-education-contact-age_bin-categorical', 36.158397617328475),
#  ('campaign-default-housing-contact-age_bin-categorical', 36.131959401248864),
#  ('previous-default-loan-contact-categorical', 36.06368452482115),
#  ('previous-default-housing-loan-contact-categorical', 36.010993721102494),
#  ('previous-job-contact-categorical', 36.00623506831858),
#  ('previous-job-marital-education-housing-contact-categorical',
#   35.986757026458875),
#  ('previous-default-housing-contact-age_bin-categorical', 35.88005190185878),
#  ('previous-default-housing-contact-categorical', 35.86703806723135),
#  ('previous-default-contact-categorical', 35.663251044033025),
#  ('previous-job-marital-education-contact-age_bin-categorical',
#   35.53311222677192),
#  ('previous-job-education-loan-contact-age_bin-categorical',
#   35.46377977849031),
#  ('major_purch_opportu', 35.39783376075027),
#  ('previous-default-contact-age_bin-categorical', 35.35700240296587),
#  ('previous-marital-education-loan-contact-categorical', 35.039528657654664),
#  ('previous-marital-default-housing-loan-contact-age_bin-categorical',
#   35.03540336747407),
#  ('campaign-marital-default-contact-categorical', 34.68563250020508),
#  ('campaign-job-education-contact-categorical', 34.65545755447047),
#  ('campaign-default-loan-contact-age_bin-categorical', 34.65156038796772),
#  ('previous-marital-default-contact-age_bin-categorical', 34.63099188961646),
#  ('campaign-job-marital-education-default-contact-categorical',
#   34.426142003007676),
#  ('campaign-education-default-loan-contact-age_bin-categorical',
#   34.38693712886464),
#  ('previous-job-marital-education-default-loan-age_bin-categorical',
#   34.18634482125579),
#  ('previous-marital-education-housing-loan-contact-categorical',
#   34.157662829012224),
#  ('previous-marital-default-housing-contact-age_bin-categorical',
#   34.024731625762506),
#  ('previous-job-education-housing-contact-categorical', 34.0103583584054),
#  ('campaign-default-contact-categorical', 33.86509995092415),
#  ('previous-marital-education-contact-age_bin-categorical', 33.68473408785953),
#  ('previous-marital-education-contact-categorical', 33.48898277479984),
#  ('campaign-education-contact-age_bin-categorical', 32.942552313829616),
#  ('previous-marital-loan-contact-age_bin-categorical', 32.92530484920083),
#  ('previous-marital-housing-contact-categorical', 32.88050201898488),
#  ('previous-job-contact-age_bin-categorical', 32.85266912232442),
#  ('major_purch_opportu-rolling-avg-45', 32.7445264331882),
#  ('campaign-marital-education-housing-contact-categorical', 32.7407628217673),
#  ('campaign-job-marital-education-default-contact-age_bin-categorical',
#   32.73485196103839),
#  ('campaign-education-contact-categorical', 32.6995185136167),
#  ('campaign-contact-age_bin-categorical', 32.67499029972027),
#  ('previous-marital-loan-contact-categorical', 32.64890970410849),
#  ('previous-marital-housing-loan-contact-categorical', 32.592561816708894),
#  ('major_purch_opportu-rolling-avg-90', 32.4493596807347),
#  ('campaign-job-marital-loan-contact-categorical', 32.407108876952606),
#  ('campaign-education-loan-contact-age_bin-categorical', 32.3854288598373),
#  ('Investment', 32.25250329425493),
#  ('previous-job-loan-contact-age_bin-categorical', 32.248420722110886),
#  ('emp.var.rate', 32.241013755425904),
#  ('campaign-job-default-loan-contact-categorical', 32.01220425042673),
#  ('previous-education-loan-contact-age_bin-categorical', 31.964379710227675),
#  ('campaign-marital-default-loan-contact-categorical', 31.914025758098266),
#  ('campaign-job-education-default-loan-contact-age_bin-categorical',
#   31.864739584667166),
#  ('previous-job-marital-education-housing-contact-age_bin-categorical',
#   31.856911501589792),
#  ('campaign-marital-default-housing-contact-categorical', 31.834165987647147),
#  ('previous-marital-education-housing-contact-categorical',
#   31.820088586836203),
#  ('previous-job-housing-loan-contact-age_bin-categorical', 31.755954935601416),
#  ('campaign-job-marital-education-default-loan-contact-age_bin-categorical',
#   31.465963757396505),
#  ('previous-marital-contact-categorical', 31.217028448364843),
#  ('campaign-marital-education-default-contact-categorical', 31.15496352556221),
#  ('previous-job-housing-contact-age_bin-categorical', 31.04475378708457),
#  ('campaign-job-default-housing-contact-categorical', 30.9851461415125),
#  ('campaign-default-housing-contact-categorical', 30.886941976775002),
#  ('campaign-job-marital-default-housing-contact-age_bin-categorical',
#   30.87230722189609),
#  ('previous-education-contact-age_bin-categorical', 30.809129718138863),
#  ('previous-loan-contact-age_bin-categorical', 30.782902925985216),
#  ('campaign-job-marital-housing-loan-contact-categorical', 30.73980619626567),
#  ('previous-job-marital-education-housing-loan-contact-age_bin-categorical',
#   30.71343121380031),
#  ('campaign-job-marital-education-housing-loan-contact-categorical',
#   30.70349971049967),
#  ('campaign-loan-contact-age_bin-categorical', 30.702752440548256),
#  ('campaign-job-marital-education-housing-contact-age_bin-categorical',
#   30.68702502484928),
#  ('campaign-marital-education-contact-categorical', 30.491388805996728),
#  ('previous-marital-education-housing-loan-contact-age_bin-categorical',
#   30.356262331509566),
#  ('previous-housing-contact-age_bin-categorical', 30.301696091661565),
#  ('previous-housing-loan-contact-age_bin-categorical', 30.258548785458512),
#  ('campaign-default-loan-contact-categorical', 30.206983185431394),
#  ('campaign-job-education-default-housing-loan-contact-age_bin-categorical',
#   30.12248026694585),
#  ('previous-marital-contact-age_bin-categorical', 29.861139692047356),
#  ('previous-loan-contact-categorical', 29.853839400880684),
#  ('campaign-job-marital-contact-age_bin-categorical', 29.77366953827828),
#  ('campaign-job-marital-education-default-housing-loan-contact-categorical',
#   29.74563362670419),
#  ('previous-marital-education-housing-contact-age_bin-categorical',
#   29.711772371153728),
#  ('campaign-job-default-housing-contact-age_bin-categorical',
#   29.708999605177763),
#  ('campaign-job-marital-education-default-housing-contact-age_bin-categorical',
#   29.6101586219492),
#  ('campaign-education-default-housing-contact-categorical', 29.58820029539357),
#  ('campaign-job-education-contact-age_bin-categorical', 29.561772235517907),
#  ('campaign-job-marital-default-housing-loan-contact-categorical',
#   29.55109932627347),
#  ('previous-education-housing-loan-contact-age_bin-categorical',
#   29.54450500297185),
#  ('previous-housing-contact-categorical', 29.466859173982957),
#  ('campaign-job-marital-housing-contact-categorical', 29.445685260610425),
#  ('previous-contact-age_bin-categorical', 29.389921086867272),
#  ('campaign-education-housing-contact-age_bin-categorical', 29.35764484264354),
#  ('contact-categorical_1', 29.286976521862606),
#  ('campaign-default-housing-loan-contact-age_bin-categorical',
#   29.27669023441342),
#  ('campaign-marital-default-housing-loan-contact-categorical',
#   29.269867004409846),
#  ('previous-housing-loan-contact-categorical', 29.224177032461235),
#  ('campaign-marital-education-default-housing-contact-categorical',
#   29.210800996546922),
#  ('previous-job-education-housing-loan-contact-age_bin-categorical',
#   29.165856790376186),
#  ('previous-marital-housing-contact-age_bin-categorical', 29.144607846279786),
#  ('campaign-job-default-housing-loan-contact-categorical', 29.07922227149427),
#  ('previous-education-contact-categorical', 29.01944254551514),
#  ('previous-education-housing-contact-age_bin-categorical',
#   28.974888526936546),
#  ('campaign-marital-contact-categorical', 28.92702212099714),
#  ('campaign-job-marital-default-loan-contact-age_bin-categorical',
#   28.926518959569577),
#  ('campaign-job-marital-education-contact-categorical', 28.89550370150155),
#  ('campaign-education-housing-contact-categorical', 28.88249516003939),
#  ('previous-job-education-housing-contact-age_bin-categorical',
#   28.7825546173927),
#  ('campaign-job-marital-education-default-loan-contact-categorical',
#   28.528986551689183),
#  ('major_purch_expect', 28.488660735072525),
#  ('previous-marital-housing-loan-contact-age_bin-categorical',
#   28.1800279306007),
#  ('campaign-housing-contact-age_bin-categorical', 28.169229564779453),
#  ('campaign-job-marital-housing-loan-contact-age_bin-categorical',
#   28.138851190232355),
#  ('campaign-job-default-loan-contact-age_bin-categorical', 28.062082475532577),
#  ('previous-job-marital-education-default-housing-loan-age_bin-categorical',
#   28.024693172905987),
#  ('campaign-job-education-housing-contact-categorical', 28.01681787332436),
#  ('campaign-job-marital-education-loan-contact-age_bin-categorical',
#   27.98948083214817),
#  ('campaign-job-education-default-housing-loan-contact-categorical',
#   27.685667039480315),
#  ('previous-education-housing-loan-contact-categorical', 27.66824427532545),
#  ('campaign-marital-housing-loan-contact-age_bin-categorical',
#   27.636482231584523),
#  ('campaign-job-marital-education-contact-age_bin-categorical',
#   27.525675969791997),
#  ('previous-education-housing-contact-categorical', 27.514805263799964),
#  ('campaign-default-housing-loan-contact-categorical', 27.49214792594661),
#  ('previous-education-loan-contact-categorical', 27.456471572184398),
#  ('financial_past-rolling-avg-90', 27.31222856224765),
#  ('campaign-education-loan-contact-categorical', 27.298749781522403),
#  ('financial_past', 27.149060874063046),
#  ('campaign-marital-housing-contact-categorical', 27.034060642825835),
#  ('campaign-education-default-housing-contact-age_bin-categorical',
#   27.02861049740633),
#  ('financial_past-rolling-avg-45', 26.961177623288997),
#  ('Current account balance', 26.62943862097372),
#  ('campaign-job-marital-loan-contact-age_bin-categorical', 26.597237674205928),
#  ('campaign-marital-default-loan-contact-age_bin-categorical',
#   26.57213626820882),
#  ('campaign-job-education-default-housing-contact-categorical',
#   26.55570134957828),
#  ('campaign-marital-loan-contact-age_bin-categorical', 26.400816791080356),
#  ('campaign-job-marital-education-housing-contact-categorical',
#   26.32815791771289),
#  ('campaign-loan-contact-categorical', 26.232146118460108),
#  ('campaign-marital-default-contact-age_bin-categorical', 26.20320492005934),
#  ('campaign-housing-contact-categorical', 26.17416948398121),
#  ('campaign-marital-default-housing-contact-age_bin-categorical',
#   26.1327697158867),
#  ('campaign-job-marital-housing-contact-age_bin-categorical',
#   26.098678988853145),
#  ('campaign-job-education-housing-loan-contact-age_bin-categorical',
#   26.014139383336026),
#  ('Government expenditure', 26.010899946689925),
#  ('major_purch_expect-rolling-avg-90', 25.9626970981486),
#  ('major_purch_expect-rolling-avg-45', 25.81009135755885),
#  ('campaign-housing-loan-contact-age_bin-categorical', 25.692415993187872),
#  ('campaign-marital-housing-loan-contact-categorical', 25.65916816657862),
#  ('campaign-marital-loan-contact-categorical', 25.609661539414112),
#  ('campaign-job-education-loan-contact-categorical', 25.52452634954076),
#  ('Business credit', 25.49133573267126),
#  ('campaign-job-marital-education-loan-contact-categorical',
#   25.39336687015811),
#  ('previous-job-marital-education-default-loan-categorical',
#   25.226265697315238),
#  ('campaign-education-default-housing-loan-contact-categorical',
#   25.046020850853658),
#  ('campaign-housing-loan-contact-categorical', 24.94718022427625),
#  ('campaign-job-education-housing-loan-contact-categorical',
#   24.792890885562503),
#  ('campaign-marital-default-housing-loan-contact-age_bin-categorical',
#   24.76633339761625),
#  ('campaign-marital-education-housing-loan-contact-categorical',
#   24.406858616069236),
#  ('campaign-marital-contact-age_bin-categorical', 24.11706283302546),
#  ('campaign-job-marital-default-housing-loan-contact-age_bin-categorical',
#   24.108137115786917),
#  ('campaign-marital-housing-contact-age_bin-categorical', 24.066639479842582),
#  ('campaign-marital-education-contact-age_bin-categorical',
#   23.982777498497025),
#  ('campaign-job-marital-education-default-housing-contact-categorical',
#   23.906268379236643),
#  ('campaign-marital-education-default-loan-contact-categorical',
#   23.88830299719615),
#  ('campaign-job-education-loan-contact-age_bin-categorical',
#   23.844823565331044),
#  ('previous-job-marital-education-default-age_bin-categorical',
#   23.8372746208322),
#  ('campaign-marital-education-default-housing-loan-contact-categorical',
#   23.778010747840206),
#  ('campaign-job-education-housing-contact-age_bin-categorical',
#   23.754217010267453),
#  ('previous-job-marital-education-default-housing-age_bin-categorical',
#   23.431224217677094),
#  ('campaign-marital-education-loan-contact-categorical', 23.13058479885501),
#  ('campaign-marital-education-loan-contact-age_bin-categorical',
#   22.919189889726578),
#  ('campaign-job-education-default-housing-contact-age_bin-categorical',
#   22.599206211779496),
#  ('campaign-education-default-housing-loan-contact-age_bin-categorical',
#   22.269274902085858),
#  ('campaign-marital-education-housing-contact-age_bin-categorical',
#   22.083914934850675),
#  ('campaign-education-housing-loan-contact-age_bin-categorical',
#   21.835091946304576),
#  ('campaign-job-default-housing-loan-contact-age_bin-categorical',
#   21.811952719479187),
#  ('campaign-job-marital-education-housing-loan-age_bin-categorical',
#   21.494230826217514),
#  ('previous-job-marital-education-default-housing-loan-categorical',
#   21.368894341398153),
#  ('campaign-education-housing-loan-contact-categorical', 21.13488492564671),
#  ('previous-job-marital-default-loan-categorical', 21.08484886058374),
#  ('campaign-job-marital-education-default-housing-loan-age_bin-categorical',
#   21.035552833260507),
#  ('Exports', 20.844294687143364),
#  ('Budget balance', 20.796354841284273),
#  ('previous-job-education-default-loan-age_bin-categorical',
#   20.459879457860197),
#  ('previous-job-education-default-loan-categorical', 20.26206854560915),
#  ('campaign-marital-education-default-contact-age_bin-categorical',
#   20.191536243754435),
#  ('previous-job-education-default-housing-loan-categorical',
#   19.78896746656421),
#  ('campaign-marital-education-housing-loan-contact-age_bin-categorical',
#   19.75486942921119),
#  ('ind_turnover', 19.6162932437688),
#  ('previous-job-marital-education-loan-age_bin-categorical',
#   19.310739198968268),
#  ('campaign-job-marital-education-default-loan-age_bin-categorical',
#   19.111077449862815),
#  ('previous-job-marital-default-loan-age_bin-categorical', 18.881206457929135),
#  ('previous-job-marital-default-housing-loan-categorical', 18.6863037506791),
#  ('ind_turnover-rolling-avg-45', 18.66071005229694),
#  ('previous-job-education-default-housing-loan-age_bin-categorical',
#   18.346405797802433),
#  ('previous-marital-education-default-loan-age_bin-categorical',
#   18.242185155105823),
#  ('ind_turnover-rolling-avg-90', 18.08305984687677),
#  ('campaign-job-education-default-loan-categorical', 18.007514080949555),
#  ('previous-job-education-default-age_bin-categorical', 17.66790495634611),
#  ('previous-job-default-loan-categorical', 17.618576994108707),
#  ('previous-job-marital-education-default-housing-categorical',
#   17.569695548708903),
#  ('previous-job-marital-default-categorical', 17.558608495425),
#  ('previous', 17.553705940451582),
#  ('previous-job-marital-education-default-categorical', 17.487797492944377),
#  ('previous-job-marital-default-age_bin-categorical', 17.466362146764165),
#  ('savings_expect', 17.334001260711194),
#  ('previous-job-marital-education-housing-loan-age_bin-categorical',
#   16.980082248901855),
#  ('previous-job-marital-default-housing-age_bin-categorical',
#   16.873094707095326),
#  ('campaign-marital-education-default-housing-contact-age_bin-categorical',
#   16.806634286462703),
#  ('previous-job-marital-default-housing-categorical', 16.745049857755532),
#  ('campaign-job-default-categorical', 16.450058418050812),
#  ('previous-job-education-default-categorical', 16.381956229799396),
#  ('household_debt_ratio', 16.276000252619657),
#  ('campaign-job-education-default-loan-age_bin-categorical', 16.2725498887075),
#  ('previous-job-default-age_bin-categorical', 16.051449638691405),
#  ('previous-job-default-housing-loan-categorical', 15.997953572501954),
#  ('campaign-job-education-default-categorical', 15.897459096738404),
#  ('campaign-marital-education-default-loan-contact-age_bin-categorical',
#   15.742826221824016),
#  ('previous-job-default-loan-age_bin-categorical', 15.703678616879422),
#  ('month', 15.499389185709882),
#  ('previous-job-default-categorical', 15.411416206918966),
#  ('Consumption as percent of GDP', 15.271177607202787),
#  ('savings_expect-rolling-avg-45', 15.202893800059678),
#  ('savings_expect-rolling-avg-90', 15.095899695364993),
#  ('previous-job-marital-default-housing-loan-age_bin-categorical',
#   15.066655103290387),
#  ('campaign-job-marital-default-categorical', 14.990012743462424),
#  ('household_debt_ratio-rolling-avg-90', 14.912271859095021),
#  ('campaign-job-marital-education-default-age_bin-categorical',
#   14.868265328477259),
#  ('previous-job-default-housing-categorical', 14.854298942095625),
#  ('household_debt_ratio-rolling-avg-45', 14.743332142573687),
#  ('previous-marital-education-default-housing-loan-age_bin-categorical',
#   14.646877150783766),
#  ('previous-job-education-default-housing-age_bin-categorical',
#   14.503099517455258),
#  ('previous-job-default-housing-age_bin-categorical', 14.442689056288033),
#  ('campaign-marital-education-default-housing-loan-contact-age_bin-categorical',
#   14.206847344778936),
#  ('previous-job-default-housing-loan-age_bin-categorical', 14.11420550709808),
#  ('previous-job-marital-education-loan-categorical', 13.928112534486543),
#  ('campaign-job-marital-default-loan-categorical', 13.895210432266532),
#  ('previous-job-education-default-housing-categorical', 13.795601684284522),
#  ('campaign-job-marital-education-default-loan-categorical',
#   13.745434805483182),
#  ('previous-job-marital-housing-age_bin-categorical', 13.298444185406884),
#  ('campaign-job-marital-education-default-categorical', 13.184139611624575),
#  ('campaign-job-marital-education-default-housing-loan-categorical',
#   13.057806425880528),
#  ('previous-job-marital-loan-categorical', 12.961075740908543),
#  ('campaign-job-education-default-housing-loan-age_bin-categorical',
#   12.890751331454913),
#  ('campaign-job-marital-education-housing-loan-categorical',
#   12.66891064358007),
#  ('Consumer credit', 12.584272928154897),
#  ('previous-job-marital-education-housing-age_bin-categorical',
#   12.545162944231354),
#  ('previous-marital-education-default-age_bin-categorical',
#   12.538445289059908),
#  ('campaign-job-marital-education-loan-age_bin-categorical',
#   12.500417430749605),
#  ('unempl_expect-rolling-avg-90', 12.481687558601514),
#  ('previous-job-marital-education-housing-loan-categorical',
#   12.45345263802928),
#  ('campaign-job-marital-categorical', 12.450283381938164),
#  ('previous-job-marital-education-age_bin-categorical', 12.411251515735971),
#  ('unempl_expect', 12.390412937297112),
#  ('campaign-job-default-age_bin-categorical', 12.30638308135044),
#  ('previous-marital-education-default-housing-age_bin-categorical',
#   12.290783500408109),
#  ('previous-job-marital-age_bin-categorical', 12.279561210312078),
#  ('previous-job-marital-housing-loan-categorical', 12.260373691917161),
#  ('previous-marital-education-loan-age_bin-categorical', 12.256402712200456),
#  ('unempl_expect-rolling-avg-45', 12.162504636637282),
#  ('campaign-job-default-housing-loan-categorical', 12.099920212464859),
#  ('campaign-job-education-housing-loan-age_bin-categorical',
#   12.013331674022727),
#  ('previous-job-marital-loan-age_bin-categorical', 11.995007514920173),
#  ('previous-marital-default-loan-age_bin-categorical', 11.969221440387766),
#  ('campaign-job-default-loan-categorical', 11.845041739728211),
#  ('campaign-job-education-default-age_bin-categorical', 11.727668276181857),
#  ('campaign-job-default-housing-categorical', 11.72528277948513),
#  ('campaign-job-marital-education-default-housing-age_bin-categorical',
#   11.717823561930103),
#  ('campaign-job-housing-loan-categorical', 11.429923563903955),
#  ('previous-job-marital-housing-loan-age_bin-categorical', 11.364286158925504),
#  ('previous-job-education-loan-age_bin-categorical', 11.206859145488906),
#  ('campaign-education-default-age_bin-categorical', 11.203060906211102),
#  ('campaign-job-marital-education-housing-age_bin-categorical',
#   11.093617093128247),
#  ('previous-job-education-age_bin-categorical', 10.966278976204105),
#  ('campaign-job-marital-default-housing-categorical', 10.901559480279259),
#  ('previous-job-marital-housing-categorical', 10.591110837168914),
#  ('Inflation annual', 10.548793682365089),
#  ('previous-job-education-housing-loan-age_bin-categorical',
#   10.536742645918265),
#  ('previous-default-loan-age_bin-categorical', 10.50268381607544),
#  ('previous-job-marital-categorical', 10.484428434667493),
#  ('campaign-job-marital-education-housing-categorical', 10.340797742744705),
#  ('campaign-job-age_bin-categorical', 10.287447990213074),
#  ('campaign-job-loan-categorical', 10.14878127361833),
#  ('campaign-job-marital-education-age_bin-categorical', 10.112738579375492),
#  ('previous-marital-default-age_bin-categorical', 10.06814324813021),
#  ('previous-marital-education-default-loan-categorical', 10.065217534921137),
#  ('previous-default-housing-loan-age_bin-categorical', 9.971201719735905),
#  ('campaign-job-education-default-housing-loan-categorical',
#   9.955864733723383),
#  ('previous-default-age_bin-categorical', 9.944901235282652),
#  ('campaign-job-loan-age_bin-categorical', 9.932763343347688),
#  ('campaign-job-marital-education-default-housing-categorical',
#   9.907563400155412),
#  ('campaign-job-marital-education-categorical', 9.740343048727809),
#  ('previous-job-marital-education-housing-categorical', 9.622868537081198),
#  ('campaign-job-marital-education-loan-categorical', 9.604744165399842),
#  ('previous-marital-default-housing-loan-age_bin-categorical',
#   9.597067207549594),
#  ('campaign-default-age_bin-categorical', 9.556216351812886),
#  ('previous-job-marital-education-categorical', 9.491112785478975),
#  ('campaign-job-marital-loan-categorical', 9.254599052068393),
#  ('campaign-job-marital-housing-loan-categorical', 9.240874288159096),
#  ('campaign-job-marital-default-housing-loan-categorical', 9.216683119662951),
#  ('previous-default-housing-age_bin-categorical', 9.198619857066989),
#  ('campaign-job-education-loan-age_bin-categorical', 9.10229770951376),
#  ('previous-education-default-loan-age_bin-categorical', 8.748849447657859),
#  ('campaign-job-education-default-housing-categorical', 8.738007698803823),
#  ('previous-education-default-housing-loan-age_bin-categorical',
#   8.688601915191944),
#  ('previous-marital-education-default-categorical', 8.672994477269942),
#  ('campaign-job-education-housing-age_bin-categorical', 8.61044711485303),
#  ('job-categorical_8', 8.580080944437485),
#  ('campaign-default-loan-age_bin-categorical', 8.536212070455484),
#  ('previous-job-education-housing-loan-categorical', 8.525617366501129),
#  ('campaign-job-housing-loan-age_bin-categorical', 8.462307607906464),
#  ('previous-marital-default-housing-age_bin-categorical', 8.460898053238795),
#  ('campaign-job-education-categorical', 8.413545657916455),
#  ('campaign-education-default-categorical', 8.380152190436723),
#  ('previous-job-education-loan-categorical', 8.308485480509958),
#  ('campaign-job-education-age_bin-categorical', 8.114810471046527),
#  ('previous-education-default-age_bin-categorical', 7.987118445088658),
#  ('previous-job-age_bin-categorical', 7.939311476241772),
#  ('previous-job-loan-categorical', 7.833905789239621),
#  ('previous-marital-education-default-housing-loan-categorical',
#   7.811592601029439),
#  ('job-categorical_9', 7.779006792734049),
#  ('previous-job-education-housing-age_bin-categorical', 7.715688775725699),
#  ('campaign-job-housing-categorical', 7.6392163011844225),
#  ('previous-education-default-housing-age_bin-categorical', 7.598766733757909),
#  ('campaign-job-education-loan-categorical', 7.520713830020317),
#  ('previous-job-education-categorical', 7.410735623364221),
#  ('previous-marital-education-housing-loan-age_bin-categorical',
#   7.369923955925169),
#  ('previous-job-housing-loan-age_bin-categorical', 7.366670219626904),
#  ('previous-job-loan-age_bin-categorical', 7.3521516951153245),
#  ('previous-marital-loan-age_bin-categorical', 7.34704744340148),
#  ('campaign-job-default-loan-age_bin-categorical', 7.2878153448679495),
#  ('previous-job-housing-age_bin-categorical', 7.232209669234746),
#  ('campaign-job-marital-housing-loan-age_bin-categorical', 7.206502029874118),
#  ('previous-job-housing-loan-categorical', 7.120222023374936),
#  ('job-categorical_1', 6.95272414161787),
#  ('campaign-education-default-loan-age_bin-categorical', 6.874636846336486),
#  ('previous-marital-default-categorical', 6.814713693953319),
#  ('Investment growth', 6.7414792613011025),
#  ('previous-marital-default-loan-categorical', 6.724676116033642),
#  ('campaign-job-education-default-housing-age_bin-categorical',
#   6.628354291069571),
#  ('education-categorical_6', 6.582606625104329),
#  ('campaign-job-marital-default-loan-age_bin-categorical', 6.55597346309116),
#  ('previous-marital-education-default-housing-categorical', 6.414811403943669),
#  ('job-categorical_5', 6.355491586030045),
#  ('previous-marital-education-age_bin-categorical', 6.351345911094251),
#  ('campaign-job-housing-age_bin-categorical', 6.293320021473365),
#  ('previous-marital-default-housing-loan-categorical', 6.229853173330346),
#  ('previous-job-housing-categorical', 6.0803154666272174),
#  ('Household consumption', 6.014598579109615),
#  ('campaign-job-default-housing-age_bin-categorical', 5.906113817009653),
#  ('previous-marital-age_bin-categorical', 5.852070985794508),
#  ('previous-marital-default-housing-categorical', 5.702105151136813),
#  ('campaign-marital-education-default-housing-categorical', 5.669296407895372),
#  ('old_prospect', 5.604791475727865),
#  ('previous-marital-education-housing-age_bin-categorical', 5.593102349403129),
#  ('previous-education-default-categorical', 5.570437350067995),
#  ('default-categorical_1', 5.531465177682301),
#  ('campaign-default-housing-age_bin-categorical', 5.488208722830167),
#  ('campaign-job-marital-loan-age_bin-categorical', 5.360177789359253),
#  ('previous-job-education-housing-categorical', 5.304081305117239),
#  ('campaign-job-marital-housing-categorical', 5.142909229955038),
#  ('previous-default-loan-categorical', 5.109814695636034),
#  ('campaign-marital-default-loan-age_bin-categorical', 4.846663550224732),
#  ('previous-marital-housing-age_bin-categorical', 4.75897523744518),
#  ('previous-marital-housing-loan-age_bin-categorical', 4.751086517725095),
#  ('campaign-education-default-loan-categorical', 4.714184079110605),
#  ('previous-education-default-loan-categorical', 4.669118231162034),
#  ('previous-loan-age_bin-categorical', 4.5278054421378355),
#  ('campaign-job-education-housing-categorical', 4.4856889808226965),
#  ('campaign-job-marital-default-age_bin-categorical', 4.2798322911730216),
#  ('previous-education-default-housing-loan-categorical', 4.050011660540317),
#  ('campaign-job-default-housing-loan-age_bin-categorical', 3.9955203557252603),
#  ('previous-default-housing-loan-categorical', 3.9947527501318443),
#  ('campaign-job-marital-default-housing-loan-age_bin-categorical',
#   3.9664090901615263),
#  ('campaign-loan-age_bin-categorical', 3.949488029148217),
#  ('campaign-education-default-housing-age_bin-categorical',
#   3.9425974363988368),
#  ('campaign-education-housing-loan-categorical', 3.9387153101298704),
#  ('previous-default-housing-categorical', 3.921440713347868),
#  ('previous-education-default-housing-categorical', 3.870539711827824),
#  ('previous-education-housing-categorical', 3.8204125761818397),
#  ('campaign-default-loan-categorical', 3.741629204541386),
#  ('campaign-job-marital-default-housing-age_bin-categorical',
#   3.6890923780419755),
#  ('campaign-marital-default-loan-categorical', 3.625552523125817),
#  ('campaign-marital-default-housing-loan-age_bin-categorical',
#   3.5601870309677515),
#  ('marital-categorical_3', 3.533959860079459),
#  ('campaign-marital-default-categorical', 3.503725648296659),
#  ('campaign-marital-housing-loan-age_bin-categorical', 3.360239022696863),
#  ('previous-education-housing-loan-categorical', 3.3320499332074633),
#  ('previous-housing-age_bin-categorical', 3.253428786973491),
#  ('previous-housing-loan-age_bin-categorical', 3.192822785542443),
#  ('campaign-job-education-housing-loan-categorical', 3.181034596349381),
#  ('previous-marital-loan-categorical', 3.1598630129109306),
#  ('campaign-default-housing-loan-age_bin-categorical', 3.153912164349786),
#  ('campaign-education-loan-categorical', 3.1101864619977526),
#  ('previous-education-loan-categorical', 3.107037595383274),
#  ('previous-housing-loan-categorical', 2.958740526622144),
#  ('education-categorical_5', 2.956020247259998),
#  ('campaign-education-default-housing-loan-age_bin-categorical',
#   2.8577804481479725),
#  ('Exchange rate to USD', 2.854930629363514),
#  ('campaign-education-default-housing-categorical', 2.85412545002797),
#  ('campaign-marital-default-age_bin-categorical', 2.8535776030225666),
#  ('previous-education-loan-age_bin-categorical', 2.8492668387179827),
#  ('Consumption growth', 2.8082167897654435),
#  ('cons.conf.idx', 2.751237650677068),
#  ('age_bin-categorical_2', 2.723439356297009),
#  ('campaign-marital-education-default-loan-age_bin-categorical',
#   2.6825800214642888),
#  ('campaign-job-marital-age_bin-categorical', 2.6118423316287966),
#  ('campaign-default-housing-categorical', 2.5414505609252314),
#  ('campaign-marital-education-default-housing-age_bin-categorical',
#   2.5254989654372832),
#  ('marital-categorical_2', 2.5109886865910216),
#  ('campaign-education-housing-categorical', 2.492136623589668),
#  ('previous-marital-education-loan-categorical', 2.450905764547557),
#  ('campaign-marital-default-housing-age_bin-categorical', 2.4402605634222985),
#  ('previous-education-housing-loan-age_bin-categorical', 2.4282068460238713),
#  ('campaign-marital-education-default-housing-loan-age_bin-categorical',
#   2.42336809945245),
#  ('previous-education-age_bin-categorical', 2.296140804157646),
#  ('campaign-marital-education-default-categorical', 2.150085860588198),
#  ('campaign-job-marital-housing-age_bin-categorical', 2.044952550443902),
#  ('campaign-housing-loan-categorical', 2.017006136679861),
#  ('previous-education-housing-age_bin-categorical', 1.953548261065971),
#  ('housing-categorical_2', 1.9065105544927918),
#  ('previous-marital-education-housing-loan-categorical', 1.7652552927127596),
#  ('campaign-education-age_bin-categorical', 1.7495630379309726),
#  ('age_bin-categorical_1', 1.7237160554566349),
#  ('job-categorical_11', 1.7137103071537125),
#  ('campaign-marital-education-housing-loan-age_bin-categorical',
#   1.6565753500915774),
#  ('campaign-marital-default-housing-categorical', 1.6534867054571052),
#  ('campaign-marital-education-default-housing-loan-categorical',
#   1.618518334345567),
#  ('cons_conf', 1.6026092861393553),
#  ('cons_conf-rolling-avg-45', 1.5410522308944874),
#  ('campaign-education-loan-age_bin-categorical', 1.527230351097634),
#  ('cons_conf-rolling-avg-90', 1.5253898765032186),
#  ('campaign-marital-education-housing-categorical', 1.3716352335247046),
#  ('education-categorical_1', 1.356423065344449),
#  ('campaign-marital-education-default-loan-categorical', 1.3525452042985733),
#  ('campaign-marital-loan-age_bin-categorical', 1.3114013895456114),
#  ('previous-marital-housing-categorical', 1.298622365091813),
#  ('previous-marital-housing-loan-categorical', 1.265529194943996),
#  ('education-categorical_3', 1.245963220756081),
#  ('previous-marital-education-categorical', 1.2354419422750564),
#  ('age-rolling-sum-60', 1.218260940331838),
#  ('age-rolling-avg-60', 1.218260940329054),
#  ('job-categorical_10', 1.2066449913908488),
#  ('campaign-marital-education-housing-age_bin-categorical',
#   1.2054197396476918),
#  ('Consumer Price Index (CPI)', 1.2023317444676787),
#  ('age-rolling-avg-10', 1.200946722646381),
#  ('age-rolling-sum-10', 1.2009467226463275),
#  ('cons.price.idx', 1.1623094940182708),
#  ('campaign-default-housing-loan-categorical', 1.1617116284572082),
#  ('Retail sales', 1.1614274217281042),
#  ('campaign-marital-education-default-age_bin-categorical',
#   1.1192333025159413),
#  ('campaign-marital-default-housing-loan-categorical', 1.0875422242333201),
#  ('campaign-education-default-housing-loan-categorical', 1.0784969891720972),
#  ('default-categorical_2', 1.071545666248955),
#  ('job-categorical_3', 0.9923148807078381),
#  ('housing-categorical_1', 0.9875733519031513),
#  ('loan-categorical_1', 0.9875733519031513),
#  ('campaign-marital-education-loan-categorical', 0.9829259997215691),
#  ('education-categorical_2', 0.9527996615149553),
#  ('campaign-housing-loan-age_bin-categorical', 0.8815060241577486),
#  ('previous-marital-education-housing-categorical', 0.8025463386776496),
#  ('campaign-marital-education-loan-age_bin-categorical', 0.7823094185673811),
#  ('job-categorical_6', 0.7510614904478244),
#  ('campaign-housing-age_bin-categorical', 0.7149311071672654),
#  ('age_bin-categorical_3', 0.6793253724525662),
#  ('marital-categorical_1', 0.6728783570145014),
#  ('month_last_contact', 0.5607958359569988),
#  ('job-categorical_2', 0.5574508231747944),
#  ('campaign-marital-housing-age_bin-categorical', 0.5236964867061907),
#  ('Economic growth', 0.47714667047425147),
#  ('education-categorical_7', 0.4530413236453706),
#  ('age-rolling-sum-30', 0.3153918890909849),
#  ('age-rolling-avg-30', 0.3153918890905276),
#  ('campaign-marital-education-categorical', 0.3094481571656305),
#  ('campaign-marital-housing-categorical', 0.23990667197489918),
#  ('campaign-education-housing-age_bin-categorical', 0.23866704945424058),
#  ('campaign-education-housing-loan-age_bin-categorical', 0.21377800672962657),
#  ('inflation_delta_expect', 0.1434380575667645),
#  ('campaign-marital-loan-categorical', 0.11501796373038499),
#  ('education-categorical_4', 0.0916053981729585),
#  ('Gross Domestic Product (GDP)', 0.08237429315718257),
#  ('job-categorical_4', 0.07047092081084726),
#  ('inflation_delta_expect-rolling-avg-45', 0.06872628072707623),
#  ('campaign-marital-education-age_bin-categorical', 0.06550139272637155),
#  ('new_prospect', 0.04646553674476931),
#  ('inflation_delta_expect-rolling-avg-90', 0.04432557009997007),
#  ('age', 0.03086667168139963),
#  ('campaign-marital-housing-loan-categorical', 0.020893829648223502),
#  ('campaign-marital-age_bin-categorical', 0.010823381474542738),
#  ('job-categorical_7', 0.0008353605362552548),
#  ('loan-categorical_2', 0.0006048898740834548),
#  ('campaign-marital-education-housing-loan-categorical',
#   0.0002753491889541692)]

# %%
#among the top 70 indicators, many are economic indicators that are highly related to one another
#to avoid redundancy we will pick only the top 10 economic indicators
rfe_test1 = [i[0] for i in best_cols][:40]

# %%
X[rfe_test1].shape
# Out:
# (41188, 40)

# %% [markdown]
# Feature Importances Via Decision Tree Regression

# %%
X_test1 = X[rfe_test1]

# %%
from sklearn.feature_selection import RFE, RFECV
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import r2_score

# %%
def test_regression(X, y):
    lr = LinearRegression()
    lr.fit(X,y)
    scores = cross_val_score(lr,X,y,cv=10, scoring = 'r2')
    print('CV R2 : %.3f +/- %.3f' %(np.mean(scores), np.std(scores)))

# %%
X_train, X_test, y_train, y_test = train_test_split(X_test1,y, test_size = 0.20, random_state=4)

# %%
model = RandomForestRegressor(max_depth = 20, min_samples_split = 1000, random_state = 4)

# %%
model.fit(X_train,y_train)
# Out:
# /Users/pauldefusco/anaconda2/envs/py36/lib/python3.6/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=20,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=1000,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=None,
#            oob_score=False, random_state=4, verbose=0, warm_start=False)

# %%
r2_score(y_test, model.predict(X_test))
# Out:
# 0.016742790411616193

# %%
#Second test with less features
rfe_test2 = [i[0] for i in best_cols][:20]
X_test2 = X[rfe_test2]

# %%
X_test2 = scale_noncat_only(X_test2)
# Out:
# /Users/pauldefusco/anaconda2/envs/py36/lib/python3.6/site-packages/sklearn/preprocessing/data.py:625: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /Users/pauldefusco/anaconda2/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:8: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.

# %%
X_train, X_test, y_train, y_test = train_test_split(X_test2,y, test_size = 0.20, random_state=4)

# %%
model = RandomForestRegressor(max_depth = 20, min_samples_split = 1000, random_state = 4)

# %%
model.fit(X_train,y_train)
# Out:
# /Users/pauldefusco/anaconda2/envs/py36/lib/python3.6/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=20,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=1000,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=None,
#            oob_score=False, random_state=4, verbose=0, warm_start=False)

# %%
r2_score(y_test, model.predict(X_test))
# Out:
# 0.016912919525384873

# %%
#loading df
X, y, names = prep_df(final_df)

# %%
#Third test with less features
rfe_test3 = [i[0] for i in best_cols][:70]
X_test3 = X[rfe_test3]

# %%
X_test3 = scale_noncat_only(X_test3)
# Out:
# /Users/pauldefusco/anaconda2/envs/py36/lib/python3.6/site-packages/sklearn/preprocessing/data.py:625: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.
#   return self.partial_fit(X, y)
# /Users/pauldefusco/anaconda2/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:8: DataConversionWarning: Data with input dtype int64, float64 were all converted to float64 by StandardScaler.

# %%
X_train, X_test, y_train, y_test = train_test_split(X_test3,y, test_size = 0.20, random_state=4)

# %%
model = RandomForestRegressor(max_depth = 20, min_samples_split = 1000, random_state = 4)

# %%
model.fit(X_train,y_train)
# Out:
# /Users/pauldefusco/anaconda2/envs/py36/lib/python3.6/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)
# RandomForestRegressor(bootstrap=True, criterion='mse', max_depth=20,
#            max_features='auto', max_leaf_nodes=None,
#            min_impurity_decrease=0.0, min_impurity_split=None,
#            min_samples_leaf=1, min_samples_split=1000,
#            min_weight_fraction_leaf=0.0, n_estimators=10, n_jobs=None,
#            oob_score=False, random_state=4, verbose=0, warm_start=False)

# %%
r2_score(y_test, model.predict(X_test))
# Out:
# 0.01978955349149969

# %% [markdown]
# Too many predictors are monthly while call duration depends on specific customer interaction

# %% [markdown]
# We give up regression methods as a way to predict call duration - will focus on autocorrelation models instead

# %%
from pandas.plotting import lag_plot

# %%
lag_plot(y, lag=50)

# %%
oldp_idx = X[X['old_prospect']==1].index

# %%
lag_plot(y[oldp_idx], alpha=0.1, lag=20)

# %%
import matplotlib.pyplot as plt
lags = 9
columns = [y]
plt.figure(figsize=(12,12))

for i in range(1,(lags + 1)):
    columns.append(y.shift(i))

dataframe = pd.concat(columns, axis=1) 
columns = ['t']

for i in range(1,(lags + 1)):
                              
    columns.append('t-' + str(i)) 

dataframe.columns = columns 

for i in range(1,(lags + 1)):
    ax = plt.subplot(260 + i)
    ax.set_title('t vs t-' + str(i))
    plt.scatter(x=dataframe['t'], y=dataframe['t-'+str(i)].values)
pyplot.show()

# %%
final_df = pd.read_pickle('../data/pickle_files/final_df_pickle')
##Old Prospect
oldp_idx = final_df[final_df['old_prospect']==1].index
y_oldprospect = y[oldp_idx]
##New Prospect
newp_idx = final_df[final_df['new_prospect']==1].index
y_newprospect = y[newp_idx]
##New Lead
newl_idx = final_df[final_df['new_lead']==1].index
y_newlead = y[newl_idx]

# %%
lag = 500
print(len(y)-lag)
print(len(y_oldprospect)-lag)
print(len(y_newprospect)-lag)
print(len(y_newlead)-lag)
# Out:
# 40688
# 5125
# 20272
# 14291

# %%
from matplotlib import pyplot
from pandas.plotting import autocorrelation_plot

fig, ax = plt.subplots(figsize=(10,6))

lag = 200
autocorrelation_plot(y[len(y)-lag:], ax=ax, color='blue', label='Total Duration')
#autocorrelation_plot(y_oldprospect[len(y_oldprospect)-lag:], ax=ax, color='blue', label='Old Prospet Duration')
#autocorrelation_plot(y_newprospect[len(y_newprospect)-lag:], ax=ax, color='orange', label='New Prospect Duration')
#autocorrelation_plot(y_newlead[len(y_newlead)-lag:], ax=ax, color='darkgreen', label='New Lead Duration')

plt.legend()
pyplot.show()

# %%
from statsmodels.tsa.ar_model import AR
from sklearn.metrics import mean_squared_error
from math import sqrt

# %%
train, test = y[len(y)-200:len(y)-7], y[len(y)-7:]

# %%
model = AR(train)
# Out:
# /Users/pauldefusco/anaconda2/envs/py36/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:221: ValueWarning: An unsupported index was provided and will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)

# %%
model_fit = model.fit()
print('Lag: %s' % model_fit.k_ar)
print('Coefficients: %s' % model_fit.params)
# Out:
# Lag: 14
# Coefficients: const          276.724
# L1.duration      0.197
# L2.duration      0.117
# L3.duration     -0.010
# L4.duration     -0.010
# L5.duration     -0.004
# L6.duration      0.089
# L7.duration     -0.095
# L8.duration      0.100
# L9.duration      0.031
# L10.duration    -0.119
# L11.duration    -0.011
# L12.duration    -0.135
# L13.duration     0.073
# L14.duration    -0.047
# dtype: float64

# %%
# make predictions
predictions = model_fit.predict(start=len(train), end=len(train)+len(test)-1, dynamic=False) 
for i in range(len(predictions)):
    print('predicted=%i, expected=%i'%(predictions.iloc[i], test.iloc[i])) 
rmse = sqrt(mean_squared_error(test, predictions))
print('Test RMSE: %.3f' % rmse)
# Out:
# predicted=338, expected=281
# predicted=334, expected=112
# predicted=333, expected=334
# predicted=366, expected=383
# predicted=323, expected=189
# predicted=370, expected=442
# predicted=371, expected=239
# Test RMSE: 115.771
# /Users/pauldefusco/anaconda2/envs/py36/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)

# %%
# plot results
pyplot.plot(test)
pyplot.plot(predictions, color='red') 
pyplot.show()

# %%
from statsmodels.tsa.arima_model import ARIMA

# %%
model = ARIMA(y_oldprospect[len(y_oldprospect)-lag:], order=(5,1,0))
model_fit = model.fit(disp=0)
# summary of fit model
print(model_fit.summary())
# line plot of residuals
residuals = pd.DataFrame(model_fit.resid) 
residuals.plot()
pyplot.show()
# Out:
# /Users/pauldefusco/anaconda2/envs/py36/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /Users/pauldefusco/anaconda2/envs/py36/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /Users/pauldefusco/anaconda2/envs/py36/lib/python3.6/site-packages/scipy/signal/signaltools.py:1341: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   out_full[ind] += zi
# /Users/pauldefusco/anaconda2/envs/py36/lib/python3.6/site-packages/scipy/signal/signaltools.py:1344: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   out = out_full[ind]
# /Users/pauldefusco/anaconda2/envs/py36/lib/python3.6/site-packages/scipy/signal/signaltools.py:1350: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   zf = out_full[ind]
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:             D.duration   No. Observations:                  199
# Model:                 ARIMA(5, 1, 0)   Log Likelihood                -554.333
# Method:                       css-mle   S.D. of innovations              3.913
# Date:                Mon, 14 Jan 2019   AIC                           1122.667
# Time:                        02:21:08   BIC                           1145.720
# Sample:                             1   HQIC                          1131.997
#
# ====================================================================================
#                        coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------------
# const               -0.0193      0.085     -0.227      0.821      -0.186       0.147
# ar.L1.D.duration    -0.7523      0.069    -10.852      0.000      -0.888      -0.616
# ar.L2.D.duration    -0.5700      0.085     -6.709      0.000      -0.737      -0.403
# ar.L3.D.duration    -0.4282      0.090     -4.781      0.000      -0.604      -0.253
# ar.L4.D.duration    -0.3345      0.085     -3.920      0.000      -0.502      -0.167
# ar.L5.D.duration    -0.2050      0.071     -2.904      0.004      -0.343      -0.067
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            0.6387           -1.1720j            1.3347           -0.1706
# AR.2            0.6387           +1.1720j            1.3347            0.1706
# AR.3           -1.4347           -0.0000j            1.4347           -0.5000
# AR.4           -0.7371           -1.1684j            1.3814           -0.3396
# AR.5           -0.7371           +1.1684j            1.3814            0.3396
# -----------------------------------------------------------------------------

# %%
# density plot of residuals 
residuals.plot(kind='kde') 
pyplot.show()
# summary stats of residuals
print(residuals.describe())
# Out:
#             0
# count 199.000
# mean    0.023
# std     3.933
# min    -7.725
# 25%    -2.360
# 50%    -0.388
# 75%     1.292
# max    23.334

# %%
size = int(len(y) * 0.80)
train, test = y[0:size], y[size:len(X)]
history = [x for x in train]
predictions = list()
# walk-forward validation
for t in range(len(test)):
    model = ARIMA(history, order=(5,1,0))
    model_fit = model.fit()
    output = model_fit.forecast()
    yhat = output[0]
    predictions.append(yhat)
    obs = test.iloc[t]
    history.append(obs)
    print('predicted=%f, expected=%f' % (yhat, obs))
# Out:
# /Users/pauldefusco/anaconda2/envs/py36/lib/python3.6/site-packages/scipy/signal/signaltools.py:1341: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   out_full[ind] += zi
# /Users/pauldefusco/anaconda2/envs/py36/lib/python3.6/site-packages/scipy/signal/signaltools.py:1344: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   out = out_full[ind]
# /Users/pauldefusco/anaconda2/envs/py36/lib/python3.6/site-packages/scipy/signal/signaltools.py:1350: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   zf = out_full[ind]
# predicted=332.919987, expected=65.000000
# predicted=307.827322, expected=66.000000
# predicted=296.980265, expected=34.000000
# predicted=229.246262, expected=333.000000
# predicted=252.391454, expected=128.000000
# predicted=234.508157, expected=102.000000
# predicted=122.351596, expected=400.000000
# predicted=180.157773, expected=175.000000
# predicted=194.788087, expected=69.000000
# predicted=200.531177, expected=126.000000
# predicted=166.853998, expected=285.000000
# predicted=192.416820, expected=327.000000
# predicted=230.462709, expected=168.000000
# predicted=192.537115, expected=127.000000
# predicted=184.423270, expected=314.000000
# predicted=225.140037, expected=147.000000
# predicted=226.217736, expected=472.000000
# predicted=261.359550, expected=246.000000
# predicted=246.400720, expected=213.000000
# predicted=253.674157, expected=173.000000
# predicted=260.473168, expected=220.000000
# predicted=243.961746, expected=130.000000
# predicted=240.204167, expected=299.000000
# predicted=214.102765, expected=247.000000
# predicted=213.938077, expected=111.000000
# predicted=196.224881, expected=195.000000
# predicted=200.731504, expected=148.000000
# predicted=187.363663, expected=286.000000
# predicted=214.338730, expected=96.000000
# predicted=179.821112, expected=75.000000
# predicted=151.502018, expected=386.000000
# predicted=199.220029, expected=544.000000
# predicted=258.013074, expected=127.000000
# predicted=252.464859, expected=155.000000
# predicted=232.256064, expected=184.000000
# predicted=244.193268, expected=120.000000
# predicted=249.032545, expected=480.000000
# predicted=269.525489, expected=194.000000
# predicted=210.270495, expected=1232.000000
# predicted=403.653063, expected=69.000000
# predicted=379.215616, expected=133.000000
# predicted=372.314149, expected=193.000000
# predicted=381.660247, expected=70.000000
# predicted=307.924387, expected=206.000000
# predicted=313.495101, expected=152.000000
# predicted=137.397009, expected=243.000000
# predicted=166.917127, expected=437.000000
# predicted=219.425017, expected=259.000000
# predicted=228.979050, expected=182.000000
# predicted=247.235859, expected=447.000000
# predicted=288.709284, expected=238.000000
# predicted=299.633914, expected=410.000000
# predicted=329.818440, expected=472.000000
# predicted=336.727163, expected=83.000000
# predicted=303.557351, expected=254.000000
# predicted=317.124514, expected=56.000000
# predicted=249.161976, expected=204.000000
# predicted=244.186299, expected=102.000000
# predicted=193.436930, expected=226.000000
# predicted=154.645313, expected=217.000000
# predicted=176.977944, expected=217.000000
# predicted=171.192649, expected=379.000000
# predicted=226.220045, expected=145.000000
# predicted=214.206553, expected=74.000000
# predicted=208.905230, expected=271.000000
# predicted=217.349021, expected=0.000000
# predicted=177.916462, expected=258.000000
# predicted=188.078854, expected=180.000000
# predicted=154.910600, expected=196.000000
# predicted=163.511115, expected=135.000000
# predicted=173.590686, expected=300.000000
# predicted=179.523164, expected=347.000000
# predicted=236.881630, expected=1001.000000
# predicted=366.784274, expected=72.000000
# predicted=341.582547, expected=498.000000
# predicted=396.368880, expected=279.000000
# predicted=414.864396, expected=50.000000
# predicted=368.794836, expected=171.000000
# predicted=342.238494, expected=211.000000
# predicted=211.930980, expected=567.000000
# predicted=297.172192, expected=170.000000
# predicted=241.701225, expected=772.000000
# predicted=329.944161, expected=298.000000
# predicted=365.544961, expected=120.000000
# predicted=355.045833, expected=219.000000
# predicted=356.357152, expected=877.000000
# predicted=411.251556, expected=214.000000
# predicted=413.848239, expected=82.000000
# predicted=302.608984, expected=304.000000
# predicted=303.560738, expected=273.000000
# predicted=324.284689, expected=471.000000
# predicted=369.599432, expected=133.000000
# predicted=246.445127, expected=301.000000
# predicted=262.097488, expected=350.000000
# predicted=305.379234, expected=86.000000
# predicted=266.451784, expected=94.000000
# predicted=237.875018, expected=1388.000000
# predicted=400.795891, expected=508.000000
# predicted=455.291822, expected=338.000000
# predicted=465.140111, expected=208.000000
# predicted=438.765236, expected=1143.000000
# predicted=614.321406, expected=503.000000
# predicted=676.506822, expected=58.000000
# predicted=458.904777, expected=142.000000
# predicted=398.614395, expected=276.000000
# predicted=382.890099, expected=201.000000
# predicted=380.758618, expected=63.000000
# predicted=205.695179, expected=222.000000
# predicted=161.585513, expected=168.000000
# predicted=177.817004, expected=192.000000
# predicted=186.601051, expected=911.000000
# predicted=299.331416, expected=439.000000
# predicted=334.768016, expected=163.000000
# predicted=350.919732, expected=273.000000
# predicted=359.292228, expected=284.000000
# predicted=373.295514, expected=288.000000
# predicted=389.108872, expected=136.000000
# predicted=262.641980, expected=66.000000
# predicted=200.583644, expected=445.000000
# predicted=249.670005, expected=123.000000
# predicted=221.644023, expected=285.000000
# predicted=225.186624, expected=927.000000
# predicted=337.173384, expected=48.000000
# predicted=313.619922, expected=164.000000
# predicted=333.242917, expected=81.000000
# predicted=269.906783, expected=89.000000
# predicted=259.839681, expected=278.000000
# predicted=262.336886, expected=214.000000
# predicted=146.353778, expected=116.000000
# predicted=157.421105, expected=16.000000
# predicted=132.144489, expected=546.000000
# predicted=212.489606, expected=8.000000
# predicted=193.692633, expected=167.000000
# predicted=179.048138, expected=72.000000
# predicted=154.152359, expected=75.000000
# predicted=144.986415, expected=14.000000
# predicted=144.697544, expected=200.000000
# predicted=90.093276, expected=13.000000
# predicted=89.031757, expected=312.000000
# predicted=116.612814, expected=134.000000
# predicted=125.285555, expected=34.000000
# predicted=117.674131, expected=15.000000
# predicted=117.516397, expected=188.000000
# predicted=115.641367, expected=788.000000
# predicted=249.238399, expected=103.000000
# predicted=210.639505, expected=106.000000
# predicted=208.536819, expected=25.000000
# predicted=203.554346, expected=52.000000
# predicted=205.409831, expected=41.000000
# predicted=181.916930, expected=234.000000
# predicted=94.388560, expected=255.000000
# predicted=120.292005, expected=200.000000
# predicted=136.268101, expected=217.000000
# predicted=168.451297, expected=9.000000
# predicted=158.318698, expected=315.000000
# predicted=205.535949, expected=128.000000
# predicted=185.922012, expected=10.000000
# predicted=145.178241, expected=352.000000
# predicted=173.997786, expected=97.000000
# predicted=150.595128, expected=54.000000
# predicted=158.498828, expected=7.000000
# predicted=107.691123, expected=63.000000
# predicted=95.637848, expected=77.000000
# predicted=106.711533, expected=117.000000
# predicted=69.471908, expected=34.000000
# predicted=58.823749, expected=104.000000
# predicted=67.739329, expected=15.000000
# predicted=67.758268, expected=14.000000
# predicted=59.489231, expected=208.000000
# predicted=82.960777, expected=11.000000
# predicted=63.598279, expected=160.000000
# predicted=86.627101, expected=197.000000
# predicted=102.264937, expected=151.000000
# predicted=123.778071, expected=131.000000
# predicted=143.548248, expected=731.000000
# predicted=235.450000, expected=756.000000
# predicted=358.739691, expected=12.000000
# predicted=329.794936, expected=114.000000
# predicted=317.538977, expected=12.000000
# predicted=287.797197, expected=365.000000
# predicted=327.000415, expected=304.000000
# predicted=259.312374, expected=11.000000
# predicted=136.587407, expected=20.000000
# predicted=138.114591, expected=109.000000
# predicted=135.520429, expected=138.000000
# predicted=155.419659, expected=6.000000
# predicted=96.792537, expected=63.000000
# predicted=58.559898, expected=200.000000
# predicted=90.221037, expected=271.000000
# predicted=132.128584, expected=42.000000
# predicted=120.111787, expected=341.000000
# predicted=156.982935, expected=100.000000
# predicted=168.839958, expected=40.000000
# predicted=164.340681, expected=114.000000
# predicted=151.039184, expected=150.000000
# predicted=130.205800, expected=431.000000
# predicted=197.572896, expected=11.000000
# predicted=140.644805, expected=91.000000
# predicted=140.592874, expected=52.000000
# predicted=140.541703, expected=257.000000
# predicted=164.361068, expected=99.000000
# predicted=155.589596, expected=49.000000
# predicted=93.647922, expected=882.000000
# predicted=245.069607, expected=7.000000
# predicted=222.444382, expected=515.000000
# predicted=306.348500, expected=158.000000
# predicted=285.547503, expected=259.000000
# predicted=309.672493, expected=206.000000
# predicted=335.720492, expected=25.000000
# predicted=192.815805, expected=300.000000
# predicted=243.430018, expected=246.000000
# predicted=198.701610, expected=178.000000
# predicted=202.080269, expected=318.000000
# predicted=214.273896, expected=201.000000
# predicted=211.513324, expected=105.000000
# predicted=223.479271, expected=214.000000
# predicted=210.391590, expected=67.000000
# predicted=178.561033, expected=85.000000
# predicted=163.551240, expected=82.000000
# predicted=124.917500, expected=142.000000
# predicted=115.414921, expected=187.000000
# predicted=129.771054, expected=69.000000
# predicted=105.421003, expected=580.000000
# predicted=195.126680, expected=62.000000
# predicted=186.354468, expected=1203.000000
# predicted=383.234712, expected=58.000000
# predicted=359.286294, expected=64.000000
# predicted=339.488055, expected=631.000000
# predicted=435.059732, expected=658.000000
# predicted=443.894425, expected=942.000000
# predicted=595.541666, expected=207.000000
# predicted=429.493916, expected=104.000000
# predicted=434.006473, expected=377.000000
# predicted=483.368215, expected=66.000000
# predicted=384.536240, expected=128.000000
# predicted=300.153568, expected=291.000000
# predicted=196.379205, expected=115.000000
# predicted=178.745603, expected=524.000000
# predicted=252.856461, expected=358.000000
# predicted=249.070221, expected=366.000000
# predicted=299.070947, expected=23.000000
# predicted=278.574215, expected=560.000000
# predicted=326.283125, expected=52.000000
# predicted=309.649762, expected=347.000000
# predicted=284.754763, expected=107.000000
# predicted=241.576895, expected=48.000000
# predicted=187.547593, expected=145.000000
# predicted=208.190996, expected=74.000000
# predicted=127.313967, expected=451.000000
# predicted=196.923376, expected=53.000000
# predicted=146.139449, expected=612.000000
# predicted=235.488906, expected=305.000000
# predicted=274.789825, expected=104.000000
# predicted=266.114605, expected=176.000000
# predicted=283.206983, expected=507.000000
# predicted=293.397611, expected=103.000000
# predicted=297.659213, expected=242.000000
# predicted=240.702100, expected=137.000000
# predicted=211.400785, expected=223.000000
# predicted=229.985387, expected=124.000000
# predicted=220.905745, expected=63.000000
# predicted=147.894018, expected=137.000000
# predicted=153.769818, expected=23.000000
# predicted=116.231090, expected=22.000000
# predicted=97.379370, expected=59.000000
# predicted=70.870664, expected=703.000000
# predicted=172.298983, expected=179.000000
# predicted=187.906998, expected=690.000000
# predicted=286.465337, expected=85.000000
# predicted=290.560205, expected=25.000000
# predicted=287.973303, expected=11.000000
# predicted=278.026273, expected=1272.000000
# predicted=382.079216, expected=69.000000
# predicted=355.502858, expected=256.000000
# predicted=291.116639, expected=300.000000
# predicted=324.907823, expected=256.000000
# predicted=355.872557, expected=7.000000
# predicted=354.550711, expected=43.000000
# predicted=154.440447, expected=244.000000
# predicted=183.306849, expected=1062.000000
# predicted=324.012694, expected=22.000000
# predicted=271.868200, expected=429.000000
# predicted=307.076103, expected=494.000000
# predicted=384.981935, expected=296.000000
# predicted=420.501243, expected=92.000000
# predicted=396.197408, expected=17.000000
# predicted=223.512674, expected=826.000000
# predicted=360.667044, expected=243.000000
# predicted=325.738592, expected=184.000000
# predicted=278.006848, expected=245.000000
# predicted=270.268136, expected=198.000000
# predicted=282.708039, expected=360.000000
# predicted=340.630986, expected=139.000000
# predicted=227.596328, expected=54.000000
# predicted=195.819127, expected=232.000000
# predicted=204.617769, expected=517.000000
# predicted=251.042677, expected=418.000000
# predicted=287.869186, expected=153.000000
# predicted=253.848816, expected=116.000000
# predicted=249.034171, expected=168.000000
# predicted=265.095717, expected=261.000000
# predicted=269.519620, expected=69.000000
# predicted=195.528860, expected=212.000000
# predicted=164.137405, expected=121.000000
# predicted=157.511226, expected=23.000000
# predicted=140.745548, expected=306.000000
# predicted=166.391403, expected=202.000000
# predicted=155.556937, expected=342.000000
# predicted=202.674948, expected=22.000000
# predicted=169.459694, expected=455.000000
# predicted=227.610995, expected=245.000000
# predicted=261.384249, expected=33.000000
# predicted=214.993426, expected=58.000000
# predicted=192.026350, expected=41.000000
# predicted=140.112348, expected=360.000000
# predicted=197.843193, expected=179.000000
# predicted=152.703364, expected=174.000000
# predicted=142.643876, expected=43.000000
# predicted=142.983644, expected=68.000000
# predicted=142.965834, expected=212.000000
# predicted=171.627915, expected=38.000000
# predicted=117.561374, expected=639.000000
# predicted=199.988631, expected=483.000000
# predicted=250.431773, expected=205.000000
# predicted=275.900832, expected=344.000000
# predicted=323.169486, expected=141.000000
# predicted=306.348893, expected=113.000000
# predicted=316.723478, expected=87.000000
# predicted=226.416587, expected=238.000000
# predicted=187.164592, expected=27.000000
# predicted=156.255250, expected=155.000000
# predicted=127.332066, expected=337.000000
# predicted=161.190377, expected=24.000000
# predicted=143.447949, expected=365.000000
# predicted=193.424587, expected=37.000000
# predicted=156.979362, expected=25.000000
# predicted=155.629039, expected=109.000000
# predicted=148.758425, expected=152.000000
# predicted=117.666513, expected=179.000000
# predicted=144.097558, expected=118.000000
# predicted=104.354317, expected=272.000000
# predicted=144.384714, expected=30.000000
# predicted=142.533163, expected=79.000000
# predicted=137.926200, expected=324.000000
# predicted=168.091633, expected=426.000000
# predicted=209.470671, expected=196.000000
# predicted=222.025670, expected=151.000000
# predicted=202.872385, expected=366.000000
# predicted=258.287151, expected=211.000000
# predicted=277.005862, expected=43.000000
# predicted=230.272412, expected=816.000000
# predicted=302.280841, expected=189.000000
# predicted=294.746997, expected=590.000000
# predicted=372.856810, expected=315.000000
# predicted=362.701671, expected=131.000000
# predicted=345.150771, expected=78.000000
# predicted=349.734837, expected=97.000000
# predicted=230.199192, expected=337.000000
# predicted=256.034363, expected=185.000000
# predicted=189.858191, expected=78.000000
# predicted=151.454201, expected=55.000000
# predicted=138.457379, expected=442.000000
# predicted=200.219601, expected=36.000000
# predicted=186.523606, expected=74.000000
# predicted=145.418753, expected=326.000000
# predicted=170.569767, expected=81.000000
# predicted=166.998130, expected=179.000000
# predicted=189.512852, expected=527.000000
# predicted=207.590600, expected=918.000000
# predicted=356.136443, expected=225.000000
# predicted=377.155402, expected=787.000000
# predicted=460.250459, expected=15.000000
# predicted=439.131338, expected=279.000000
# predicted=454.884426, expected=416.000000
# predicted=437.682038, expected=83.000000
# predicted=296.581693, expected=25.000000
# predicted=264.917536, expected=542.000000
# predicted=229.458260, expected=256.000000
# predicted=265.073832, expected=189.000000
# predicted=252.270875, expected=251.000000
# predicted=226.645073, expected=116.000000
# predicted=228.040473, expected=1100.000000
# predicted=413.870092, expected=451.000000
# predicted=395.394141, expected=184.000000
# predicted=384.025506, expected=232.000000
# predicted=390.593697, expected=209.000000
# predicted=377.385207, expected=16.000000
# predicted=358.066771, expected=340.000000
# predicted=238.601034, expected=313.000000
# predicted=215.911940, expected=191.000000
# predicted=216.883990, expected=7.000000
# predicted=179.272313, expected=493.000000
# predicted=228.995258, expected=1182.000000
# predicted=426.643914, expected=216.000000
# predicted=400.641621, expected=184.000000
# predicted=382.848291, expected=360.000000
# predicted=408.074841, expected=165.000000
# predicted=425.843804, expected=161.000000
# predicted=373.147584, expected=84.000000
# predicted=194.095362, expected=61.000000
# predicted=167.107188, expected=267.000000
# predicted=182.554463, expected=351.000000
# predicted=182.607587, expected=183.000000
# predicted=185.363110, expected=516.000000
# predicted=247.993457, expected=393.000000
# predicted=296.985270, expected=286.000000
# predicted=333.008552, expected=87.000000
# predicted=301.829892, expected=277.000000
# predicted=289.503044, expected=200.000000
# predicted=290.123100, expected=725.000000
# predicted=330.747028, expected=204.000000
# predicted=296.776922, expected=175.000000
# predicted=279.435065, expected=247.000000
# predicted=304.913853, expected=136.000000
# predicted=277.522729, expected=218.000000
# predicted=281.748360, expected=59.000000
# predicted=172.036524, expected=146.000000
# predicted=162.958858, expected=77.000000
# predicted=145.952106, expected=245.000000
# predicted=147.185752, expected=482.000000
# predicted=207.037962, expected=56.000000
# predicted=177.478506, expected=354.000000
# predicted=229.688905, expected=396.000000
# predicted=269.925154, expected=136.000000
# predicted=276.165026, expected=549.000000
# predicted=331.564873, expected=17.000000
# predicted=249.669518, expected=439.000000
# predicted=316.052888, expected=107.000000
# predicted=272.290242, expected=369.000000
# predicted=269.696630, expected=356.000000
# predicted=306.469908, expected=561.000000
# predicted=310.922190, expected=175.000000
# predicted=334.180252, expected=309.000000
# predicted=314.258977, expected=139.000000
# predicted=316.039693, expected=148.000000
# predicted=278.328418, expected=139.000000
# predicted=242.877222, expected=549.000000
# predicted=245.139223, expected=395.000000
# predicted=280.959164, expected=145.000000
# predicted=253.657471, expected=119.000000
# predicted=249.880708, expected=88.000000
# predicted=236.507837, expected=463.000000
# predicted=292.024863, expected=232.000000
# predicted=239.564983, expected=57.000000
# predicted=184.339048, expected=300.000000
# predicted=211.876488, expected=83.000000
# predicted=201.596463, expected=200.000000
# predicted=221.187642, expected=225.000000
# predicted=183.404454, expected=844.000000
# predicted=289.839651, expected=293.000000
# predicted=325.144727, expected=262.000000
# predicted=320.715225, expected=137.000000
# predicted=326.794768, expected=130.000000
# predicted=310.973460, expected=387.000000
# predicted=339.683409, expected=211.000000
# predicted=235.702371, expected=246.000000
# predicted=229.716454, expected=357.000000
# predicted=246.716471, expected=322.000000
# predicted=275.840982, expected=584.000000
# predicted=353.563411, expected=240.000000
# predicted=327.080721, expected=374.000000
# predicted=355.149944, expected=215.000000
# predicted=347.579569, expected=22.000000
# predicted=289.130040, expected=207.000000
# predicted=271.640329, expected=183.000000
# predicted=205.004348, expected=100.000000
# predicted=181.696334, expected=955.000000
# predicted=287.020901, expected=146.000000
# predicted=269.047358, expected=31.000000
# predicted=271.189939, expected=334.000000
# predicted=293.321909, expected=271.000000
# predicted=302.363052, expected=223.000000
# predicted=323.700691, expected=95.000000
# predicted=184.032902, expected=106.000000
# predicted=176.123493, expected=36.000000
# predicted=174.868620, expected=458.000000
# predicted=199.335348, expected=53.000000
# predicted=160.698993, expected=148.000000
# predicted=150.665791, expected=179.000000
# predicted=164.274034, expected=223.000000
# predicted=182.135814, expected=165.000000
# predicted=203.532916, expected=127.000000
# predicted=149.704650, expected=158.000000
# predicted=166.637188, expected=409.000000
# predicted=211.505328, expected=165.000000
# predicted=207.500089, expected=88.000000
# predicted=185.650411, expected=536.000000
# predicted=250.319336, expected=380.000000
# predicted=289.367998, expected=1531.000000
# predicted=528.402263, expected=107.000000
# predicted=468.795256, expected=132.000000
# predicted=464.283308, expected=406.000000
# predicted=514.529451, expected=240.000000
# predicted=457.787812, expected=278.000000
# predicted=443.957428, expected=908.000000
# predicted=351.507076, expected=706.000000
# predicted=448.225404, expected=215.000000
# predicted=459.710859, expected=161.000000
# predicted=418.695543, expected=370.000000
# predicted=436.756283, expected=157.000000
# predicted=412.743026, expected=209.000000
# predicted=300.998564, expected=399.000000
# predicted=253.443035, expected=1925.000000
# predicted=549.426120, expected=829.000000
# predicted=652.948675, expected=328.000000
# predicted=646.933337, expected=109.000000
# predicted=633.549175, expected=178.000000
# predicted=617.579133, expected=242.000000
# predicted=590.334650, expected=450.000000
# predicted=354.268820, expected=485.000000
# predicted=301.004278, expected=76.000000
# predicted=256.769143, expected=328.000000
# predicted=294.835222, expected=289.000000
# predicted=310.453320, expected=163.000000
# predicted=295.626427, expected=118.000000
# predicted=242.143127, expected=53.000000
# predicted=169.724532, expected=453.000000
# predicted=234.764185, expected=324.000000
# predicted=233.727015, expected=637.000000
# predicted=296.151813, expected=301.000000
# predicted=316.694639, expected=139.000000
# predicted=317.594995, expected=118.000000
# predicted=326.406753, expected=32.000000
# predicted=253.836630, expected=278.000000
# predicted=248.666739, expected=112.000000
# predicted=162.064409, expected=34.000000
# predicted=118.403363, expected=80.000000
# predicted=109.199273, expected=609.000000
# predicted=194.145547, expected=276.000000
# predicted=231.894149, expected=548.000000
# predicted=281.726102, expected=291.000000
# predicted=308.776274, expected=1710.000000
# predicted=597.123317, expected=217.000000
# predicted=606.729893, expected=192.000000
# predicted=540.185144, expected=208.000000
# predicted=526.234131, expected=415.000000
# predicted=497.781426, expected=278.000000
# predicted=496.749376, expected=326.000000
# predicted=274.172270, expected=173.000000
# predicted=265.372454, expected=306.000000
# predicted=284.184209, expected=350.000000
# predicted=307.718287, expected=614.000000
# predicted=343.673180, expected=224.000000
# predicted=332.311270, expected=668.000000
# predicted=393.517135, expected=748.000000
# predicted=488.341520, expected=474.000000
# predicted=513.117436, expected=143.000000
# predicted=477.375889, expected=168.000000
# predicted=401.808167, expected=317.000000
# predicted=415.024397, expected=106.000000
# predicted=320.770209, expected=234.000000
# predicted=239.885302, expected=314.000000
# predicted=214.929085, expected=897.000000
# predicted=344.643330, expected=398.000000
# predicted=379.625858, expected=422.000000
# predicted=398.928292, expected=130.000000
# predicted=398.487427, expected=61.000000
# predicted=364.894489, expected=863.000000
# predicted=462.743400, expected=255.000000
# predicted=352.646552, expected=259.000000
# predicted=332.945032, expected=29.000000
# predicted=266.340729, expected=750.000000
# predicted=370.897229, expected=306.000000
# predicted=407.275504, expected=266.000000
# predicted=311.871882, expected=314.000000
# predicted=322.917116, expected=775.000000
# predicted=409.130537, expected=181.000000
# predicted=428.774847, expected=178.000000
# predicted=336.932843, expected=254.000000
# predicted=327.792754, expected=351.000000
# predicted=339.259889, expected=373.000000
# predicted=350.794142, expected=180.000000
# predicted=253.263962, expected=135.000000
# predicted=244.906962, expected=216.000000
# predicted=250.526291, expected=86.000000
# predicted=220.582410, expected=85.000000
# predicted=177.465628, expected=325.000000
# predicted=172.460954, expected=187.000000
# predicted=172.101542, expected=463.000000
# predicted=229.992568, expected=142.000000
# predicted=215.506758, expected=280.000000
# predicted=248.046194, expected=398.000000
# predicted=300.319587, expected=149.000000
# predicted=268.004294, expected=191.000000
# predicted=269.969593, expected=193.000000
# predicted=225.268484, expected=302.000000
# predicted=251.345775, expected=317.000000
# predicted=258.595252, expected=211.000000
# predicted=227.785614, expected=101.000000
# predicted=218.767408, expected=172.000000
# predicted=215.293072, expected=464.000000
# predicted=261.913853, expected=343.000000
# predicted=268.380992, expected=98.000000
# predicted=231.761694, expected=198.000000
# predicted=230.504632, expected=361.000000
# predicted=272.417408, expected=345.000000
# predicted=300.411201, expected=114.000000
# predicted=242.699857, expected=210.000000
# predicted=222.059358, expected=556.000000
# predicted=299.230916, expected=68.000000
# predicted=272.799188, expected=239.000000
# predicted=256.281257, expected=349.000000
# predicted=257.577355, expected=112.000000
# predicted=252.693289, expected=34.000000
# predicted=224.363191, expected=181.000000
# predicted=164.032236, expected=178.000000
# predicted=180.422169, expected=206.000000
# predicted=176.329226, expected=194.000000
# predicted=152.170328, expected=209.000000
# predicted=168.019000, expected=692.000000
# predicted=280.958324, expected=210.000000
# predicted=281.619984, expected=206.000000
# predicted=287.368623, expected=355.000000
# predicted=312.667364, expected=339.000000
# predicted=333.262404, expected=737.000000
# predicted=425.386808, expected=191.000000
# predicted=339.888093, expected=175.000000
# predicted=334.018946, expected=286.000000
# predicted=346.658557, expected=93.000000
# predicted=298.602031, expected=170.000000
# predicted=272.591813, expected=173.000000
# predicted=181.123733, expected=541.000000
# predicted=241.943466, expected=89.000000
# predicted=224.498197, expected=213.000000
# predicted=214.786237, expected=194.000000
# predicted=230.276998, expected=158.000000
# predicted=225.677910, expected=472.000000
# predicted=278.991504, expected=135.000000
# predicted=209.991773, expected=304.000000
# predicted=247.430370, expected=275.000000
# predicted=257.274525, expected=155.000000
# predicted=248.237189, expected=125.000000
# predicted=242.966387, expected=96.000000
# predicted=180.480079, expected=175.000000
# predicted=186.938155, expected=134.000000
# predicted=159.033968, expected=22.000000
# predicted=116.914933, expected=807.000000
# predicted=232.333056, expected=235.000000
# predicted=245.282913, expected=673.000000
# predicted=346.681543, expected=124.000000
# predicted=333.844873, expected=57.000000
# predicted=316.905226, expected=225.000000
# predicted=350.548339, expected=144.000000
# predicted=239.165341, expected=177.000000
# predicted=231.109271, expected=455.000000
# predicted=200.226642, expected=264.000000
# predicted=221.351912, expected=295.000000
# predicted=261.556024, expected=285.000000
# predicted=271.436132, expected=166.000000
# predicted=272.242024, expected=456.000000
# predicted=320.833463, expected=101.000000
# predicted=259.445136, expected=256.000000
# predicted=259.853753, expected=497.000000
# predicted=295.640933, expected=600.000000
# predicted=348.008395, expected=268.000000
# predicted=363.555647, expected=899.000000
# predicted=443.863751, expected=339.000000
# predicted=476.034668, expected=220.000000
# predicted=468.427680, expected=700.000000
# predicted=506.742043, expected=150.000000
# predicted=424.556988, expected=147.000000
# predicted=405.580317, expected=236.000000
# predicted=298.295482, expected=133.000000
# predicted=260.513351, expected=58.000000
# predicted=233.972267, expected=234.000000
# predicted=160.371570, expected=1388.000000
# predicted=375.470512, expected=130.000000
# predicted=362.838001, expected=57.000000
# predicted=336.331753, expected=70.000000
# predicted=322.934574, expected=31.000000
# predicted=309.296328, expected=50.000000
# predicted=280.527236, expected=496.000000
# predicted=142.192008, expected=94.000000
# predicted=133.152990, expected=83.000000
# predicted=138.669580, expected=29.000000
# predicted=130.748230, expected=16.000000
# predicted=125.080855, expected=46.000000
# predicted=124.801931, expected=20.000000
# predicted=47.224686, expected=152.000000
# predicted=58.432612, expected=61.000000
# predicted=54.305100, expected=389.000000
# predicted=117.199694, expected=1108.000000
# predicted=305.111069, expected=8.000000
# predicted=289.571274, expected=310.000000
# predicted=342.302612, expected=197.000000
# predicted=344.994429, expected=21.000000
# predicted=331.074250, expected=117.000000
# predicted=289.625846, expected=413.000000
# predicted=179.250071, expected=24.000000
# predicted=178.076439, expected=254.000000
# predicted=173.061785, expected=65.000000
# predicted=148.913483, expected=53.000000
# predicted=152.252857, expected=164.000000
# predicted=161.633976, expected=321.000000
# predicted=147.932372, expected=5.000000
# predicted=142.479439, expected=82.000000
# predicted=115.863718, expected=81.000000
# predicted=117.180453, expected=136.000000
# predicted=130.023746, expected=133.000000
# predicted=126.073135, expected=14.000000
# predicted=75.083987, expected=320.000000
# predicted=129.777431, expected=77.000000
# predicted=126.297170, expected=211.000000
# predicted=149.526353, expected=129.000000
# predicted=147.971747, expected=26.000000
# predicted=128.182732, expected=200.000000
# predicted=160.522966, expected=38.000000
# predicted=112.233438, expected=95.000000
# predicted=115.942964, expected=49.000000
# predicted=89.276370, expected=210.000000
# predicted=103.601640, expected=863.000000
# predicted=248.590519, expected=15.000000
# predicted=211.508304, expected=259.000000
# predicted=252.042287, expected=130.000000
# predicted=254.247878, expected=211.000000
# predicted=277.384065, expected=87.000000
# predicted=257.712230, expected=774.000000
# predicted=251.198983, expected=15.000000
# predicted=244.398027, expected=348.000000
# predicted=263.601850, expected=129.000000
# predicted=260.571512, expected=44.000000
# predicted=228.789312, expected=231.000000
# predicted=255.459318, expected=155.000000
# predicted=152.843687, expected=74.000000
# predicted=162.236508, expected=135.000000
# predicted=128.667107, expected=217.000000
# predicted=143.016931, expected=22.000000
# predicted=137.479060, expected=32.000000
# predicted=105.462284, expected=435.000000
# predicted=154.975048, expected=25.000000
# predicted=142.639766, expected=370.000000
# predicted=186.389935, expected=201.000000
# predicted=182.390938, expected=793.000000
# predicted=313.778523, expected=152.000000
# predicted=329.106200, expected=66.000000
# predicted=267.905085, expected=213.000000
# predicted=298.628161, expected=150.000000
# predicted=258.058882, expected=364.000000
# predicted=288.487374, expected=329.000000
# predicted=214.338596, expected=282.000000
# predicted=235.580371, expected=173.000000
# predicted=252.244226, expected=51.000000
# predicted=223.082367, expected=68.000000
# predicted=208.485213, expected=109.000000
# predicted=166.441219, expected=23.000000
# predicted=115.628706, expected=1073.000000
# predicted=257.332244, expected=207.000000
# predicted=256.371338, expected=193.000000
# predicted=281.913590, expected=134.000000
# predicted=291.180172, expected=224.000000
# predicted=304.594847, expected=173.000000
# predicted=329.606913, expected=67.000000
# predicted=165.290311, expected=149.000000
# predicted=156.620867, expected=29.000000
# predicted=127.777897, expected=610.000000
# predicted=211.844368, expected=118.000000
# predicted=190.923794, expected=95.000000
# predicted=178.947857, expected=84.000000
# predicted=181.161457, expected=43.000000
# predicted=159.873540, expected=93.000000
# predicted=171.243684, expected=172.000000
# predicted=101.215403, expected=161.000000
# predicted=108.572925, expected=785.000000
# predicted=229.139263, expected=628.000000
# predicted=318.554023, expected=172.000000
# predicted=336.976900, expected=200.000000
# predicted=354.556283, expected=134.000000
# predicted=342.774227, expected=51.000000
# predicted=321.736217, expected=850.000000
# predicted=342.576749, expected=526.000000
# predicted=324.656302, expected=140.000000
# predicted=318.160578, expected=93.000000
# predicted=300.227476, expected=87.000000
# predicted=286.862523, expected=318.000000
# predicted=331.530933, expected=9.000000
# predicted=192.554910, expected=19.000000
# predicted=110.653424, expected=157.000000
# predicted=114.261994, expected=79.000000
# predicted=109.833735, expected=9.000000
# predicted=97.414448, expected=19.000000
# predicted=48.862944, expected=659.000000
# predicted=161.406809, expected=39.000000
# predicted=159.491829, expected=502.000000
# predicted=222.975057, expected=113.000000
# predicted=224.583249, expected=267.000000
# predicted=265.633494, expected=30.000000
# predicted=265.794826, expected=355.000000
# predicted=217.872683, expected=43.000000
# predicted=215.922870, expected=240.000000
# predicted=175.212839, expected=10.000000
# predicted=156.437255, expected=17.000000
# predicted=114.132395, expected=47.000000
# predicted=117.283447, expected=296.000000
# predicted=109.587168, expected=69.000000
# predicted=112.726757, expected=323.000000
# predicted=130.117369, expected=167.000000
# predicted=154.438392, expected=570.000000
# predicted=248.634770, expected=516.000000
# predicted=326.523580, expected=220.000000
# predicted=311.638496, expected=177.000000
# predicted=329.103616, expected=388.000000
# predicted=339.194752, expected=61.000000
# predicted=317.216359, expected=585.000000
# predicted=326.479715, expected=699.000000
# predicted=358.969404, expected=133.000000
# predicted=339.713990, expected=6.000000
# predicted=311.648912, expected=96.000000
# predicted=260.684539, expected=318.000000
# predicted=301.913857, expected=413.000000
# predicted=277.228072, expected=66.000000
# predicted=172.617341, expected=590.000000
# predicted=253.333718, expected=272.000000
# predicted=292.639067, expected=88.000000
# predicted=289.186928, expected=15.000000
# predicted=239.331964, expected=152.000000
# predicted=194.695797, expected=902.000000
# predicted=339.674244, expected=294.000000
# predicted=288.154862, expected=15.000000
# predicted=245.868781, expected=290.000000
# predicted=280.336968, expected=12.000000
# predicted=271.537434, expected=31.000000
# predicted=252.411581, expected=135.000000
# predicted=129.320075, expected=142.000000
# predicted=103.529026, expected=669.000000
# predicted=217.591274, expected=123.000000
# predicted=186.425414, expected=391.000000
# predicted=252.182704, expected=93.000000
# predicted=258.604727, expected=133.000000
# predicted=255.706882, expected=99.000000
# predicted=248.727684, expected=256.000000
# predicted=181.953766, expected=394.000000
# predicted=228.845450, expected=74.000000
# predicted=174.774695, expected=67.000000
# predicted=170.728971, expected=131.000000
# predicted=169.500578, expected=149.000000
# predicted=176.325100, expected=27.000000
# predicted=138.626914, expected=152.000000
# predicted=100.841230, expected=116.000000
# predicted=106.940868, expected=41.000000
# predicted=101.816071, expected=302.000000
# predicted=133.092766, expected=275.000000
# predicted=153.498608, expected=128.000000
# predicted=169.297145, expected=78.000000
# predicted=157.191260, expected=11.000000
# predicted=137.559922, expected=101.000000
# predicted=147.152253, expected=147.000000
# predicted=122.571133, expected=262.000000
# predicted=122.478448, expected=46.000000
# predicted=107.787327, expected=546.000000
# predicted=189.890789, expected=1512.000000
# predicted=447.209488, expected=104.000000
# predicted=435.885720, expected=85.000000
# predicted=428.504360, expected=119.000000
# predicted=400.201828, expected=423.000000
# predicted=456.977217, expected=315.000000
# predicted=421.832565, expected=78.000000
# predicted=187.854458, expected=9.000000
# predicted=171.265043, expected=44.000000
# predicted=162.202069, expected=75.000000
# predicted=154.131875, expected=157.000000
# predicted=112.468403, expected=109.000000
# predicted=79.297682, expected=66.000000
# predicted=77.230000, expected=7.000000
# predicted=75.994591, expected=529.000000
# predicted=160.476898, expected=349.000000
# predicted=204.340377, expected=101.000000
# predicted=194.456116, expected=127.000000
# predicted=198.136861, expected=83.000000
# predicted=197.114565, expected=333.000000
# predicted=252.205370, expected=408.000000
# predicted=234.875529, expected=205.000000
# predicted=210.610732, expected=158.000000
# predicted=220.156796, expected=18.000000
# predicted=199.137281, expected=276.000000
# predicted=231.739585, expected=264.000000
# predicted=220.663365, expected=109.000000
# predicted=171.186133, expected=234.000000
# predicted=178.248122, expected=115.000000
# predicted=168.831931, expected=272.000000
# predicted=211.586637, expected=329.000000
# predicted=221.672632, expected=155.000000
# predicted=202.248850, expected=589.000000
# predicted=286.255498, expected=363.000000
# predicted=305.055063, expected=951.000000
# predicted=449.133656, expected=172.000000
# predicted=426.369060, expected=53.000000
# predicted=378.711523, expected=34.000000
# predicted=356.468265, expected=82.000000
# predicted=269.322412, expected=155.000000
# predicted=237.121891, expected=788.000000
# predicted=219.738562, expected=528.000000
# predicted=277.602979, expected=296.000000
# predicted=317.133327, expected=114.000000
# predicted=327.976361, expected=314.000000
# predicted=363.754584, expected=249.000000
# predicted=377.204545, expected=562.000000
# predicted=345.096621, expected=112.000000
# predicted=273.914588, expected=204.000000
# predicted=259.564298, expected=168.000000
# predicted=267.053869, expected=60.000000
# predicted=222.223479, expected=734.000000
# predicted=310.124627, expected=80.000000
# predicted=225.352950, expected=60.000000
# predicted=217.593393, expected=281.000000
# predicted=232.106302, expected=321.000000
# predicted=254.175829, expected=149.000000
# predicted=268.850139, expected=155.000000
# predicted=175.566578, expected=87.000000
# predicted=174.627556, expected=49.000000
# predicted=171.226759, expected=354.000000
# predicted=186.718092, expected=294.000000
# predicted=182.290348, expected=137.000000
# predicted=179.881910, expected=191.000000
# predicted=186.876070, expected=172.000000
# predicted=198.922782, expected=55.000000
# predicted=198.001463, expected=167.000000
# predicted=168.983927, expected=85.000000
# predicted=133.584065, expected=92.000000
# predicted=126.204890, expected=16.000000
# predicted=97.051259, expected=444.000000
# predicted=145.873146, expected=132.000000
# predicted=155.837833, expected=10.000000
# predicted=129.767176, expected=324.000000
# predicted=172.271806, expected=315.000000
# predicted=206.766283, expected=64.000000
# predicted=213.160137, expected=110.000000
# predicted=160.118966, expected=421.000000
# predicted=209.105590, expected=79.000000
# predicted=216.306850, expected=174.000000
# predicted=194.337970, expected=257.000000
# predicted=185.637513, expected=228.000000
# predicted=210.695192, expected=296.000000
# predicted=243.162552, expected=9.000000
# predicted=172.951014, expected=337.000000
# predicted=217.999999, expected=476.000000
# predicted=268.720748, expected=185.000000
# predicted=254.466915, expected=104.000000
# predicted=234.984467, expected=244.000000
# predicted=226.325322, expected=152.000000
# predicted=246.803226, expected=573.000000
# predicted=291.091798, expected=231.000000
# predicted=248.892454, expected=184.000000
# predicted=248.705281, expected=124.000000
# predicted=250.978993, expected=21.000000
# predicted=210.648562, expected=233.000000
# predicted=226.023423, expected=96.000000
# predicted=146.871473, expected=99.000000
# predicted=125.857010, expected=117.000000
# predicted=115.527220, expected=53.000000
# predicted=102.309996, expected=261.000000
# predicted=143.997436, expected=201.000000
# predicted=138.576514, expected=155.000000
# predicted=148.281832, expected=43.000000
# predicted=138.272655, expected=53.000000
# predicted=126.664150, expected=363.000000
# predicted=180.163877, expected=14.000000
# predicted=136.482104, expected=56.000000
# predicted=114.213507, expected=108.000000
# predicted=106.686654, expected=459.000000
# predicted=177.061100, expected=425.000000
# predicted=239.482507, expected=200.000000
# predicted=212.394216, expected=223.000000
# predicted=247.058458, expected=413.000000
# predicted=305.441092, expected=747.000000
# predicted=413.309292, expected=177.000000
# predicted=363.203587, expected=66.000000
# predicted=304.187701, expected=716.000000
# predicted=393.599909, expected=253.000000
# predicted=391.151958, expected=14.000000
# predicted=325.875137, expected=316.000000
# predicted=259.310721, expected=152.000000
# predicted=249.585448, expected=137.000000
# predicted=261.653039, expected=155.000000
# predicted=171.623444, expected=154.000000
# predicted=154.294846, expected=165.000000
# predicted=179.185198, expected=466.000000
# predicted=207.574001, expected=1101.000000
# predicted=371.070335, expected=368.000000
# predicted=403.563725, expected=201.000000
# predicted=411.438892, expected=146.000000
# predicted=406.693108, expected=77.000000
# predicted=385.672420, expected=157.000000
# predicted=336.207302, expected=96.000000
# predicted=172.245397, expected=104.000000
# predicted=129.553268, expected=38.000000
# predicted=102.390612, expected=154.000000
# predicted=104.584282, expected=148.000000
# predicted=116.192830, expected=342.000000
# predicted=149.148985, expected=43.000000
# predicted=138.034537, expected=394.000000
# predicted=189.510344, expected=68.000000
# predicted=190.555266, expected=364.000000
# predicted=227.658420, expected=125.000000
# predicted=222.085055, expected=179.000000
# predicted=195.154238, expected=427.000000
# predicted=261.290042, expected=63.000000
# predicted=202.628082, expected=197.000000
# predicted=225.987613, expected=409.000000
# predicted=235.418158, expected=299.000000
# predicted=261.790445, expected=323.000000
# predicted=287.551677, expected=215.000000
# predicted=252.006689, expected=290.000000
# predicted=288.646149, expected=147.000000
# predicted=278.539149, expected=143.000000
# predicted=234.684395, expected=541.000000
# predicted=278.736815, expected=172.000000
# predicted=250.234763, expected=309.000000
# predicted=268.505716, expected=69.000000
# predicted=229.661054, expected=79.000000
# predicted=216.270253, expected=299.000000
# predicted=244.114030, expected=213.000000
# predicted=189.435887, expected=196.000000
# predicted=194.555760, expected=54.000000
# predicted=151.787986, expected=54.000000
# predicted=147.922011, expected=247.000000
# predicted=176.801959, expected=426.000000
# predicted=199.888453, expected=404.000000
# predicted=232.775942, expected=80.000000
# predicted=211.704045, expected=135.000000
# predicted=224.680427, expected=162.000000
# predicted=240.324008, expected=130.000000
# predicted=219.838577, expected=341.000000
# predicted=209.593730, expected=366.000000
# predicted=204.494175, expected=118.000000
# predicted=208.661457, expected=168.000000
# predicted=214.873530, expected=308.000000
# predicted=238.829580, expected=176.000000
# predicted=244.206217, expected=300.000000
# predicted=240.136928, expected=223.000000
# predicted=216.208690, expected=35.000000
# predicted=199.924770, expected=199.000000
# predicted=206.615917, expected=206.000000
# predicted=189.088363, expected=721.000000
# predicted=284.515760, expected=641.000000
# predicted=342.010270, expected=163.000000
# predicted=328.728598, expected=234.000000
# predicted=361.942005, expected=86.000000
# predicted=337.812247, expected=180.000000
# predicted=332.513802, expected=68.000000
# predicted=225.542849, expected=103.000000
# predicted=138.097713, expected=102.000000
# predicted=128.274944, expected=239.000000
# predicted=130.463866, expected=325.000000
# predicted=171.237870, expected=234.000000
# predicted=179.962618, expected=194.000000
# predicted=200.694125, expected=134.000000
# predicted=204.399604, expected=77.000000
# predicted=198.527376, expected=674.000000
# predicted=276.301764, expected=216.000000
# predicted=254.423048, expected=122.000000
# predicted=236.746688, expected=109.000000
# predicted=222.418145, expected=622.000000
# predicted=304.681894, expected=1966.000000
# predicted=631.243827, expected=131.000000
# predicted=527.147633, expected=140.000000
# predicted=518.807597, expected=281.000000
# predicted=541.117134, expected=156.000000
# predicted=537.286815, expected=161.000000
# predicted=464.659543, expected=44.000000
# predicted=151.411315, expected=240.000000
# predicted=170.536345, expected=172.000000
# predicted=174.939917, expected=127.000000
# predicted=149.811940, expected=248.000000
# predicted=166.830097, expected=115.000000
# predicted=157.263690, expected=38.000000
# predicted=155.295609, expected=201.000000
# predicted=150.677857, expected=341.000000
# predicted=179.344518, expected=298.000000
# predicted=207.807938, expected=314.000000
# predicted=220.367172, expected=52.000000
# predicted=206.943291, expected=77.000000
# predicted=212.274443, expected=390.000000
# predicted=245.653912, expected=804.000000
# predicted=326.409762, expected=417.000000
# predicted=344.440860, expected=361.000000
# predicted=353.996459, expected=809.000000
# predicted=481.859755, expected=156.000000
# predicted=484.787271, expected=44.000000
# predicted=427.557955, expected=166.000000
# predicted=323.466372, expected=58.000000
# predicted=259.866601, expected=76.000000
# predicted=214.325031, expected=312.000000
# predicted=137.252926, expected=298.000000
# predicted=160.486599, expected=466.000000
# predicted=232.847734, expected=829.000000
# predicted=347.058576, expected=291.000000
# predicted=379.596588, expected=484.000000
# predicted=449.364170, expected=204.000000
# predicted=426.854131, expected=169.000000
# predicted=402.531506, expected=437.000000
# predicted=401.035099, expected=937.000000
# predicted=424.830835, expected=37.000000
# predicted=375.123225, expected=193.000000
# predicted=331.145941, expected=230.000000
# predicted=332.774366, expected=204.000000
# predicted=334.275528, expected=163.000000
# predicted=291.202003, expected=159.000000
# predicted=164.800165, expected=1970.000000
# predicted=502.517981, expected=358.000000
# predicted=514.049229, expected=195.000000
# predicted=511.664874, expected=1302.000000
# predicted=702.297393, expected=96.000000
# predicted=668.345545, expected=154.000000
# predicted=672.706102, expected=246.000000
# predicted=391.340119, expected=122.000000
# predicted=345.168976, expected=276.000000
# predicted=362.135973, expected=151.000000
# predicted=174.235143, expected=297.000000
# predicted=208.741613, expected=119.000000
# predicted=201.128133, expected=172.000000
# predicted=189.496770, expected=74.000000
# predicted=180.075644, expected=187.000000
# predicted=166.234676, expected=141.000000
# predicted=164.136579, expected=124.000000
# predicted=136.052039, expected=186.000000
# predicted=147.986940, expected=1975.000000
# predicted=464.494352, expected=252.000000
# predicted=477.054313, expected=248.000000
# predicted=493.543541, expected=85.000000
# predicted=478.069923, expected=199.000000
# predicted=480.791332, expected=482.000000
# predicted=533.706474, expected=226.000000
# ...
# predicted=260.482859, expected=112.000000
# predicted=248.404134, expected=390.000000
# predicted=298.803781, expected=217.000000
# predicted=291.092559, expected=405.000000
# predicted=307.501502, expected=150.000000
# predicted=285.751605, expected=245.000000
# predicted=253.270592, expected=272.000000
# predicted=279.368188, expected=134.000000
# predicted=234.731845, expected=133.000000
# predicted=222.207469, expected=173.000000
# predicted=183.957980, expected=157.000000
# predicted=184.139754, expected=349.000000
# predicted=204.665630, expected=232.000000
# predicted=197.229197, expected=224.000000
# predicted=212.614484, expected=246.000000
# predicted=231.300393, expected=249.000000
# predicted=242.361509, expected=395.000000
# predicted=283.650635, expected=732.000000
# predicted=351.533378, expected=618.000000
# predicted=414.706459, expected=19.000000
# predicted=375.482456, expected=6.000000
# predicted=334.518696, expected=262.000000
# predicted=333.702365, expected=157.000000
# predicted=291.570738, expected=188.000000
# predicted=207.812186, expected=169.000000
# predicted=135.587743, expected=132.000000
# predicted=152.032261, expected=290.000000
# predicted=200.630090, expected=156.000000
# predicted=181.495328, expected=379.000000
# predicted=221.539138, expected=1616.000000
# predicted=472.462278, expected=162.000000
# predicted=454.048304, expected=1298.000000
# predicted=666.646311, expected=315.000000
# predicted=653.920273, expected=990.000000
# predicted=792.282598, expected=6.000000
# predicted=723.255996, expected=104.000000
# predicted=471.830816, expected=237.000000
# predicted=485.288110, expected=282.000000
# predicted=315.387375, expected=600.000000
# predicted=371.566303, expected=13.000000
# predicted=206.998978, expected=21.000000
# predicted=209.287941, expected=242.000000
# predicted=231.738667, expected=110.000000
# predicted=205.875778, expected=201.000000
# predicted=197.390000, expected=232.000000
# predicted=139.051894, expected=245.000000
# predicted=176.164717, expected=211.000000
# predicted=207.565100, expected=678.000000
# predicted=285.106342, expected=845.000000
# predicted=408.326494, expected=197.000000
# predicted=402.025964, expected=131.000000
# predicted=385.843103, expected=142.000000
# predicted=363.007417, expected=143.000000
# predicted=347.240120, expected=164.000000
# predicted=266.374913, expected=278.000000
# predicted=177.060125, expected=161.000000
# predicted=170.089157, expected=5.000000
# predicted=147.822302, expected=9.000000
# predicted=125.264491, expected=10.000000
# predicted=101.458207, expected=311.000000
# predicted=129.461349, expected=486.000000
# predicted=167.775805, expected=649.000000
# predicted=252.546098, expected=808.000000
# predicted=388.752826, expected=608.000000
# predicted=484.427418, expected=261.000000
# predicted=520.084231, expected=275.000000
# predicted=511.476812, expected=48.000000
# predicted=432.581361, expected=391.000000
# predicted=394.186420, expected=229.000000
# predicted=299.092098, expected=541.000000
# predicted=294.097310, expected=218.000000
# predicted=284.798767, expected=691.000000
# predicted=358.530811, expected=1020.000000
# predicted=522.630960, expected=1246.000000
# predicted=667.163793, expected=604.000000
# predicted=724.848814, expected=197.000000
# predicted=661.648916, expected=138.000000
# predicted=640.514043, expected=236.000000
# predicted=560.636341, expected=116.000000
# predicted=412.583986, expected=122.000000
# predicted=232.573998, expected=118.000000
# predicted=153.906133, expected=73.000000
# predicted=132.183308, expected=194.000000
# predicted=143.407043, expected=146.000000
# predicted=128.288956, expected=319.000000
# predicted=164.452229, expected=437.000000
# predicted=218.539974, expected=512.000000
# predicted=284.732819, expected=282.000000
# predicted=317.104400, expected=272.000000
# predicted=329.039496, expected=309.000000
# predicted=353.955792, expected=375.000000
# predicted=362.652247, expected=251.000000
# predicted=331.953043, expected=135.000000
# predicted=269.394198, expected=369.000000
# predicted=285.939975, expected=363.000000
# predicted=299.811644, expected=133.000000
# predicted=269.298068, expected=401.000000
# predicted=278.460866, expected=317.000000
# predicted=286.293751, expected=162.000000
# predicted=288.619944, expected=291.000000
# predicted=278.977453, expected=450.000000
# predicted=293.634778, expected=195.000000
# predicted=300.689054, expected=278.000000
# predicted=283.542396, expected=123.000000
# predicted=248.383609, expected=110.000000
# predicted=237.706073, expected=252.000000
# predicted=233.745225, expected=165.000000
# predicted=185.795091, expected=485.000000
# predicted=239.130514, expected=160.000000
# predicted=216.419311, expected=251.000000
# predicted=238.648331, expected=79.000000
# predicted=230.581386, expected=4.000000
# predicted=186.308094, expected=34.000000
# predicted=165.445163, expected=383.000000
# predicted=153.087357, expected=185.000000
# predicted=156.024990, expected=146.000000
# predicted=140.799463, expected=137.000000
# predicted=149.973559, expected=4.000000
# predicted=145.076393, expected=54.000000
# predicted=148.841143, expected=114.000000
# predicted=105.675087, expected=203.000000
# predicted=110.090693, expected=362.000000
# predicted=149.283699, expected=187.000000
# predicted=156.142113, expected=166.000000
# predicted=182.655649, expected=242.000000
# predicted=213.240310, expected=253.000000
# predicted=234.534522, expected=323.000000
# predicted=256.244340, expected=143.000000
# predicted=218.858043, expected=250.000000
# predicted=230.274937, expected=146.000000
# predicted=224.693822, expected=209.000000
# predicted=219.549164, expected=130.000000
# predicted=199.051466, expected=5.000000
# predicted=144.857057, expected=169.000000
# predicted=151.190635, expected=216.000000
# predicted=145.628752, expected=190.000000
# predicted=153.486147, expected=194.000000
# predicted=152.738716, expected=6.000000
# predicted=129.098235, expected=252.000000
# predicted=171.814189, expected=357.000000
# predicted=203.675646, expected=133.000000
# predicted=188.094836, expected=119.000000
# predicted=178.161957, expected=99.000000
# predicted=160.291507, expected=192.000000
# predicted=190.012392, expected=585.000000
# predicted=251.283535, expected=326.000000
# predicted=244.679695, expected=235.000000
# predicted=262.181203, expected=491.000000
# predicted=325.688492, expected=246.000000
# predicted=343.059043, expected=317.000000
# predicted=365.683080, expected=301.000000
# predicted=319.643987, expected=174.000000
# predicted=291.296752, expected=322.000000
# predicted=308.238546, expected=509.000000
# predicted=313.628811, expected=219.000000
# predicted=305.974515, expected=786.000000
# predicted=392.439412, expected=72.000000
# predicted=344.590862, expected=181.000000
# predicted=346.418368, expected=158.000000
# predicted=318.228400, expected=212.000000
# predicted=266.164698, expected=6.000000
# predicted=231.487592, expected=187.000000
# predicted=136.781842, expected=106.000000
# predicted=140.484690, expected=1176.000000
# predicted=318.594093, expected=130.000000
# predicted=303.220103, expected=209.000000
# predicted=306.519607, expected=567.000000
# predicted=400.800710, expected=333.000000
# predicted=413.511108, expected=310.000000
# predicted=451.899417, expected=464.000000
# predicted=339.209829, expected=509.000000
# predicted=399.153286, expected=252.000000
# predicted=404.040985, expected=170.000000
# predicted=338.639971, expected=526.000000
# predicted=372.801681, expected=222.000000
# predicted=353.095500, expected=180.000000
# predicted=308.497446, expected=102.000000
# predicted=241.022033, expected=95.000000
# predicted=211.893950, expected=767.000000
# predicted=319.462213, expected=138.000000
# predicted=249.531843, expected=338.000000
# predicted=274.278988, expected=159.000000
# predicted=267.381483, expected=133.000000
# predicted=266.942100, expected=192.000000
# predicted=285.137137, expected=218.000000
# predicted=195.442597, expected=337.000000
# predicted=230.608622, expected=898.000000
# predicted=331.502905, expected=178.000000
# predicted=326.448814, expected=268.000000
# predicted=351.343023, expected=621.000000
# predicted=423.441562, expected=7.000000
# predicted=375.937533, expected=5.000000
# predicted=325.185783, expected=238.000000
# predicted=218.925313, expected=487.000000
# predicted=269.475704, expected=139.000000
# predicted=248.266127, expected=316.000000
# predicted=203.671314, expected=150.000000
# predicted=222.465057, expected=411.000000
# predicted=290.164314, expected=235.000000
# predicted=288.860447, expected=453.000000
# predicted=286.786548, expected=178.000000
# predicted=290.160970, expected=262.000000
# predicted=281.405192, expected=1032.000000
# predicted=436.316456, expected=759.000000
# predicted=490.304739, expected=549.000000
# predicted=544.089287, expected=201.000000
# predicted=498.225623, expected=330.000000
# predicted=517.171486, expected=212.000000
# predicted=504.595865, expected=256.000000
# predicted=379.428693, expected=339.000000
# predicted=314.225188, expected=738.000000
# predicted=351.076904, expected=394.000000
# predicted=379.847219, expected=716.000000
# predicted=449.439906, expected=234.000000
# predicted=445.571400, expected=168.000000
# predicted=427.224721, expected=380.000000
# predicted=435.955822, expected=84.000000
# predicted=322.252647, expected=142.000000
# predicted=284.181599, expected=554.000000
# predicted=264.122767, expected=344.000000
# predicted=278.588136, expected=608.000000
# predicted=357.782215, expected=92.000000
# predicted=304.290561, expected=83.000000
# predicted=300.965040, expected=225.000000
# predicted=314.503602, expected=189.000000
# predicted=251.942021, expected=304.000000
# predicted=250.210549, expected=400.000000
# predicted=219.331987, expected=182.000000
# predicted=230.968718, expected=253.000000
# predicted=260.019732, expected=254.000000
# predicted=263.348280, expected=324.000000
# predicted=285.400366, expected=226.000000
# predicted=272.699485, expected=297.000000
# predicted=257.104670, expected=215.000000
# predicted=260.971473, expected=129.000000
# predicted=238.933251, expected=211.000000
# predicted=232.962618, expected=293.000000
# predicted=228.338660, expected=318.000000
# predicted=244.539732, expected=196.000000
# predicted=227.762111, expected=604.000000
# predicted=297.077188, expected=238.000000
# predicted=309.449887, expected=17.000000
# predicted=275.287141, expected=701.000000
# predicted=350.929022, expected=711.000000
# predicted=412.687545, expected=223.000000
# predicted=414.866410, expected=882.000000
# predicted=472.800274, expected=409.000000
# predicted=489.237182, expected=508.000000
# predicted=570.763190, expected=184.000000
# predicted=483.703524, expected=170.000000
# predicted=390.431874, expected=255.000000
# predicted=396.438491, expected=258.000000
# predicted=294.019804, expected=71.000000
# predicted=238.197350, expected=18.000000
# predicted=157.823977, expected=188.000000
# predicted=159.156774, expected=176.000000
# predicted=159.332185, expected=159.000000
# predicted=145.341143, expected=240.000000
# predicted=144.707495, expected=360.000000
# predicted=192.931343, expected=119.000000
# predicted=206.448087, expected=230.000000
# predicted=215.362524, expected=207.000000
# predicted=218.839473, expected=120.000000
# predicted=210.199417, expected=137.000000
# predicted=194.694077, expected=507.000000
# predicted=223.417963, expected=106.000000
# predicted=216.269315, expected=148.000000
# predicted=205.259418, expected=212.000000
# predicted=205.834466, expected=141.000000
# predicted=205.233700, expected=742.000000
# predicted=314.756357, expected=449.000000
# predicted=303.154464, expected=282.000000
# predicted=331.775047, expected=354.000000
# predicted=366.310378, expected=326.000000
# predicted=379.457558, expected=283.000000
# predicted=402.305759, expected=301.000000
# predicted=331.968039, expected=467.000000
# predicted=336.968676, expected=600.000000
# predicted=391.376857, expected=334.000000
# predicted=386.037993, expected=137.000000
# predicted=352.838939, expected=111.000000
# predicted=321.489303, expected=394.000000
# predicted=337.554832, expected=301.000000
# predicted=310.335827, expected=212.000000
# predicted=248.743864, expected=228.000000
# predicted=232.260408, expected=404.000000
# predicted=276.105167, expected=164.000000
# predicted=281.522777, expected=182.000000
# predicted=248.307333, expected=98.000000
# predicted=213.072358, expected=223.000000
# predicted=214.757116, expected=134.000000
# predicted=198.977225, expected=289.000000
# predicted=183.129204, expected=357.000000
# predicted=216.408000, expected=482.000000
# predicted=267.642649, expected=413.000000
# predicted=319.669519, expected=319.000000
# predicted=334.089369, expected=414.000000
# predicted=380.211198, expected=199.000000
# predicted=360.944008, expected=191.000000
# predicted=333.494547, expected=74.000000
# predicted=264.674091, expected=128.000000
# predicted=217.446159, expected=78.000000
# predicted=177.734128, expected=138.000000
# predicted=133.838080, expected=200.000000
# predicted=135.642065, expected=173.000000
# predicted=132.648282, expected=173.000000
# predicted=149.508549, expected=206.000000
# predicted=162.530205, expected=787.000000
# predicted=286.502953, expected=262.000000
# predicted=301.014365, expected=238.000000
# predicted=309.177461, expected=449.000000
# predicted=355.631596, expected=162.000000
# predicted=344.981525, expected=330.000000
# predicted=369.925344, expected=333.000000
# predicted=296.354609, expected=1166.000000
# predicted=455.389149, expected=985.000000
# predicted=579.161212, expected=1556.000000
# predicted=773.279900, expected=226.000000
# predicted=766.599574, expected=224.000000
# predicted=743.096034, expected=300.000000
# predicted=731.724493, expected=386.000000
# predicted=598.670033, expected=456.000000
# predicted=520.619227, expected=508.000000
# predicted=353.812364, expected=260.000000
# predicted=356.014181, expected=193.000000
# predicted=349.007701, expected=597.000000
# predicted=401.501133, expected=97.000000
# predicted=346.397118, expected=244.000000
# predicted=316.019341, expected=222.000000
# predicted=268.430218, expected=200.000000
# predicted=255.397081, expected=419.000000
# predicted=298.000182, expected=344.000000
# predicted=256.166839, expected=202.000000
# predicted=272.053202, expected=237.000000
# predicted=271.344206, expected=315.000000
# predicted=285.499129, expected=741.000000
# predicted=380.396454, expected=127.000000
# predicted=326.313115, expected=92.000000
# predicted=285.589203, expected=528.000000
# predicted=342.315444, expected=252.000000
# predicted=337.261325, expected=712.000000
# predicted=413.505601, expected=397.000000
# predicted=355.043378, expected=324.000000
# predicted=384.712042, expected=371.000000
# predicted=430.905338, expected=526.000000
# predicted=429.590673, expected=112.000000
# predicted=401.924065, expected=655.000000
# predicted=401.621304, expected=185.000000
# predicted=359.426816, expected=152.000000
# predicted=330.449710, expected=545.000000
# predicted=365.471356, expected=159.000000
# predicted=297.048925, expected=363.000000
# predicted=343.872881, expected=514.000000
# predicted=323.615960, expected=843.000000
# predicted=434.515651, expected=510.000000
# predicted=492.048938, expected=347.000000
# predicted=458.256917, expected=385.000000
# predicted=492.864611, expected=1868.000000
# predicted=756.987677, expected=403.000000
# predicted=722.521853, expected=651.000000
# predicted=701.244185, expected=236.000000
# predicted=646.808128, expected=144.000000
# predicted=599.239573, expected=154.000000
# predicted=564.991092, expected=293.000000
# predicted=309.242669, expected=112.000000
# predicted=261.120078, expected=353.000000
# predicted=217.736434, expected=329.000000
# predicted=232.803103, expected=208.000000
# predicted=241.452901, expected=180.000000
# predicted=246.245995, expected=360.000000
# predicted=257.952374, expected=124.000000
# predicted=256.058774, expected=483.000000
# predicted=283.713212, expected=151.000000
# predicted=250.318618, expected=254.000000
# predicted=258.772265, expected=281.000000
# predicted=276.098530, expected=112.000000
# predicted=231.119255, expected=334.000000
# predicted=269.915706, expected=383.000000
# predicted=254.156214, expected=189.000000
# predicted=258.096171, expected=442.000000
# predicted=293.889259, expected=239.000000

# %%
plt.figure(figsize=(30,5))
# evaluate forecasts
rmse = sqrt(mean_squared_error(test, predictions)) 
print('Test RMSE: %.3f' % rmse)
# plot forecasts against actual outcomes pyplot.plot(test)
pyplot.plot(predictions, color='red') 
pyplot.show()
# Out:
# Test RMSE: 268.870

# %%
# !pwd
# Out:
# /Users/pauldefusco/Documents/PythonWork/machine_learning_projects/marketing_campaign_prediction/iteration_1

# %%
from __future__ import division
#Let's try dividing duration by 60 to predict minutes:
final_df = pd.read_pickle('../../../../mkt_camp_data/final_df_pickle.pickle')
##Old Prospect
oldp_idx = final_df[final_df['old_prospect']==1].index
y_oldprospect = y[oldp_idx]/60
y_oldprospect.index = final_df[final_df['old_prospect']==1].Date
##New Prospect
newp_idx = final_df[final_df['new_prospect']==1].index
y_newprospect = y[newp_idx]/60
y_newprospect.index = final_df[final_df['new_prospect']==1].Date
##New Lead
newl_idx = final_df[final_df['new_lead']==1].index
y_newlead = y[newl_idx]/60
y_newlead.index = final_df[final_df['new_lead']==1].Date

# %%
from matplotlib import pyplot
from pandas.plotting import autocorrelation_plot

fig, ax = plt.subplots(figsize=(10,6))

lag = 200
autocorrelation_plot(y_oldprospect[len(y_oldprospect)-lag:], ax=ax, color='blue', label='Total Duration')
#autocorrelation_plot(y_oldprospect[len(y_oldprospect)-lag:], ax=ax, color='blue', label='Old Prospet Duration')
#autocorrelation_plot(y_newprospect[len(y_newprospect)-lag:], ax=ax, color='orange', label='New Prospect Duration')
#autocorrelation_plot(y_newlead[len(y_newlead)-lag:], ax=ax, color='darkgreen', label='New Lead Duration')

plt.legend()
pyplot.show()

# %%
pyplot.figure(figsize=(20,7))
pyplot.subplot(211)
plot_acf(y_oldprospect[len(y_oldprospect)-lag:], ax=pyplot.gca())
pyplot.subplot(212)
plot_pacf(y_oldprospect[len(y_oldprospect)-lag:], ax=pyplot.gca())
pyplot.show()
# Out:
# /Users/pauldefusco/anaconda2/envs/py36/lib/python3.6/site-packages/statsmodels/regression/linear_model.py:1283: RuntimeWarning: invalid value encountered in sqrt
#   return rho, np.sqrt(sigmasq)

# %%
from statsmodels.graphics.tsaplots import plot_acf
from statsmodels.graphics.tsaplots import plot_pacf

# %%
train, test = y_oldprospect[len(y_oldprospect)-50:len(y_oldprospect)-7], y_oldprospect[len(y_oldprospect)-7:]

# %%
model = AR(train)
# Out:
# /Users/pauldefusco/anaconda2/envs/py36/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:225: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)

# %%
model_fit = model.fit()
print('Lag: %s' % model_fit.k_ar)
print('Coefficients: %s' % model_fit.params)
# Out:
# Lag: 10
# Coefficients: const           4.991
# L1.duration     0.004
# L2.duration     0.138
# L3.duration     0.206
# L4.duration     0.162
# L5.duration     0.209
# L6.duration     0.028
# L7.duration     0.030
# L8.duration     0.314
# L9.duration    -0.380
# L10.duration   -0.454
# dtype: float64

# %%
# make predictions
predictions = model_fit.predict(start=len(train), end=len(train)+len(test)-1, dynamic=False) 
for i in range(len(predictions)):
    print('predicted=%i, expected=%i'%(predictions.iloc[i], test.iloc[i])) 
rmse = sqrt(mean_squared_error(test, predictions))
print('Test RMSE: %.3f' % rmse)
# Out:
# predicted=8, expected=4
# predicted=12, expected=5
# predicted=9, expected=3
# predicted=11, expected=3
# predicted=8, expected=8
# predicted=9, expected=1
# predicted=18, expected=3
# Test RMSE: 8.074
# /Users/pauldefusco/anaconda2/envs/py36/lib/python3.6/site-packages/statsmodels/tsa/base/tsa_model.py:531: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)
