# %% [markdown]
# # Yelp Business Search

# %%
#Business Search      URL -- 'https://api.yelp.com/v3/businesses/search'
#Business Match       URL -- 'https://api.yelp.com/v3/businesses/matches'
#Phone Search         URL -- 'https://api.yelp.com/v3/businesses/search/phone'

#Business Details     URL -- 'https://api.yelp.com/v3/businesses/{id}'
#Business Reviews     URL -- 'https://api.yelp.com/v3/businesses/{id}/reviews'

#Businesses, Total, Region

# Import the modules
import requests
import json
import pandas as pd

# %%
# Define a business ID
business_id = '4AErMBEoNzbk7Q8g45kKaQ'
unix_time = 1546047836

# Define my API Key, My Endpoint, and My Header
API_KEY = ''
ENDPOINT = 'https://api.yelp.com/v3/businesses/search'
HEADERS = {'Authorization': 'bearer %s' % API_KEY}

# %% [markdown]
# Business Search Example:
# - Using the offset and limit parameters, you can get up to 1000 businesses from this endpoint if there are more than 1000 results.
# - If you request a page out of this 1000 business limit, this endpoint will return an error.

# %%
# Define my parameters of the search
# BUSINESS SEARCH PARAMETERS - EXAMPLE
PARAMETERS = {#'term': 'food',
              'limit': 50,
              'offset': 51,
              'radius': 40000,
              'location': 'San Diego',
             'categories':'dentists'}

#BUSINESS MATCH PARAMETERS - EXAMPLE
#PARAMETERS = {'name': 'Peets Coffee & Tea',
#              'address1': '7845 Highland Village Pl',
#              'city': 'San Diego',
#             'state': 'CA',
#              'country': 'US'}

# %%
# Make a request to the Yelp API
response = requests.get(url = ENDPOINT,
                        params = PARAMETERS,
                        headers = HEADERS)

# %%
# Conver the JSON String
business_data = response.json()

# %%
# print the response
print(json.dumps(business_data, indent = 3))
# Out:
# {
#    "businesses": [
#       {
#          "id": "XBvtCsYtFBIBGWKTUazVNA",
#          "alias": "andrew-r-chapokas-dmd-san-diego",
#          "name": "Andrew R. Chapokas DMD",
#          "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/dz75NMvKgU_5WeoRQEa-Tw/o.jpg",
#          "is_closed": false,
#          "url": "https://www.yelp.com/biz/andrew-r-chapokas-dmd-san-diego?adjust_creative=so3DyPxV4jy7d0woHd_3_Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=so3DyPxV4jy7d0woHd_3_Q",
#          "review_count": 55,
#          "categories": [
#             {
#                "alias": "periodontists",
#                "title": "Periodontists"
#             },
#             {
#                "alias": "cosmeticdentists",
#                "title": "Cosmetic Dentists"
#             },
#             {
#                "alias": "prosthodontists",
#                "title": "Prosthodontists"
#             }
#          ],
#          "rating": 5.0,
#          "coordinates": {
#             "latitude": 32.745685,
#             "longitude": -117.163064
#          },
#          "transactions": [],
#          "location": {
#             "address1": "2728 Third Ave",
#             "address2": "",
#             "address3": "",
#             "city": "San Diego",
#             "zip_code": "92103",
#             "country": "US",
#             "state": "CA",
#             "display_address": [
#                "2728 Third Ave",
#                "San Diego, CA 92103"
#             ]
#          },
#          "phone": "+16192327433",
#          "display_phone": "(619) 232-7433",
#          "distance": 5061.056680724272
#       },
#       {
#          "id": "IHXCbNHwLTySbueGdqg2fQ",
#          "alias": "a-jayson-tengonciang-dmd-san-diego",
#          "name": "A Jayson Tengonciang, DMD",
#          "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/JM9DFlK8OPV8ANUVVig2dw/o.jpg",
#          "is_closed": false,
#          "url": "https://www.yelp.com/biz/a-jayson-tengonciang-dmd-san-diego?adjust_creative=so3DyPxV4jy7d0woHd_3_Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=so3DyPxV4jy7d0woHd_3_Q",
#          "review_count": 59,
#          "categories": [
#             {
#                "alias": "endodontists",
#                "title": "Endodontists"
#             }
#          ],
#          "rating": 5.0,
#          "coordinates": {
#             "latitude": 32.808636,
#             "longitude": -117.201378
#          },
#          "transactions": [],
#          "location": {
#             "address1": "3762 Clairemont Dr",
#             "address2": "",
#             "address3": "",
#             "city": "San Diego",
#             "zip_code": "92117",
#             "country": "US",
#             "state": "CA",
#             "display_address": [
#                "3762 Clairemont Dr",
#                "San Diego, CA 92117"
#             ]
#          },
#          "phone": "+18582702760",
#          "display_phone": "(858) 270-2760",
#          "distance": 4850.287637750244
#       },
#       {
#          "id": "8M9-eKrRmez_J_wQY2xrNg",
#          "alias": "mission-bay-family-dentistry-san-diego",
#          "name": "Mission Bay Family Dentistry",
#          "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/UFPqb3ZAdn89aEHeZsDa2g/o.jpg",
#          "is_closed": false,
#          "url": "https://www.yelp.com/biz/mission-bay-family-dentistry-san-diego?adjust_creative=so3DyPxV4jy7d0woHd_3_Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=so3DyPxV4jy7d0woHd_3_Q",
#          "review_count": 47,
#          "categories": [
#             {
#                "alias": "generaldentistry",
#                "title": "General Dentistry"
#             }
#          ],
#          "rating": 5.0,
#          "coordinates": {
#             "latitude": 32.80322,
#             "longitude": -117.21497
#          },
#          "transactions": [],
#          "location": {
#             "address1": "3023 Bunker Hill St",
#             "address2": "Ste 101",
#             "address3": "",
#             "city": "San Diego",
#             "zip_code": "92109",
#             "country": "US",
#             "state": "CA",
#             "display_address": [
#                "3023 Bunker Hill St",
#                "Ste 101",
#                "San Diego, CA 92109"
#             ]
#          },
#          "phone": "+18582701400",
#          "display_phone": "(858) 270-1400",
#          "distance": 5867.137985288249
#       },
#       {
#          "id": "bG9YiIgggETFbvsS0MXfAQ",
#          "alias": "alpha-dental-san-diego-3",
#          "name": "Alpha Dental",
#          "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/-lXtTR4acb4Kj59xelN58w/o.jpg",
#          "is_closed": false,
#          "url": "https://www.yelp.com/biz/alpha-dental-san-diego-3?adjust_creative=so3DyPxV4jy7d0woHd_3_Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=so3DyPxV4jy7d0woHd_3_Q",
#          "review_count": 59,
#          "categories": [
#             {
#                "alias": "generaldentistry",
#                "title": "General Dentistry"
#             },
#             {
#                "alias": "cosmeticdentists",
#                "title": "Cosmetic Dentists"
#             }
#          ],
#          "rating": 4.5,
#          "coordinates": {
#             "latitude": 32.7543907165527,
#             "longitude": -117.079086303711
#          },
#          "transactions": [],
#          "location": {
#             "address1": "4276 54th Pl",
#             "address2": "Ste D",
#             "address3": "",
#             "city": "San Diego",
#             "zip_code": "92115",
#             "country": "US",
#             "state": "CA",
#             "display_address": [
#                "4276 54th Pl",
#                "Ste D",
#                "San Diego, CA 92115"
#             ]
#          },
#          "phone": "+16192650566",
#          "display_phone": "(619) 265-0566",
#          "distance": 8085.873142863866
#       },
#       {
#          "id": "PtxZ41bJ7pfP0S5uvyxO0w",
#          "alias": "urban-dental-san-diego",
#          "name": "Urban Dental",
#          "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/DsouQrBAsIHWIyLGCjzsEQ/o.jpg",
#          "is_closed": false,
#          "url": "https://www.yelp.com/biz/urban-dental-san-diego?adjust_creative=so3DyPxV4jy7d0woHd_3_Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=so3DyPxV4jy7d0woHd_3_Q",
#          "review_count": 50,
#          "categories": [
#             {
#                "alias": "generaldentistry",
#                "title": "General Dentistry"
#             },
#             {
#                "alias": "cosmeticdentists",
#                "title": "Cosmetic Dentists"
#             }
#          ],
#          "rating": 5.0,
#          "coordinates": {
#             "latitude": 32.71701,
#             "longitude": -117.15898
#          },
#          "transactions": [],
#          "location": {
#             "address1": "1111 6th Ave",
#             "address2": "Ste 510",
#             "address3": "",
#             "city": "San Diego",
#             "zip_code": "92101",
#             "country": "US",
#             "state": "CA",
#             "display_address": [
#                "1111 6th Ave",
#                "Ste 510",
#                "San Diego, CA 92101"
#             ]
#          },
#          "phone": "+16196960510",
#          "display_phone": "(619) 696-0510",
#          "distance": 8193.287323368713
#       },
#       {
#          "id": "F49xMQ6DWOHnc-eE_t4ktQ",
#          "alias": "pacifica-center-for-oral-and-facial-surgery-san-diego",
#          "name": "Pacifica Center For Oral and Facial Surgery",
#          "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/9PyZrmytAmpOYOrfbYzI3g/o.jpg",
#          "is_closed": false,
#          "url": "https://www.yelp.com/biz/pacifica-center-for-oral-and-facial-surgery-san-diego?adjust_creative=so3DyPxV4jy7d0woHd_3_Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=so3DyPxV4jy7d0woHd_3_Q",
#          "review_count": 41,
#          "categories": [
#             {
#                "alias": "oralsurgeons",
#                "title": "Oral Surgeons"
#             },
#             {
#                "alias": "cosmeticsurgeons",
#                "title": "Cosmetic Surgeons"
#             }
#          ],
#          "rating": 5.0,
#          "coordinates": {
#             "latitude": 32.7913804,
#             "longitude": -117.1582248
#          },
#          "transactions": [],
#          "location": {
#             "address1": "7695 Cardinal Ct",
#             "address2": "Ste 350",
#             "address3": "",
#             "city": "San Diego",
#             "zip_code": "92123",
#             "country": "US",
#             "state": "CA",
#             "display_address": [
#                "7695 Cardinal Ct",
#                "Ste 350",
#                "San Diego, CA 92123"
#             ]
#          },
#          "phone": "+18585986800",
#          "display_phone": "(858) 598-6800",
#          "distance": 397.5003592720505
#       },
#       {
#          "id": "NyGIWKt6yR3TXsTVphTPsA",
#          "alias": "sorrento-valley-dental-group-san-diego",
#          "name": "Sorrento Valley Dental Group",
#          "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/9cd1P8cDAUPJyWuswjuMoA/o.jpg",
#          "is_closed": false,
#          "url": "https://www.yelp.com/biz/sorrento-valley-dental-group-san-diego?adjust_creative=so3DyPxV4jy7d0woHd_3_Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=so3DyPxV4jy7d0woHd_3_Q",
#          "review_count": 99,
#          "categories": [
#             {
#                "alias": "cosmeticdentists",
#                "title": "Cosmetic Dentists"
#             },
#             {
#                "alias": "generaldentistry",
#                "title": "General Dentistry"
#             }
#          ],
#          "rating": 4.5,
#          "coordinates": {
#             "latitude": 32.89993,
#             "longitude": -117.18821
#          },
#          "transactions": [],
#          "location": {
#             "address1": "5915 Mira Mesa Blvd",
#             "address2": "Ste B",
#             "address3": "",
#             "city": "San Diego",
#             "zip_code": "92121",
#             "country": "US",
#             "state": "CA",
#             "display_address": [
#                "5915 Mira Mesa Blvd",
#                "Ste B",
#                "San Diego, CA 92121"
#             ]
#          },
#          "phone": "+18585582121",
#          "display_phone": "(858) 558-2121",
#          "distance": 12575.771269050276
#       },
#       {
#          "id": "rjWjWW-j-8qKwwbDvy1XPw",
#          "alias": "david-c-adams-dds-ms-san-diego",
#          "name": "David C Adams, DDS, MS",
#          "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/tYhC2R0hKRirwSbEMjJePg/o.jpg",
#          "is_closed": false,
#          "url": "https://www.yelp.com/biz/david-c-adams-dds-ms-san-diego?adjust_creative=so3DyPxV4jy7d0woHd_3_Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=so3DyPxV4jy7d0woHd_3_Q",
#          "review_count": 62,
#          "categories": [
#             {
#                "alias": "orthodontists",
#                "title": "Orthodontists"
#             },
#             {
#                "alias": "pediatric_dentists",
#                "title": "Pediatric Dentists"
#             }
#          ],
#          "rating": 4.5,
#          "coordinates": {
#             "latitude": 32.7311714,
#             "longitude": -117.162358
#          },
#          "transactions": [],
#          "location": {
#             "address1": "239 Laurel St",
#             "address2": "Ste 201",
#             "address3": "",
#             "city": "San Diego",
#             "zip_code": "92101",
#             "country": "US",
#             "state": "CA",
#             "display_address": [
#                "239 Laurel St",
#                "Ste 201",
#                "San Diego, CA 92101"
#             ]
#          },
#          "phone": "+16192915266",
#          "display_phone": "(619) 291-5266",
#          "distance": 6649.916849849048
#       },
#       {
#          "id": "pqcRyaCxB_9QRv63oJRflw",
#          "alias": "kurt-hummeldorf-dmd-san-diego",
#          "name": "Kurt Hummeldorf, DMD",
#          "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/8ihvv20JwwneYUxW8Yu1FQ/o.jpg",
#          "is_closed": false,
#          "url": "https://www.yelp.com/biz/kurt-hummeldorf-dmd-san-diego?adjust_creative=so3DyPxV4jy7d0woHd_3_Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=so3DyPxV4jy7d0woHd_3_Q",
#          "review_count": 57,
#          "categories": [
#             {
#                "alias": "oralsurgeons",
#                "title": "Oral Surgeons"
#             }
#          ],
#          "rating": 4.5,
#          "coordinates": {
#             "latitude": 32.77234,
#             "longitude": -117.13479
#          },
#          "transactions": [],
#          "location": {
#             "address1": "2655 Camino Del Rio N",
#             "address2": "Ste 140",
#             "address3": "",
#             "city": "San Diego",
#             "zip_code": "92108",
#             "country": "US",
#             "state": "CA",
#             "display_address": [
#                "2655 Camino Del Rio N",
#                "Ste 140",
#                "San Diego, CA 92108"
#             ]
#          },
#          "phone": "+16192827088",
#          "display_phone": "(619) 282-7088",
#          "distance": 2709.2552146590574
#       },
#       {
#          "id": "KSRyvuMRk0dEs_ZXPxvylA",
#          "alias": "the-oral-surgery-and-dental-implant-specialists-of-san-diego-san-diego-2",
#          "name": "The Oral Surgery & Dental Implant Specialists of San Diego",
#          "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/14xU2ZJLLkS7B41-KkJnPA/o.jpg",
#          "is_closed": false,
#          "url": "https://www.yelp.com/biz/the-oral-surgery-and-dental-implant-specialists-of-san-diego-san-diego-2?adjust_creative=so3DyPxV4jy7d0woHd_3_Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=so3DyPxV4jy7d0woHd_3_Q",
#          "review_count": 51,
#          "categories": [
#             {
#                "alias": "oralsurgeons",
#                "title": "Oral Surgeons"
#             },
#             {
#                "alias": "cosmeticsurgeons",
#                "title": "Cosmetic Surgeons"
#             }
#          ],
#          "rating": 5.0,
#          "coordinates": {
#             "latitude": 32.7763824462891,
#             "longitude": -117.060577392578
#          },
#          "transactions": [],
#          "location": {
#             "address1": "6386 Alvarado Ct",
#             "address2": "Ste 110",
#             "address3": "",
#             "city": "San Diego",
#             "zip_code": "92120",
#             "country": "US",
#             "state": "CA",
#             "display_address": [
#                "6386 Alvarado Ct",
#                "Ste 110",
#                "San Diego, CA 92120"
#             ]
#          },
#          "phone": "+16192875000",
#          "display_phone": "(619) 287-5000",
#          "distance": 8918.048234712705
#       },
#       {
#          "id": "OzM6Jqo0sY9AQ56PGtZwug",
#          "alias": "san-diego-california-dental-group-san-diego",
#          "name": "San Diego California Dental Group",
#          "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/n9sUMyGfxsUJO9Rq4wG8oA/o.jpg",
#          "is_closed": false,
#          "url": "https://www.yelp.com/biz/san-diego-california-dental-group-san-diego?adjust_creative=so3DyPxV4jy7d0woHd_3_Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=so3DyPxV4jy7d0woHd_3_Q",
#          "review_count": 56,
#          "categories": [
#             {
#                "alias": "periodontists",
#                "title": "Periodontists"
#             },
#             {
#                "alias": "orthodontists",
#                "title": "Orthodontists"
#             },
#             {
#                "alias": "cosmeticdentists",
#                "title": "Cosmetic Dentists"
#             }
#          ],
#          "rating": 4.5,
#          "coordinates": {
#             "latitude": 32.8260498046875,
#             "longitude": -117.153511047363
#          },
#          "transactions": [],
#          "location": {
#             "address1": "7825 Engineer Rd",
#             "address2": "Ste 111",
#             "address3": "",
#             "city": "San Diego",
#             "zip_code": "92111",
#             "country": "US",
#             "state": "CA",
#             "display_address": [
#                "7825 Engineer Rd",
#                "Ste 111",
#                "San Diego, CA 92111"
#             ]
#          },
#          "phone": "+18582791004",
#          "display_phone": "(858) 279-1004",
#          "distance": 3947.572004588999
#       },
#       {
#          "id": "JJuEc7uc8CCreq0fP4Durg",
#          "alias": "sutton-guy-c-dds-san-diego",
#          "name": "Sutton Guy C, DDS",
#          "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/5IxY9e5fQGlo0Oo0THOQ-g/o.jpg",
#          "is_closed": false,
#          "url": "https://www.yelp.com/biz/sutton-guy-c-dds-san-diego?adjust_creative=so3DyPxV4jy7d0woHd_3_Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=so3DyPxV4jy7d0woHd_3_Q",
#          "review_count": 46,
#          "categories": [
#             {
#                "alias": "generaldentistry",
#                "title": "General Dentistry"
#             }
#          ],
#          "rating": 5.0,
#          "coordinates": {
#             "latitude": 32.828629,
#             "longitude": -117.126124
#          },
#          "transactions": [],
#          "location": {
#             "address1": "5075 Ruffin Rd",
#             "address2": "",
#             "address3": "",
#             "city": "San Diego",
#             "zip_code": "92123",
#             "country": "US",
#             "state": "CA",
#             "display_address": [
#                "5075 Ruffin Rd",
#                "San Diego, CA 92123"
#             ]
#          },
#          "phone": "+18582781454",
#          "display_phone": "(858) 278-1454",
#          "distance": 4973.702752158133
#       },
#       {
#          "id": "bbDJnaT8UwX4fSZt7O2LIA",
#          "alias": "robert-fremont-dds-san-diego",
#          "name": "Robert Fremont, DDS",
#          "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/OQ5wSV5yn2JNcN-PAdB3qA/o.jpg",
#          "is_closed": false,
#          "url": "https://www.yelp.com/biz/robert-fremont-dds-san-diego?adjust_creative=so3DyPxV4jy7d0woHd_3_Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=so3DyPxV4jy7d0woHd_3_Q",
#          "review_count": 60,
#          "categories": [
#             {
#                "alias": "generaldentistry",
#                "title": "General Dentistry"
#             }
#          ],
#          "rating": 4.5,
#          "coordinates": {
#             "latitude": 32.79918,
#             "longitude": -117.24623
#          },
#          "transactions": [],
#          "location": {
#             "address1": "4527 Fanuel St",
#             "address2": "",
#             "address3": "",
#             "city": "San Diego",
#             "zip_code": "92109",
#             "country": "US",
#             "state": "CA",
#             "display_address": [
#                "4527 Fanuel St",
#                "San Diego, CA 92109"
#             ]
#          },
#          "phone": "+18582722222",
#          "display_phone": "(858) 272-2222",
#          "distance": 8673.095003340904
#       },
#       {
#          "id": "H_Fs_9IRsbI7v27EK19KLA",
#          "alias": "sparrow-joseph-dds-san-diego",
#          "name": "Sparrow Joseph DDS",
#          "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/fRpry3XmpEpEy6PP0N8CxA/o.jpg",
#          "is_closed": false,
#          "url": "https://www.yelp.com/biz/sparrow-joseph-dds-san-diego?adjust_creative=so3DyPxV4jy7d0woHd_3_Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=so3DyPxV4jy7d0woHd_3_Q",
#          "review_count": 44,
#          "categories": [
#             {
#                "alias": "generaldentistry",
#                "title": "General Dentistry"
#             }
#          ],
#          "rating": 4.5,
#          "coordinates": {
#             "latitude": 32.802499,
#             "longitude": -117.1387947
#          },
#          "transactions": [],
#          "location": {
#             "address1": "3292 Sandrock Rd",
#             "address2": "",
#             "address3": "",
#             "city": "San Diego",
#             "zip_code": "92123",
#             "country": "US",
#             "state": "CA",
#             "display_address": [
#                "3292 Sandrock Rd",
#                "San Diego, CA 92123"
#             ]
#          },
#          "phone": "+18582777474",
#          "display_phone": "(858) 277-7474",
#          "distance": 1939.6026362461512
#       },
#       {
#          "id": "jfSLv3CA5ftTDAiIIdkpJg",
#          "alias": "diane-j-milberg-dds-msd-san-diego-2",
#          "name": "Diane J Milberg, DDS MSD",
#          "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/IgP-PQIMgo-_hSsg0MyRDQ/o.jpg",
#          "is_closed": false,
#          "url": "https://www.yelp.com/biz/diane-j-milberg-dds-msd-san-diego-2?adjust_creative=so3DyPxV4jy7d0woHd_3_Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=so3DyPxV4jy7d0woHd_3_Q",
#          "review_count": 40,
#          "categories": [
#             {
#                "alias": "orthodontists",
#                "title": "Orthodontists"
#             }
#          ],
#          "rating": 5.0,
#          "coordinates": {
#             "latitude": 32.7417640686035,
#             "longitude": -117.162368774414
#          },
#          "transactions": [],
#          "location": {
#             "address1": "306 Walnut Ave",
#             "address2": "Ste 33",
#             "address3": "",
#             "city": "San Diego",
#             "zip_code": "92103",
#             "country": "US",
#             "state": "CA",
#             "display_address": [
#                "306 Walnut Ave",
#                "Ste 33",
#                "San Diego, CA 92103"
#             ]
#          },
#          "phone": "+16192993560",
#          "display_phone": "(619) 299-3560",
#          "distance": 5484.015667258949
#       },
#       {
#          "id": "lHFlEmLCW2JNEn8A0DehtA",
#          "alias": "coastal-dental-arts-san-diego",
#          "name": "Coastal Dental Arts",
#          "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/3RoQS5r40nkhJVgZ-I2-mw/o.jpg",
#          "is_closed": false,
#          "url": "https://www.yelp.com/biz/coastal-dental-arts-san-diego?adjust_creative=so3DyPxV4jy7d0woHd_3_Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=so3DyPxV4jy7d0woHd_3_Q",
#          "review_count": 113,
#          "categories": [
#             {
#                "alias": "generaldentistry",
#                "title": "General Dentistry"
#             },
#             {
#                "alias": "oralsurgeons",
#                "title": "Oral Surgeons"
#             },
#             {
#                "alias": "cosmeticdentists",
#                "title": "Cosmetic Dentists"
#             }
#          ],
#          "rating": 4.0,
#          "coordinates": {
#             "latitude": 32.718163,
#             "longitude": -117.167677
#          },
#          "transactions": [],
#          "location": {
#             "address1": "1230 Columbia St",
#             "address2": "Ste 870",
#             "address3": "",
#             "city": "San Diego",
#             "zip_code": "92101",
#             "country": "US",
#             "state": "CA",
#             "display_address": [
#                "1230 Columbia St",
#                "Ste 870",
#                "San Diego, CA 92101"
#             ]
#          },
#          "phone": "+16198588080",
#          "display_phone": "(619) 858-8080",
#          "distance": 8150.95353304441
#       },
#       {
#          "id": "_9QQoUZLO_7lmkaniAn6KA",
#          "alias": "complete-dental-health-san-diego-2",
#          "name": "Complete Dental Health",
#          "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/mAMB1wN69L_rV0qSIkSKeQ/o.jpg",
#          "is_closed": false,
#          "url": "https://www.yelp.com/biz/complete-dental-health-san-diego-2?adjust_creative=so3DyPxV4jy7d0woHd_3_Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=so3DyPxV4jy7d0woHd_3_Q",
#          "review_count": 32,
#          "categories": [
#             {
#                "alias": "generaldentistry",
#                "title": "General Dentistry"
#             },
#             {
#                "alias": "cosmeticdentists",
#                "title": "Cosmetic Dentists"
#             }
#          ],
#          "rating": 5.0,
#          "coordinates": {
#             "latitude": 32.7471542358398,
#             "longitude": -117.165229797363
#          },
#          "transactions": [],
#          "location": {
#             "address1": "3808 Front St",
#             "address2": "",
#             "address3": "",
#             "city": "San Diego",
#             "zip_code": "92103",
#             "country": "US",
#             "state": "CA",
#             "display_address": [
#                "3808 Front St",
#                "San Diego, CA 92103"
#             ]
#          },
#          "phone": "+16192952202",
#          "display_phone": "(619) 295-2202",
#          "distance": 4941.5914476787175
#       },
#       {
#          "id": "F3AAsw-RwHzm9ILymVEt5g",
#          "alias": "rio-vista-family-dentistry-san-diego",
#          "name": "Rio Vista Family Dentistry",
#          "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/MD2cvIAZ6COFMWEr5kmTiA/o.jpg",
#          "is_closed": false,
#          "url": "https://www.yelp.com/biz/rio-vista-family-dentistry-san-diego?adjust_creative=so3DyPxV4jy7d0woHd_3_Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=so3DyPxV4jy7d0woHd_3_Q",
#          "review_count": 69,
#          "categories": [
#             {
#                "alias": "generaldentistry",
#                "title": "General Dentistry"
#             }
#          ],
#          "rating": 4.5,
#          "coordinates": {
#             "latitude": 32.7761659798183,
#             "longitude": -117.144580842849
#          },
#          "transactions": [],
#          "location": {
#             "address1": "8590 Rio San Diego Dr",
#             "address2": "Ste 110",
#             "address3": "",
#             "city": "San Diego",
#             "zip_code": "92108",
#             "country": "US",
#             "state": "CA",
#             "display_address": [
#                "8590 Rio San Diego Dr",
#                "Ste 110",
#                "San Diego, CA 92108"
#             ]
#          },
#          "phone": "+16192991122",
#          "display_phone": "(619) 299-1122",
#          "distance": 1831.4459391942896
#       },
#       {
#          "id": "n1R2SL7cqXW0IpMVLhAyGg",
#          "alias": "padre-dental-group-san-diego",
#          "name": "Padre Dental Group",
#          "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/n2BgSXpvW9xvquF_kFka-A/o.jpg",
#          "is_closed": false,
#          "url": "https://www.yelp.com/biz/padre-dental-group-san-diego?adjust_creative=so3DyPxV4jy7d0woHd_3_Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=so3DyPxV4jy7d0woHd_3_Q",
#          "review_count": 78,
#          "categories": [
#             {
#                "alias": "generaldentistry",
#                "title": "General Dentistry"
#             },
#             {
#                "alias": "periodontists",
#                "title": "Periodontists"
#             },
#             {
#                "alias": "cosmeticdentists",
#                "title": "Cosmetic Dentists"
#             }
#          ],
#          "rating": 4.5,
#          "coordinates": {
#             "latitude": 32.7496368315572,
#             "longitude": -117.159833908081
#          },
#          "transactions": [],
#          "location": {
#             "address1": "501 Washington St",
#             "address2": "Ste 704",
#             "address3": "",
#             "city": "San Diego",
#             "zip_code": "92103",
#             "country": "US",
#             "state": "CA",
#             "display_address": [
#                "501 Washington St",
#                "Ste 704",
#                "San Diego, CA 92103"
#             ]
#          },
#          "phone": "+16196881001",
#          "display_phone": "(619) 688-1001",
#          "distance": 4583.136503827137
#       },
#       {
#          "id": "6IbvVkaugh9R6gTWRrpa7w",
#          "alias": "pravina-reddy-dmd-san-diego",
#          "name": "Pravina Reddy, DMD",
#          "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/Dl0Qs6Vojiodt55kU6V8hA/o.jpg",
#          "is_closed": false,
#          "url": "https://www.yelp.com/biz/pravina-reddy-dmd-san-diego?adjust_creative=so3DyPxV4jy7d0woHd_3_Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=so3DyPxV4jy7d0woHd_3_Q",
#          "review_count": 32,
#          "categories": [
#             {
#                "alias": "cosmeticdentists",
#                "title": "Cosmetic Dentists"
#             },
#             {
#                "alias": "generaldentistry",
#                "title": "General Dentistry"
#             },
#             {
#                "alias": "endodontists",
#                "title": "Endodontists"
#             }
#          ],
#          "rating": 5.0,
#          "coordinates": {
#             "latitude": 32.894294,
#             "longitude": -117.193486
#          },
#          "transactions": [],
#          "location": {
#             "address1": "5830 Oberlin Dr",
#             "address2": "Ste 201",
#             "address3": "Sorrento Valley Smiles",
#             "city": "San Diego",
#             "zip_code": "92121",
#             "country": "US",
#             "state": "CA",
#             "display_address": [
#                "5830 Oberlin Dr",
#                "Ste 201",
#                "Sorrento Valley Smiles",
#                "San Diego, CA 92121"
#             ]
#          },
#          "phone": "+18584124696",
#          "display_phone": "(858) 412-4696",
#          "distance": 12106.822599750312
#       },
#       {
#          "id": "d-4aFWdUmWLUM3dqSRB9XQ",
#          "alias": "jeffrey-s-keeny-dds-san-diego",
#          "name": "Jeffrey S Keeny, DDS",
#          "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/oubrpQvVf3vZZrw-GrqLTg/o.jpg",
#          "is_closed": false,
#          "url": "https://www.yelp.com/biz/jeffrey-s-keeny-dds-san-diego?adjust_creative=so3DyPxV4jy7d0woHd_3_Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=so3DyPxV4jy7d0woHd_3_Q",
#          "review_count": 64,
#          "categories": [
#             {
#                "alias": "generaldentistry",
#                "title": "General Dentistry"
#             },
#             {
#                "alias": "endodontists",
#                "title": "Endodontists"
#             },
#             {
#                "alias": "cosmeticdentists",
#                "title": "Cosmetic Dentists"
#             }
#          ],
#          "rating": 4.5,
#          "coordinates": {
#             "latitude": 32.7461399,
#             "longitude": -117.14583
#          },
#          "transactions": [],
#          "location": {
#             "address1": "1807 Robinson Ave",
#             "address2": "Ste 101",
#             "address3": "",
#             "city": "San Diego",
#             "zip_code": "92103",
#             "country": "US",
#             "state": "CA",
#             "display_address": [
#                "1807 Robinson Ave",
#                "Ste 101",
#                "San Diego, CA 92103"
#             ]
#          },
#          "phone": "+16192951512",
#          "display_phone": "(619) 295-1512",
#          "distance": 5001.449343259846
#       },
#       {
#          "id": "HNoeu5NaR5Oc-1ypX9B2iA",
#          "alias": "friendly-family-dental-san-diego",
#          "name": "Friendly Family Dental",
#          "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/kcWEb5pqlWjnQ0bo5GJi-g/o.jpg",
#          "is_closed": false,
#          "url": "https://www.yelp.com/biz/friendly-family-dental-san-diego?adjust_creative=so3DyPxV4jy7d0woHd_3_Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=so3DyPxV4jy7d0woHd_3_Q",
#          "review_count": 27,
#          "categories": [
#             {
#                "alias": "cosmeticdentists",
#                "title": "Cosmetic Dentists"
#             },
#             {
#                "alias": "generaldentistry",
#                "title": "General Dentistry"
#             }
#          ],
#          "rating": 5.0,
#          "coordinates": {
#             "latitude": 32.8088445,
#             "longitude": -117.2012916
#          },
#          "transactions": [],
#          "location": {
#             "address1": "3774 Clairemont Dr",
#             "address2": "",
#             "address3": "",
#             "city": "San Diego",
#             "zip_code": "92117",
#             "country": "US",
#             "state": "CA",
#             "display_address": [
#                "3774 Clairemont Dr",
#                "San Diego, CA 92117"
#             ]
#          },
#          "phone": "+18582741219",
#          "display_phone": "(858) 274-1219",
#          "distance": 4857.866602892019
#       },
#       {
#          "id": "lpwmgJlRv7b5uzrbzrolrA",
#          "alias": "louis-e-paulerio-dds-san-diego-3",
#          "name": "Louis E Paulerio, DDS",
#          "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/PIevQHdT4TLv-U1ypLmm8A/o.jpg",
#          "is_closed": false,
#          "url": "https://www.yelp.com/biz/louis-e-paulerio-dds-san-diego-3?adjust_creative=so3DyPxV4jy7d0woHd_3_Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=so3DyPxV4jy7d0woHd_3_Q",
#          "review_count": 46,
#          "categories": [
#             {
#                "alias": "generaldentistry",
#                "title": "General Dentistry"
#             },
#             {
#                "alias": "cosmeticdentists",
#                "title": "Cosmetic Dentists"
#             }
#          ],
#          "rating": 5.0,
#          "coordinates": {
#             "latitude": 32.7276888,
#             "longitude": -117.2263801
#          },
#          "transactions": [],
#          "location": {
#             "address1": "1635 Rosecrans St",
#             "address2": "Ste A",
#             "address3": "Family And Cosmetic Dentistry",
#             "city": "San Diego",
#             "zip_code": "92106",
#             "country": "US",
#             "state": "CA",
#             "display_address": [
#                "1635 Rosecrans St",
#                "Ste A",
#                "Family And Cosmetic Dentistry",
#                "San Diego, CA 92106"
#             ]
#          },
#          "phone": "+16192233811",
#          "display_phone": "(619) 223-3811",
#          "distance": 9725.823591035203
#       },
#       {
#          "id": "RMY_Xy1qihbws71zrncKxw",
#          "alias": "liberty-station-orthodontics-san-diego-2",
#          "name": "Liberty Station Orthodontics",
#          "image_url": "https://s3-media2.fl.yelpcdn.com/bphoto/CTALZv9yiFwuEAs7BeqEeQ/o.jpg",
#          "is_closed": false,
#          "url": "https://www.yelp.com/biz/liberty-station-orthodontics-san-diego-2?adjust_creative=so3DyPxV4jy7d0woHd_3_Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=so3DyPxV4jy7d0woHd_3_Q",
#          "review_count": 27,
#          "categories": [
#             {
#                "alias": "orthodontists",
#                "title": "Orthodontists"
#             }
#          ],
#          "rating": 5.0,
#          "coordinates": {
#             "latitude": 32.736511,
#             "longitude": -117.21653
#          },
#          "transactions": [],
#          "location": {
#             "address1": "2445 Truxtun Rd",
#             "address2": "Ste 104",
#             "address3": "",
#             "city": "San Diego",
#             "zip_code": "92106",
#             "country": "US",
#             "state": "CA",
#             "display_address": [
#                "2445 Truxtun Rd",
#                "Ste 104",
#                "San Diego, CA 92106"
#             ]
#          },
#          "phone": "+16192251611",
#          "display_phone": "(619) 225-1611",
#          "distance": 8380.162330353074
#       },
#       {
#          "id": "bzZMLYDvemZQRdisIEyjGw",
#          "alias": "center-point-dental-group-san-diego",
#          "name": "Center Point Dental Group",
#          "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/kcg4QQN94gORbJtzSa6vxw/o.jpg",
#          "is_closed": false,
#          "url": "https://www.yelp.com/biz/center-point-dental-group-san-diego?adjust_creative=so3DyPxV4jy7d0woHd_3_Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=so3DyPxV4jy7d0woHd_3_Q",
#          "review_count": 32,
#          "categories": [
#             {
#                "alias": "cosmeticdentists",
#                "title": "Cosmetic Dentists"
#             },
#             {
#                "alias": "generaldentistry",
#                "title": "General Dentistry"
#             },
#             {
#                "alias": "endodontists",
#                "title": "Endodontists"
#             }
#          ],
#          "rating": 5.0,
#          "coordinates": {
#             "latitude": 32.76709,
#             "longitude": -117.05793
#          },
#          "transactions": [],
#          "location": {
#             "address1": "6544 El Cajon Blvd",
#             "address2": "",
#             "address3": "",
#             "city": "San Diego",
#             "zip_code": "92115",
#             "country": "US",
#             "state": "CA",
#             "display_address": [
#                "6544 El Cajon Blvd",
#                "San Diego, CA 92115"
#             ]
#          },
#          "phone": "+16195827722",
#          "display_phone": "(619) 582-7722",
#          "distance": 9368.268866110531
#       },
#       {
#          "id": "_NHGR960HJDxN737QaUGgw",
#          "alias": "pablo-liciaga-dds-san-diego",
#          "name": "Pablo Liciaga, DDS",
#          "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/YnSWD8FKv0ni2VgfkAMgzg/o.jpg",
#          "is_closed": false,
#          "url": "https://www.yelp.com/biz/pablo-liciaga-dds-san-diego?adjust_creative=so3DyPxV4jy7d0woHd_3_Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=so3DyPxV4jy7d0woHd_3_Q",
#          "review_count": 46,
#          "categories": [
#             {
#                "alias": "generaldentistry",
#                "title": "General Dentistry"
#             }
#          ],
#          "rating": 5.0,
#          "coordinates": {
#             "latitude": 32.7503890991211,
#             "longitude": -117.247711181641
#          },
#          "transactions": [],
#          "location": {
#             "address1": "2115 Bacon St",
#             "address2": "",
#             "address3": "",
#             "city": "San Diego",
#             "zip_code": "92107",
#             "country": "US",
#             "state": "CA",
#             "display_address": [
#                "2115 Bacon St",
#                "San Diego, CA 92107"
#             ]
#          },
#          "phone": "+16192242986",
#          "display_phone": "(619) 224-2986",
#          "distance": 9830.650816886144
#       },
#       {
#          "id": "ro_Q6aIq7uPBei019ucnmA",
#          "alias": "pb-smiles-dentistry-san-diego",
#          "name": "PB Smiles Dentistry",
#          "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/pH3a8JTOhyQn9aYNGra9Lg/o.jpg",
#          "is_closed": false,
#          "url": "https://www.yelp.com/biz/pb-smiles-dentistry-san-diego?adjust_creative=so3DyPxV4jy7d0woHd_3_Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=so3DyPxV4jy7d0woHd_3_Q",
#          "review_count": 104,
#          "categories": [
#             {
#                "alias": "generaldentistry",
#                "title": "General Dentistry"
#             },
#             {
#                "alias": "endodontists",
#                "title": "Endodontists"
#             },
#             {
#                "alias": "orthodontists",
#                "title": "Orthodontists"
#             }
#          ],
#          "rating": 4.0,
#          "coordinates": {
#             "latitude": 32.801146,
#             "longitude": -117.23377
#          },
#          "transactions": [],
#          "location": {
#             "address1": "1975 Garnet Ave",
#             "address2": "Ste E",
#             "address3": null,
#             "city": "San Diego",
#             "zip_code": "92109",
#             "country": "US",
#             "state": "CA",
#             "display_address": [
#                "1975 Garnet Ave",
#                "Ste E",
#                "San Diego, CA 92109"
#             ]
#          },
#          "phone": "+18588660808",
#          "display_phone": "(858) 866-0808",
#          "distance": 7540.6748266243
#       },
#       {
#          "id": "bWOX_ad9dpLfzwwhhIKNqQ",
#          "alias": "mission-valley-dentists-san-diego",
#          "name": "Mission Valley Dentists",
#          "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/ZW8qabugixf7-i6zHMbvug/o.jpg",
#          "is_closed": false,
#          "url": "https://www.yelp.com/biz/mission-valley-dentists-san-diego?adjust_creative=so3DyPxV4jy7d0woHd_3_Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=so3DyPxV4jy7d0woHd_3_Q",
#          "review_count": 192,
#          "categories": [
#             {
#                "alias": "generaldentistry",
#                "title": "General Dentistry"
#             },
#             {
#                "alias": "oralsurgeons",
#                "title": "Oral Surgeons"
#             },
#             {
#                "alias": "cosmeticdentists",
#                "title": "Cosmetic Dentists"
#             }
#          ],
#          "rating": 3.5,
#          "coordinates": {
#             "latitude": 32.774175,
#             "longitude": -117.157346
#          },
#          "transactions": [],
#          "location": {
#             "address1": "5638 Mission Center Rd",
#             "address2": "Ste 107",
#             "address3": null,
#             "city": "San Diego",
#             "zip_code": "92108",
#             "country": "US",
#             "state": "CA",
#             "display_address": [
#                "5638 Mission Center Rd",
#                "Ste 107",
#                "San Diego, CA 92108"
#             ]
#          },
#          "phone": "+16192200159",
#          "display_phone": "(619) 220-0159",
#          "distance": 1848.3130991229982
#       },
#       {
#          "id": "n5VhxJZF9jx5SEHurRkMFw",
#          "alias": "affinity-dental-hillcrest-san-diego-6",
#          "name": "Affinity Dental Hillcrest",
#          "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/Gl1xmiCnnZBH5rYhP3viDQ/o.jpg",
#          "is_closed": false,
#          "url": "https://www.yelp.com/biz/affinity-dental-hillcrest-san-diego-6?adjust_creative=so3DyPxV4jy7d0woHd_3_Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=so3DyPxV4jy7d0woHd_3_Q",
#          "review_count": 129,
#          "categories": [
#             {
#                "alias": "generaldentistry",
#                "title": "General Dentistry"
#             },
#             {
#                "alias": "cosmeticdentists",
#                "title": "Cosmetic Dentists"
#             },
#             {
#                "alias": "oralsurgeons",
#                "title": "Oral Surgeons"
#             }
#          ],
#          "rating": 4.0,
#          "coordinates": {
#             "latitude": 32.7404,
#             "longitude": -117.16248
#          },
#          "transactions": [],
#          "location": {
#             "address1": "3330 3rd Ave",
#             "address2": "Ste 400",
#             "address3": "",
#             "city": "San Diego",
#             "zip_code": "92103",
#             "country": "US",
#             "state": "CA",
#             "display_address": [
#                "3330 3rd Ave",
#                "Ste 400",
#                "San Diego, CA 92103"
#             ]
#          },
#          "phone": "+16192918750",
#          "display_phone": "(619) 291-8750",
#          "distance": 5623.889274167319
#       },
#       {
#          "id": "vaJxJMvM9d-6T0YYqOXO3Q",
#          "alias": "michael-d-carter-dmd-san-diego",
#          "name": "Michael D Carter, DMD",
#          "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/H_IYp6MWyfV5iEYFWiR-Kg/o.jpg",
#          "is_closed": false,
#          "url": "https://www.yelp.com/biz/michael-d-carter-dmd-san-diego?adjust_creative=so3DyPxV4jy7d0woHd_3_Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=so3DyPxV4jy7d0woHd_3_Q",
#          "review_count": 42,
#          "categories": [
#             {
#                "alias": "endodontists",
#                "title": "Endodontists"
#             }
#          ],
#          "rating": 4.5,
#          "coordinates": {
#             "latitude": 32.809299,
#             "longitude": -117.210688
#          },
#          "transactions": [],
#          "location": {
#             "address1": "3737 Moraga Ave",
#             "address2": "Ste B220",
#             "address3": "",
#             "city": "San Diego",
#             "zip_code": "92117",
#             "country": "US",
#             "state": "CA",
#             "display_address": [
#                "3737 Moraga Ave",
#                "Ste B220",
#                "San Diego, CA 92117"
#             ]
#          },
#          "phone": "+18584833636",
#          "display_phone": "(858) 483-3636",
#          "distance": 5685.810720907701
#       },
#       {
#          "id": "fUSJuCKlmAbDQT_OnZK00w",
#          "alias": "george-georgaklis-dds-san-diego-2",
#          "name": "George Georgaklis, DDS",
#          "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/fDvtDz08N2M5S2V_B9eQHQ/o.jpg",
#          "is_closed": false,
#          "url": "https://www.yelp.com/biz/george-georgaklis-dds-san-diego-2?adjust_creative=so3DyPxV4jy7d0woHd_3_Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=so3DyPxV4jy7d0woHd_3_Q",
#          "review_count": 45,
#          "categories": [
#             {
#                "alias": "orthodontists",
#                "title": "Orthodontists"
#             },
#             {
#                "alias": "cosmeticdentists",
#                "title": "Cosmetic Dentists"
#             },
#             {
#                "alias": "generaldentistry",
#                "title": "General Dentistry"
#             }
#          ],
#          "rating": 4.5,
#          "coordinates": {
#             "latitude": 32.8761269,
#             "longitude": -117.210803
#          },
#          "transactions": [],
#          "location": {
#             "address1": "4510 Executive Dr",
#             "address2": "Ste 106",
#             "address3": "",
#             "city": "San Diego",
#             "zip_code": "92121",
#             "country": "US",
#             "state": "CA",
#             "display_address": [
#                "4510 Executive Dr",
#                "Ste 106",
#                "San Diego, CA 92121"
#             ]
#          },
#          "phone": "+18585521223",
#          "display_phone": "(858) 552-1223",
#          "distance": 10889.968666841767
#       },
#       {
#          "id": "RSmDuYQL88wCMVlkDrf3LA",
#          "alias": "premier-dental-san-diego",
#          "name": "Premier Dental",
#          "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/5stZSb3B8KtSsvRg7RSucw/o.jpg",
#          "is_closed": false,
#          "url": "https://www.yelp.com/biz/premier-dental-san-diego?adjust_creative=so3DyPxV4jy7d0woHd_3_Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=so3DyPxV4jy7d0woHd_3_Q",
#          "review_count": 46,
#          "categories": [
#             {
#                "alias": "oralsurgeons",
#                "title": "Oral Surgeons"
#             },
#             {
#                "alias": "periodontists",
#                "title": "Periodontists"
#             },
#             {
#                "alias": "cosmeticdentists",
#                "title": "Cosmetic Dentists"
#             }
#          ],
#          "rating": 4.5,
#          "coordinates": {
#             "latitude": 32.755258,
#             "longitude": -117.09584
#          },
#          "transactions": [],
#          "location": {
#             "address1": "4575 El Cajon Blvd",
#             "address2": "Ste A",
#             "address3": null,
#             "city": "San Diego",
#             "zip_code": "92115",
#             "country": "US",
#             "state": "CA",
#             "display_address": [
#                "4575 El Cajon Blvd",
#                "Ste A",
#                "San Diego, CA 92115"
#             ]
#          },
#          "phone": "+16192815569",
#          "display_phone": "(619) 281-5569",
#          "distance": 6713.417803657639
#       },
#       {
#          "id": "X3HBtkQDSZActtxTvk9v4w",
#          "alias": "pacific-beach-smile-studio-san-diego-5",
#          "name": "Pacific Beach Smile Studio",
#          "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/XqjmhVWFX8iRMe7t3Xym5Q/o.jpg",
#          "is_closed": false,
#          "url": "https://www.yelp.com/biz/pacific-beach-smile-studio-san-diego-5?adjust_creative=so3DyPxV4jy7d0woHd_3_Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=so3DyPxV4jy7d0woHd_3_Q",
#          "review_count": 52,
#          "categories": [
#             {
#                "alias": "generaldentistry",
#                "title": "General Dentistry"
#             },
#             {
#                "alias": "cosmeticdentists",
#                "title": "Cosmetic Dentists"
#             }
# ...
#             "address3": "",
#             "city": "San Diego",
#             "zip_code": "92103",
#             "country": "US",
#             "state": "CA",
#             "display_address": [
#                "3730 Third Ave",
#                "San Diego, CA 92103"
#             ]
#          },
#          "phone": "+16192972949",
#          "display_phone": "(619) 297-2949",
#          "distance": 5060.2997012326505
#       },
#       {
#          "id": "6oSijBFIIWB0U4r8_zywzw",
#          "alias": "the-oral-surgery-and-dental-implant-specialists-of-san-diego-san-diego",
#          "name": "The Oral Surgery & Dental Implant Specialists of San Diego",
#          "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/nD8gMWM-DETopw4qSYTZHA/o.jpg",
#          "is_closed": false,
#          "url": "https://www.yelp.com/biz/the-oral-surgery-and-dental-implant-specialists-of-san-diego-san-diego?adjust_creative=so3DyPxV4jy7d0woHd_3_Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=so3DyPxV4jy7d0woHd_3_Q",
#          "review_count": 41,
#          "categories": [
#             {
#                "alias": "oralsurgeons",
#                "title": "Oral Surgeons"
#             },
#             {
#                "alias": "cosmeticdentists",
#                "title": "Cosmetic Dentists"
#             },
#             {
#                "alias": "orthodontists",
#                "title": "Orthodontists"
#             }
#          ],
#          "rating": 4.5,
#          "coordinates": {
#             "latitude": 32.80937,
#             "longitude": -117.21014
#          },
#          "transactions": [],
#          "location": {
#             "address1": "3737 Moraga Ave",
#             "address2": "Ste B-216",
#             "address3": "",
#             "city": "San Diego",
#             "zip_code": "92117",
#             "country": "US",
#             "state": "CA",
#             "display_address": [
#                "3737 Moraga Ave",
#                "Ste B-216",
#                "San Diego, CA 92117"
#             ]
#          },
#          "phone": "+18582747901",
#          "display_phone": "(858) 274-7901",
#          "distance": 5683.554059697471
#       },
#       {
#          "id": "iRYzpdcF2i85ktK_BFpKAA",
#          "alias": "yolanda-garcia-lorett-dds-san-diego",
#          "name": "Yolanda Garcia Lorett, DDS",
#          "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/GlU-topE514h-X04ZXe5Ow/o.jpg",
#          "is_closed": false,
#          "url": "https://www.yelp.com/biz/yolanda-garcia-lorett-dds-san-diego?adjust_creative=so3DyPxV4jy7d0woHd_3_Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=so3DyPxV4jy7d0woHd_3_Q",
#          "review_count": 30,
#          "categories": [
#             {
#                "alias": "generaldentistry",
#                "title": "General Dentistry"
#             },
#             {
#                "alias": "cosmeticdentists",
#                "title": "Cosmetic Dentists"
#             },
#             {
#                "alias": "periodontists",
#                "title": "Periodontists"
#             }
#          ],
#          "rating": 5.0,
#          "coordinates": {
#             "latitude": 32.812238,
#             "longitude": -117.153836
#          },
#          "transactions": [],
#          "location": {
#             "address1": "3750 Convoy St",
#             "address2": "Ste 307",
#             "address3": "",
#             "city": "San Diego",
#             "zip_code": "92111",
#             "country": "US",
#             "state": "CA",
#             "display_address": [
#                "3750 Convoy St",
#                "Ste 307",
#                "San Diego, CA 92111"
#             ]
#          },
#          "phone": "+18582774453",
#          "display_phone": "(858) 277-4453",
#          "distance": 2400.121515237501
#       },
#       {
#          "id": "CZsyD9DR_g4uKm6lFnkoCQ",
#          "alias": "paul-j-styrt-orthodontics-and-pediatric-dentistry-san-diego",
#          "name": "Paul J. Styrt, Orthodontics & Pediatric Dentistry",
#          "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/baD_td1srKPqqSAZHym0og/o.jpg",
#          "is_closed": false,
#          "url": "https://www.yelp.com/biz/paul-j-styrt-orthodontics-and-pediatric-dentistry-san-diego?adjust_creative=so3DyPxV4jy7d0woHd_3_Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=so3DyPxV4jy7d0woHd_3_Q",
#          "review_count": 56,
#          "categories": [
#             {
#                "alias": "orthodontists",
#                "title": "Orthodontists"
#             },
#             {
#                "alias": "pediatric_dentists",
#                "title": "Pediatric Dentists"
#             }
#          ],
#          "rating": 4.5,
#          "coordinates": {
#             "latitude": 32.8758819,
#             "longitude": -117.2129877
#          },
#          "transactions": [],
#          "location": {
#             "address1": "9339 Genesee Ave",
#             "address2": "Ste 270",
#             "address3": "",
#             "city": "San Diego",
#             "zip_code": "92121",
#             "country": "US",
#             "state": "CA",
#             "display_address": [
#                "9339 Genesee Ave",
#                "Ste 270",
#                "San Diego, CA 92121"
#             ]
#          },
#          "phone": "+18584581088",
#          "display_phone": "(858) 458-1088",
#          "distance": 10967.177832317298
#       },
#       {
#          "id": "Kt8WPmNBj4_eGCyeVGnq7g",
#          "alias": "dixon-pediatric-dental-group-san-diego",
#          "name": "Dixon Pediatric Dental Group",
#          "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/mSFWa1f91vxu8SdZ9xoLuQ/o.jpg",
#          "is_closed": false,
#          "url": "https://www.yelp.com/biz/dixon-pediatric-dental-group-san-diego?adjust_creative=so3DyPxV4jy7d0woHd_3_Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=so3DyPxV4jy7d0woHd_3_Q",
#          "review_count": 66,
#          "categories": [
#             {
#                "alias": "pediatric_dentists",
#                "title": "Pediatric Dentists"
#             },
#             {
#                "alias": "orthodontists",
#                "title": "Orthodontists"
#             }
#          ],
#          "rating": 4.5,
#          "coordinates": {
#             "latitude": 32.8915577186158,
#             "longitude": -117.196595800658
#          },
#          "transactions": [],
#          "location": {
#             "address1": "5627 Oberlin Dr",
#             "address2": "Ste 100",
#             "address3": "",
#             "city": "San Diego",
#             "zip_code": "92121",
#             "country": "US",
#             "state": "CA",
#             "display_address": [
#                "5627 Oberlin Dr",
#                "Ste 100",
#                "San Diego, CA 92121"
#             ]
#          },
#          "phone": "+18584527272",
#          "display_phone": "(858) 452-7272",
#          "distance": 11911.04726809631
#       },
#       {
#          "id": "vkdehRK2XhSX-dJjbqLkwA",
#          "alias": "lawrence-p-lotzof-dds-san-diego",
#          "name": "Lawrence P. Lotzof, DDS",
#          "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/kt2RexZ7wzOIAhpDJgsLIg/o.jpg",
#          "is_closed": false,
#          "url": "https://www.yelp.com/biz/lawrence-p-lotzof-dds-san-diego?adjust_creative=so3DyPxV4jy7d0woHd_3_Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=so3DyPxV4jy7d0woHd_3_Q",
#          "review_count": 31,
#          "categories": [
#             {
#                "alias": "orthodontists",
#                "title": "Orthodontists"
#             }
#          ],
#          "rating": 4.5,
#          "coordinates": {
#             "latitude": 32.821338,
#             "longitude": -117.184196
#          },
#          "transactions": [],
#          "location": {
#             "address1": "4320 Genesee Ave",
#             "address2": "Ste 206",
#             "address3": "",
#             "city": "San Diego",
#             "zip_code": "92117",
#             "country": "US",
#             "state": "CA",
#             "display_address": [
#                "4320 Genesee Ave",
#                "Ste 206",
#                "San Diego, CA 92117"
#             ]
#          },
#          "phone": "+18582796210",
#          "display_phone": "(858) 279-6210",
#          "distance": 4430.114485791269
#       },
#       {
#          "id": "C62srvdQTaqVDAkp15oQEg",
#          "alias": "university-dental-san-diego",
#          "name": "University Dental",
#          "image_url": "https://s3-media4.fl.yelpcdn.com/bphoto/Z5pVmpIkt14zegKSyQPZeg/o.jpg",
#          "is_closed": false,
#          "url": "https://www.yelp.com/biz/university-dental-san-diego?adjust_creative=so3DyPxV4jy7d0woHd_3_Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=so3DyPxV4jy7d0woHd_3_Q",
#          "review_count": 42,
#          "categories": [
#             {
#                "alias": "cosmeticdentists",
#                "title": "Cosmetic Dentists"
#             },
#             {
#                "alias": "oralsurgeons",
#                "title": "Oral Surgeons"
#             },
#             {
#                "alias": "orthodontists",
#                "title": "Orthodontists"
#             }
#          ],
#          "rating": 4.5,
#          "coordinates": {
#             "latitude": 32.754624,
#             "longitude": -117.059574
#          },
#          "transactions": [],
#          "location": {
#             "address1": "6324 University Ave",
#             "address2": "",
#             "address3": null,
#             "city": "San Diego",
#             "zip_code": "92115",
#             "country": "US",
#             "state": "CA",
#             "display_address": [
#                "6324 University Ave",
#                "San Diego, CA 92115"
#             ]
#          },
#          "phone": "+16195824224",
#          "display_phone": "(619) 582-4224",
#          "distance": 9698.127175331865
#       },
#       {
#          "id": "p_wtiX22FjoMBXWr8lVp4w",
#          "alias": "bay-park-dental-group-san-diego-2",
#          "name": "Bay Park Dental Group",
#          "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/7t_AAeqngqzM5wAcbA7sYA/o.jpg",
#          "is_closed": false,
#          "url": "https://www.yelp.com/biz/bay-park-dental-group-san-diego-2?adjust_creative=so3DyPxV4jy7d0woHd_3_Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=so3DyPxV4jy7d0woHd_3_Q",
#          "review_count": 41,
#          "categories": [
#             {
#                "alias": "generaldentistry",
#                "title": "General Dentistry"
#             },
#             {
#                "alias": "periodontists",
#                "title": "Periodontists"
#             },
#             {
#                "alias": "cosmeticdentists",
#                "title": "Cosmetic Dentists"
#             }
#          ],
#          "rating": 4.5,
#          "coordinates": {
#             "latitude": 32.7903147,
#             "longitude": -117.2028696
#          },
#          "transactions": [],
#          "location": {
#             "address1": "2619 Clairemont Dr",
#             "address2": "",
#             "address3": "",
#             "city": "San Diego",
#             "zip_code": "92117",
#             "country": "US",
#             "state": "CA",
#             "display_address": [
#                "2619 Clairemont Dr",
#                "San Diego, CA 92117"
#             ]
#          },
#          "phone": "+16192760963",
#          "display_phone": "(619) 276-0963",
#          "distance": 4560.473992298299
#       },
#       {
#          "id": "uD4baX-ATE6yWEmQULBs7g",
#          "alias": "jason-brown-dds-san-diego-2",
#          "name": "Jason Brown, DDS",
#          "image_url": "",
#          "is_closed": false,
#          "url": "https://www.yelp.com/biz/jason-brown-dds-san-diego-2?adjust_creative=so3DyPxV4jy7d0woHd_3_Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=so3DyPxV4jy7d0woHd_3_Q",
#          "review_count": 26,
#          "categories": [
#             {
#                "alias": "generaldentistry",
#                "title": "General Dentistry"
#             },
#             {
#                "alias": "endodontists",
#                "title": "Endodontists"
#             },
#             {
#                "alias": "periodontists",
#                "title": "Periodontists"
#             }
#          ],
#          "rating": 5.0,
#          "coordinates": {
#             "latitude": 32.7417491,
#             "longitude": -117.1624731
#          },
#          "transactions": [],
#          "location": {
#             "address1": "306 Walnut Ave",
#             "address2": "Ste 24",
#             "address3": "",
#             "city": "San Diego",
#             "zip_code": "92103",
#             "country": "US",
#             "state": "CA",
#             "display_address": [
#                "306 Walnut Ave",
#                "Ste 24",
#                "San Diego, CA 92103"
#             ]
#          },
#          "phone": "+16192321005",
#          "display_phone": "(619) 232-1005",
#          "distance": 5484.951110097862
#       },
#       {
#          "id": "W5tcIbSoc6GxRYNLFbpxtw",
#          "alias": "mission-hills-dental-group-san-diego",
#          "name": "Mission Hills Dental Group",
#          "image_url": "https://s3-media1.fl.yelpcdn.com/bphoto/C_nyBYgf6JzHtQ9LMj0maA/o.jpg",
#          "is_closed": false,
#          "url": "https://www.yelp.com/biz/mission-hills-dental-group-san-diego?adjust_creative=so3DyPxV4jy7d0woHd_3_Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=so3DyPxV4jy7d0woHd_3_Q",
#          "review_count": 87,
#          "categories": [
#             {
#                "alias": "oralsurgeons",
#                "title": "Oral Surgeons"
#             },
#             {
#                "alias": "generaldentistry",
#                "title": "General Dentistry"
#             },
#             {
#                "alias": "cosmeticdentists",
#                "title": "Cosmetic Dentists"
#             }
#          ],
#          "rating": 4.0,
#          "coordinates": {
#             "latitude": 32.7500316047158,
#             "longitude": -117.169734612107
#          },
#          "transactions": [],
#          "location": {
#             "address1": "718 W Washington St",
#             "address2": null,
#             "address3": null,
#             "city": "San Diego",
#             "zip_code": "92103",
#             "country": "US",
#             "state": "CA",
#             "display_address": [
#                "718 W Washington St",
#                "San Diego, CA 92103"
#             ]
#          },
#          "phone": "+16196999008",
#          "display_phone": "(619) 699-9008",
#          "distance": 4739.180192963982
#       },
#       {
#          "id": "hgJZhRq4dtQhbaLRqYHd-A",
#          "alias": "fifth-avenue-dental-arts-san-diego-9",
#          "name": "Fifth Avenue Dental Arts",
#          "image_url": "https://s3-media3.fl.yelpcdn.com/bphoto/3DOvPn1Elx1n2lQwcJqZIQ/o.jpg",
#          "is_closed": false,
#          "url": "https://www.yelp.com/biz/fifth-avenue-dental-arts-san-diego-9?adjust_creative=so3DyPxV4jy7d0woHd_3_Q&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=so3DyPxV4jy7d0woHd_3_Q",
#          "review_count": 53,
#          "categories": [
#             {
#                "alias": "endodontists",
#                "title": "Endodontists"
#             },
#             {
#                "alias": "periodontists",
#                "title": "Periodontists"
#             },
#             {
#                "alias": "cosmeticdentists",
#                "title": "Cosmetic Dentists"
#             }
#          ],
#          "rating": 4.5,
#          "coordinates": {
#             "latitude": 32.7190219,
#             "longitude": -117.1604822
#          },
#          "transactions": [],
#          "location": {
#             "address1": "450 A St",
#             "address2": "Ste 200",
#             "address3": null,
#             "city": "San Diego",
#             "zip_code": "92101",
#             "country": "US",
#             "state": "CA",
#             "display_address": [
#                "450 A St",
#                "Ste 200",
#                "San Diego, CA 92101"
#             ]
#          },
#          "phone": "+16192333338",
#          "display_phone": "(619) 233-3338",
#          "distance": 7978.181994672361
#       }
#    ],
#    "total": 676,
#    "region": {
#       "center": {
#          "longitude": -117.15408325195312,
#          "latitude": 32.790569394537286
#       }
#    }
# }

# %%
business_data.keys()
# Out:
# dict_keys(['businesses', 'total', 'region'])

# %%
{'alias': 'cosmeticdentists', 'title': 'Cosme...
# 7   [{'alias': 'orthodontists', 'title': 'Orthodon...
# 8   [{'alias': 'oralsurgeons', 'title': 'Oral Surg...
# 9   [{'alias': 'oralsurgeons', 'title': 'Oral Surg...
# 10  [{'alias': 'periodontists', 'title': 'Periodon...
# 11  [{'alias': 'generaldentistry', 'title': 'Gener...
# 12  [{'alias': 'generaldentistry', 'title': 'Gener...
# 13  [{'alias': 'generaldentistry', 'title': 'Gener...
# 14  [{'alias': 'orthodontists', 'title': 'Orthodon...
# 15  [{'alias': 'generaldentistry', 'title': 'Gener...
# 16  [{'alias': 'generaldentistry', 'title': 'Gener...
# 17  [{'alias': 'generaldentistry', 'title': 'Gener...
# 18  [{'alias': 'generaldentistry', 'title': 'Gener...
# 19  [{'alias': 'cosmeticdentists', 'title': 'Cosme...
# 20  [{'alias': 'generaldentistry', 'title': 'Gener...
# 21  [{'alias': 'cosmeticdentists', 'title': 'Cosme...
# 22  [{'alias': 'generaldentistry', 'title': 'Gener...
# 23  [{'alias': 'orthodontists', 'title': 'Orthodon...
# 24  [{'alias': 'cosmeticdentists', 'title': 'Cosme...
# 25  [{'alias': 'generaldentistry', 'title': 'Gener...
# 26  [{'alias': 'generaldentistry', 'title': 'Gener...
# 27  [{'alias': 'generaldentistry', 'title': 'Gener...
# 28  [{'alias': 'generaldentistry', 'title': 'Gener...
# 29  [{'alias': 'endodontists', 'title': 'Endodonti...
# 30  [{'alias': 'orthodontists', 'title': 'Orthodon...
# 31  [{'alias': 'oralsurgeons', 'title': 'Oral Surg...
# 32  [{'alias': 'generaldentistry', 'title': 'Gener...
# 33  [{'alias': 'generaldentistry', 'title': 'Gener...
# 34  [{'alias': 'generaldentistry', 'title': 'Gener...
# 35  [{'alias': 'cosmeticdentists', 'title': 'Cosme...
# 36  [{'alias': 'cosmeticdentists', 'title': 'Cosme...
# 37  [{'alias': 'lactationservices', 'title': 'Lact...
# 38  [{'alias': 'generaldentistry', 'title': 'Gener...
# 39  [{'alias': 'cosmeticdentists', 'title': 'Cosme...
# 40  [{'alias': 'oralsurgeons', 'title': 'Oral Surg...
# 41  [{'alias': 'generaldentistry', 'title': 'Gener...
# 42  [{'alias': 'orthodontists', 'title': 'Orthodon...
# 43  [{'alias': 'pediatric_dentists', 'title': 'Ped...
# 44  [{'alias': 'orthodontists', 'title': 'Orthodon...
# 45  [{'alias': 'cosmeticdentists', 'title': 'Cosme...
# 46  [{'alias': 'generaldentistry', 'title': 'Gener...
# 47  [{'alias': 'generaldentistry', 'title': 'Gener...
# 48  [{'alias': 'oralsurgeons', 'title': 'Oral Surg...
# 49  [{'alias': 'endodontists', 'title': 'Endodonti...
#
#                                           coordinates   display_phone  \
# 0   {'latitude': 32.745685, 'longitude': -117.163064}  (619) 232-7433
# 1   {'latitude': 32.808636, 'longitude': -117.201378}  (858) 270-2760
# 2     {'latitude': 32.80322, 'longitude': -117.21497}  (858) 270-1400
# 3   {'latitude': 32.7543907165527, 'longitude': -1...  (619) 265-0566
# 4     {'latitude': 32.71701, 'longitude': -117.15898}  (619) 696-0510
# 5   {'latitude': 32.7913804, 'longitude': -117.158...  (858) 598-6800
# 6     {'latitude': 32.89993, 'longitude': -117.18821}  (858) 558-2121
# 7   {'latitude': 32.7311714, 'longitude': -117.162...  (619) 291-5266
# 8     {'latitude': 32.77234, 'longitude': -117.13479}  (619) 282-7088
# 9   {'latitude': 32.7763824462891, 'longitude': -1...  (619) 287-5000
# 10  {'latitude': 32.8260498046875, 'longitude': -1...  (858) 279-1004
# 11  {'latitude': 32.828629, 'longitude': -117.126124}  (858) 278-1454
# 12    {'latitude': 32.79918, 'longitude': -117.24623}  (858) 272-2222
# 13  {'latitude': 32.802499, 'longitude': -117.1387...  (858) 277-7474
# 14  {'latitude': 32.7417640686035, 'longitude': -1...  (619) 299-3560
# 15  {'latitude': 32.718163, 'longitude': -117.167677}  (619) 858-8080
# 16  {'latitude': 32.7471542358398, 'longitude': -1...  (619) 295-2202
# 17  {'latitude': 32.7761659798183, 'longitude': -1...  (619) 299-1122
# 18  {'latitude': 32.7496368315572, 'longitude': -1...  (619) 688-1001
# 19  {'latitude': 32.894294, 'longitude': -117.193486}  (858) 412-4696
# 20  {'latitude': 32.7461399, 'longitude': -117.14583}  (619) 295-1512
# 21  {'latitude': 32.8088445, 'longitude': -117.201...  (858) 274-1219
# 22  {'latitude': 32.7276888, 'longitude': -117.226...  (619) 223-3811
# 23   {'latitude': 32.736511, 'longitude': -117.21653}  (619) 225-1611
# 24    {'latitude': 32.76709, 'longitude': -117.05793}  (619) 582-7722
# 25  {'latitude': 32.7503890991211, 'longitude': -1...  (619) 224-2986
# 26   {'latitude': 32.801146, 'longitude': -117.23377}  (858) 866-0808
# 27  {'latitude': 32.774175, 'longitude': -117.157346}  (619) 220-0159
# 28     {'latitude': 32.7404, 'longitude': -117.16248}  (619) 291-8750
# 29  {'latitude': 32.809299, 'longitude': -117.210688}  (858) 483-3636
# 30  {'latitude': 32.8761269, 'longitude': -117.210...  (858) 552-1223
# 31   {'latitude': 32.755258, 'longitude': -117.09584}  (619) 281-5569
# 32    {'latitude': 32.80156, 'longitude': -117.22987}  (858) 272-6047
# 33  {'latitude': 32.826302, 'longitude': -117.191086}  (858) 279-6100
# 34    {'latitude': 32.80237, 'longitude': -117.23046}  (858) 270-4904
# 35  {'latitude': 32.7958431, 'longitude': -117.250...  (858) 412-5155
# 36  {'latitude': 32.741764, 'longitude': -117.162366}  (619) 295-4545
# 37     {'latitude': 32.94743, 'longitude': -117.2396}  (858) 480-9454
# 38  {'latitude': 32.8009262084961, 'longitude': -1...  (858) 270-6711
# 39    {'latitude': 32.74568, 'longitude': -117.16306}  (619) 297-2949
# 40    {'latitude': 32.80937, 'longitude': -117.21014}  (858) 274-7901
# 41  {'latitude': 32.812238, 'longitude': -117.153836}  (858) 277-4453
# 42  {'latitude': 32.8758819, 'longitude': -117.212...  (858) 458-1088
# 43  {'latitude': 32.8915577186158, 'longitude': -1...  (858) 452-7272
# 44  {'latitude': 32.821338, 'longitude': -117.184196}  (858) 279-6210
# 45  {'latitude': 32.754624, 'longitude': -117.059574}  (619) 582-4224
# 46  {'latitude': 32.7903147, 'longitude': -117.202...  (619) 276-0963
# 47  {'latitude': 32.7417491, 'longitude': -117.162...  (619) 232-1005
# 48  {'latitude': 32.7500316047158, 'longitude': -1...  (619) 699-9008
# 49  {'latitude': 32.7190219, 'longitude': -117.160...  (619) 233-3338
#
#         distance                      id  \
# 0    5061.056681  XBvtCsYtFBIBGWKTUazVNA
# 1    4850.287638  IHXCbNHwLTySbueGdqg2fQ
# 9   {'address1': '6386 Alvarado Ct', 'address2': '...
# 10  {'address1': '7825 Engineer Rd', 'address2': '...
# 11  {'address1': '5075 Ruffin Rd', 'address2': '',...
# 12  {'address1': '4527 Fanuel St', 'address2': '',...
# 13  {'address1': '3292 Sandrock Rd', 'address2': '...
# 14  {'address1': '306 Walnut Ave', 'address2': 'St...
# 15  {'address1': '1230 Columbia St', 'address2': '...
# 16  {'address1': '3808 Front St', 'address2': '', ...
# 17  {'address1': '8590 Rio San Diego Dr', 'address...
# 18  {'address1': '501 Washington St', 'address2': ...
# 19  {'address1': '5830 Oberlin Dr', 'address2': 'S...
# 20  {'address1': '1807 Robinson Ave', 'address2': ...
# 21  {'address1': '3774 Clairemont Dr', 'address2':...
# 22  {'address1': '1635 Rosecrans St', 'address2': ...
# 23  {'address1': '2445 Truxtun Rd', 'address2': 'S...
# 24  {'address1': '6544 El Cajon Blvd', 'address2':...
# 25  {'address1': '2115 Bacon St', 'address2': '', ...
# 26  {'address1': '1975 Garnet Ave', 'address2': 'S...
# 27  {'address1': '5638 Mission Center Rd', 'addres...
# 28  {'address1': '3330 3rd Ave', 'address2': 'Ste ...
# 29  {'address1': '3737 Moraga Ave', 'address2': 'S...
# 30  {'address1': '4510 Executive Dr', 'address2': ...
# 31  {'address1': '4575 El Cajon Blvd', 'address2':...
# 32  {'address1': '4460 Olney St', 'address2': '', ...
# 33  {'address1': '4690 Genesee Ave', 'address2': '...
# 34  {'address1': '2180 Garnet Ave', 'address2': ''...
# 35  {'address1': '1038 Grand Ave', 'address2': '',...
# 36  {'address1': '306 Walnut Ave', 'address2': 'St...
# 37  {'address1': '12625 High Bluff Dr', 'address2'...
# 38  {'address1': '2036 Hornblend St', 'address2': ...
# 39  {'address1': '3730 Third Ave', 'address2': Non...
# 40  {'address1': '3737 Moraga Ave', 'address2': 'S...
# 41  {'address1': '3750 Convoy St', 'address2': 'St...
# 42  {'address1': '9339 Genesee Ave', 'address2': '...
# 43  {'address1': '5627 Oberlin Dr', 'address2': 'S...
# 44  {'address1': '4320 Genesee Ave', 'address2': '...
# 45  {'address1': '6324 University Ave', 'address2'...
# 46  {'address1': '2619 Clairemont Dr', 'address2':...
# 47  {'address1': '306 Walnut Ave', 'address2': 'St...
# 48  {'address1': '718 W Washington St', 'address2'...
# 49  {'address1': '450 A St', 'address2': 'Ste 200'...
#
#                                                  name         phone  rating  \
# 0                              Andrew R. Chapokas DMD  +16192327433     5.0
# 1                           A Jayson Tengonciang, DMD  +18582702760     5.0
# 2                        Mission Bay Family Dentistry  +18582701400     5.0
# 3                                        Alpha Dental  +16192650566     4.5
# 4                                        Urban Dental  +16196960510     5.0
# 5         Pacifica Center For Oral and Facial Surgery  +18585986800     5.0
# 6                        Sorrento Valley Dental Group  +18585582121     4.5
# 7                              David C Adams, DDS, MS  +16192915266     4.5
# 8                                Kurt Hummeldorf, DMD  +16192827088     4.5
# 9   The Oral Surgery & Dental Implant Specialists ...  +16192875000     5.0
# 10                  San Diego California Dental Group  +18582791004     4.5
# 11                                  Sutton Guy C, DDS  +18582781454     5.0
# 12                                Robert Fremont, DDS  +18582722222     4.5
# 13                                 Sparrow Joseph DDS  +18582777474     4.5
# 14                           Diane J Milberg, DDS MSD  +16192993560     5.0
# 15                                Coastal Dental Arts  +16198588080     4.0
# 16                             Complete Dental Health  +16192952202     5.0
# 17                         Rio Vista Family Dentistry  +16192991122     4.5
# 18                                 Padre Dental Group  +16196881001     4.5
# 19                                 Pravina Reddy, DMD  +18584124696     5.0
# 20                               Jeffrey S Keeny, DDS  +16192951512     4.5
# 21                             Friendly Family Dental  +18582741219     5.0
# 22                              Louis E Paulerio, DDS  +16192233811     5.0
# 23                       Liberty Station Orthodontics  +16192251611     5.0
# 24                          Center Point Dental Group  +16195827722     5.0
# 25                                 Pablo Liciaga, DDS  +16192242986     5.0
# 26                                PB Smiles Dentistry  +18588660808     4.0
# 27                            Mission Valley Dentists  +16192200159     3.5
# 28                          Affinity Dental Hillcrest  +16192918750     4.0
# 29                              Michael D Carter, DMD  +18584833636     4.5
# 30                             George Georgaklis, DDS  +18585521223     4.5
# 31                                     Premier Dental  +16192815569     4.5
# 32                         Pacific Beach Smile Studio  +18582726047     4.5
# 33            Stuart T. Tani, DDS - Allegiance Dental  +18582796100     4.5
# 34                                   All Coast Dental  +18582704904     5.0
# 35                                  Shira Shasho, DMD  +18584125155     4.5
# 36                                 Marcos Ortega, DDS  +16192954545     4.5
# 37                                    Team Tongue Tie  +18584809454     5.0
# 38                                   Vaida Avery, DDS  +18582706711     5.0
# 39                                    The Dental Docs  +16192972949     4.5
# 40  The Oral Surgery & Dental Implant Specialists ...  +18582747901     4.5
# 41                         Yolanda Garcia Lorett, DDS  +18582774453     5.0
# 42  Paul J. Styrt, Orthodontics & Pediatric Dentistry  +18584581088     4.5
# 43                       Dixon Pediatric Dental Group  +18584527272     4.5
# 44                            Lawrence P. Lotzof, DDS  +18582796210     4.5
# 45                                  University Dental  +16195824224     4.5
# 46                              Bay Park Dental Group  +16192760963     4.5
# 47                                   Jason Brown, DDS  +16192321005     5.0
# 48                         Mission Hills Dental Group  +16196999008     4.0
# 49                           Fifth Avenue Dental Arts  +16192333338     4.5
#
#     review_count transactions  \
# 0             55           []
# 1             59           []
# 2             47           []
# 3             59           []
# 4             50           []
# 5             41           []
# 6             99           []
# 7             62           []
# 8             57           []
# 9             51           []
# 10            56           []
# 11            46           []
# 12            60           []
# 13            44           []
# 14            40           []
# 15           113           []
# 16            32           []
# 17            69           []
# 18            78           []
# 19            32           []
# 20            64           []
# 21            27           []
# 22            46           []
# 23            27           []
# 24            32           []
# 25            46           []
# 26           104           []
# 27           192           []
# 28           129           []
# 29            42           []
# 30            45           []
# 31            46           []
# 32            52           []
# 33            69           []
# 34            34           []
# 35            58           []
# 36            45           []
# 37            38           []
# 38            34           []
# 39            35           []
# 40            41           []
# 41            30           []
# 42            56           []
# 43            66           []
# 44            31           []
# 45            42           []
# 46            41           []
# 47            26           []
# 48            87           []
