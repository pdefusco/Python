# %% [markdown]
# ### Download Financial Statements with Augmented Master Index (Includes SIC)
#
# ###### Objective: improve query statements module with increased query flexibility
#
# ###### To do:
#
# - Ability to input a date range in the query rather than entering single dates
# - Improved error handling functionality to force query inputs within the constraints
# - An improved UI
# - Ability to download financial statements without manually picking reports for each company
# - Ability to retrieve statements by 10Q not just 10K
#
# 10/3/19 - This script picks up from the query_statements notebook

# %%
import pandas as pd
import edgar
import psycopg2
import os
import glob
import numpy as np

# %% [markdown]
# ### Establish and Test DB Connection

# %% [markdown]
# You will have to enter DB login credentials here:

# %%
conn = psycopg2.connect("host=localhost dbname=postgres user=postgres password=Paolino1")

# %%
cur = conn.cursor()

# %%
cur.execute('SELECT * FROM NEW_MASTER LIMIT 20')

# %%
query = cur.fetchall()

# %%
if len(query) == 20:
    print('DB Connection Succesfully Established')
# Out:
# DB Connection Succesfully Established

# %%
cur.execute('ALTER TABLE NEW_MASTER ALTER COLUMN Filing_Date TYPE DATE \
            USING to_date(Filing_Date, \'YYYY-MM-DD\')')

# %%
cur.execute('SELECT * FROM NEW_MASTER LIMIT 20')

# %%
query = cur.fetchall()

# %%
#Sample time based query:
cur.execute('SELECT * FROM NEW_MASTER WHERE Filing_Date BETWEEN \'2014-03-14\' AND \'2014-03-31\'')

# %%
query = cur.fetchall()

# %%
#Only run if this cell if you have already run the whole script once and the table exists:
#conn = psycopg2.connect("host=localhost dbname=postgres user=postgres password=Paolino1")
cur = conn.cursor()
##cur.execute("""DROP TABLE SIC""")
cur.close()
conn.close()

# %%
query
# Out:
# [(1000230,
#   'OPTICAL CABLE CORP',
#   '10-Q',
#   datetime.date(2014, 3, 17),
#   'edgar/data/1000230/0001000230-14-000010.txt',
#   'edgar/data/1000230/0001000230-14-000010-index.html',
#   '3357'),
#  (1000232,
#   'KENTUCKY BANCSHARES INC /KY/',
#   '10-K',
#   datetime.date(2014, 3, 28),
#   'edgar/data/1000232/0001104659-14-023992.txt',
#   'edgar/data/1000232/0001104659-14-023992-index.html',
#   '22'),
#  (1000298,
#   'IMPAC MORTGAGE HOLDINGS INC',
#   '10-K',
#   datetime.date(2014, 3, 20),
#   'edgar/data/1000298/0001047469-14-002725.txt',
#   'edgar/data/1000298/0001047469-14-002725-index.html',
#   '6798'),
#  (1000683,
#   'BLONDER TONGUE LABORATORIES INC',
#   '10-K',
#   datetime.date(2014, 3, 31),
#   'edgar/data/1000683/0001144204-14-019460.txt',
#   'edgar/data/1000683/0001144204-14-019460-index.html',
#   '3663'),
#  (1001171,
#   'BROADWAY FINANCIAL CORP \\DE\\',
#   '10-K',
#   datetime.date(2014, 3, 31),
#   'edgar/data/1001171/0001047469-14-003251.txt',
#   'edgar/data/1001171/0001047469-14-003251-index.html',
#   '35'),
#  (1001385,
#   'NORTHWEST PIPE CO',
#   '10-K',
#   datetime.date(2014, 3, 17),
#   'edgar/data/1001385/0001193125-14-102569.txt',
#   'edgar/data/1001385/0001193125-14-102569-index.html',
#   '3317'),
#  (1001601,
#   'MGT CAPITAL INVESTMENTS INC',
#   '10-K',
#   datetime.date(2014, 3, 28),
#   'edgar/data/1001601/0001144204-14-018803.txt',
#   'edgar/data/1001601/0001144204-14-018803-index.html',
#   '6794'),
#  (1001614,
#   'TENGASCO INC',
#   '10-K',
#   datetime.date(2014, 3, 31),
#   'edgar/data/1001614/0001140361-14-014703.txt',
#   'edgar/data/1001614/0001140361-14-014703-index.html',
#   '1311'),
#  (1002390,
#   "America's Suppliers, Inc.",
#   '10-K',
#   datetime.date(2014, 3, 24),
#   'edgar/data/1002390/0001144204-14-017186.txt',
#   'edgar/data/1002390/0001144204-14-017186-index.html',
#   '7372'),
#  (1002761,
#   'AMERICREDIT FINANCIAL SERVICES INC',
#   '10-K',
#   datetime.date(2014, 3, 31),
#   'edgar/data/1002761/0001193125-14-
C',
#   '10-K',
#   datetime.date(2014, 3, 31),
#   'edgar/data/1005414/0001005414-14-000010.txt',
#   'edgar/data/1005414/0001005414-14-000010-index.html',
#   '5945'),
#  (1005817,
#   'TOMPKINS FINANCIAL CORP',
#   '10-K',
#   datetime.date(2014, 3, 17),
#   'edgar/data/1005817/0001387131-14-000894.txt',
#   'edgar/data/1005817/0001387131-14-000894-index.html',
#   '22'),
#  (1006045,
#   'IRIDEX CORP',
#   '10-K',
#   datetime.date(2014, 3, 27),
#   'edgar/data/1006045/0001564590-14-001025.txt',
#   'edgar/data/1006045/0001564590-14-001025-index.html',
#   '3845'),
#  (100625,
#   'SIERRA MONITOR CORP /CA/',
#   '10-K',
#   datetime.date(2014, 3, 27),
#   'edgar/data/100625/0001144204-14-018005.txt',
#   'edgar/data/100625/0001144204-14-018005-index.html',
#   '3829'),
#  (1006424,
#   'FIRST FEDERAL BANCSHARES OF ARKANSAS INC',
#   '10-K',
#   datetime.date(2014, 3, 28),
#   'edgar/data/1006424/0001437749-14-005396.txt',
#   'edgar/data/1006424/0001437749-14-005396-index.html',
#   '22'),
#  (1006837,
#   'PTGi HOLDING, INC.',
#   '10-K',
#   datetime.date(2014, 3, 31),
#   'edgar/data/1006837/0001193125-14-124108.txt',
#   'edgar/data/1006837/0001193125-14-124108-index.html',
#   '34'),
#  (1007019,
#   'COFFEE HOLDING CO INC',
#   '10-Q',
#   datetime.date(2014, 3, 14),
#   'edgar/data/1007019/0001354488-14-001149.txt',
#   'edgar/data/1007019/0001354488-14-001149-index.html',
#   '51'),
#  (100716,
#   'UNICO AMERICAN CORP',
#   '10-K',
#   datetime.date(2014, 3, 28),
#   'edgar/data/100716/0000100716-14-000005.txt',
#   'edgar/data/100716/0000100716-14-000005-index.html',
#   '6331'),
#  (1007330,
#   'PRGX GLOBAL, INC.',
#   '10-K',
#   datetime.date(2014, 3, 14),
#   'edgar/data/1007330/0001007330-14-000006.txt',
#   'edgar/data/1007330/0001007330-14-000006-index.html',
#   '80'),
#  (1007587,
#   'KVH INDUSTRIES INC \\DE\\',
#   '10-K',
#   datetime.date(2014, 3, 17),
#   'edgar/data/1007587/0001007587-14-000005.txt',
#   'edgar/data/1007587/0001007587-14-000005-index.html',
#   '3663'),
#  (1008579,
#   'HIGHLANDS BANKSHARES INC /VA/',
#   '10-K',
#   datetime.date(2014, 3, 31),
#   'edgar/data/1008579/0001002105-14-000025.txt',
#   'edgar/data/1008579/0001002105-14-000025-index.html',
#   '22'),
#  (1008817,
#   'SAPIENT CORP',
#   '10-K',
#   datetime.date(2014, 3, 18),
#   'edgar/data/1008817/0001193125-14-104549.txt',
#   'edgar/data/1008817/0001193125-14-104549-index.html',
#   '7373'),
#  (1009829,
#   'JAKKS PACIFIC INC',
#   '10-K',
#   datetime.date(2014, 3, 17),
#   'edgar/data/1009829/0001157523-14-001096.txt',
#   'edgar/data/1009829/0001157523-14-001096-index.html',
#   '3944'),
#  (1009891,
#   'AIR INDUSTRIES GROUP',
#   '10-K',
#   datetime.date(2014, 3, 25),
#   'edgar/data/1009891/0001193805-14-000587.txt',
#   'edgar/data/1009891/0001193805-14-000587-index.html',
#   '3728'),
#  (1009925,
#   'American Fiber Green Products, Inc.',
#   '10-K',
#   datetime.date(2014, 3, 27),
#   'edgar/data/1009925/0001477932-14-001266.txt',
#   'edgar/data/1009925/0001477932-14-001266-index.html',
#   '32'),
#  (1009976,
#   'COMMERCIAL BANCSHARES INC \\OH\\',
#   '10-K',
#   datetime.date(2014, 3, 17),
#   'edgar/data/1009976/0001144204-14-015980.txt',
#   'edgar/data/1009976/0001144204-14-015980-index.html',
#   '22'),
#  (1010566,
#   'CHINA LONGYI GROUP INTERNATIONAL HOLDINGS LTD',
#   '10-K',
#   datetime.date(2014, 3, 31),
#   'edgar/data/1010566/0001062993-14-001723.txt',
#   'edgar/data/1010566/0001062993-14-001723-index.html',
#   '7389'),
#  (1011432,
#   'AUXILIO INC',
#   '10-K',
#   datetime.date(2014, 3, 31),
#   'edgar/data/1011432/0001445866-14-000206.txt',
#   'edgar/data/1011432/0001445866-14-000206-index.html',
#   '7389'),
#  (1011662,
#   'GLOBAL DIGITAL SOLUTIONS INC',
#   '10-K',
#   datetime.date(2014, 3, 28),
#   'edgar/data/1011662/0001213900-14-001837.txt',
#   'edgar/data/1011662/0001213900-14-001837-index.html',
#   '2844'),
#  (1012704,
#   'DRIVETIME AUTOMOTIVE GROUP INC',
#   '10-K',
#   datetime.date(2014, 3, 25),
#   'edgar/data/1012704/0001445305-14-001134.txt',
#   'edgar/data/1012704/0001445305-14-001134-index.html',
#   '50'),
#  (101295,
#   'UNITED GUARDIAN INC',
#   '10-K',
#   datetime.date(2014, 3, 24),
#   'edgar/data/101295/0001171843-14-001385.txt',
#   'edgar/data/101295/0001171843-14-001385-index.html',
#   '2844'),
#  (1013706,
#   'Wilhelmina International, Inc.',
#   '10-K',
#   datetime.date(2014, 3, 31),
#   'edgar/data/1013706/0001171843-14-001499.txt',
#   'edgar/data/1013706/0001171843-14-001499-index.html',
#   '8742'),
#  (101390,
#   'UNITED MORTGAGE TRUST',
#   '10-K',
#   datetime.date(2014, 3, 31),
#   'edgar/data/101390/0001144204-14-019611.txt',
#   'edgar/data/101390/0001144204-14-019611-index.html',
#   '6798'),
#  (1015155,
#   'CHARLES & COLVARD LTD',
#   '10-K',
#   datetime.date(2014, 3, 27),
#   'edgar/data/1015155/0001140361-14-014335.txt',
#   'edgar/data/1015155/0001140361-14-014335-index.html',
#   '39'),
#  (101538,
#   'UNITED STATES ANTIMONY CORP',
#   '10-K',
#   datetime.date(2014, 3, 17),
#   'edgar/data/101538/0001354488-14-001190.txt',
#   'edgar/data/101538/0001354488-14-001190-index.html',
#   '33'),
#  (1015593,
#   'RIVER VALLEY BANCORP',
#   '10-K',
#   datetime.date(2014, 3, 18),
#   'edgar/data/1015593/0000908834-14-000151.txt',
#   'edgar/data/1015593/0000908834-14-000151-index.html',
#   '35'),
#  (1016708,
#   'RenovaCare, Inc.',
#   '10-K',
#   datetime.date(2014, 3, 28),
#   'edgar/data/1016708/0001477932-14-001298.txt',
#   'edgar/data/1016708/0001477932-14-001298-index.html',
#   '3841'),
#  (1017290,
#   'Silver Dragon Resources Inc.',
#   '10-K',
#   datetime.date(2014, 3, 31),
#   'edgar/data/1017290/0001062993-14-001790.txt',
#   'edgar/data/1017290/0001062993-14-001790-index.html',
#   None),
#  (1017303,
#   'TRANSACT TECHNOLOGIES INC',
#   '10-K',
#   datetime.date(2014, 3, 14),
#   'edgar/data/1017303/0001017303-14-000015.txt',
#   'edgar/data/1017303/0001017303-14-000015-index.html',
#   '3577'),
#  (1017480,
#   'HIBBETT SPORTS INC',
#   '10-K',
#   datetime.date(2014, 3, 31),
#   'edgar/data/1017480/0001017480-14-000009.txt',
#   'edgar/data/1017480/0001017480-14-000009-index.html',
#   '59'),
#  (1017491,
#   'APRICUS BIOSCIENCES, INC.',
#   '10-K',
#   datetime.date(2014, 3, 17),
#   'edgar/data/1017491/0001017491-14-000052.txt',
#   'edgar/data/1017491/0001017491-14-000052-index.html',
#   '2834'),
#  (1017655,
#   'PAID INC',
#   '10-K',
#   datetime.date(2014, 3, 31),
#   'edgar/data/1017655/0001144204-14-019476.txt',
#   'edgar/data/1017655/0001144204-14-019476-index.html',
#   '7389'),
#  (1017793,
#   'SUN BANCORP INC /NJ/',
#   '10-K',
#   datetime.date(2014, 3, 14),
#   'edgar/data/1017793/0001193125-14-098208.txt',
#   'edgar/data/1017793/0001193125-14-098208-index.html',
#   '29'),
#  (1018164,
#   'WILLIS LEASE FINANCE CORP',
#   '10-K',
#   datetime.date(2014, 3, 17),
#   'edgar/data/1018164/0001104659-14-020272.txt',
#   'edgar/data/1018164/0001104659-14-020272-index.html',
#   None),
#  (1018399,
#   'ENTERPRISE BANCORP INC /MA/',
#   '10-K',
#   datetime.date(2014, 3, 14),
#   'edgar/data/1018399/0001018399-14-000012.txt',
#   'edgar/data/1018399/0001018399-14-000012-index.html',
#   '22'),
#  (1018840,
#   'ABERCROMBIE & FITCH CO /DE/',
#   '10-K',
#   datetime.date(2014, 3, 31),
#   'edgar/data/1018840/0001018840-14-000033.txt',
#   'edgar/data/1018840/0001018840-14-000033-index.html',
#   '5651'),
#  (1019034,
#   'BIO KEY INTERNATIONAL INC',
#   '10-K',
#   datetime.date(2014, 3, 31),
#   'edgar/data/1019034/0001437749-14-005560.txt',
#   'edgar/data/1019034/0001437749-14-005560-index.html',
#   '3576'),
#  (1019272,
#   'EMPIRE RESOURCES INC /NEW/',
#   '10-K',
#   datetime.date(2014, 3, 31),
#   'edgar/data/1019272/0001144204-14-019501.txt',
#   'edgar/data/1019272/0001144204-14-019501-index.html',
#   '51'),
#  (1019787,
#   'PURADYN FILTER TECHNOLOGIES INC',
#   '10-K',
#   datetime.date(2014, 3, 27),
#   'edgar/data/1019787/0001553350-14-000291.txt',
#   'edgar/data/1019787/0001553350-14-000291-index.html',
#   '3714'),
#  (1020477,
#   'ROTATE BLACK INC',
#   '10-Q',
#   datetime.date(2014, 3, 21),
#   'edgar/data/1020477/0001354488-14-001334.txt',
#   'edgar/data/1020477/0001354488-14-001334-index.html',
#   '11'),
#  (1021096,
#   'ROOMLINX INC',
#   '10-K',
#   datetime.date(2014, 3, 31),
#   'edgar/data/1021096/0001188112-14-000893.txt',
#   'edgar/data/1021096/0001188112-14-000893-index.html',
#   '4841'),
#  (1021270,
#   'FAMOUS DAVES OF AMERICA INC',
#   '10-K',
#   datetime.date(2014, 3, 14),
#   'edgar/data/1021270/0001193125-14-099714.txt',
#   'edgar/data/1021270/0001193125-14-099714-index.html',
#   '5812'),
#  (1021435,
#   'hopTo Inc.',
#   '10-K',
#   datetime.date(2014, 3, 31),
#   'edgar/data/1021435/0001437749-14-005539.txt',
#   'edgar/data/1021435/0001437749-14-005539-index.html',
#   '7372'),
#  (1021561,
#   'NU SKIN ENTERPRISES INC',
#   '10-K',
#   datetime.date(2014, 3, 18),
#   'edgar/data/1021561/0001021561-14-000031.txt',
#   'edgar/data/1021561/0001021561-14-000031-index.html',
#   '5122'),
#  (1021604,
#   'ON TRACK INNOVATIONS LTD',
#   '10-K',
#   datetime.date(2014, 3, 31),
#   'edgar/data/1021604/0001178913-14-001152.txt',
#   'edgar/data/1021604/0001178913-14-001152-index.html',
#   '3674'),
#  (1022505,
#   'NATIONAL SCIENTIFIC CORP/AZ',
#   '10-Q',
#   datetime.date(2014, 3, 20),
#   'edgar/data/1022505/0000721748-14-000277.txt',
#   'edgar/data/1022505/0000721748-14-000277-index.html',
#   '7374'),
#  (1022701,
#   'NEOMEDIA TECHNOLOGIES INC',
#   '10-K',
#   datetime.date(2014, 3, 17),
#   'edgar/data/1022701/0001144204-14-016069.txt',
#   'edgar/data/1022701/0001144204-14-016069-index.html',
#   '7373'),
#  (1023453,
#   'AIS FUTURES FUND IV LP',
#   '10-K',
#   datetime.date(2014, 3, 31),
#   'edgar/data/1023453/0001144204-14-019090.txt',
#   'edgar/data/1023453/0001144204-14-019090-index.html',
#   '6221'),
#  (1023458,
#   'AEI INCOME & GROWTH FUND XXII LTD PARTNERSHIP',
#   '10-K',
#   datetime.date(2014, 3, 31),
#   'edgar/data/1023458/0000868740-14-000014.txt',
#   'edgar/data/1023458/0000868740-14-000014-index.html',
#   '60'),
#  (1023860,
#   'STEWARDSHIP FINANCIAL CORP',
#   '10-K',
#   datetime.date(2014, 3, 26),
#   'edgar/data/1023860/0000914317-14-000403.txt',
#   'edgar/data/1023860/0000914317-14-000403-index.html',
#   '22'),
#  (1024048,
#   'Panacea Global, Inc.',
#   '10-K',
#   datetime.date(2014, 3, 31),
#   'edgar/data/1024048/0001511164-14-000155.txt',
#   'edgar/data/1024048/0001511164-14-000155-index.html',
#   '6531'),
#  (1024126,
#   'PERNIX THERAPEUTICS HOLDINGS, INC.',
#   '10-K',
#   datetime.date(2014, 3, 17),
#   'edgar/data/1024126/0001354488-14-001218.txt',
#   'edgar/data/1024126/0001354488-14-001218-index.html',
#   '2834'),
#  (1024920,
#   'Fuelstream INC',
#   '10-K',
#   datetime.date(2014, 3, 31),
#   'edgar/data/1024920/0001391609-14-000011.txt',
#   'edgar/data/1024920/0001391609-14-000011-index.html',
#   '7389'),
#  (1025315,
#   '24HOLDINGS INC',
#   '10-K',
#   datetime.date(2014, 3, 26),
#   'edgar/data/1025315/0001144204-14-017898.txt',
#   'edgar/data/1025315/0001144204-14-017898-index.html',
#   '67'),
#  (1025362,
#   'GOLDEN QUEEN MINING CO LTD',
#   '10-K',
#   datetime.date(2014, 3, 17),
#   'edgar/data/1025362/0001062993-14-001386.txt',
#   'edgar/data/1025362/0001062993-14-001386-index.html',
#   None),
#  (1025835,
#   'ENTERPRISE FINANCIAL SERVICES CORP',
#   '10-K',
#   datetime.date(2014, 3, 17),
#   'edgar/data/1025835/0001025835-14-000012.txt',
#   'edgar/data/1025835/0001025835-14-000012-index.html',
#   '22'),
#  (1026655,
#   'CORE MOLDING TECHNOLOGIES INC',
#   '10-K',
#   datetime.date(2014, 3, 20),
#   'edgar/data/
INC.',
#   '10-K',
#   datetime.date(2014, 3, 31),
#   'edgar/data/1036044/0001564590-14-001232.txt',
#   'edgar/data/1036044/0001564590-14-001232-index.html',
#   '3577'),
#  (1036262,
#   'INTEST CORP',
#   '10-K',
#   datetime.date(2014, 3, 27),
#   'edgar/data/1036262/0001036262-14-000004.txt',
#   'edgar/data/1036262/0001036262-14-000004-index.html',
#   '3825'),
#  (1037049,
#   'AURORA GOLD CORP',
#   '10-K',
#   datetime.date(2014, 3, 31),
#   'edgar/data/1037049/0001144204-14-018971.txt',
#   'edgar/data/1037049/0001144204-14-018971-index.html',
#   None),
#  (1037189,
#   'WESTPORT FUTURES FUND L.P.',
#   '10-K',
#   datetime.date(2014, 3, 28),
#   'edgar/data/1037189/0001193125-14-121790.txt',
#   'edgar/data/1037189/0001193125-14-121790-index.html',
#   '6221'),
#  (1037649,
#   'INTERLEUKIN GENETICS INC',
#   '10-K',
#   datetime.date(2014, 3, 20),
#   'edgar/data/1037649/0001144204-14-016879.txt',
#   'edgar/data/1037649/0001144204-14-016879-index.html',
#   '2835'),
#  (1038133,
#   'HESKA CORP',
#   '10-K',
#   datetime.date(2014, 3, 31),
#   'edgar/data/1038133/0001038133-14-000017.txt',
#   'edgar/data/1038133/0001038133-14-000017-index.html',
#   '2836'),
#  (1038277,
#   'INTERNATIONAL ISOTOPES INC',
#   '10-K',
#   datetime.date(2014, 3, 28),
#   'edgar/data/1038277/0001515971-14-000091.txt',
#   'edgar/data/1038277/0001515971-14-000091-index.html',
#   '3823'),
#  (1038286,
#   'GOLDEN STATE PETROLEUM TRANSPORT CORP',
#   '10-K',
#   datetime.date(2014, 3, 25),
#   'edgar/data/1038286/0000913290-14-000012.txt',
#   'edgar/data/1038286/0000913290-14-000012-index.html',
#   '40'),
#  (103872,
#   'VOLT INFORMATION SCIENCES, INC.',
#   '10-Q',
#   datetime.date(2014, 3, 14),
#   'edgar/data/103872/0001445305-14-001046.txt',
#   'edgar/data/103872/0001445305-14-001046-index.html',
#   '7363'),
#  (1038773,
#   'CORNERSTONE BANCSHARES INC',
#   '10-K',
#   datetime.date(2014, 3, 31),
#   'edgar/data/1038773/0001144204-14-019242.txt',
#   'edgar/data/1038773/0001144204-14-019242-index.html',
#   '21'),
#  (1040799,
#   'FOUR OAKS FINCORP INC',
#   '10-K',
#   datetime.date(2014, 3, 31),
#   'edgar/data/1040799/0001445305-14-001226.txt',
#   'edgar/data/1040799/0001445305-14-001226-index.html',
#   '22'),
#  (1040896,
#   'Intellicheck Mobilisa, Inc.',
#   '10-K',
#   datetime.date(2014, 3, 25),
#   'edgar/data/1040896/0001144204-14-017636.txt',
#   'edgar/data/1040896/0001144204-14-017636-index.html',
#   '7372'),
#  (1041550,
#   'HOPFED BANCORP INC',
#   '10-K',
#   datetime.date(2014, 3, 14),
#   'edgar/data/1041550/0001193125-14-100252.txt',
#   'edgar/data/1041550/0001193125-14-100252-index.html',
#   '22'),
#  (1041657,
#   'RADIO ONE, INC.',
#   '10-K',
#   datetime.date(2014, 3, 31),
#   'edgar/data/1041657/0001144204-14-019095.txt',
#   'edgar/data/1041657/0001144204-14-019095-index.html',
#   '4832'),
#  (104169,
#   'WAL MART STORES INC',
#   '10-K',
#   datetime.date(2014, 3, 21),
#   'edgar/data/104169/0000104169-14-000019.txt',
#   'edgar/data/104169/0000104169-14-000019-index.html',
#   '5331'),
#  (1041859,
#   'CHILDRENS PLACE RETAIL STORES INC',
#   '10-K',
#   datetime.date(2014, 3, 20),
#   'edgar/data/1041859/0001445305-14-001116.txt',
#   'edgar/data/1041859/0001445305-14-001116-index.html',
#   '5651'),
#  (1042074,
#   'CymaBay Therapeutics, Inc.',
#   '10-K',
#   datetime.date(2014, 3, 31),
#   'edgar/data/1042074/0001193125-14-124127.txt',
#   'edgar/data/1042074/0001193125-14-124127-index.html',
#   '2834'),
#  (104207,
#   'WALGREEN CO',
#   '10-Q',
#   datetime.date(2014, 3, 27),
#   'edgar/data/104207/0000104207-14-000027.txt',
#   'edgar/data/104207/0000104207-14-000027-index.html',
#   '5912'),
#  (1042173,
#   'SCIENTIFIC LEARNING CORP',
#   '10-K',
#   datetime.date(2014, 3, 28),
#   'edgar/data/
',
#   '10-K',
#   datetime.date(2014, 3, 31),
#   'edgar/data/1058307/0001415889-14-001013.txt',
#   'edgar/data/1058307/0001415889-14-001013-index.html',
#   '4813'),
#  (1058623,
#   'CUMULUS MEDIA INC',
#   '10-K',
#   datetime.date(2014, 3, 17),
#   'edgar/data/1058623/0001058623-14-000014.txt',
#   'edgar/data/1058623/0001058623-14-000014-index.html',
#   '4832'),
#  (1058690,
#   'WASHINGTON BANKING CO',
#   '10-K',
#   datetime.date(2014, 3, 14),
#   'edgar/data/1058690/0001058690-14-000003.txt',
#   'edgar/data/1058690/0001058690-14-000003-index.html',
#   '22'),
#  (1059376,
#   'CORPORATE BOND BACKED CERT TR SER 1998-CAT 1',
#   '10-K',
#   datetime.date(2014, 3, 28),
#   'edgar/data/1059376/0001193125-14-121310.txt',
#   'edgar/data/1059376/0001193125-14-121310-index.html',
#   '6189'),
#  (1059377,
#   'CORPORATE BOND BACKED CERT TR SER 1998-ADM 1',
#   '10-K',
#   datetime.date(2014, 3, 28),
#   'edgar/data/1059377/0001193125-14-121404.txt',
#   'edgar/data/1059377/0001193125-14-121404-index.html',
#   '6189'),
#  (1059378,
#   'CORPORATE BOND BACKED CERT TR SER 1998-NSC 1',
#   '10-K',
#   datetime.date(2014, 3, 28),
#   'edgar/data/1059378/0001193125-14-121376.txt',
#   'edgar/data/1059378/0001193125-14-121376-index.html',
#   '6189'),
#  (1059562,
#   'LMI AEROSPACE INC',
#   '10-K',
#   datetime.date(2014, 3, 17),
#   'edgar/data/1059562/0001445305-14-001071.txt',
#   'edgar/data/1059562/0001445305-14-001071-index.html',
#   '3728'),
#  (1060219,
#   'SALISBURY BANCORP INC',
#   '10-K',
#   datetime.date(2014, 3, 28),
#   'edgar/data/1060219/0001554795-14-000223.txt',
#   'edgar/data/1060219/0001554795-14-000223-index.html',
#   '35'),
#  (1060523,
#   'CARDINAL FINANCIAL CORP',
#   '10-K',
#   datetime.date(2014, 3, 14),
#   'edgar/data/1060523/0001047469-14-002387.txt',
#   'edgar/data/1060523/0001047469-14-002387-index.html',
#   '21'),
#  (1060910,
#   'GENERAL METALS CORP',
#   '10-Q',
#   datetime.date(2014, 3, 24),
#   'edgar/data/1060910/0001199835-14-000104.txt',
#   'edgar/data/1060910/0001199835-14-000104-index.html',
#   None),
#  (1060990,
#   'QUICKSILVER RESOURCES INC',
#   '10-K',
#   datetime.date(2014, 3, 17),
#   'edgar/data/1060990/0001060990-14-000037.txt',
#   'edgar/data/1060990/0001060990-14-000037-index.html',
#   '1311'),
#  (1061069,
#   'AVALON HOLDINGS CORP',
#   '10-K',
#   datetime.date(2014, 3, 25),
#   'edgar/data/1061069/0001437749-14-005016.txt',
#   'edgar/data/1061069/0001437749-14-005016-index.html',
#   '4953'),
#  (1061169,
#   'CEPHAS HOLDING CORP.',
#   '10-Q',
#   datetime.date(2014, 3, 19),
#   'edgar/data/1061169/0001061169-14-000002.txt',
#   'edgar/data/1061169/0001061169-14-000002-index.html',
#   '3669'),
#  (1061169,
#   'CEPHAS HOLDING CORP.',
#   '10-Q',
#   datetime.date(2014, 3, 19),
#   'edgar/data/1061169/0001061169-14-000003.txt',
#   'edgar/data/1061169/0001061169-14-000003-index.html',
#   '3669'),
#  (1061169,
#   'CEPHAS HOLDING CORP.',
#   '10-Q',
#   datetime.date(2014, 3, 21),
#   'edgar/data/1061169/0001061169-14-000004.txt',
#   'edgar/data/1061169/0001061169-14-000004-index.html',
#   '3669'),
#  (1062292,
#   'XO GROUP INC.',
#   '10-K',
#   datetime.date(2014, 3, 17),
#   'edgar/data/1062292/0001062292-14-000037.txt',
#   'edgar/data/1062292/0001062292-14-000037-index.html',
#   '59'),
#  (1063197,
#   'TORVEC INC',
#   '10-K',
#   datetime.date(2014, 3, 28),
#   'edgar/data/1063197/0001437749-14-005393.txt',
#   'edgar/data/1063197/0001437749-14-005393-index.html',
#   '3714'),
#  (1063537,
#   'RiceBran Technologies',
#   '10-K',
#   datetime.date(2014, 3, 31),
#   'edgar/data/1063537/0001140361-14-014774.txt',
#   'edgar/data/1063537/0001140361-14-014774-index.html',
#   None),
#  (1065059,
#   'USEC INC',
#   '10-K',
#   datetime.date(2014, 3, 31),
#   'edgar/data/
',
#   '10-K',
#   datetime.date(2014, 3, 28),
#   'edgar/data/1084031/0001213900-14-001832.txt',
#   'edgar/data/1084031/0001213900-14-001832-index.html',
#   '3569'),
#  (1084182,
#   'IMMEDIATEK INC',
#   '10-K',
#   datetime.date(2014, 3, 31),
#   'edgar/data/1084182/0001214659-14-002327.txt',
#   'edgar/data/1084182/0001214659-14-002327-index.html',
#   '7372'),
#  (1084226,
#   'Searchlight Minerals Corp.',
#   '10-K',
#   datetime.date(2014, 3, 28),
#   'edgar/data/1084226/0001144204-14-018873.txt',
#   'edgar/data/1084226/0001144204-14-018873-index.html',
#   None),
#  (1084267,
#   'Mobiquity Technologies, Inc.',
#   '10-K',
#   datetime.date(2014, 3, 21),
#   'edgar/data/1084267/0001019687-14-000941.txt',
#   'edgar/data/1084267/0001019687-14-000941-index.html',
#   '73'),
#  (1084384,
#   'ELEPHANT TALK COMMUNICATIONS CORP',
#   '10-K',
#   datetime.date(2014, 3, 31),
#   'edgar/data/1084384/0001144204-14-019632.txt',
#   'edgar/data/1084384/0001144204-14-019632-index.html',
#   '7373'),
#  (1084463,
#   'COIL TUBING TECHNOLOGY, INC.',
#   '10-K',
#   datetime.date(2014, 3, 31),
#   'edgar/data/1084463/0001019687-14-001087.txt',
# ...
#   'edgar/data/1362502/0001477932-14-001078.txt',
#   'edgar/data/1362502/0001477932-14-001078-index.html',
#   None),
#  (1362705,
#   'Constellation Energy Partners LLC',
#   '10-K',
#   datetime.date(2014, 3, 27),
#   'edgar/data/1362705/0001362705-14-000012.txt',
#   'edgar/data/1362705/0001362705-14-000012-index.html',
#   '1311'),
#  (1363254,
#   'Pegasi Energy Resources Corporation.',
#   '10-K',
#   datetime.date(2014, 3, 24),
#   'edgar/data/1363254/0001185185-14-000610.txt',
#   'edgar/data/1363254/0001185185-14-000610-index.html',
#   '1311'),
#  (1363958,
#   'WESTERN CAPITAL RESOURCES, INC.',
#   '10-K',
#   datetime.date(2014, 3, 26),
#   'edgar/data/1363958/0001144204-14-017791.txt',
#   'edgar/data/1363958/0001144204-14-017791-index.html',
#   '50'),
#  (1364479,
#   'HERTZ GLOBAL HOLDINGS INC',
#   '10-K',
#   datetime.date(2014, 3, 19),
#   'edgar/data/1364479/0001364479-14-000006.txt',
#   'edgar/data/1364479/0001364479-14-000006-index.html',
#   '73'),
#  (1364652,
#   'iPayment Holdings, Inc',
#   '10-K',
#   datetime.date(2014, 3, 28),
#   'edgar/data/1364652/0001364652-14-000007.txt',
#   'edgar/data/1364652/0001364652-14-000007-index.html',
#   '7389'),
#  (1365038,
#   'DEMAND MEDIA INC.',
#   '10-K',
#   datetime.date(2014, 3, 17),
#   'edgar/data/1365038/0001564590-14-000861.txt',
#   'edgar/data/1365038/0001564590-14-000861-index.html',
#   '7374'),
#  (1365101,
#   'Primo Water Corp',
#   '10-K',
#   datetime.date(2014, 3, 17),
#   'edgar/data/1365101/0001140361-14-013050.txt',
#   'edgar/data/1365101/0001140361-14-013050-index.html',
#   '5141'),
#  (1365388,
#   'Gulf & Orient Steamship Company, Ltd.',
#   '10-K',
#   datetime.date(2014, 3, 31),
#   'edgar/data/1365388/0001010412-14-000051.txt',
#   'edgar/data/1365388/0001010412-14-000051-index.html',
#   '67'),
#  (1365784,
#   'BIOSHAFT WATER TECHNOLOGY, INC.',
#   '10-Q',
#   datetime.date(2014, 3, 14),
#   'edgar/data/1365784/0001393905-14-000091.txt',
#   'edgar/data/1365784/0001393905-14-000091-index.html',
#   '49'),
#  (1365997,
#   'Bank of the Carolinas CORP',
#   '10-K',
#   datetime.date(2014, 3, 26),
#   'edgar/data/1365997/0001193125-14-116562.txt',
#   'edgar/data/1365997/0001193125-14-116562-index.html',
#   '21'),
#  (1366246,
#   'GLU MOBILE INC',
#   '10-K',
#   datetime.date(2014, 3, 14),
#   'edgar/data/1366246/0001193125-14-100352.txt',
#   'edgar/data/1366246/0001193125-14-100352-index.html',
#   '7371'),
#  (1366340,
#   'FINJAN HOLDINGS, INC.',
#   '10-K',
#   datetime.date(2014, 3, 14),
#   'edgar/data/1366340/0001193125-14-098279.txt',
#   'edgar/data/1366340/0001193125-14-098279-index.html',
#   '6794'),
#  (1366649,
#   'Dialogic Inc.',
#   '10-K',
#   datetime.date(2014, 3, 31),
#   'edgar/data/1366649/0001366649-14-000008.txt',
#   'edgar/data/1366649/0001366649-14-000008-index.html',
#   '7373'),
#  (1366928,
#   'AEP Texas Central Transition Funding II LLC',
#   '10-K',
#   datetime.date(2014, 3, 28),
#   'edgar/data/1366928/0000004904-14-000029.txt',
#   'edgar/data/1366928/0000004904-14-000029-index.html',
#   '6189'),
#  (1367306,
#   'PowerShares DB Multi-Sector Commodity Trust',
#   '10-K',
#   datetime.date(2014, 3, 14),
#   'edgar/data/1367306/0001193125-14-100043.txt',
#   'edgar/data/1367306/0001193125-14-100043-index.html',
#   '6221'),
#  (1367311,
#   'DAKOTA PLAINS HOLDINGS, INC.',
#   '10-K',
#   datetime.date(2014, 3, 14),
#   'edgar/data/1367311/0000897101-14-000323.txt',
#   'edgar/data/1367311/0000897101-14-000323-index.html',
#   '5171'),
#  (1367832,
#   'AURORA DIAGNOSTICS HOLDINGS LLC',
#   '10-K',
#   datetime.date(2014, 3, 25),
#   'edgar/data/1367832/0001564590-14-000983.txt',
#   'edgar/data/1367832/0001564590-14-000983-index.html',
#   '71'),
#  (1367920,
#   'CONCERT PHARMACEUTICALS, INC.',
#   '10-K',
#   datetime.date(2014, 3, 31),
#   'edgar/data/1367920/0001193125-14-122579.txt',
#   'edgar/data/1367920/0001193125-14-122579-index.html',
#   '2834'),
#  (1368308,
#   'Highpower International, Inc.',
#   '10-K',
#   datetime.date(2014, 3, 31),
#   'edgar/data/1368308/0001144204-14-019162.txt',
#   'edgar/data/1368308/0001144204-14-019162-index.html',
#   '36'),
#  (1368365,
#   'Remark Media, Inc.',
#   '10-K',
#   datetime.date(2014, 3, 31),
#   'edgar/data/1368365/0001562762-14-000097.txt',
#   'edgar/data/1368365/0001562762-14-000097-index.html',
#   '4899'),
#  (1368514,
#   'ADMA BIOLOGICS, INC.',
#   '10-K',
#   datetime.date(2014, 3, 28),
#   'edgar/data/1368514/0001193805-14-000641.txt',
#   'edgar/data/1368514/0001193805-14-000641-index.html',
#   '2836'),
#  (1368637,
#   'Rockdale Resources Corp',
#   '10-K',
#   datetime.date(2014, 3, 31),
#   'edgar/data/1368637/0001185185-14-000725.txt',
#   'edgar/data/1368637/0001185185-14-000725-index.html',
#   '1311'),
#  (1368757,
#   'GTJ REIT, Inc.',
#   '10-K',
#   datetime.date(2014, 3, 24),
#   'edgar/data/1368757/0001193125-14-111750.txt',
#   'edgar/data/1368757/0001193125-14-111750-index.html',
#   '6798'),
#  (1368993,
#   'WaferGen Bio-systems, Inc.',
#   '10-K',
#   datetime.date(2014, 3, 14),
#   'edgar/data/1368993/0001368993-14-000026.txt',
#   'edgar/data/1368993/0001368993-14-000026-index.html',
#   '3826'),
#  (1369568,
#   'CATALYST PHARMACEUTICAL PARTNERS, INC.',
#   '10-K',
#   datetime.date(2014, 3, 19),
#   'edgar/data/1369568/0001193125-14-104658.txt',
#   'edgar/data/1369568/0001193125-14-104658-index.html',
#   '2834'),
#  (1369628,
#   'COMMODITY ADVISORS FUND L.P.',
#   '10-K',
#   datetime.date(2014, 3, 28),
#   'edgar/data/1369628/0001193125-14-121689.txt',
#   'edgar/data/1369628/0001193125-14-121689-index.html',
#   '6221'),
#  (1370030,
#   'Bio-AMD Inc.',
#   '10-K',
#   datetime.date(2014, 3, 28),
#   'edgar/data/1370030/0001185185-14-000677.txt',
#   'edgar/data/1370030/0001185185-14-000677-index.html',
#   None),
#  (1370450,
#   'Willdan Group, Inc.',
#   '10-K',
#   datetime.date(2014, 3, 25),
#   'edgar/data/1370450/0001047469-14-002940.txt',
#   'edgar/data/1370450/0001047469-14-002940-index.html',
#   '8711'),
#  (1370804,
#   'DIAGNOSTIC IMAGING INTERNATIONAL CORP',
#   '10-K',
#   datetime.date(2014, 3, 28),
#   'edgar/data/1370804/0001515971-14-000089.txt',
#   'edgar/data/1370804/0001515971-14-000089-index.html',
#   '71'),
#  (1371128,
#   'BioSolar Inc',
#   '10-K',
#   datetime.date(2014, 3, 24),
#   'edgar/data/1371128/0001445866-14-000147.txt',
#   'edgar/data/1371128/0001445866-14-000147-index.html',
#   '81'),
#  (1371217,
#   'EnteroMedics Inc',
#   '10-K',
#   datetime.date(2014, 3, 27),
#   'edgar/data/1371217/0001193125-14-118800.txt',
#   'edgar/data/1371217/0001193125-14-118800-index.html',
#   '3845'),
#  (1371424,
#   'ROYAL MINES & MINERALS CORP',
#   '10-Q',
#   datetime.date(2014, 3, 17),
#   'edgar/data/1371424/0001062993-14-001378.txt',
#   'edgar/data/1371424/0001062993-14-001378-index.html',
#   None),
#  (1371446,
#   'FBR & Co.',
#   '10-K',
#   datetime.date(2014, 3, 14),
#   'edgar/data/1371446/0001193125-14-100176.txt',
#   'edgar/data/1371446/0001193125-14-100176-index.html',
#   '6211'),
#  (1371571,
#   'PowerShares DB US Dollar Index Trust',
#   '10-K',
#   datetime.date(2014, 3, 14),
#   'edgar/data/1371571/0001193125-14-099580.txt',
#   'edgar/data/1371571/0001193125-14-099580-index.html',
#   '6221'),
#  (1371781,
#   'World Energy Solutions, Inc.',
#   '10-K',
#   datetime.date(2014, 3, 31),
#   'edgar/data/1371781/0001564590-14-001150.txt',
#   'edgar/data/1371781/0001564590-14-001150-index.html',
#   '7389'),
#  (1372336,
#   'LIBERTY ENERGY CORP.',
#   '10-Q',
#   datetime.date(2014, 3, 17),
#   'edgar/data/1372336/0001469709-14-000083.txt',
#   'edgar/data/1372336/0001469709-14-000083-index.html',
#   None),
#  (1373149,
#   'RJS Development, Inc.',
#   '10-K',
#   datetime.date(2014, 3, 31),
#   'edgar/data/1373149/0001193805-14-000657.txt',
#   'edgar/data/1373149/0001193805-14-000657-index.html',
#   '6552'),
#  (1373206,
#   'STRATS Trust For News Corp. Securities, Series 2006-4',
#   '10-K',
#   datetime.date(2014, 3, 31),
#   'edgar/data/1373206/0001373206-14-000002.txt',
#   'edgar/data/1373206/0001373206-14-000002-index.html',
#   '6189'),
#  (1373525,
#   'FIRST CAPITAL BANCORP, INC.',
#   '10-K',
#   datetime.date(2014, 3, 27),
#   'edgar/data/1373525/0001373525-14-000004.txt',
#   'edgar/data/1373525/0001373525-14-000004-index.html',
#   '22'),
#  (1373561,
#   'NewStar Financial, Inc.',
#   '10-K',
#   datetime.date(2014, 3, 14),
#   'edgar/data/1373561/0001193125-14-100145.txt',
#   'edgar/data/1373561/0001193125-14-100145-index.html',
#   '6172'),
#  (1373670,
#   'BioFuel Energy Corp.',
#   '10-K',
#   datetime.date(2014, 3, 26),
#   'edgar/data/1373670/0001144204-14-017928.txt',
#   'edgar/data/1373670/0001144204-14-017928-index.html',
#   '1531'),
#  (1373846,
#   'China Internet Cafe Holdings Group, Inc.',
#   '10-K',
#   datetime.date(2014, 3, 26),
#   'edgar/data/1373846/0001144204-14-018000.txt',
#   'edgar/data/1373846/0001144204-14-018000-index.html',
#   '59'),
#  (1374328,
#   'FITLIFE BRANDS, INC.',
#   '10-K',
#   datetime.date(2014, 3, 28),
#   'edgar/data/1374328/0001415889-14-000995.txt',
#   'edgar/data/1374328/0001415889-14-000995-index.html',
#   '2833'),
#  (1374536,
#   'Medytox Solutions, Inc.',
#   '10-K',
#   datetime.date(2014, 3, 31),
#   'edgar/data/1374536/0001019687-14-001142.txt',
#   'edgar/data/1374536/0001019687-14-001142-index.html',
#   '8734'),
#  (1374694,
#   'WELLS MID-HORIZON VALUE-ADDED FUND I LLC',
#   '10-K',
#   datetime.date(2014, 3, 28),
#   'edgar/data/1374694/0001374694-14-000006.txt',
#   'edgar/data/1374694/0001374694-14-000006-index.html',
#   '60'),
#  (1374985,
#   'Atlas Resources Public #16-2007 (A) L.P.',
#   '10-K',
#   datetime.date(2014, 3, 31),
#   'edgar/data/1374985/0001564590-14-001187.txt',
#   'edgar/data/1374985/0001564590-14-001187-index.html',
#   '1311'),
#  (1375195,
#   '3DICON CORP',
#   '10-K',
#   datetime.date(2014, 3, 31),
#   'edgar/data/1375195/0001144204-14-019106.txt',
#   'edgar/data/1375195/0001144204-14-019106-index.html',
#   '3669'),
#  (1375685,
#   'BTHC X INC',
#   '10-K',
#   datetime.date(2014, 3, 31),
#   'edgar/data/1375685/0001213900-14-002001.txt',
#   'edgar/data/1375685/0001213900-14-002001-index.html',
#   '67'),
#  (1375686,
#   'THT Heat Transfer Technology, Inc.',
#   '10-K',
#   datetime.date(2014, 3, 31),
#   'edgar/data/1375686/0001062993-14-001768.txt',
#   'edgar/data/1375686/0001062993-14-001768-index.html',
#   '3443'),
#  (1375796,
#   'TREMOR VIDEO INC.',
#   '10-K',
#   datetime.date(2014, 3, 28),
#   'edgar/data/1375796/0001104659-14-023528.txt',
#   'edgar/data/1375796/0001104659-14-023528-index.html',
#   '7311'),
#  (1376074,
#   'LEAF Equipment Leasing Income Fund III, L.P.',
#   '10-K',
#   datetime.date(2014, 3, 31),
#   'edgar/data/1376074/0001140361-14-014783.txt',
#   'edgar/data/1376074/0001140361-14-014783-index.html',
#   '73'),
#  (1376755,
#   'KINGDOM KONCRETE, INC.',
#   '10-K',
#   datetime.date(2014, 3, 18),
#   'edgar/data/1376755/0001121781-14-000051.txt',
#   'edgar/data/1376755/0001121781-14-000051-index.html',
#   '5211'),
#  (1377149,
#   'CareView Communications Inc',
#   '10-K',
#   datetime.date(2014, 3, 28),
#   'edgar/data/1377149/0001387131-14-001109.txt',
#   'edgar/data/1377149/0001387131-14-001109-index.html',
#   '3663'),
#  (1377848,
#   'ICON LEASING FUND TWELVE, LLC',
#   '10-K',
#   datetime.date(2014, 3, 20),
#   'edgar/data/1377848/0001377848-14-000006.txt',
#   'edgar/data/1377848/0001377848-14-000006-index.html',
#   '7359'),
#  (1378125,
#   'Blink Couture Inc.',
#   '10-Q',
#   datetime.date(2014, 3, 14),
#   'edgar/data/1378125/0001354488-14-001156.txt',
#   'edgar/data/1378125/0001354488-14-001156-index.html',
#   '7385'),
#  (1378140,
#   'Ocean Power Technologies, Inc.',
#   '10-Q',
#   datetime.date(2014, 3, 14),
#   'edgar/data/1378140/0001437749-14-004140.txt',
#   'edgar/data/1378140/0001437749-14-004140-index.html',
#   '4911'),
#  (1378774,
#   'Sentio Healthcare Properties Inc',
#   '10-K',
#   datetime.date(2014, 3, 21),
#   'edgar/data/1378774/0001144204-14-017059.txt',
#   'edgar/data/1378774/0001144204-14-017059-index.html',
#   '6798'),
#  (1379043,
#   'Duke Mountain Resources, Inc',
#   '10-K',
#   datetime.date(2014, 3, 31),
#   'edgar/data/1379043/0001551163-14-000048.txt',
#   'edgar/data/1379043/0001551163-14-000048-index.html',
#   None),
#  (1379246,
#   'BODY CENTRAL CORP',
#   '10-K',
#   datetime.date(2014, 3, 27),
#   'edgar/data/1379246/0001379246-14-000022.txt',
#   'edgar/data/1379246/0001379246-14-000022-index.html',
#   '50'),
#  (1379404,
#   'Corporate Backed Callable Trust Certificates, J.C. Penny Debenture-Backed Series 2006-1 Trust',
#   '10-K',
#   datetime.date(2014, 3, 28),
#   'edgar/data/1379404/0001193125-14-121432.txt',
#   'edgar/data/1379404/0001193125-14-121432-index.html',
#   '6189'),
#  (1379763,
#   'Atlas America Series 27-2006 L.P.',
#   '10-K',
#   datetime.date(2014, 3, 31),
#   'edgar/data/1379763/0001564590-14-001165.txt',
#   'edgar/data/1379763/0001564590-14-001165-index.html',
#   '1311'),
#  (1380509,
#   'HFF, Inc.',
#   '10-K',
#   datetime.date(2014, 3, 14),
#   'edgar/data/1380509/0001193125-14-099911.txt',
#   'edgar/data/1380509/0001193125-14-099911-index.html',
#   '6519'),
#  (1381240,
#   'Cyberspace Vita, Inc.',
#   '10-K',
#   datetime.date(2014, 3, 18),
#   'edgar/data/1381240/0001145443-14-000346.txt',
#   'edgar/data/1381240/0001145443-14-000346-index.html',
#   '50'),
#  (1382462,
#   'DEL TORO SILVER CORP.',
#   '10-Q',
#   datetime.date(2014, 3, 18),
#   'edgar/data/1382462/0001437749-14-004493.txt',
#   'edgar/data/1382462/0001437749-14-004493-index.html',
#   None),
#  (1382787,
#   'AmREIT Monthly Income & Growth Fund IV LP',
#   '10-K',
#   datetime.date(2014, 3, 21),
#   'edgar/data/1382787/0000897101-14-000357.txt',
#   'edgar/data/1382787/0000897101-14-000357-index.html',
#   '6798'),
#  (1383054,
#   'POWERSHARES DB SILVER FUND',
#   '10-K',
#   datetime.date(2014, 3, 14),
#   'edgar/data/1383054/0001193125-14-100043.txt',
#   'edgar/data/1383054/0001193125-14-100043-index.html',
#   '6221'),
#  (1383094,
#   'SANTANDER DRIVE AUTO RECEIVABLES LLC',
#   '10-K',
#   datetime.date(2014, 3, 28),
#   'edgar/data/1383094/0001193125-14-119727.txt',
#   'edgar/data/1383094/0001193125-14-119727-index.html',
#   '6189'),
#  (1383094,
#   'SANTANDER DRIVE AUTO RECEIVABLES LLC',
#   '10-K',
#   datetime.date(2014, 3, 28),
#   'edgar/data/1383094/0001193125-14-119733.txt',
#   'edgar/data/1383094/0001193125-14-119733-index.html',
#   '6189'),
#  (1383094,
#   'SANTANDER DRIVE AUTO RECEIVABLES LLC',
#   '10-K',
#   datetime.date(2014, 3, 28),
#   'edgar/data/1383094/0001193125-14-119751.txt',
#   'edgar/data/1383094/0001193125-14-119751-index.html',
#   '6189'),
#  (1383094,
#   'SANTANDER DRIVE AUTO RECEIVABLES LLC',
#   '10-K',
#   datetime.date(2014, 3, 28),
#   'edgar/data/1383094/0001193125-14-119752.txt',
#   'edgar/data/1383094/0001193125-14-119752-index.html',
#   '6189'),
#  (1383094,
#   'SANTANDER DRIVE AUTO RECEIVABLES LLC',
#   '10-K',
#   datetime.date(2014, 3, 28),
#   'edgar/data/1383094/0001193125-14-119758.txt',
#   'edgar/data/1383094/0001193125-14-119758-index.html',
#   '6189'),
#  (1383094,
#   'SANTANDER DRIVE AUTO RECEIVABLES LLC',
#   '10-K',
#   datetime.date(2014, 3, 28),
#   'edgar/data/1383094/0001193125-14-119766.txt',
#   'edgar/data/1383094/0001193125-14-119766-index.html',
#   '6189'),
#  (1383094,
#   'SANTANDER DRIVE AUTO RECEIVABLES LLC',
#   '10-K',
#   datetime.date(2014, 3, 28),
#   'edgar/data/1383094/0001193125-14-119768.txt',
#   'edgar/data/1383094/0001193125-14-119768-index.html',
#   '6189'),
#  (1383094,
#   'SANTANDER DRIVE AUTO RECEIVABLES LLC',
#   '10-K',
#   datetime.date(2014, 3, 28),
#   'edgar/data/1383094/0001193125-14-119787.txt',
#   'edgar/data/1383094/0001193125-14-119787-index.html',
#   '6189'),
#  (1383094,
#   'SANTANDER DRIVE AUTO RECEIVABLES LLC',
#   '10-K',
#   datetime.date(2014, 3, 28),
#   'edgar/data/1383094/0001193125-14-119791.txt',
#   'edgar/data/1383094/0001193125-14-119791-index.html',
#   '6189'),
#  (1383094,
#   'SANTANDER DRIVE AUTO RECEIVABLES LLC',
#   '10-K',
#   datetime.date(2014, 3, 28),
#   'edgar/data/1383094/0001193125-14-119797.txt',
#   'edgar/data/1383094/0001193125-14-119797-index.html',
#   '6189'),
#  (1383094,
#   'SANTANDER DRIVE AUTO RECEIVABLES LLC',
#   '10-K',
#   datetime.date(2014, 3, 28),
#   'edgar/data/1383094/0001193125-14-119802.txt',
#   'edgar/data/1383094/0001193125-14-119802-index.html',
#   '6189'),
#  (1383094,
#   'SANTANDER DRIVE AUTO RECEIVABLES LLC',
#   '10-K',
#   datetime.date(2014, 3, 28),
#   'edgar/data/1383094/0001193125-14-119812.txt',
#   'edgar/data/1383094/0001193125-14-119812-index.html',
#   '6189'),
#  (1383094,
#   'SANTANDER DRIVE AUTO RECEIVABLES LLC',
#   '10-K',
#   datetime.date(2014, 3, 28),
#   'edgar/data/1383094/0001193125-14-119817.txt',
#   'edgar/data/1383094/0001193125-14-119817-index.html',
#   '6189'),
#  ...]

# %% [markdown]
# ### API

# %%
# Function to query database by company:

def select_dates(start_date, end_date):
    
    ## Function to query the index by company name
    ## Expectes list of company names to execute select query
    
    ##Connect to DB:
    conn = psycopg2.connect("host=localhost dbname=postgres user=postgres password=Paolino1")
    cur = conn.cursor()
    
    ##Create Query:
    SQL = 'SELECT * FROM NEW_MASTER WHERE Filing_Date BETWEEN %s AND %s;'
    cur.execute(SQL, (str(start_date),str(end_date)))
    
    #Present query results:
    output = cur.fetchall()
    columns = ['CIK', 'Company_Name', 'Filing_Type', 'Filing_Date', 'URL_txt', 'URL_html', 'SIC']
    result = pd.DataFrame(output, columns=columns)
    
    ##Closing DB connection:
    cur.close()
    conn.close()
    
    return result

# %%
select_dates('2014-03-14', '2014-03-31')

# %%
# Function to query database by company:

def select_company(company_names):
    
    ## Function to query the index by company name
    ## Expectes list of company names to execute select query
    
    ##Connect to DB:
    conn = psycopg2.connect("host=localhost dbname=postgres user=postgres password=Paolino1")
    cur = conn.cursor()
    
    ##Create Query:
    SQL = 'SELECT * FROM NEW_MASTER WHERE Company_Name IN %(list)s;'
    cur.execute(SQL, {
        'list':tuple(company_names),
    })
    
    #Present query results:
    output = cur.fetchall()
    columns = ['CIK', 'Company_Name', 'Filing_Type', 'Filing_Date', 'URL_txt', 'URL_html', 'SIC']
    result = pd.DataFrame(output, columns=columns)
    
    ##Closing DB connection:
    cur.close()
    conn.close()
    
    return result

# %%
#Sample query to retrieve index data for Amazon and American Airlines:
df_co_name = select_company(['AMAZON COM INC', 'AMERICAN AIRLINES INC'])

# %%
#Checking that both Amazon and AA were found:
df_co_name.Company_Name.unique()

# %%
# Function to query database by SIC:

def select_SIC(company_sics):
    
    ## Function to query the index by SIC
    
    ##Connect to DB:
    conn = psycopg2.connect("host=localhost dbname=postgres user=postgres password=Paolino1")
    cur = conn.cursor()
    
    ##Create Query:
    SQL = 'SELECT * FROM NEW_MASTER WHERE SIC IN %(list)s;'
    cur.execute(SQL, {
        'list':tuple(company_sics),
    })
    
    #Present query results:
    output = cur.fetchall()
    columns = ['CIK', 'Company_Name', 'Filing_Type', 'Filing_Date', 'URL_txt', 'URL_html', 'SIC']
    result = pd.DataFrame(output, columns=columns)
    
    ##Closing DB connection:
    cur.close()
    conn.close()
    
    return result

# %%
df_sic = select_SIC(['6172'])

# %%
df_sic

# %%
# Function to query database by SIC:

# Table DDL:
#CREATE TABLE NEW_MASTER(CIK integer, Company_Name text, 
#Filing_Type text,Filing_Date text,URL_text text, URL_html text, SIC text)

def select_mult_criteria(companies, sics, dates):
    
    ## Function to query the index by companies, sics or years
    
    ##Connect to DB:
    conn = psycopg2.connect("host=localhost dbname=postgres user=postgres password=Paolino1")
    cur = conn.cursor()

    print(len(companies))
    print(len(sics))
    print(len(dates))
    
    
    if (len(companies)>0 & len(sics)>0 & len(dates)>0):
        print('Cannot specify both Company Names and SICs')
        pass
        
    elif len(companies)==0 and len(sics)>0 and len(dates)>0:
        SQL = 'SELECT * FROM NEW_MASTER WHERE SIC IN %(sic_list)s AND Filing_Date IN %(dates_list)s;'

        cur.execute(SQL, {'sic_list':tuple(sics),
                         'dates_list':tuple(dates),})
        
    elif len(companies)>0 and len(sics)==0 and len(dates)>0:
        SQL = 'SELECT * FROM NEW_MASTER WHERE Company_Name IN %(co_list)s AND Filing_Date IN %(dates_list)s;'

        cur.execute(SQL, {'co_list':tuple(companies),
                          'dates_list':tuple(dates),})
    
    elif len(companies)==0 and len(sics)>0 and len(dates)==0:
        SQL = 'SELECT * FROM NEW_MASTER WHERE SIC IN %(sic_list)s;'

        cur.execute(SQL, {'sic_list':tuple(sics),})
    
    else:
        print('Query format not complying to standards')
        print('Please make sure to enter some dates')
        pass
    
    #Present query results:
    output = cur.fetchall()
    columns = ['CIK', 'Company_Name', 'Filing_Type', 'Filing_Date', 'URL_txt', 'URL_html', 'SIC']
    result = pd.DataFrame(output, columns=columns)
    
    ##Closing DB connection:
    cur.close()
    conn.close()
    
    return result

# %% [markdown]
# ### Create Financial Statements
# Objective: connect to Edgar and retrieve financial statments for selected companies

# %% [markdown]
# Reference for XML Table Schema: https://www.w3schools.com/html/html_tables.asp

# %%
import requests
from bs4 import BeautifulSoup
import lxml

# %%
def query_results():
    ## Function to retrieve url for 2018 10-K
    ## Expects input from select_company function
    
    #Returning 10-K from 2018. If it does not exist, returning most recent 10-K
    
    print('Welcome to ValuTrack Query Managemnt Tool')
    print('QMT lets you query the Edgar Index by Company Name, SIC Code, and Date')
    print('----------------------------------------------------------------------------------------')
    print('In the next steps you will be asked to formulate a query to retrieve available financial statements')
    print('You can add as many search conditions as you would like')
    print('The query will search for index entries matching all conditions entered')
    print('If you only wish to search by SIC code, leave the steps for Company Name and Year blank')
    print('----------------------------------------------------------------------------------------')
    print('Please make sure to either enter some Companies or SIC codes - Not Both!')
    print('----------------------------------------------------------------------------------------')
    print('Step 1: Company Names')
    print('Please enter company names in list format with names in quotes and separated by commas')
    print('For example: ["MINT LEASING INC", "NewStar Financial, Inc."]')
    
    selected_companies = []
    
    print('Please enter number of companies you want to search for:')
    n = int(input('> '))
    
    for i in range(0,n):
        
        print('Please enter next Company name:')
        ele = str(input('> '))
        
        selected_companies.append(ele)
    
    #Will need to add error handling here
    #print('You have entered')
    
    print('----------------------------------------------------------------------------------------')
    print('Step 2: SIC Codes')
    print('Please enter SIC codes in list format with codes in quotes and separated by commas')
    print('For example: ["6162", "6172"]')
    
    selected_sics = []
    
    print('Please enter number of SIC codes you want to search for:')
    n = int(input('> '))
    
    for i in range(0,n):
        
        print('Please enter next SIC:')
        ele = str(input('> '))
        
        selected_sics.append(ele)
    
    #Will need to add error handling here
    #print('You have entered')
    
    print('----------------------------------------------------------------------------------------')
    print('Step 3: Dates')
    print('Please enter Dates in list format with Dates in quotes and separated by commas')
    print('For example: ["2014-03-31", "2014-03-14"]')
    
    selected_dates = []
    
    print('Please enter number of Dates you want to search for:')
    n = int(input('> '))
    
    for i in range(0,n):
        
        print('Please enter next Date:')
        ele = str(input('> '))
        
        selected_dates.append(ele)
    
    #Will need to add error handling here
    #print('You have entered')
    
    df = select_mult_criteria(selected_companies, selected_sics, selected_dates)
    
    df_10k = df[df['Filing_Type'] == '10-K']
    
    return df_10k

# %%
def index_url(df, base_url = r"https://www.sec.gov/Archives/"):
    
    ## Function to retrieve url for 2018 10-K
    ## Expects input from select_company function
    
    #Returning most recent 10-K if it exists
    
    df_recent = df[(df['Filing_Type'] == '10-K')].sort_values('Filing_Date', ascending=False)
        
    if len(df_recent) == 0:
        print('No 10-K available for this company')
        pass
        
    declination = df_recent[['URL_txt']].iloc[0][0]
    
    declination = declination.replace("-","").replace(".txt","/index.json")
    
    return base_url + declination

# %%
#def index_url(base_url = r"https://www.sec.gov/Archives/"):
#    urls = ["https://www.sec.gov/Archives/"+url.replace("-","")\
#            .replace(".txt","/index.json") for url in list(df_10k['URL_txt'])]
#        
#    return urls

# %%
def download_summary(urls):

    ## Function to retrieve the 10-K Summary which contains links to individual reports
    ## Expects input from index_url function
    
    download = requests.get(co_url).json()
    
    xml_summary = r'https://www.sec.gov'
    
    for item in download['directory']['item']:
        if item['name'] == 'FilingSummary.xml':
            xml_summary += download['directory']['name']+'/' + item['name']

    new_base_url = xml_summary.replace('FilingSummary.xml', '')
    content = requests.get(xml_summary).content
    
    #Using BS4 to parse the XML content
    soup = BeautifulSoup(content, 'lxml')
    reports = soup.find('myreports')
    
    if reports is None:
        print('---------------------')
        print('Sorry, no reports were found for this company!')
        print('Please try a different public company!')
        print('---------------------')
        pass
    
    return new_base_url, reports

# %%
def download_summary(co_url):

    ## Function to retrieve the 10-K Summary which contains links to individual reports
    ## Expects input from index_url function
    
    download = requests.get(co_url).json()
    
    xml_summary = r'https://www.sec.gov'
    
    for item in download['directory']['item']:
        if item['name'] == 'FilingSummary.xml':
            xml_summary += download['directory']['name']+'/' + item['name']

    new_base_url = xml_summary.replace('FilingSummary.xml', '')
    content = requests.get(xml_summary).content
    
    #Using BS4 to parse the XML content
    soup = BeautifulSoup(content, 'lxml')
    reports = soup.find('myreports')
    
    if reports is None:
        print('---------------------')
        print('Sorry, no reports were found for this company!')
        print('Please try a different public company!')
        print('---------------------')
        pass
    
    return new_base_url, reports

# %%
def show_statements(reports):
    
    #Function to select among available statements contained in the 10-K:
    print('------------------------')
    print('Please select the reports you would like to include in your download')
    print('Copy your selections into the user input provided by the select_reports function')
    print('------------------------')
    
    if reports is None:
        
        print('---------------------')
        print('Sorry, no reports were found for this company!')
        print('Please try a different public company!')
        print('---------------------')
        pass
    
    all_reports = []
    for report in reports.find_all('report'):
        print(report.shortname.text)
        all_reports.append(report.shortname.text)

    return all_reports

# %%
def select_reports(all_reports):
    
    all_selections = []
    
    while len(all_selections)<4:
        
        selected = input()
        
        if selected not in all_reports:
            print('Your entry is not valid')
            print('Please copy/paste a report name from the list above.')
            print('Please do not use quotes when entering the report name.')
        else:
            print('-----')
            print('You have entered a valid report!')
            print('Please enter another report from the list above.')
            print('\n')
            all_selections.append(selected)
            
    return all_selections

# %%
def statements_urls(new_base_url, reports, short_names):
    
    #Function to create the 4 URL's associated with each Financial Statement Report (see list below)
    #Expectes input from download_summary and pick_statments functions
    
    #Empty dictionary with URL's to downloaded reports
    statements_urls = {}
    
    #Iterating through different reports in the index
    for report in reports.find_all('report'):
        if report.shortname.text in short_names:
            #print('URL for '+report.shortname.text)
            #print(new_base_url+report.htmlfilename.text)
            statements_urls[report.shortname.text] = new_base_url+report.htmlfilename.text

    return statements_urls

# %%
def statements_data(statements_urls):
    
    ## Function scrapes financial statements at URL's found and returns a dictionary of unparsed data   
    ## Expects dictionary output by statements_url function
    
    stm_data = {}
    for key, url in statements_urls.items():
        
        statement_data = {}
        statement_data['headers'] = []
        statement_data['sections'] = []
        statement_data['data'] = []

        content = requests.get(url).content
        soup = BeautifulSoup(content, 'html')

        for index, row in enumerate(soup.table.find_all('tr')):

            cols = row.find_all('td')

            if (len(row.find_all('th')) == 0 and len(row.find_all('strong')) == 0): 
                reg_row = [dt.text.strip() for dt in cols]
                statement_data['data'].append(reg_row)

            elif (len(row.find_all('th')) == 0 and len(row.find_all('strong')) != 0):
                sec_row = cols[0].text.strip()
                statement_data['sections'].append(sec_row)

            elif (len(row.find_all('th')) != 0):            
                hed_row = [dt.text.strip() for dt in row.find_all('th')]
                statement_data['headers'].append(hed_row)

            else:            
                print('Error.')

        stm_data[key] = statement_data   
        
    return stm_data

# %%
def financial_statements(stm_data):
    
    ## Function to create dictionary containing the four reports that make up a financial statement
    ## Expects inputs from statements_data function

    financial_statements = {}
    for key, statement in stm_data.items():

        header = statement['headers']
        data = statement['data']
        df = pd.DataFrame(data)

        #Some formatting to make sure every df is presented well regardless of dimension
        df = df.replace('[\$,)]','', regex=True )\
                             .replace( '[(]','-', regex=True)\
                             .replace( '', 'NaN', regex=True)\
                             .replace( '\[.*?]', 'NaN', regex=True)

        df.index = df.iloc[:,0]

        df = df.drop(df.columns[0], axis=1)

        df = df.replace('((?:[ a-z ]+\S*\d+|\d\S*[a-z]+)[a-z\d_-]*)', 'NaN', regex=True)\
                        .replace('[^0-9]','', regex=True)\
                        .replace('',np.nan, regex=True)

        df.fillna(value=pd.np.nan, inplace=True)
        df = df.dropna(axis=1, how='all')
        df = df.dropna(axis=0, how='all')

        var = df.shape[1]
        temp = [i for sublist in header for i in sublist]
        df.columns = temp[-var:]
        df.index.name = temp[0]

        df = df.apply(pd.to_numeric)

        #Appending All 4 Statements to Dictionary:
        financial_statements[key]=df
        
    return financial_statements

# %%
def run_all():
    
    #Function executes all functions to retrieve Financial Statements for all listed companies
    #Returns a dictionary whose key is the company CIK and values are the 4 statements
    
    df = query_results()
    
    uniques = df.Company_Name.unique()
    df_list = []
    print('----------------------------------------------')
    print('Your query selected the following companies:')
    print(uniques)
    print('----------------------------------------------')
    print('A dataframe containing all index entries matching your query will also be returned')
    print('Along with related financial statements')
    print('----------------------------------------------')
    
    
    
    company_statements_dict = {}
    
    for val in uniques:
        df_list.append(df[df['Company_Name'] == val])
        
    #Executing all functions in sequence:
    for df, val in zip(df_list,uniques):
        print('-------------------------------')
        print('Please select statements for: ')
        print(val)
        print('-------------------------------')
        
        #Retrieving url
        df_url = index_url(df, base_url = r"https://www.sec.gov/Archives/")
        #Downloading index
        new_base_url, reports = download_summary(df_url)
        #Showing all reports for company
        all_reports = show_statements(reports) #Stop printing all
        #Selecting 4 reports
        selected_reports = select_reports(all_reports)
        #Selecting URL's for each report
        urls = statements_urls(new_base_url, reports, selected_reports)
        #Downloading statements
        stm_data = statements_data(urls)
        #Converting statements into Pandas Dataframes
        statements_dict = financial_statements(stm_data)
        #Loading dictionary containing all statements for all input companies:
        key = df.Company_Name.unique()[0]
        company_statements_dict[key] = statements_dict
        
        
    return df, company_statements_dict

# %% [markdown]
# #### Run the following Function and pick the statements you want to download

# %%
df, out = run_all()

# %%
df

# %%
out['MINT LEASING INC'].keys()

# %%
#Tests

# %%
print('Financial statements for the followign companies have been downloaded:')
print(out.keys())

# %%
print('The following statements for each company have been downloaded for AA:')
print(out['MINT LEASING INC'].keys())

# %%
print('The following statements for each company have been downloaded for Amazon:')
print(out['MINT LEASING INC'].keys())

# %% [markdown]
# American Airlines

# %%
out['MINT LEASING INC']['Consolidated Balance Sheets']

# %%
out['AMERICAN AIRLINES INC']['Consolidated Balance Sheets']

# %%
out['AMERICAN AIRLINES INC']['Consolidated Statements of Cash Flows']

# %%
out['AMERICAN AIRLINES INC']["Consolidated Statements of Stockholders' Equity"]

# %% [markdown]
# Amazon

# %%
out['AMAZON COM INC']['Consolidated Statements of Cash Flows']

# %%
out['AMAZON COM INC']['Consolidated Statements of Comprehensive Income']

# %%
out['AMAZON COM INC']['Consolidated Balance Sheets']

# %%
out['AMAZON COM INC']["Consolidated Statements of Stockholders' Equity"]
