# %%
import pandas as pd
import numpy as np

# %%
#Columns are CIK, row values are SIC
#There are 5 rows because each row is originated from one of the five dictionaries used 
#to create the file
pd.read_csv('sic_cik_mapping_1_new.csv').head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-4cd3a71955ad> in <module>
#       2 #There are 5 rows because each row is originated from one of the five dictionaries used
#       3 #to create the file
# ----> 4 pd.read_csv('sic_cik_mapping_1_new.csv').head()
#
# ...

# %%
#Columns are CIK, row values are SIC
#There are 2 rows because each row is originated from one of the two dictionaries used 
#to create the file
pd.read_csv('sic_cik_mapping_2_new.csv').head()

# %%
pd.read_csv('sic_cik_mapping_3_new.csv').head()

# %%
#All columns have at least one non-null value
pd.read_csv('sic_cik_mapping_3_new.csv').head()

# %%
pd.read_csv('sic_cik_mapping_4_new.csv')

# %%
#All columns have at least one non-null value
pd.read_csv('sic_cik_mapping_5_new.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-5be9ffe01879> in <module>
#       1 #All columns have at least one non-null value
# ----> 2 pd.read_csv('sic_cik_mapping_5_new.csv')
#
# ...

# %%
#All columns have at least one non-null value
pd.read_csv('sic_cik_mapping_6_new.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-c50e668cd766> in <module>
#       1 #All columns have at least one non-null value
# ----> 2 pd.read_csv('sic_cik_mapping_6_new.csv')
#
# ...

# %%
#All columns have at least one non-null value
pd.read_csv('sic_cik_mapping_7_new.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-1d321512be44> in <module>
#       1 #All columns have at least one non-null value
# ----> 2 pd.read_csv('sic_cik_mapping_7_new.csv')
#
# ...

# %%
#All columns have at least one non-null value
pd.read_csv('sic_cik_mapping_8_new.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-531cc3a4d19a> in <module>
#       1 #All columns have at least one non-null value
# ----> 2 pd.read_csv('sic_cik_mapping_8_new.csv')
#
# ...

# %%
#All columns have at least one non-null value
pd.read_csv('sic_cik_mapping_9_new.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-9-95239935c228> in <module>
#       1 #All columns have at least one non-null value
# ----> 2 pd.read_csv('sic_cik_mapping_9_new.csv')
#
# ...

# %%
#All columns have at least one non-null value
pd.read_csv('sic_cik_mapping_10_new.csv')
# Out:
#    1761  1969  1988  2145  2435  2457  2648  3228  3398  3449  ...  1058625  \
# 0  2670  4955  3577  5190  3672  3564  6311  1040  3661  6411  ...     7320
#
#   1058634  1058635  1058673  1059010  1059067  1059068  1061154  1061156  \
# 0    7320     7320     None     None     None     None     None     None
#
#    1092481
# 0     None
#
# [1 rows x 3882 columns]

# %%
df1 = pd.read_csv('sic_cik_mapping_1_new.csv')
df2 = pd.read_csv('sic_cik_mapping_2_new.csv')
df3 = pd.read_csv('sic_cik_mapping_3_new.csv')
df4 = pd.read_csv('sic_cik_mapping_4_new.csv')
df5 = pd.read_csv('sic_cik_mapping_5_new.csv')
df6 = pd.read_csv('sic_cik_mapping_6_new.csv')
df7 = pd.read_csv('sic_cik_mapping_7_new.csv')
df8 = pd.read_csv('sic_cik_mapping_8_new.csv')
df9 = pd.read_csv('sic_cik_mapping_9_new.csv')
df10 = pd.read_csv('sic_cik_mapping_10_new.csv')

# %%
df = pd.concat([df1,df2,df3,df4,df5,df6,df7,df8,df9,df10], ignore_index=True)
# Out:
# /Applications/anaconda3/envs/py36/lib/python3.6/site-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-00cf07b74dcd> in <module>
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
df = df.fillna(method='ffill').iloc[-1,:]

# %%
df = df.reset_index()
df.columns = ['CIK', 'SIC']

# %%
df['CIK'] = df['CIK'].astype('int')

# %%
master_df = pd.read_csv('data_sic/master.csv', delimiter='@')

# %%
master = master_df.merge(df, how='left', on='CIK')

# %%
master.head(10)
# Out:
#       CIK              Company_Name Filing_Type Filing_Date  \
# 0  100030                   TRW INC     DEF 14A  1995-03-14
# 1  100030                   TRW INC         S-8  1995-03-27
# 2  100030                   TRW INC         S-8  1995-03-27
# 3  100030                   TRW INC    SC 13G/A  1995-02-02
# 4  100030                   TRW INC      SC 13G  1995-02-10
# 5  100030                   TRW INC      SC 13G  1995-02-16
# 6  100063              TSI INC /MN/    SC 13G/A  1995-02-10
# 7  100063              TSI INC /MN/    SC 13G/A  1995-02-13
# 8  100122  TUCSON ELECTRIC POWER CO        10-K  1995-03-09
# 9  100122  TUCSON ELECTRIC POWER CO         S-8  1995-01-11
#
#                                       URL_txt  \
# 0  edgar/data/100030/0000950132-95-000059.txt
# 1  edgar/data/100030/0000950152-95-000436.txt
# 2  edgar/data/100030/0000950152-95-000439.txt
# 3  edgar/data/100030/0000950152-95-000083.txt
# 4  edgar/data/100030/0000315066-95-002097.txt
# ...

# %%
ms_test = master[master['Filing_Type'].isin(['10-K','10-Q'])]

# %%
if sum(ms_test['SIC'].isnull()) == 0:
    print('Test Passed: all SIC codes have been applied to 10k and 10q filings')
# Out:
# Test Passed: all SIC codes have been applied to 10k and 10q filings

# %%
ms_test.iloc[1000:2000]
# Out:
#           CIK                               Company_Name Filing_Type  \
# 11528  711513         MCDONNELL DOUGLAS FINANCE CORP /DE        10-K
# 11547  711761                     LOTUS DEVELOPMENT CORP        10-K
# 11564   71222                   COMMONWEALTH ELECTRIC CO        10-K
# 11566  712425                                 ALPNET INC        10-K
# 11570  712515                        ELECTRONIC ARTS INC        10-Q
# 11576  712537     FIRST COMMONWEALTH FINANCIAL CORP /PA/        10-K
# 11583  712752                   SILICON VALLEY GROUP INC        10-Q
# 11616  713002                    FLOW INTERNATIONAL CORP        10-Q
# 11621   71304                 COMMONWEALTH ENERGY SYSTEM        10-K
# 11626  713095                  FARMERS CAPITAL BANK CORP        10-K
# 11644  713425                      AMERICAN SOFTWARE INC        10-Q
# 11648  713676                              PNC BANK CORP        10-K
# 11685  714154                       COMPAQ COMPUTER CORP        10-K
# ...

# %%
master.to_csv('data_sic/master_wsic.csv', index=False)

# %%
df.to_csv('data_sic/cik_sic_mapping.csv', index=False)

# %%
#Reading from CSV and loading into table

# %%
#master_df.merge(new, how='left', on=)

# %%
df = pd.read_csv('data_sic/cik_sic_mapping.csv')

# %%
master = pd.read_csv('data_sic/master_wsic.csv')

# %%
master = master[master['Filing_Type'].isin(['10-K','10-Q'])]

# %%
master.shape
# Out:
# (776688, 7)

# %%
master[master['SIC'] == 'None'].shape
# Out:
# (5865, 7)

# %%
df['SIC'] = df['SIC'].str.replace(r'.0','')

# %%
#Removing nones for now
master = master[master['SIC'] != 'None']

# %%
#df[df['SIC'] == 'None']

# %%
master['SIC'] = master['SIC'].str.replace(r'.0', '')

# %%
master.to_csv('data_sic/master_final.csv', index=False)

# %%
master[master['SIC'] == ''].shape
# Out:
# (30390, 7)

# %%
master.sort_values('Filing_Date', ascending=False).head()
# Out:
#              CIK               Company_Name Filing_Type Filing_Date  \
# 8122504   728387               Isoray, Inc.        10-K  2019-09-27
# 8013573  1384135             SMARTHEAT INC.        10-Q  2019-09-27
# 8069679  1672572                Landbay Inc        10-Q  2019-09-27
# 8002272  1300734              SHINECO, INC.        10-K  2019-09-27
# 7975393  1082733  VISIUM TECHNOLOGIES, INC.        10-K  2019-09-27
#
#                                              URL_txt  \
# 8122504   edgar/data/728387/0001437749-19-019176.txt
# 8013573  edgar/data/1384135/0001185185-19-001302.txt
# 8069679  edgar/data/1672572/0001017386-19-000266.txt
# 8002272  edgar/data/1300734/0001213900-19-019170.txt
# 7975393  edgar/data/1082733/0001493152-19-014676.txt
#
#                                                   URL_html   SIC
# 8122504  edgar/data/728387/0001437749-19-019176-index.html  3841
# 8013573  edgar/data/1384135/0001185185-19-001302-index....  3433
# ...

# %%
len(master['CIK'])
# Out:
# 770823

# %%
len(master['CIK'].unique())
# Out:
# 38280

# %% [markdown]
# ### ETL - Loading the new index into new table

# %%
import pandas as pd
import edgar
import psycopg2
import os
import glob
import numpy as np

# %%
conn = psycopg2.connect("host=localhost dbname=postgres user=postgres password=Paolino1")

# %%
cur = conn.cursor()

# %%
#Only run once
cur.execute("""CREATE TABLE NEW_MASTER(CIK integer, Company_Name text, Filing_Type text,
                Filing_Date text,URL_text text, URL_html text, SIC text)""")

# %%
#Only run once
with open('data_sic/master_final.csv', 'r', encoding='utf-8') as f:
    #cur.copy_from(f, 'new_index', sep='@')
    cur.copy_expert("COPY NEW_MASTER FROM STDIN WITH CSV HEADER DELIMITER AS ','", f)
    conn.commit()

# %%
#Only run once
#del master_df

# %%
#Checking simple query
cur.execute('SELECT * FROM NEW_MASTER LIMIT 20')

# %%
query = cur.fetchall()

# %%
query
# Out:
# [(100122,
#   'TUCSON ELECTRIC POWER CO',
#   '10-K',
#   '1995-03-09',
#   'edgar/data/100122/0000100122-95-000007.txt',
#   'edgar/data/100122/0000100122-95-000007-index.html',
#   '4911'),
#  (10012,
#   'BARNETT BANKS INC',
#   '10-K',
#   '1995-02-03',
#   'edgar/data/10012/0000912057-95-000305.txt',
#   'edgar/data/10012/0000912057-95-000305-index.html',
#   '22'),
#  (100166,
#   'TULTEX CORP',
#   '10-K',
#   '1995-03-31',
#   'edgar/data/100166/0000100166-95-000031.txt',
#   'edgar/data/100166/0000100166-95-000031-index.html',
#   '2253'),
#  (100331,
#   '20TH CENTURY INDUSTRIES',
#   '10-K',
#   '1995-03-31',
#   'edgar/data/100331/0000100331-95-000014.txt',
#   'edgar/data/100331/0000100331-95-000014-index.html',
#   '6331'),
#  (100441,
#   'TYCO INTERNATIONAL LTD',
#   '10-Q',
#   '1995-01-30',
#   'edgar/data/100441/0000950112-95-000184.txt',
#   'edgar/data/100441/0000950112-95-000184-index.html',
#   '3569'),
#  (100493,
#   'TYSON FOODS INC',
#   '10-Q',
# ...

# %%
cur.close()

# %%
conn.close()

# %%
#Cleaning directory
#The data is now only in the database
#!rm data/*sv
