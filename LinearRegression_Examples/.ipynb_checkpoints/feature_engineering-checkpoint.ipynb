# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
credits = pd.read_csv('movies_dataset/tmdb_5000_credits.csv')
movies = pd.read_csv('movies_dataset/tmdb_5000_movies.csv')

# %%
obj_movies = movies.select_dtypes(exclude=('int64', 'float64'))

# %%
obj_movies.genres[1].from_dict()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-8e45df7f8717> in <module>()
# ----> 1 obj_movies.genres[1].from_dict()
#
# AttributeError: 'str' object has no attribute 'from_dict'

# %%
pd.DataFrame.from_records(obj_movies.genres.items())
# Out:
#          0                                                  1
# 0        0  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 1        1  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 2        2  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 3        3  [{"id": 28, "name": "Action"}, {"id": 80, "nam...
# 4        4  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 5        5  [{"id": 14, "name": "Fantasy"}, {"id": 28, "na...
# 6        6  [{"id": 16, "name": "Animation"}, {"id": 10751...
# 7        7  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 8        8  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 9        9  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# 10      10  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 11      11  [{"id": 12, "name": "Adventure"}, {"id": 28, "...
# 12      12  [{"id": 12, "name": "Adventure"}, {"id": 14, "...
# 13      13  [{"id": 28, "name": "Action"}, {"id": 12, "nam...
# ...

# %%
pd.DataFrame.from_records(obj_movies.genres.values.tolist()).stack().reset_index()
# Out:
#         level_0  level_1  0
# 0             0        0  [
# 1             0        1  {
# 2             0        2  "
# 3             0        3  i
# 4             0        4  d
# 5             0        5  "
# 6             0        6  :
# 7             0        7
# 8             0        8  2
# 9             0        9  8
# 10            0       10  ,
# 11            0       11
# 12            0       12  "
# 13            0       13  n
# 14            0       14  a
# 15            0       15  m
# 16            0       16  e
# 17            0       17  "
# 18            0       18  :
# 19            0       19
# 20            0       20  "
# 21            0       21  A
# 22            0       22  c
# 23            0       23  t
# 24            0       24  i
# 25            0       25  o
# 26            0       26  n
# 27            0       27  "
# 28            0       28  }
# 29            0       29  ,
# ...         ...      ... ..
# 380761     4802        5  "
# ...

# %%
obj_movies.genres[0]
# Out:
# '[{"id": 28, "name": "Action"}, {"id": 12, "name": "Adventure"}, {"id": 14, "name": "Fantasy"}, {"id": 878, "name": "Science Fiction"}]'

# %%
pd.io.json.json_normalize(obj_movies['genres'], meta = ['id','name'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-59-8bd629009e1f> in <module>()
# ----> 1 pd.io.json.json_normalize(obj_movies['genres'])
#
# /Users/pauldefusco/anaconda2/envs/py27/lib/python2.7/site-packages/pandas/io/json/normalize.pyc in json_normalize(data, record_path, meta, meta_prefix, record_prefix, errors, sep)
#     190
#     191     if record_path is None:
# --> 192         if any([isinstance(x, dict) for x in compat.itervalues(data[0])]):
#     193             # naive normalization, this is idempotent for flat records
#     194             # and potentially will inflate the data considerably for
#
# /Users/pauldefusco/anaconda2/envs/py27/lib/python2.7/site-packages/pandas/compat/__init__.pyc in itervalues(obj, **kw)
#     194
#     195     def itervalues(obj, **kw):
# --> 196         return obj.itervalues(**kw)
#     197
# ...

# %%
pd.read_json([i for i in obj_movies['genres']])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-61-1b6817a2f0f2> in <module>()
# ----> 1 pd.read_json([i for i in obj_movies['genres']])
#
# /Users/pauldefusco/anaconda2/envs/py27/lib/python2.7/site-packages/pandas/io/json/json.pyc in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression)
#     350     compression = _infer_compression(path_or_buf, compression)
#     351     filepath_or_buffer, _, compression = get_filepath_or_buffer(
# --> 352         path_or_buf, encoding=encoding, compression=compression,
#     353     )
#     354
#
# /Users/pauldefusco/anaconda2/envs/py27/lib/python2.7/site-packages/pandas/io/common.pyc in get_filepath_or_buffer(filepath_or_buffer, encoding, compression)
#     209     if not is_file_like(filepath_or_buffer):
# ...

# %%
obj_movies['genres'].apply(lambda genres: len(genres)).value_counts()
# Out:
# 29     371
# 30     369
# 63     286
# 59     285
# 93     272
# 62     213
# 91     192
# 64     182
# 61     159
# 94     156
# 95     151
# 90     151
# 60     141
# 92     120
# 124     95
# 103     79
# 120     75
# 96      73
# 35      68
# 58      59
# 102     57
# 123     57
# 97      54
# 89      53
# 125     51
# 135     49
# 66      47
# 126     43
# 129     39
# 88      37
#       ...
# 158      5
# 104      5
# 168      5
# 34       5
# 196      4
# 139      4
# 190      4
# 197      4
# 165      3
# 68       3
# 170      3
# 162      3
# 194      3
# 151      3
# 186      2
# 199      2
# 189      2
# 192      2
# 119      2
# 221      1
# 184      1
# 188      1
# 200      1
# 224      1
# 185      1
# 138      1
# 230      1
# 195      1
# 74       1
# 219      1
# Name: genres, Length: 105, dtype: int64

# %%
for i in obj_movies['genres']:
    pd.DataFrame(pd.io.json.json_normalize(i,['id','name']))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-87-463170a18fea> in <module>()
#       1 for i in obj_movies['genres']:
# ----> 2     pd.DataFrame(pd.io.json.json_normalize(i,['id','name']))
#
# /Users/pauldefusco/anaconda2/envs/py27/lib/python2.7/site-packages/pandas/io/json/normalize.pyc in json_normalize(data, record_path, meta, meta_prefix, record_prefix, errors, sep)
#     254                 records.extend(recs)
#     255
# --> 256     _recursive_extract(data, record_path, {}, level=0)
#     257
#     258     result = DataFrame(records)
#
# /Users/pauldefusco/anaconda2/envs/py27/lib/python2.7/site-packages/pandas/io/json/normalize.pyc in _recursive_extract(data, path, seen_meta, level)
#     226                         seen_meta[key] = _pull_field(obj, val[-1])
#     227
# --> 228                 _recursive_extract(obj[path[0]], path[1:],
# ...

# %%
pd.read_json((obj_movies['genres']).to_json(), orient=obj_movies.index)
# Out:
# /Users/pauldefusco/anaconda2/envs/py27/lib/python2.7/site-packages/pandas/core/indexes/base.py:3846: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   result = op(self.values, np.asarray(other))
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-80-efb566df9e40> in <module>()
# ----> 1 pd.read_json((obj_movies['genres']).to_json(), orient=obj_movies.index)
#
# /Users/pauldefusco/anaconda2/envs/py27/lib/python2.7/site-packages/pandas/io/json/json.pyc in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines, chunksize, compression)
#     364         return json_reader
#     365
# --> 366     return json_reader.read()
#     367
#     368
#
# ...

# %%
pd.io.json.json_normalize(obj_movies.to_json(),['genres',['id','name']])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-84-cbf1dc5ff0b6> in <module>()
# ----> 1 pd.io.json.json_normalize(obj_movies.to_json(),['genres',['id','name']])
#
# /Users/pauldefusco/anaconda2/envs/py27/lib/python2.7/site-packages/pandas/io/json/normalize.pyc in json_normalize(data, record_path, meta, meta_prefix, record_prefix, errors, sep)
#     254                 records.extend(recs)
#     255
# --> 256     _recursive_extract(data, record_path, {}, level=0)
#     257
#     258     result = DataFrame(records)
#
# /Users/pauldefusco/anaconda2/envs/py27/lib/python2.7/site-packages/pandas/io/json/normalize.pyc in _recursive_extract(data, path, seen_meta, level)
#     226                         seen_meta[key] = _pull_field(obj, val[-1])
#     227
# --> 228                 _recursive_extract(obj[path[0]], path[1:],
# ...

# %%
for i in obj_movies.genres:
    pd.io.json.json_normalize(i,['id','name'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-73-56ac41b5fce2> in <module>()
#       1 for i in obj_movies.genres:
# ----> 2     pd.io.json.json_normalize(i,['id','name'])
#
# /Users/pauldefusco/anaconda2/envs/py27/lib/python2.7/site-packages/pandas/io/json/normalize.pyc in json_normalize(data, record_path, meta, meta_prefix, record_prefix, errors, sep)
#     254                 records.extend(recs)
#     255
# --> 256     _recursive_extract(data, record_path, {}, level=0)
#     257
#     258     result = DataFrame(records)
#
# /Users/pauldefusco/anaconda2/envs/py27/lib/python2.7/site-packages/pandas/io/json/normalize.pyc in _recursive_extract(data, path, seen_meta, level)
#     226                         seen_meta[key] = _pull_field(obj, val[-1])
#     227
# --> 228                 _recursive_extract(obj[path[0]], path[1:],
# ...
