# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
% matplotlib inline

# %%
my_data = pd.DataFrame.from_csv('AK_2002.tab', sep='\t')
# Out:
# /Users/pauldefusco/anaconda2/envs/py27/lib/python2.7/site-packages/ipykernel_launcher.py:1: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#   """Entry point for launching an IPython kernel.

# %%
my_data.columns
# Out:
# Index([u'year', u'ed_precinct', u'precinct', u'ed', u'precinct_code',
#        u'g2002_REG_tv', u'g2002_GOV_tv', u'g2002_GOV_dv', u'g2002_GOV_rv',
#        u'g2002_STH_dv', u'g2002_STH_rv', u'g2002_STS_dv', u'g2002_STS_rv',
#        u'g2002_USH_dv', u'g2002_USH_rv', u'g2002_USS_dv', u'g2002_USS_rv'],
#       dtype='object')

# %%
import geopandas as gpd

# %%
fp = 'AK_Shapefile/AK_final.shp'

# %%
data = gpd.read_file(fp)

# %%
type(data)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
data.head()
# Out:
#   STATEFP10 COUNTYFP10 VTDST10      GEOID10 VTDI10  \
# 0        02        013  37-732  0201337-732      A
# 1        02        013  37-734  0201337-734      A
# 2        02        013  37-720  0201337-720      A
# 3        02        013  37-712  0201337-712      A
# 4        02        013  37-700  0201337-700      A
#
#                                               NAME10  \
# 0  Port Heiden Precinct (Part; Also See Part In L...
# 1                                Sand Point Precinct
# 2                                 King Cove Precinct
# 3                                  Cold Bay Precinct
# 4                                    Akutan Precinct
#
#                                           NAMELSAD10 LSAD10 MTFCC10  \
# 0  Port Heiden Precinct (Part; Also See Part In L...     00   G5240
# 1                                Sand Point Precinct     00   G5240
# 2                                 King Cove Precinct     00   G5240
# ...

# %%
py.pyplot.figure()
data.plot()
py.pyplot.show()

# %%
data.crs
# Out:
# {}

# %%
data.columns
# Out:
# Index(['STATEFP10', 'COUNTYFP10', 'VTDST10', 'GEOID10', 'VTDI10', 'NAME10',
#        'NAMELSAD10', 'LSAD10', 'MTFCC10', 'FUNCSTAT10', 'ALAND10', 'AWATER10',
#        'INTPTLAT10', 'INTPTLON10', 'OID_', 'AK_GEO_ID', 'VOTE_ID', 'VTDST10_1',
#        'NAME10_1', 'VAP', 'TOTPOP', 'STATEFP1_1', 'COUNTYFP_1', 'VTDST10_12',
#        'GEOID10_1', 'VTDI10_1', 'NAME100', 'NAMELSAD_1', 'LSAD10_1',
#        'MTFCC10_1', 'FUNCSTAT_1', 'ALAND10_1', 'AWATER10_1', 'INTPTLAT_1',
#        'INTPTLON_1', 'NAME', 'RVS_08', 'VOTES_08', 'USP_R_08', 'USP_D_08',
#        'USP_08', 'NDV', 'NRV', 'geometry'],
#       dtype='object')

# %%
data.crs = {'init': 'epsg:4326', 'no_defs': True}

# %%
data.crs
# Out:
# {'init': 'epsg:4326', 'no_defs': True}

# %%
data['geometry']
# Out:
# 0      POLYGON ((-159.028589 56.67215299999999, -159....
# 1      (POLYGON ((-159.426336 54.75864199999999, -159...
# 2      (POLYGON ((-161.006232 55.16575899999999, -161...
# 3      (POLYGON ((-163.03943 55.450724, -163.033158 5...
# 4      POLYGON ((-165.770886 54.231134, -165.769167 5...
# 5      (POLYGON ((-170.14768 57.121464, -170.153554 5...
# 6      (POLYGON ((173.403376 52.777562, 173.405728 52...
# 7      (POLYGON ((-168.002249 53.988041, -167.999541 ...
# 8      POLYGON ((-169.401641 56.636553, -169.39007 56...
# 9      POLYGON ((-149.913346 61.177746, -149.913596 6...
# 10     POLYGON ((-149.924003 61.20773699999999, -149....
# 11     POLYGON ((-149.878819 61.119785, -149.87882 61...
# 12     POLYGON ((-149.86583 61.151956, -149.866038 61...
# 13     POLYGON ((-149.885148 61.16632199999999, -149....
# 14     POLYGON ((-149.886312 61.12336699999999, -149....
# 15     POLYGON ((-149.757152 61.198915, -149.757028 6...
# ...

# %%
def getPolyCoords(row, geom, coord_type):
    """Returns the coordinates ('x' or 'y') of edges of a Polygon exterior"""

    # Parse the exterior of the coordinate
    exterior = row[geom].exterior

    if coord_type == 'x':
        # Get the x coordinates of the exterior
        return list( exterior.coords.xy[0] )
    elif coord_type == 'y':
        # Get the y coordinates of the exterior
        return list( exterior.coords.xy[1] )

# %%
data['x'] = data.apply(getPolyCoords, geom='geometry', coord_type='x', axis=1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-28-12da1250c4d3> in <module>()
# ----> 1 data['x'] = data.apply(getPolyCoords, geom='geometry', coord_type='x', axis=1)
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/pandas/core/frame.py in apply(self, func, axis, broadcast, raw, reduce, args, **kwds)
#    4875                         f, axis,
#    4876                         reduce=reduce,
# -> 4877                         ignore_failures=ignore_failures)
#    4878             else:
#    4879                 return self._apply_broadcast(f, axis)
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/pandas/core/frame.py in _apply_standard(self, func, axis, ignore_failures, reduce)
#    4971             try:
#    4972                 for i, v in enumerate(series_gen):
# -> 4973                     results[i] = func(v)
# ...

# %%
fp = 'groads-v1-europe-shp/gROADS-v1-europe.shp'

# %%
data = gpd.read_file(fp)

# %%
type(data)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
data.plot()
py.pyplot.show()

# %%
data.columns
# Out:
# Index(['SOURCEID', 'EXS', 'NOTES', 'ROADID', 'ONME', 'RTENME', 'NTLCLASS',
#        'FCLASS', 'CRGWAY', 'NUMLANES', 'LNEWIDTHM', 'RDWIDTHM', 'AXLELOADMT',
#        'TOTLOADMT', 'SRFTPE', 'SRFCOND', 'SRFPREP', 'ISSEASONAL', 'CURNTPRAC',
#        'GDWTHRPRAC', 'BDWTHRPRAC', 'SPEEDLIMIT', 'CURNTSPEED', 'GNRALSPEED',
#        'ISUNDRCSTR', 'CSTWRKETC', 'GRADDEG', 'SEC', 'HASSHOULDR', 'HASSIDEWLK',
#        'DRIVSIDE', 'ISELEVATED', 'HASMEDIAN', 'OPSTATUS', 'LENGTH_KM',
#        'Shape_Leng', 'geometry'],
#       dtype='object')

# %% [markdown]
# Bike Routes

# %%
bk_routes = gpd.read_file('bike_routes_datasd.geojson')

# %%
sd_boundaries = gpd.read_file('san_diego_boundary_datasd.geojson')

# %%
base_map = sd_boundaries.plot(color='green')
plt.title('San Diego Boundaries')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
# Out:
# Text(49.9128,0.5,'Latitude')

# %%
plt.figure()
base_map = sd_boundaries.plot(color='green')
bk_routes.plot(ax=base_map, color = 'red')
plt.title('San Diego Bike Routs')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.show()

# %%
from bokeh.io import output_file, output_notebook, show
from bokeh.plotting import figure, ColumnDataSource
output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="ec0a7396-2ab1-47c6-b6af-082fab89c962">Loading BokehJS ...</span>
#     </div>

# %%
sd_boundaries.head()
# Out:
#    objectid  code                                           geometry
# 0         0     0  POLYGON ((-116.99398646 33.10913689, -116.9921...
# 1         1     0  POLYGON ((-116.54561292 32.68519253, -116.5474...
# 2         2     0  POLYGON ((-116.93242648 32.64889803, -116.9325...
# 3         3     0  POLYGON ((-116.9314759 32.60475689, -116.93163...

# %%
def getLineCoords(row, geom, coord_type):
    """Returns a list of coordinates ('x' or 'y') of a LineString geometry"""
    if coord_type == 'x':
        return list( row[geom].coords.xy[0] )
    elif coord_type == 'y':
        return list( row[geom].coords.xy[1] )

# %%
def getPolyCoords(row, geom, coord_type):
    """Returns the coordinates ('x' or 'y') of edges of a Polygon exterior"""

    # Parse the exterior of the coordinate
    exterior = row[geom].exterior

    if coord_type == 'x':
        # Get the x coordinates of the exterior
        return list( exterior.coords.xy[0] )
    elif coord_type == 'y':
        # Get the y coordinates of the exterior
        return list( exterior.coords.xy[1] )

# %%
sd_boundaries['x'] = sd_boundaries.apply(getPolyCoords, geom='geometry', coord_type='x', axis=1)
sd_boundaries['y'] = sd_boundaries.apply(getPolyCoords, geom='geometry', coord_type='y', axis=1)

# %%
sd_df = sd_boundaries.drop(columns='geometry', axis=1).copy()

# %%
bk_routes['x'] = bk_routes.apply(getLineCoords, geom='geometry', coord_type='x', axis=1)
bk_routes['y'] = bk_routes.apply(getLineCoords, geom='geometry', coord_type='y', axis=1)

# %%
bk_df = bk_routes.drop(columns='geometry', axis=1).copy()

# %%
mask = (len(bk_df['x']==2) & (len(bk_df['y']==2))
# Out:
#   File "<ipython-input-173-0727001688bc>", line 1
#     mask = (len(bk_df['x']==2) & (len(bk_df['y']==2))
#                                                      ^
# SyntaxError: unexpected EOF while parsing

# %%
df[~(df.A.str.len() > 10)]

# %%
r = bk_df[(bk_df.x.str.len()==2) & (bk_df.y.str.len()==2)]

# %%
r
# Out:
#       objectid                   rd20full  max_elev  route  \
# 0           12                       B ST    81.150      3
# 3           32            KEARNY VILLA RD   393.277      2
# 4           33            KEARNY VILLA RD   393.118      2
# 5           39            E SAN YSIDRO BL    57.552      8
# 7           46                    05TH AV     9.876      8
# 8           47            E SAN YSIDRO BL    55.067      8
# 9           48            E SAN YSIDRO BL    54.834      8
# 10          49            E SAN YSIDRO BL    55.247      8
# 11          56               MONTECITO WY   295.602      8
# 20          92           FORT STOCKTON DR   274.760      3
# 23         107                  EUCLID AV   251.729      3
# 26         114                 PACIFIC HY    13.567      2
# 29         117        PACIFIC HY NB ON RA    23.499      2
# 30         118                 PACIFIC HY    45.366      3
# 31         119           FORT STOCKTON DR   270.981      3
# ...

# %%
msrc = ColumnDataSource(r)

# %%
p = figure(title="A map of the Helsinki metro")

# Add the lines to the map from our 'msource' ColumnDataSource -object
p.line('x', 'y', source=msrc, color='red', line_width=3)
show(p)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="606bfa56-04a8-4a79-ac85-6e5cddb58485"></div>
# </div>
# /Users/pauldefusco/anaconda2/envs/py36/lib/python3.6/site-packages/bokeh/core/json_encoder.py:80: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(type(obj), np.float):
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-182-14a81f1240ac> in <module>()
#       3 # Add the lines to the map from our 'msource' ColumnDataSource -object
#       4 p.line('x', 'y', source=msrc, color='red', line_width=3)
# ----> 5 show(p)
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/bokeh/util/api.py in wrapper(*args, **kw)
#     188         @wraps(obj)
#     189         def wrapper(*args, **kw):
# ...

# %%
bk_routes = bk_routes.drop(columns='geometry')

# %%
sd_boundaries
# Out:
#    objectid  code                                                  x  \
# 0         0     0  [-116.99398646, -116.99216296, -116.99184617, ...
# 1         1     0  [-116.54561292, -116.54744712, -116.54920774, ...
# 2         2     0  [-116.93242648, -116.93250563, -116.93263339, ...
# 3         3     0  [-116.9314759, -116.93163677, -116.9316486, -1...
#
#                                                    y
# 0  [33.10913689, 33.10898708, 33.10898714, 33.108...
# 1  [32.68519253, 32.68405442, 32.68603001, 32.687...
# 2  [32.64889803, 32.64898795, 32.6491306, 32.6492...
# 3  [32.60475689, 32.60514652, 32.60514304, 32.604...

# %%
r = bk_routes[bk_routes['class']=='Bike Route']

# %%
sd_boundaries
# Out:
#    objectid  code                                                  x  \
# 0         0     0  [-116.99398646, -116.99216296, -116.99184617, ...
# 1         1     0  [-116.54561292, -116.54744712, -116.54920774, ...
# 2         2     0  [-116.93242648, -116.93250563, -116.93263339, ...
# 3         3     0  [-116.9314759, -116.93163677, -116.9316486, -1...
#
#                                                    y
# 0  [33.10913689, 33.10898708, 33.10898714, 33.108...
# 1  [32.68519253, 32.68405442, 32.68603001, 32.687...
# 2  [32.64889803, 32.64898795, 32.6491306, 32.6492...
# 3  [32.60475689, 32.60514652, 32.60514304, 32.604...

# %%
sd=ColumnDataSource(sd_boundaries)
bk=ColumnDataSource(r)

# %%
sd=ColumnDataSource(data=dict(x = sd_boundaries['x'],y=sd_boundaries['y']))

# %%
TOOLS = "pan,wheel_zoom,box_zoom,reset,hover,save"

# %%
sd
# Out:
# ColumnDataSource(id='add66619-85c7-47de-965b-2e0b32d66bee', ...)

# %%
p = figure(title="San Diego", tools=TOOLS, x_axis_location=None, 
                y_axis_location=None)
#p.multi_line('x', 'y', source=sd, color="black", line_width=2)
p.line('x', 'y', source=bk)
show(p)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="a72d2e8f-764f-4959-8bad-c3bc90bc4a81"></div>
# </div>
# /Users/pauldefusco/anaconda2/envs/py36/lib/python3.6/site-packages/bokeh/core/json_encoder.py:80: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(type(obj), np.float):
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-146-5aaeb2cb30c6> in <module>()
#       3 #p.multi_line('x', 'y', source=sd, color="black", line_width=2)
#       4 p.line('x', 'y', source=bk)
# ----> 5 show(p)
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/bokeh/util/api.py in wrapper(*args, **kw)
#     188         @wraps(obj)
#     189         def wrapper(*args, **kw):
# --> 190             return obj(*args, **kw)
#     191
# ...

# %%
p = figure(title="Chicago")
p.multi_line('x', 'y', source=sd, color="black", line_width=2)
show(p)
# Out:
# <div class="bk-root">
#     <div class="bk-plotdiv" id="f4c0d4d6-40f6-4bee-8104-19827e5660d0"></div>
# </div>
# /Users/pauldefusco/anaconda2/envs/py36/lib/python3.6/site-packages/bokeh/core/json_encoder.py:80: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   elif np.issubdtype(type(obj), np.float):
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-149-1d0a1bf193de> in <module>()
#       1 p = figure(title="Chicago")
#       2 p.multi_line('x', 'y', source=sd, color="black", line_width=2)
# ----> 3 show(p)
#
# ~/anaconda2/envs/py36/lib/python3.6/site-packages/bokeh/util/api.py in wrapper(*args, **kw)
#     188         @wraps(obj)
#     189         def wrapper(*args, **kw):
# --> 190             return obj(*args, **kw)
#     191
# ...
