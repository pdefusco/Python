# %%
import pandas as pd
import json

# %%
fil = read_json('/data/olympics.json')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-8cafefb24c05> in <module>()
# ----> 1 fil = read_json('/data/olympics.json')
#
# NameError: name 'read_json' is not defined

# %%
with open('data/olympics.json') as data_file:    
    data = json.load(data_file)

# %%
df = pd.DataFrame(data)

# %%
df[df.Year=='1924']
# Out:
#         City         Country       Discipline                 Event Gender  \
# 0   Chamonix         Austria   Figure skating            individual      M
# 1   Chamonix         Austria   Figure skating            individual      W
# 2   Chamonix         Austria   Figure skating                 pairs      X
# 3   Chamonix         Belgium        Bobsleigh              four-man      M
# 4   Chamonix          Canada       Ice Hockey            ice hockey      M
# 5   Chamonix         Finland         Biathlon       military patrol      M
# 6   Chamonix         Finland   Figure skating                 pairs      X
# 7   Chamonix         Finland    Speed skating                10000m      M
# 8   Chamonix         Finland    Speed skating                10000m      M
# 9   Chamonix         Finland    Speed skating                 1500m      M
# 10  Chamonix         Finland    Speed skating                 5000m      M
# ...
